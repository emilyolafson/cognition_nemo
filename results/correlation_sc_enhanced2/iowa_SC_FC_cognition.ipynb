# %%
# This Jupyter notebook was created by Emily Olafson to predicit cognitive scores from structural and functional connectivity data in stroke subjects.
# Last updated: March 10 2022
# https://github.com/emilyolafson/cognition_nemo

#import relevant libraries
import sys; sys.path
import pandas as pd
import numpy as np 
import seaborn as sns
from datetime import datetime
import pickle 
from sklearn.pipeline import Pipeline
import scipy.io as sio
from scipy.stats import spearmanr, pearsonr
from joblib import parallel_backend, Parallel, delayed
from sklearn import preprocessing, linear_model
from sklearn.metrics import explained_variance_score, r2_score, make_scorer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold, StratifiedKFold
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from sklearn.utils.fixes import loguniform
import matplotlib as mpl
from numpy import genfromtxt
import nibabel as nib
import os

# %%
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import AxesGrid

def shiftedColorMap(cmap, start=0, midpoint=0.5, stop=1.0, name='shiftedcmap'):
    '''
    FROM: https://stackoverflow.com/questions/7404116/defining-the-midpoint-of-a-colormap-in-matplotlib
    Function to offset the "center" of a colormap. Useful for
    data with a negative min and positive max and you want the
    middle of the colormap's dynamic range to be at zero.

    Input
    -----
      cmap : The matplotlib colormap to be altered
      start : Offset from lowest point in the colormap's range.
          Defaults to 0.0 (no lower offset). Should be between
          0.0 and `midpoint`.
      midpoint : The new center of the colormap. Defaults to 
          0.5 (no shift). Should be between 0.0 and 1.0. In
          general, this should be  1 - vmax / (vmax + abs(vmin))
          For example if your data range from -15.0 to +5.0 and
          you want the center of the colormap at 0.0, `midpoint`
          should be set to  1 - 5/(5 + 15)) or 0.75
      stop : Offset from highest point in the colormap's range.
          Defaults to 1.0 (no upper offset). Should be between
          `midpoint` and 1.0.
    '''
    cdict = {
        'red': [],
        'green': [],
        'blue': [],
        'alpha': []
    }

    # regular index to compute the colors
    reg_index = np.linspace(start, stop, 257)

    # shifted index to match the data
    shift_index = np.hstack([
        np.linspace(0.0, midpoint, 128, endpoint=False), 
        np.linspace(midpoint, 1.0, 129, endpoint=True)
    ])

    for ri, si in zip(reg_index, shift_index):
        r, g, b, a = cmap(ri)

        cdict['red'].append((si, r, r))
        cdict['green'].append((si, g, g))
        cdict['blue'].append((si, b, b))
        cdict['alpha'].append((si, a, a))

    newcmap = matplotlib.colors.LinearSegmentedColormap(name, cdict)
    plt.register_cmap(cmap=newcmap)

    return newcmap

def prepare_data(X):
    '''Clean X-data (remove zero-value input variables)'''

    # remove inputs that are 0 for all subjects
    zeros=X==0
    zeros=np.sum(zeros,0)
    zeros=zeros==X.shape[0]
    X=X[:,~zeros]
    print("Final size of X: " + str(X.shape))
    
    return X

def prepare_image_data(X):
    '''Clean X-data (remove zero-value input variables)'''

    # remove inputs that are 0 for all subjects
    X=np.reshape(X, (101,902629))
    print("Final size of X: " + str(X.shape))
    
    return X

def np_pearson_cor(x, y):
    '''Fast array-based pearson correlation that is more efficient. 
    FROM: https://cancerdatascience.org/blog/posts/pearson-correlation/.
        x - input N x p
        y - output N x 1
        
        returns correlation p x 1 '''
    xv = x - x.mean(axis=0)
    yv = y - y.mean(axis=0)
    xvss = (xv * xv).sum(axis=0)
    yvss = (yv * yv).sum(axis=0)
    result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
    
    # bound the values to -1 to 1 in the event of precision issues
    return np.maximum(np.minimum(result, 1.0), -1.0)


def naive_pearson_cor(X, Y):
    '''Naive (scipy-based/iterative) pearson correlation. 
    FROM: https://cancerdatascience.org/blog/posts/pearson-correlation/.
        x - input N x p
        y - output N x 1
        
        returns correlation p x 1 '''
    result = np.zeros(shape=(X.shape[1], Y.shape[1]))
    for i in range(X.shape[1]):
        for j in range(Y.shape[1]):
            r, _ = pearsonr(X[:,i], Y[:,j])
            result[i,j] = r
    return result[0]


def feature_select_PCA(x_train, x_test, a):
    """Return values for the top a PCs of x based on PCA of x.
         
         Inputs:
             x = input matrix
             y = variable/s predicted 
             a = number of PCs
         
        Returns:
            x_train_featselect = training data with selected features 
            x_test_featselect = test data matrix with selected features 
            var_expl = variance explained by top a components
            components = PCs selected"""
    
    # check that dimension of x is greater than a
    if x_train.shape[1]<a:
        raise Exception('Number of features in X is less than the number of features specified to retain (a).') 
    
    # Feature selection: use only the top n features based on top a PCs in training data 
    pca = PCA(n_components=a, copy=True, random_state=42)
    x_train_featselect = pca.fit(x_train).transform(x_train)
    x_test_featselect = pca.transform(x_test)
    components = pca.components_

    
    var_expl = pca.explained_variance_


    return x_train_featselect,x_test_featselect, components

def feature_select_correlation(x_train, x_test, y, a):
    """Return values for the top a features of x based on abs. value Spearman correlation with y.
         Inputs:
             x_train = input matrix for training subjects
             x_test = input matrix for test subjects
             y = variable/s predicted 
             a = number of features to retain
        
        Returns:
            x_train_featselect = training data with selected features 
            x_test_featselect = test data matrix with selected features
            ind = indices of top a features """
    
    # check that dimension of x is greater than a
    if x_train.shape[1]<a:
        raise Exception('Number of features in X is less than the number of features specified to retain (a).') 
        
        
    # Feature selection: use only the top n features based on correlation of training features with y
    correl = abs(np_pearson_cor(x_train, y))
    ind = np.argpartition(correl, -a, 0)[-a:] # select top a features

    # return training/test data with only top features
    x_train_featselect=np.squeeze(x_train[:,ind],2)
    
    x_test_featselect=np.squeeze(x_test[:,ind],2)

    return x_train_featselect,x_test_featselect, ind


def scale_data(x_train, x_test):
    '''Scale the training data and apply transformation to the test/validation data.

        Inputs:
            x_train = training predictors
            x_test = training predictors 
        
        Returns:
            x_train_scaled
            x_test_scaled '''
    
    # Scale x_train 
    scaler = preprocessing.StandardScaler().fit(x_train)
    
    # apply transformation to train & test set.
    x_train_scaled = scaler.transform(x_train)
    x_test_scaled = scaler.transform(x_test)
    
    return x_train_scaled, x_test_scaled

def normalize_data(x_train, x_test):
    '''subtracting the mean and dividing by the l2-norm'''
    x_train_mean=np.mean(x_train)
    x_train_norm=np.linalg.norm(x_train)
    
    x_test_mean=np.mean(x_test)
    x_test_norm=np.linalg.norm(x_test)
    
    x_train=(x_train-x_train_mean)/x_train_norm
    x_test=(x_test-x_test_mean)/x_test_norm

    return x_train, x_test

def gcv_ridge(hyperparam, x, y, k, featsel='None', a=10):
    """Perform gridsearch using k-fold cross-validation on a single hyperparameter 
    in ridge regression, and return mean R^2 across inner folds.
    
    Inputs: 
        hyperparam = list of hyperparameter values to train & test on validation est
        x = N x p input matrix
        y = 1 x p variable to predict
        k = k value in k-fold cross validation 
        featsel = type string, feature selection method, default="None"
            'None' - no feature selection; use all variables for prediction
            'correlation'- calculate the abs. val. Pearson correlation between all training variables with the varibale to predict. Use the highest 'a' variables based on their correlation for prediction
            'PCA' - perform PCA on the training variables and use the top 'a' PCs as input variables, by variance explained, for prediction
        a = number of features to select using one of the above methods, default=10 
    
    Returns:
        expl_var = the mean R^2 (coefficient of determination) across inner loop folds for the given hyperparameter
    """
    
    # make sure k is reasonable 
    if x.shape[0]/k <= 2:
        raise Exception('R^2 is not well-defined with less than 2 subjects.')   
    
    # set alpha in ridge regression
    alpha = hyperparam
    # Initialize lists with final results
    y_pred_total = []
    y_valid_total = []
    R2 = []
    comp = []
    correl=[]
    explvar=[]
    # Split data into test and train: random state fixed for reproducibility
    kf = KFold(n_splits=k,shuffle=True,random_state=43)
    
    # K-fold cross-validation 
    for train_index, valid_index in kf.split(x):
        x_train, x_valid = x[train_index], x[valid_index]
        y_train, y_valid = y[train_index], y[valid_index]
        
        #x_train, x_valid = scale_data(x_train, x_valid)
        
        if featsel=='correlation':
            x_train, x_valid, ind = feature_select_correlation(x_train, x_valid, y_train, a)
            comp.append(ind)
            
        elif featsel=='PCA':
            x_train, x_valid, components = feature_select_PCA(x_train, x_valid, a)
            comp.append(components)
        
        # Fit ridge regression with (x_train_scaled, y_train), and predict x_train_scaled
        regr = linear_model.Ridge(alpha=alpha, normalize=True, max_iter=1000000, random_state=42)
        y_pred = regr.fit(x_train, y_train).predict(x_valid)

        R2.append(r2_score(y_valid, y_pred))
        correlation=np_pearson_cor(y_pred, y_valid)[0]
        correl.append(correlation)
        explvar.append(explained_variance_score(y_valid, y_pred))
        
        # Append y_pred and y_valid values of this k-fold step to list with all values
        y_pred_total.append(y_pred)
        y_valid_total.append(y_valid)
 
    # note: don't use r2_score for ridge regression bc it does not account for bias error
    r2=np.mean(R2)
    
    cor=np.mean(correl)
    
    # use explained_variance_score instead:
    expl_var=np.mean(explvar)
    
    return expl_var

def gcv_ridge_strat(hyperparam, x, y, k, chronic_bin, featsel='None', a=10):
    """Perform gridsearch using k-fold cross-validation on a single hyperparameter 
    in ridge regression, and return mean R^2 across inner folds.
    
    Inputs: 
        hyperparam = list of hyperparameter values to train & test on validation est
        x = N x p input matrix
        y = 1 x p variable to predict
        k = k value in k-fold cross validation 
        featsel = type string, feature selection method, default="None"
            'None' - no feature selection; use all variables for prediction
            'correlation'- calculate the abs. val. Pearson correlation between all training variables with the varibale to predict. Use the highest 'a' variables based on their correlation for prediction
            'PCA' - perform PCA on the training variables and use the top 'a' PCs as input variables, by variance explained, for prediction
        a = number of features to select using one of the above methods, default=10 
    
    Returns:
        expl_var = the mean R^2 (coefficient of determination) across inner loop folds for the given hyperparameter
    """
    
    # make sure k is reasonable 
    if x.shape[0]/k <= 2:
        raise Exception('R^2 is not well-defined with less than 2 subjects.')   
    
    # set alpha in ridge regression
    alpha = hyperparam
    # Initialize lists with final results
    y_pred_total = []
    y_valid_total = []
    R2 = []
    comp = []
    correl=[]
    explvar=[]
    # Split data into test and train: random state fixed for reproducibility
    kf = KFold(n_splits=k,shuffle=True,random_state=43)
    
    # K-fold cross-validation 
    for train_index, valid_index in kf.split(x):
        x_train, x_valid = x[train_index], x[valid_index]
        y_train, y_valid = y[train_index], y[valid_index]
        
        chron_train=chronic_bin[train_index] 
        chron_valid=chronic_bin[valid_index]
        
        #x_train, x_valid = scale_data(x_train, x_valid)
        
        if featsel=='correlation':
            x_train, x_valid, ind = feature_select_correlation(x_train, x_valid, y_train, a)
            comp.append(ind)
            
        elif featsel=='PCA':
            x_train, x_valid, components = feature_select_PCA(x_train, x_valid, a)
            comp.append(components)
        
        # add chronicity variable after features selection
        chron_train=np.reshape(np.double(chron_train), (x_train.shape[0], 1))
        x_train=np.concatenate((x_train, chron_train),axis=1)
        
        chron_valid=np.reshape(np.double(chron_valid), (x_valid.shape[0], 1))
        x_valid=np.concatenate((x_valid, chron_valid),axis=1)
        
        # Fit ridge regression with (x_train_scaled, y_train), and predict x_train_scaled
        regr = linear_model.Ridge(alpha=alpha, normalize=True, max_iter=1000000, random_state=42)
        y_pred = regr.fit(x_train, y_train).predict(x_valid)

        R2.append(r2_score(y_valid, y_pred))
        correlation=np_pearson_cor(y_pred, y_valid)[0]
        correl.append(correlation)
        explvar.append(explained_variance_score(y_valid, y_pred))
        
        # Append y_pred and y_valid values of this k-fold step to list with total values
        y_pred_total.append(y_pred)
        y_valid_total.append(y_valid)

    # note: don't use r2_score for ridge regression bc it does not account for bias error
    r2=np.mean(R2)
    
    cor=np.mean(correl)
    
    # use explained_variance_score instead:
    expl_var=np.mean(explvar)
    
    
    return expl_var

def parallel_featsearch_strat(alpha, X, Y, k, chronic_bin, featselect, feat):
    ''' Stratified grid search in parallel.

    Returns:
        expl_var - explained variance for given combination of alpha/feat/featselect'''
    
    expl_var=gcv_ridge_strat(alpha, X, Y, k, chronic_bin, featselect, feat)
    
    return expl_var

def parallel_featsearch(alpha, X, Y, k, featselect, feat):
    ''' Grid search in parallel.

    Returns:
        expl_var - explained variance for given combination of alpha/feat/featselect'''
    
    expl_var=gcv_ridge(alpha, X, Y, k, featselect, feat)
    return expl_var

# Inner loop - grid search
def gridsearch_cv_strat(k, x, y, chronic_bin, featselect, alphas, feats):
    ''' Performs grid search using fixed predefined hyperparameter ranges and returns the best alpha and # of features for 
        a given training/validation sample. Uses stratified k-fold cross-validation for inner loop.
        
        Input:
            x = N x p input matrix
            y = 1 x p variable to predict
            k = k value in k-fold cross validation 
            featsel = type string, feature selection method, default="None"
                'None' - no feature selection; use all variables for prediction
                'correlation'- calculate the abs. val. Pearson correlation between all training variables with the varibale to predict. Use the highest 'a' variables based on their correlation for prediction
                'PCA' - perform PCA on the training variables and use the top 'feats' PCs as input variables, by variance explained, for prediction
            chronic_bin - stratification binary variable
            featselect - type of features selection. can be "correlation" or "PCA"
            alphas - range of alpha parameters to search 
            feats - range of # features to search
        
        Returns:
            bestalpha - optimal alpha based on grid search
            bestfeats - optimal number of features based on grid search
            bestr2 - mean R^2 across folds obtained for the optimal combination of hyperparameters
            gcv_values - R^2 across all combinations of hyperparametrs.'''
    
    print(str(k)+"-fold cross-validation results in "+str((x.shape[0]/k)*(k-1))+ " subjects in the training set, and "+ str(x.shape[0]/k) + " subjects in the validation set")

    # initialize array to store r2
    gcv_values=np.empty(shape=(len(alphas),len(feats)),dtype='float')

    # iterate through alphas
    for alpha in alphas:
        row, = np.where(alphas==alpha)
        
        # run feature selection (# of components) in parallel
        gcv=Parallel(n_jobs=-1,verbose=0)(delayed(parallel_featsearch_strat)(alpha,x, y, k, chronic_bin, featselect, feat) for feat in feats)
        gcv=np.array(gcv)
        gcv_values[row]=gcv
            
        row=np.argmax(np.max(gcv_values, axis=1))
        col=np.argmax(np.max(gcv_values, axis=0))

    bestalpha=alphas[row]
    bestfeats=feats[col]
    bestr2=np.max(gcv_values)

    return bestalpha, bestfeats, bestr2, gcv_values

# Inner loop - grid search
def gridsearch_cv(k, x, y, featselect, alphas, feats):
    ''' Performs grid search using fixed predefined hyperparameter ranges and returns the best alpha and # of features for 
        a given training/validation sample. 
        
        Input:
            x = N x p input matrix
            y = 1 x p variable to predict
            k = k value in k-fold cross validation 
            featsel = type string, feature selection method, default="None"
                'None' - no feature selection; use all variables for prediction
                'correlation'- calculate the abs. val. Pearson correlation between all training variables with the varibale to predict. Use the highest 'a' variables based on their correlation for prediction
                'PCA' - perform PCA on the training variables and use the top 'a' PCs as input variables, by variance explained, for prediction
            alphas - range of alpha parameters to search 
            feats - range of # features to search
        
        Returns:
            bestalpha - optimal alpha based on grid search
            bestfeats - optimal number of features based on grid search
            bestr2 - mean R^2 across folds obtained for the optimal combination of hyperparameters
            gcv_values - R^2 across all combinations of hyperparametrs.'''
    
    print(str(k)+"-fold cross-validation results in "+str((x.shape[0]/k)*(k-1))+ " subjects in the training set, and "+ str(x.shape[0]/k) + " subjects in the validation set")

    # initialize array to store r2
    gcv_values=np.empty(shape=(len(alphas),len(feats)),dtype='float')

    # iterate through alphas
    for alpha in alphas:
        row, = np.where(alphas==alpha)
        
        # run feature selection (# of components) in parallel
        gcv=Parallel(n_jobs=-1,verbose=0)(delayed(parallel_featsearch)(alpha,x, y, k, featselect, feat) for feat in feats)
        gcv=np.array(gcv)
        gcv_values[row]=gcv
            
        row=np.argmax(np.max(gcv_values, axis=1))
        col=np.argmax(np.max(gcv_values, axis=0))

    bestalpha=alphas[row]
    bestfeats=feats[col]
    bestr2=np.max(gcv_values)

    return bestalpha, bestfeats, bestr2, gcv_values

def gridsearch_plsr(k, x, y, components):
    ''' Performs grid search for PLS regression using fixed predefined hyperparameter range and returns the best n components for 
        a given training/validation sample. Calculates PRESS (preedicted residual sum of squares) for each subject.

        Returns:
            presssum - sum of PRESS for all subjects'''
    
    presssum=[]
    # iterate through components
    for comp in components:
        
        row, = np.where(components==comp)
        
        kf = KFold(n_splits=k,shuffle=True,random_state=43)
        
        scores=[]
        press=[]
        
        # calculate PRESS for each held-out subject
        for i in range(0, x.shape[0]):
            trainx = np.delete(x, i, axis=0)
            trainy = np.delete(y, i, axis=0)
            
            pls = PLSRegression(n_components=comp, scale=True, copy=False)
            pls.fit(trainx, trainy)

            ypred = pls.predict(x[i,:].reshape(1, -1) )
            ytrue=y[i].reshape(1, -1)
            press.append(sum((ytrue.T-ypred.T)**2))
            
        presssum.append(np.sum(press))
        
    return presssum

def plot_figure(gcv_values, string, midpoint):
    '''Plots the R^2 value obtained across all grid-search pairs (# features and regularization values.)
    
    Inputs:
        gcv_values - matrix to plot
        string - title
        midpoint - point at which blue turns to red.'''
    
    plt.figure(figsize=(17,14))
    shifted_cmap = shiftedColorMap(plt.get_cmap('bwr'), midpoint=midpoint, name='shifted')

    plt.imshow(gcv_values, cmap=shifted_cmap, interpolation='nearest')

    plt.xlabel('# Features', fontsize=15, fontweight='bold')
    plt.ylabel('Alphas', fontsize=15, fontweight='bold')

    row=np.argmax(np.max(gcv_values, axis=0))
    col=np.argmax(np.max(gcv_values, axis=1))

    ax = plt.axes()

    ax.xaxis.set_major_locator(plt.MultipleLocator(1))
    ax.yaxis.set_major_locator(plt.MultipleLocator(1))

    xticks= np.linspace(feat_start, feat_end,n_feats, dtype=int)
    yticks= np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

    plt.xticks(np.arange(len(feats)), fontsize=18)
    plt.yticks(np.arange(len(alphas)), fontsize=18)

    ax.set_xticklabels(xticks)
    ax.set_yticklabels(np.round(yticks,3))

    #ax.xaxis.set_major_formatter(mpl.ticker.StrMethodFormatter('{xticks: .2f}'))
    cbar = plt.colorbar()
    cbar.set_label('R^2')
    plt.title(string + '_Best R^2 = ' + str(np.round(np.max(gcv_values), 3)), fontsize=20)

    plt.scatter(row,col,color='k')
    plt.savefig(results_dir+string+ '.png')
    plt.show()

# %%
# ------- Load data -----------

# Set paths
data_dir='/home/ubuntu/cognition_iowa/'
results_dir='/home/ubuntu/cognition_iowa/results/' 

#Load input variables (estimated SC and FC) and save all subjects to one .mat file for eFC prediction (Zijin's code)
nROIs=86
df =  pd.read_csv(data_dir + 'enhanced_df2.csv', header=0)
subj_id=df['eIDs2']

sc= np.zeros([len(subj_id),3655])

# Load SC (acute)
for i in range(len(subj_id)):
    if subj_id[i]=='ca124': # no lesion
        print("not found: " + str(i))
        continue
    if subj_id[i]=='ca089': # no lesion
        print("not found: " + str(i))
        continue
    filename = data_dir + "data/sc/%s_nemo_output_chacoconn_fs86subj_nemoSC_volnorm.txt" % (subj_id[i])
    sc_tmp = np.genfromtxt(filename, delimiter='')

    # pairwise vectorized upper triangular
    np.fill_diagonal(sc_tmp, 0)
    sc[i,:] = sc_tmp[np.triu_indices(nROIs,k=1)]

sc = np.delete(sc,(75), axis=0)
df =  pd.read_csv(data_dir + 'enhanced_df2.csv',header=0)
wais = np.array(df['eWAIS2'])
wais = np.delete(wais,(75), axis=0)

chronicity = np.array(df["eChronicity2"])
chronicity = np.delete(chronicity,(75), axis=0)

acute_id = chronicity=="acute"
chronic_id = chronicity=="chronic"

# Load lesion volume
lesionvol = np.zeros([len(subj_id),1])

for i in range(len(subj_id)):
    if subj_id[i]=='ca124': # no lesion
        print("not found: " + str(i))
        continue
    if subj_id[i]=='ca089': # no lesion
        print("not found: " + str(i))
        continue
    filename = data_dir + "lesionvol/%s.txt" % (subj_id[i])
    tmp= np.genfromtxt(filename, delimiter='')
    lesionvol[i,:] =tmp[0]
    
lesionvol=np.log(lesionvol) # log-transform lesion data
lesionvol = np.delete(lesionvol,(75), axis=0)


# Load lesion PC score
filename = data_dir + "pc_score.csv"
pc_lesion = pd.read_csv(filename, header=None)

# Load all demographic scores
demogs= pd.read_csv(data_dir + 'df_final.csv',header=0)

demogs_acute=demogs[demogs['acute_chronic']=='acute']
demogs_chronic=demogs[demogs['acute_chronic']=='chronic']

plt.subplot(1,2,1)
plt.hist(demogs_acute['Age_at_Onset_Years'])
plt.title("Acute")
plt.xlabel('Age at onset (years)')

plt.subplot(1,2,2)
plt.hist(demogs_chronic['Age_at_Onset_Years'])
plt.title("Chronic")
plt.xlabel('Age at onset (years)')
demogs2= pd.read_csv(data_dir + 'df_final_cardiac_race_smoker_diabetes.csv',header=0)

new =demogs2[['Age_at_Onset_Years','Time_from_onset_years','SEX', 'HANDEDNESS','RACE_3','RACE_5', 'RACE_7','EDUC','Smoker_1','Smoker_2','Smoker_3','Smoker_4', 'Diabetes_type_II_1',  'Diabetes_type_II_2', 'Diabetes_type_II_3','Cardiac_history_1', 'Cardiac_history_2', 'Cardiac_history_3', 'Cardiac_history_4', 'Cardiac_history_5','Cardiac_history_6', ]]
clin_vars=pd.get_dummies(new)
clin_vars['HANDEDNESS']=clin_vars['HANDEDNESS']-1
# Out:
# not found: 75
# not found: 75
# <ipython-input-23-a742995cd1c4>:54: RuntimeWarning: divide by zero encountered in log
#   lesionvol=np.log(lesionvol) # log-transform lesion data

# %%
plt.subplot(1,2,1)
demogs_acute['Time_from_onset_months'][105]=0.97 # ca156. stroke 11/10/2012, testing 12/09/2011, listed as acute, assuming testing is 12/09/2012
plt.hist(demogs_acute['Time_from_onset_months'])
plt.title('Acute')
plt.xlabel('Time from onset (months)')

plt.subplot(1,2,2)
plt.hist(demogs_chronic['Time_from_onset_months'])
plt.title('Chronic')
plt.xlabel('Time from onset (months)')
# Out:
# <ipython-input-24-20b831e273e7>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   demogs_acute['Time_from_onset_months'][105]=0.97 # ca156. stroke 11/10/2012, testing 12/09/2011, listed as acute, assuming testing is 12/09/2012
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3437: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# Text(0.5, 0, 'Time from onset (months)')

# %%
plt.subplot(1,2,1)
plt.hist(demogs_acute['WAIS_IV_DS_TOTAL_RAW'])
plt.title('Acute')
plt.xlabel('WAIS_IV_DS_TOTAL_RAW')

plt.subplot(1,2,2)
plt.hist(demogs_chronic['WAIS_IV_DS_TOTAL_RAW'])
plt.title('Chronic')
plt.xlabel('WAIS_IV_DS_TOTAL_RAW')
# Out:
# Text(0.5, 0, 'WAIS_IV_DS_TOTAL_RAW')

# %%
female=np.sum(demogs_acute['SEX']=='F')
male=np.sum(demogs_acute['SEX']!='F')

print("--- Acute ---")
print("Number of female subjects: " + str(female))
print("Number of male subjects: " + str(male))

female=np.sum(demogs_chronic['SEX']=='F')
male=np.sum(demogs_chronic['SEX']!='F')

print("--- Chronic ---")
print("Number of female subjects: " + str(female))
print("Number of male subjects: " + str(male))
# Out:
# --- Acute ---
# Number of female subjects: 13
# Number of male subjects: 12
# --- Chronic ---
# Number of female subjects: 39
# Number of male subjects: 43

# %%
# SC average across stroke subjects
from nilearn import datasets
from nilearn import plotting

fs86 = np.zeros((86, 86))
inds = np.triu_indices(86, k=1)
fs86[inds] = np.mean(sc, axis=0)

sub = np.zeros((86, 86))
sub[inds] = sc[2]

fs86[fs86>16000]=1000

coordinates = plotting.find_parcellation_cut_coords('fs86_allsubj_mode.nii.gz')
plotting.plot_connectome(fs86, coordinates,edge_threshold="90%",
                         title='Mean stroke subject SC')

# %%
# -------------------- MODEL OPTIMIZATION --------------------
# range of alphas
n_alphas=20
alpha_start=-4
alpha_end=2
alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10,dtype=None)
p=0
#number of features (# pricipal components or variables to retain)
feat_start=1
feat_end=50

n_feats=feat_end-feat_start+1
feats = np.linspace(feat_start, feat_end, n_feats, dtype=int)

#set the proportion of data you want in your training set
train_size = .8

#set the number of folds you want in the inner and outer folds of the nested cross-validation
k = 5
#set x data to be the input variable you want to use
#ie fc, sc, or hc
#X=np.concatenate([sc, fc], axis=1)
X=np.array(sc)
X=prepare_data(X)

#set y to be the measure you want to predict
Y = np.array(wais)
Y=np.reshape(Y, (107,1))

featselect = 'correlation'

# set aside data for hold-out final testing: 
x, x_test, y, y_test = train_test_split(X, Y, test_size=1-train_size, shuffle=True, random_state=134)

bestalpha, bestfeats, bestr2, gcv_values_r2= gridsearch_cv(k, x, y, featselect, alphas, feats)

row=np.argmax(np.max(gcv_values_r2, axis=1))
col=np.argmax(np.max(gcv_values_r2, axis=0))
k = 5
bestalpha=alphas[row]
bestfeats=feats[col]

print('Best combination: \n alpha = ', str(alphas[row]), '\n Features = ', str(feats[col]), '\n R^2 = ', str(np.round(np.max(gcv_values_r2), 3)))

if featselect=='correlation':
    x_train_featselect,x_test_featureselect,ind = feature_select_correlation(x,x_test, y, bestfeats)

elif featselect=='PCA':
    x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(x,x_test, bestfeats)

# initialize Ridge regression with alpha selected from hyperparameter search
regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)

# fit model 
y_pred = regr.fit(x_train_featselect, y).predict(x_test_featureselect)
# Out:
# Final size of X: (107, 3192)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Best combination:
#  alpha =  0.06951927961775606
#  Features =  1
#  R^2 =  0.247

# %%
# plot variance explained over hyperparameter search space
plot_figure(gcv_values_r2,'correlation_wais_SC',0.999)
# Out:
# <ipython-input-14-343597912cef>:524: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = plt.axes()

# %%
# predictions for SC-  PCA and correlation
results_dir='/home/ubuntu/cognition_iowa/results/correlation_sc_enhanced2/'
import datetime

# feature selection type
f=['correlation']

for featselect in f: 
    #set the number of folds you want in the inner and outer folds of the nested cross-validation
    k = 5

    #set the proportion of data you want in your training set
    train_size = .8

    #X=np.concatenate([sc, fc], axis=1)
    X=sc
    X=prepare_data(X)
    #set y to be the measure you want to predict
    #Y = np.log(np.array(tmt))

    Y=np.array(wais)
    Y=np.reshape(Y, (107,1))
    
    # range of alphas
    n_alphas=20
    alpha_start=-1
    alpha_end=2
    alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

    #number of features (# pricipal components or variables to retain)
    feat_start=1
    feat_end=30
    n_feats=feat_end-feat_start+1
    feats = np.linspace(feat_start, feat_end, n_feats, dtype=int)

    # initialize lists to store model results for each permuation
    allR2=[]
    meanR2=[]
    features=[]
    bestalphas=[]
    importance=[]
    allexpl_var=[]
    correlations=[]
    chronic_allexpl_var=[]
    #joblib-based parallelism to increase speed,
    ytestc=[]
    ypredc=[]
    for p in range(0, 100):
        outer_cv = StratifiedKFold(n_splits=k, shuffle=True, random_state=p)
        print('Permutation: ' + str(p))
        # initialize lists to store model results for eah fold
        R2=[]
        featur=[]
        best_alphas=[]
        impt=[] 
        expl_var=[]
        chronic_explvar=[]
        cor=[]
        for train, test in outer_cv.split(X, chronic_id):
            begin_time = datetime.datetime.now()
            
            chronic_bin=chronic_id[train]
            chronic_test=chronic_id[test]
            
            # select model using training data
            bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv_strat(k, X[train], Y[train], chronic_bin, featselect, alphas, feats)

            # using optimal num. of features, select final features using entire training data.

            if featselect=='correlation':
                x_train_featselect,x_test_featureselect,ind = feature_select_correlation(X[train],X[test], Y[train], bestfeats)
                featur.append(ind)

            elif featselect=='PCA':
                x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(X[train],X[test], bestfeats)
                featur.append(ind)
                
            
            chronic_bin=np.reshape(np.double(chronic_bin), (x_train_featselect.shape[0], 1))
            x_train_featselect=np.concatenate((x_train_featselect, chronic_bin),axis=1)
        
            chronic_test=np.reshape(np.double(chronic_test), (x_test_featureselect.shape[0], 1))
            x_test_featureselect=np.concatenate((x_test_featureselect, chronic_test),axis=1)
                
            # initialize Ridge regression with alpha selected from hyperparameter search
            regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)

            # fit model 
            y_pred = regr.fit(x_train_featselect, Y[train]).predict(x_test_featureselect)

            # store results for each fold k
            impt.append(regr.coef_)
            R2.append(r2_score(Y[test], y_pred))
            expl_var.append(explained_variance_score(Y[test], y_pred))

            best_alphas.append(bestalpha)
            print('time to run loop: ' + str(datetime.datetime.now() - begin_time)) 
            print("R2 loop: " + str(r2_score(Y[test], y_pred)))
            print("Explained var: " + str(explained_variance_score(Y[test], y_pred)))
            print("correlation: " + str(np_pearson_cor(Y[test], y_pred)))
            
            chronicsubs_test=chronic_id[test]==True
            chronicsubs_train=chronic_id[train]==True
            chronicsubs_test=chronicsubs_test.flatten()
            chronicsubs_train=chronicsubs_train.flatten()
            cor.append(np_pearson_cor(Y[test], y_pred))
            Xtest=x_test_featureselect
            Xtrain=X[train]
            Ytest=Y[test]

            ytrue_chronic = Ytest[chronicsubs_test]
            xtest_chronic=Xtest[chronicsubs_test]
            
            ytestc.append(ytrue_chronic)
            
            ychronic_pred = regr.fit(x_train_featselect, Y[train]).predict(xtest_chronic)
            print("Explained variance, chronic only:  " + str(explained_variance_score(ytrue_chronic, ychronic_pred)))
            ypredc.append(ychronic_pred)

            chronic_explvar.append(explained_variance_score(ytrue_chronic, ychronic_pred))
            
 
        # store results for each permutation p

        allexpl_var.append(expl_var)
        bestalphas.append(best_alphas)
        importance.append(impt)
        chronic_allexpl_var.append(chronic_explvar)
        correlations.append(cor)
        print("---- Permutation avg. chronic explained variance: " + str(np.mean(chronic_explvar)) + "----")
        np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_chronic_all_explvar.txt', chronic_allexpl_var, delimiter=',')

        print("---- Permutation avg. explained variance: " + str(np.mean(expl_var)) + "----")
        np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_all_explvar.txt', expl_var, delimiter=',')

        output = open(results_dir + featselect + 'p' + str(p) + '_SC_features.pkl', 'wb')
        pickle.dump(featur, output)
        output.close()
        
        output = open(results_dir + featselect + 'p' + str(p) + '_SC_correlations.pkl', 'wb')
        pickle.dump(correlations, output)
        output.close()

        output = open(results_dir + featselect + 'p' + str(p) + '_SC_bestalphas.pkl', 'wb')
        pickle.dump(best_alphas, output)
        output.close()
     
        output = open(results_dir + featselect + 'p' + str(p) + '_SC_varimpt.pkl', 'wb')
        pickle.dump(importance, output)
        output.close()
# Out:
# Final size of X: (107, 3192)
# Permutation: 0
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.264614
# R2 loop: 0.23324933056565922
# Explained var: 0.25798883231693115
# correlation: [[0.50806784]]
# Explained variance, chronic only:  0.2651276874840044
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.359914
# R2 loop: 0.15089356946690002
# Explained var: 0.15101080919802945
# correlation: [[0.45934078]]
# Explained variance, chronic only:  0.18187840387803988
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.276036
# R2 loop: 0.2166535823223349
# Explained var: 0.26376125481969903
# correlation: [[0.52089328]]
# Explained variance, chronic only:  0.3392309925457041
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.257363
# R2 loop: 0.06109957044296821
# Explained var: 0.0836293375924978
# correlation: [[0.38334683]]
# Explained variance, chronic only:  -0.3320572175456351
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.360606
# R2 loop: 0.13049092187281985
# Explained var: 0.2648544373455344
# correlation: [[0.51465118]]
# Explained variance, chronic only:  0.2666379057759731
# ---- Permutation avg. chronic explained variance: 0.14416355442761727----
# ---- Permutation avg. explained variance: 0.20424893425453838----
# Permutation: 1
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.231667
# R2 loop: -0.01169225252360162
# Explained var: -0.011589483481110774
# correlation: [[0.29634684]]
# Explained variance, chronic only:  -0.13468030262290465
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.361374
# R2 loop: 0.4515433461120816
# Explained var: 0.4546837051107374
# correlation: [[0.70244534]]
# Explained variance, chronic only:  0.5232545551490665
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.366286
# R2 loop: 0.2449450605412412
# Explained var: 0.2476218325769438
# correlation: [[0.49788382]]
# Explained variance, chronic only:  0.2287221561142122
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.379250
# R2 loop: 0.09048096724492283
# Explained var: 0.15006703544357758
# correlation: [[0.41449059]]
# Explained variance, chronic only:  0.06237285262557268
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.355730
# R2 loop: 0.17638235918203293
# Explained var: 0.24785839729181147
# correlation: [[0.51839279]]
# Explained variance, chronic only:  0.16967015423035248
# ---- Permutation avg. chronic explained variance: 0.16986788309925985----
# ---- Permutation avg. explained variance: 0.21772829738839192----
# Permutation: 2
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.318019
# R2 loop: -0.12276880044498006
# Explained var: -0.08959466699706375
# correlation: [[0.4550863]]
# Explained variance, chronic only:  -0.05496599172670824
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.344056
# R2 loop: 0.3288753940041306
# Explained var: 0.3408158624753751
# correlation: [[0.62841511]]
# Explained variance, chronic only:  0.35228457349605435
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.420280
# R2 loop: 0.024674973875260187
# Explained var: 0.05111713242836513
# correlation: [[0.25535778]]
# Explained variance, chronic only:  -0.05786457592284422
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.412361
# R2 loop: 0.2777127031836065
# Explained var: 0.2800069167080885
# correlation: [[0.58432284]]
# Explained variance, chronic only:  0.19041018799178622
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.443405
# R2 loop: 0.32256892818525296
# Explained var: 0.3226507761051164
# correlation: [[0.56880474]]
# Explained variance, chronic only:  0.34698019543367775
# ---- Permutation avg. chronic explained variance: 0.15536887785439318----
# ---- Permutation avg. explained variance: 0.18099920414397627----
# Permutation: 3
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.329311
# R2 loop: 0.21684927711961166
# Explained var: 0.262081069865966
# correlation: [[0.51263246]]
# Explained variance, chronic only:  0.04005554598943162
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.357843
# R2 loop: 0.12079246962617185
# Explained var: 0.12522511197411446
# correlation: [[0.37842309]]
# Explained variance, chronic only:  0.12494931247769925
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.330118
# R2 loop: 0.02515829597877861
# Explained var: 0.10115881679280692
# correlation: [[0.33315071]]
# Explained variance, chronic only:  -0.04969834348812108
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.336319
# R2 loop: 0.20033968139462965
# Explained var: 0.3006592663690365
# correlation: [[0.6767593]]
# Explained variance, chronic only:  0.3524517669998948
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.376620
# R2 loop: 0.49739412552083806
# Explained var: 0.5305620556662227
# correlation: [[0.78777717]]
# Explained variance, chronic only:  0.5712290337532158
# ---- Permutation avg. chronic explained variance: 0.20779746314642406----
# ---- Permutation avg. explained variance: 0.26393726413362933----
# Permutation: 4
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.279093
# R2 loop: 0.1745982568720713
# Explained var: 0.17935592499375808
# correlation: [[0.42498959]]
# Explained variance, chronic only:  0.0789256760855016
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.249514
# R2 loop: 0.060688906817178645
# Explained var: 0.06141058462703519
# correlation: [[0.251649]]
# Explained variance, chronic only:  -0.008179562508309424
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.363593
# R2 loop: 0.5350358239297518
# Explained var: 0.6049957423072273
# correlation: [[0.79429249]]
# Explained variance, chronic only:  0.6711630167461258
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.362147
# R2 loop: 0.2979462748958388
# Explained var: 0.3979802637341613
# correlation: [[0.64495519]]
# Explained variance, chronic only:  0.36923167978575866
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.317258
# R2 loop: -0.021219502613413876
# Explained var: -0.009659882585961288
# correlation: [[0.01999255]]
# Explained variance, chronic only:  0.025603624749878096
# ---- Permutation avg. chronic explained variance: 0.22734888697179093----
# ---- Permutation avg. explained variance: 0.24681652661524414----
# Permutation: 5
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.328879
# R2 loop: -0.06856323983494028
# Explained var: -0.060088519782510064
# correlation: [[0.25739988]]
# Explained variance, chronic only:  -0.44440273117906326
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.326454
# R2 loop: -0.18084811405690826
# Explained var: 0.13251700832111402
# correlation: [[0.42606932]]
# Explained variance, chronic only:  0.15825857868036863
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-14-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:04.324891
# R2 loop: 0.4905307050086378
# Explained var: 0.49363995634205515
# correlation: [[0.74121414]]
# Explained variance, chronic only:  0.5146636088651436
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.333896
# R2 loop: 0.22315959678653519
# Explained var: 0.23678693955306862
# correlation: [[0.63858901]]
# Explained variance, chronic only:  0.2511706644229851
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.354233
# R2 loop: 0.003993315464096647
# Explained var: 0.25371796730709506
# correlation: [[0.52397748]]
# Explained variance, chronic only:  -0.30735012202344314
# ---- Permutation avg. chronic explained variance: 0.034467999753198184----
# ---- Permutation avg. explained variance: 0.2113146703481646----
# Permutation: 6
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.335007
# R2 loop: -0.06067634411975131
# Explained var: -0.042380742910965274
# correlation: [[0.25494506]]
# Explained variance, chronic only:  -0.4947037296682435
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.380133
# R2 loop: 0.4384776351756734
# Explained var: 0.4392980836074927
# correlation: [[0.72444914]]
# Explained variance, chronic only:  0.49657011939766327
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.306416
# R2 loop: 0.4144763313665989
# Explained var: 0.4195162890430195
# correlation: [[0.65006083]]
# Explained variance, chronic only:  0.4238614543074015
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.404062
# R2 loop: 0.10703626163835611
# Explained var: 0.12125461537536064
# correlation: [[0.35432107]]
# Explained variance, chronic only:  0.07784041424995158
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.322685
# R2 loop: 0.1481892998217057
# Explained var: 0.14859179891236973
# correlation: [[0.39304054]]
# Explained variance, chronic only:  0.1640996471848325
# ---- Permutation avg. chronic explained variance: 0.13353358109432106----
# ---- Permutation avg. explained variance: 0.21725600880545545----
# Permutation: 7
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.341647
# R2 loop: 0.3168957360958259
# Explained var: 0.501369892175806
# correlation: [[0.73140376]]
# Explained variance, chronic only:  0.5064583780878223
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.296518
# R2 loop: 0.2641654758637987
# Explained var: 0.26766223925537735
# correlation: [[0.61215183]]
# Explained variance, chronic only:  0.3240262971545722
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.252032
# R2 loop: -0.6292607569450119
# Explained var: -0.5513397438900605
# correlation: [[-0.41486582]]
# Explained variance, chronic only:  -0.6432342014193284
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.361479
# R2 loop: 0.02849457951666612
# Explained var: 0.047762504314202925
# correlation: [[0.26097154]]
# Explained variance, chronic only:  0.024222107999253284
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.391197
# R2 loop: 0.1850184385734196
# Explained var: 0.2915458137092918
# correlation: [[0.59843427]]
# Explained variance, chronic only:  0.13167526988477984
# ---- Permutation avg. chronic explained variance: 0.06862957034141985----
# ---- Permutation avg. explained variance: 0.11140014111292351----
# Permutation: 8
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.331469
# R2 loop: 0.43214331678810625
# Explained var: 0.4539218068632497
# correlation: [[0.68452283]]
# Explained variance, chronic only:  0.5589351769020869
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.270789
# R2 loop: -0.014545226621191176
# Explained var: 0.006481100200778744
# correlation: [[0.32293733]]
# Explained variance, chronic only:  -0.10978452931977456
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.397690
# R2 loop: 0.2605984920539266
# Explained var: 0.27249928724023964
# correlation: [[0.53785831]]
# Explained variance, chronic only:  0.03078119101420007
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.457674
# R2 loop: 0.26953317357250994
# Explained var: 0.28104468997738674
# correlation: [[0.61544108]]
# Explained variance, chronic only:  0.2949544527388107
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.371171
# R2 loop: 0.20043450787463157
# Explained var: 0.24461424041359026
# correlation: [[0.50246113]]
# Explained variance, chronic only:  0.15778931866031343
# ---- Permutation avg. chronic explained variance: 0.1865351219991273----
# ---- Permutation avg. explained variance: 0.251712224939049----
# Permutation: 9
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.319174
# R2 loop: 0.10737323430809975
# Explained var: 0.19059981443989793
# correlation: [[0.44874591]]
# Explained variance, chronic only:  0.2415340821469869
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.367258
# R2 loop: 0.36196989754573383
# Explained var: 0.38804607793346657
# correlation: [[0.72852849]]
# Explained variance, chronic only:  0.4063727343117264
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.346343
# R2 loop: -0.23943663503942125
# Explained var: -0.23799573178099886
# correlation: [[0.18354809]]
# Explained variance, chronic only:  -0.28997753809903015
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.347287
# R2 loop: -0.18991798897244183
# Explained var: -0.07391010410878596
# correlation: [[-0.02604236]]
# Explained variance, chronic only:  -0.1638636993709499
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.346575
# R2 loop: 0.04330757437241872
# Explained var: 0.08161840346043592
# correlation: [[0.29073847]]
# Explained variance, chronic only:  0.03510723994003773
# ---- Permutation avg. chronic explained variance: 0.04583456378575419----
# ---- Permutation avg. explained variance: 0.06967169198880312----
# Permutation: 10
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.334519
# R2 loop: -0.009742904235208849
# Explained var: 0.013686929832961492
# correlation: [[0.33951079]]
# Explained variance, chronic only:  -0.018010148845604146
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.213634
# R2 loop: -0.05040903151784737
# Explained var: 0.16124155416009467
# correlation: [[0.80670069]]
# Explained variance, chronic only:  0.19224701522382714
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.190199
# R2 loop: 0.214981417417331
# Explained var: 0.23538996953048974
# correlation: [[0.48518934]]
# Explained variance, chronic only:  0.08790097093377458
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.274735
# R2 loop: -0.11303822733581836
# Explained var: 0.0968994679606654
# correlation: [[0.31849205]]
# Explained variance, chronic only:  -0.07158354786552912
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.386841
# R2 loop: -0.013536365734983624
# Explained var: -0.010032414493690078
# correlation: [[0.05763005]]
# Explained variance, chronic only:  -0.043338773290398924
# ---- Permutation avg. chronic explained variance: 0.029443103231213907----
# ---- Permutation avg. explained variance: 0.09943710139810424----
# Permutation: 11
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.166618
# R2 loop: 0.013450933174283142
# Explained var: 0.1838349711106405
# correlation: [[0.77714875]]
# Explained variance, chronic only:  0.18793361282274268
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.334413
# R2 loop: -0.06462333809789422
# Explained var: 0.08021326277693808
# correlation: [[0.29423394]]
# Explained variance, chronic only:  0.07978529678053758
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.379965
# R2 loop: -0.012968110526711207
# Explained var: 0.05541648772014496
# correlation: [[0.28718859]]
# Explained variance, chronic only:  0.09618500728228241
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.414703
# R2 loop: -0.1664844443793052
# Explained var: -0.13836202971338563
# correlation: [[0.19187249]]
# Explained variance, chronic only:  -0.18557983049584492
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.426122
# R2 loop: -0.006755483217236069
# Explained var: 0.09289263040925466
# correlation: [[0.34256118]]
# Explained variance, chronic only:  0.10261354911933052
# ---- Permutation avg. chronic explained variance: 0.05618752710180965----
# ---- Permutation avg. explained variance: 0.05479906446071851----
# Permutation: 12
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.159000
# R2 loop: 0.20995695595457942
# Explained var: 0.21144506462062163
# correlation: [[0.46493456]]
# Explained variance, chronic only:  0.338122006561698
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.138614
# R2 loop: 0.03535858990147067
# Explained var: 0.03811697987307194
# correlation: [[0.20546579]]
# Explained variance, chronic only:  -0.0391351247456555
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.351478
# R2 loop: 0.1495659942134694
# Explained var: 0.14965639908137174
# correlation: [[0.38685692]]
# Explained variance, chronic only:  0.1514370068635229
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.170305
# R2 loop: 0.23770639632038648
# Explained var: 0.23773378219933616
# correlation: [[0.49542548]]
# Explained variance, chronic only:  0.10922391156744371
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.343537
# R2 loop: 0.2907172490469212
# Explained var: 0.3341161056511007
# correlation: [[0.58579878]]
# Explained variance, chronic only:  0.21978625374107308
# ---- Permutation avg. chronic explained variance: 0.15588681079761643----
# ---- Permutation avg. explained variance: 0.19421366628510045----
# Permutation: 13
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.428113
# R2 loop: 0.17671877828195448
# Explained var: 0.24289280654653256
# correlation: [[0.61477758]]
# Explained variance, chronic only:  0.41207024753703336
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.347859
# R2 loop: 0.10985278722360614
# Explained var: 0.1101864759542942
# correlation: [[0.33195478]]
# Explained variance, chronic only:  0.0664310536892132
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.251322
# R2 loop: 0.0318025775844466
# Explained var: 0.10980191337616563
# correlation: [[0.35059762]]
# Explained variance, chronic only:  0.05295083511874776
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.372849
# R2 loop: 0.19800168037574772
# Explained var: 0.21813699642442186
# correlation: [[0.48298869]]
# Explained variance, chronic only:  0.23899941690054038
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.384214
# R2 loop: 0.0069783095855859845
# Explained var: 0.059029780408221155
# correlation: [[0.26344857]]
# Explained variance, chronic only:  0.0463114145613458
# ---- Permutation avg. chronic explained variance: 0.1633525935613761----
# ---- Permutation avg. explained variance: 0.14800959454192708----
# Permutation: 14
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.284985
# R2 loop: -0.24452069773792684
# Explained var: -0.19476864019044426
# correlation: [[0.28026026]]
# Explained variance, chronic only:  -1.044950730136959
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.275284
# R2 loop: 0.06948561288016242
# Explained var: 0.14224711169198823
# correlation: [[0.37724602]]
# Explained variance, chronic only:  0.1207438061424605
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.414521
# R2 loop: 0.08480048475765778
# Explained var: 0.21050548485816112
# correlation: [[0.45881317]]
# Explained variance, chronic only:  0.2679818622308161
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.359199
# R2 loop: 0.2628163946229316
# Explained var: 0.3027615979534676
# correlation: [[0.63880013]]
# Explained variance, chronic only:  0.3060053307388907
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.402652
# R2 loop: 0.3545814944740142
# Explained var: 0.37422398397088175
# correlation: [[0.67898438]]
# Explained variance, chronic only:  0.40469437071851166
# ---- Permutation avg. chronic explained variance: 0.010894927938744003----
# ---- Permutation avg. explained variance: 0.16699390765681088----
# Permutation: 15
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.409283
# R2 loop: 0.17119775702525009
# Explained var: 0.30824938836275295
# correlation: [[0.55575468]]
# Explained variance, chronic only:  0.27742906088869135
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.279609
# R2 loop: 0.5385970816894103
# Explained var: 0.5742186495672059
# correlation: [[0.7579822]]
# Explained variance, chronic only:  0.5738974504726395
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.411453
# R2 loop: 0.2576753018790703
# Explained var: 0.2677589696330651
# correlation: [[0.53923449]]
# Explained variance, chronic only:  0.30774210076814434
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.389551
# R2 loop: -0.6990077978485087
# Explained var: -0.6107499975561121
# correlation: [[-0.09716458]]
# Explained variance, chronic only:  -0.8174832930695928
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.188349
# R2 loop: 0.14741515714446274
# Explained var: 0.23426527271864472
# correlation: [[0.50151718]]
# Explained variance, chronic only:  0.11911853549176432
# ---- Permutation avg. chronic explained variance: 0.09214077091032932----
# ---- Permutation avg. explained variance: 0.15474845654511132----
# Permutation: 16
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.363434
# R2 loop: 0.0717277658080332
# Explained var: 0.07277622224971136
# correlation: [[0.27831909]]
# Explained variance, chronic only:  0.04926314849815683
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.425783
# R2 loop: -0.16849140690475295
# Explained var: -0.16235142132516467
# correlation: [[0.08735606]]
# Explained variance, chronic only:  -0.22968353026850186
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.341121
# R2 loop: 0.3525427892763433
# Explained var: 0.41007791651300973
# correlation: [[0.76807198]]
# Explained variance, chronic only:  0.37780261007500626
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.286399
# R2 loop: -0.02573598948777045
# Explained var: -0.01820695078155876
# correlation: [[0.30351505]]
# Explained variance, chronic only:  -0.044496624992448774
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.264235
# R2 loop: 0.15288364436418855
# Explained var: 0.16334420931779647
# correlation: [[0.64933247]]
# Explained variance, chronic only:  0.1852873699365144
# ---- Permutation avg. chronic explained variance: 0.06763459464974537----
# ---- Permutation avg. explained variance: 0.09312799519475883----
# Permutation: 17
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.259051
# R2 loop: -0.020404702775720596
# Explained var: -0.012998756036605386
# correlation: [[0.26143981]]
# Explained variance, chronic only:  -0.07367283289959858
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.284713
# R2 loop: 0.09460684391921237
# Explained var: 0.172476830365912
# correlation: [[0.41850291]]
# Explained variance, chronic only:  -0.02774824893970962
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.321591
# R2 loop: 0.46922791926031404
# Explained var: 0.4856563368202502
# correlation: [[0.74156682]]
# Explained variance, chronic only:  0.5316230276266211
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.435970
# R2 loop: 0.22979008486523356
# Explained var: 0.37241950302129556
# correlation: [[0.67747443]]
# Explained variance, chronic only:  0.4369624058689314
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.352586
# R2 loop: 0.21095182929464484
# Explained var: 0.21806938718446212
# correlation: [[0.4669799]]
# Explained variance, chronic only:  0.16379305907894004
# ---- Permutation avg. chronic explained variance: 0.2061914821470369----
# ---- Permutation avg. explained variance: 0.2471246602710629----
# Permutation: 18
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.359992
# R2 loop: 0.11976142511884158
# Explained var: 0.1975581398794406
# correlation: [[0.44675751]]
# Explained variance, chronic only:  0.19609619513159748
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.351217
# R2 loop: -0.22597351684231182
# Explained var: -0.2242557589208498
# correlation: [[-0.27011367]]
# Explained variance, chronic only:  -0.31028174125109187
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.422703
# R2 loop: 0.2982840737741267
# Explained var: 0.3121044153639806
# correlation: [[0.75769428]]
# Explained variance, chronic only:  0.30475936737796727
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.397654
# R2 loop: 0.10767040109787851
# Explained var: 0.1677316422579852
# correlation: [[0.41923726]]
# Explained variance, chronic only:  0.13393095283268597
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.367632
# R2 loop: 0.11386521762942237
# Explained var: 0.12005286222347322
# correlation: [[0.3890887]]
# Explained variance, chronic only:  0.05951551508323838
# ---- Permutation avg. chronic explained variance: 0.07680405783487945----
# ---- Permutation avg. explained variance: 0.11463826016080596----
# Permutation: 19
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.119034
# R2 loop: 0.36243160120677753
# Explained var: 0.4123821678532248
# correlation: [[0.65449158]]
# Explained variance, chronic only:  0.5549037178463939
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.285600
# R2 loop: 0.15696496337025156
# Explained var: 0.16927394622936898
# correlation: [[0.47636887]]
# Explained variance, chronic only:  0.10873335281728447
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.035685
# R2 loop: 0.00041174618490846804
# Explained var: 0.04683813209715271
# correlation: [[0.29948466]]
# Explained variance, chronic only:  -0.011307872790185414
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.338771
# R2 loop: 0.034632162427687296
# Explained var: 0.08439850086218192
# correlation: [[0.30399492]]
# Explained variance, chronic only:  0.09164451052690892
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.373039
# R2 loop: 0.4153695903443272
# Explained var: 0.41536971999664696
# correlation: [[0.72913541]]
# Explained variance, chronic only:  0.47048343694666817
# ---- Permutation avg. chronic explained variance: 0.24289142906941402----
# ---- Permutation avg. explained variance: 0.22565249340771504----
# Permutation: 20
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.332897
# R2 loop: -0.06420436402614338
# Explained var: 0.0804793130999244
# correlation: [[0.30342803]]
# Explained variance, chronic only:  -0.003980329919400338
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.272356
# R2 loop: 0.26228971765001274
# Explained var: 0.27979122336550666
# correlation: [[0.5295393]]
# Explained variance, chronic only:  0.24853721002405005
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.396949
# R2 loop: -0.013219000064754294
# Explained var: 0.07134847393526689
# correlation: [[0.27839406]]
# Explained variance, chronic only:  0.12240251421843029
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.300398
# R2 loop: 0.0005951667152144235
# Explained var: 0.001694175779963003
# correlation: [[0.2659348]]
# Explained variance, chronic only:  -0.0627886927555188
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.441225
# R2 loop: 0.5056533096541327
# Explained var: 0.5148401701974736
# correlation: [[0.82306479]]
# Explained variance, chronic only:  0.5904106393107043
# ---- Permutation avg. chronic explained variance: 0.1789162681756531----
# ---- Permutation avg. explained variance: 0.1896306712756269----
# Permutation: 21
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.354180
# R2 loop: -0.017833119911931927
# Explained var: 0.06711649780762241
# correlation: [[0.26861895]]
# Explained variance, chronic only:  0.05007786705419193
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.302124
# R2 loop: 0.027149237064429954
# Explained var: 0.030455027442170657
# correlation: [[0.22337773]]
# Explained variance, chronic only:  -0.0844501323551079
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.315913
# R2 loop: 0.3115224767763761
# Explained var: 0.3126044139387396
# correlation: [[0.58736578]]
# Explained variance, chronic only:  0.3119096376369651
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.390068
# R2 loop: 0.38905156247505834
# Explained var: 0.468237573285903
# correlation: [[0.75045883]]
# Explained variance, chronic only:  0.5199380654050751
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.374564
# R2 loop: 0.21915701995247472
# Explained var: 0.24101184683599275
# correlation: [[0.49401796]]
# Explained variance, chronic only:  0.020448259818283576
# ---- Permutation avg. chronic explained variance: 0.16358473951188157----
# ---- Permutation avg. explained variance: 0.22388507186208567----
# Permutation: 22
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.405959
# R2 loop: -0.47310935884499794
# Explained var: -0.46831645133803224
# correlation: [[0.10031202]]
# Explained variance, chronic only:  -0.661605207422451
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.378544
# R2 loop: 0.5087238459822666
# Explained var: 0.5293052115256338
# correlation: [[0.72767966]]
# Explained variance, chronic only:  0.5601264657458107
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.428109
# R2 loop: 0.13876178083011703
# Explained var: 0.18473382179039366
# correlation: [[0.43678669]]
# Explained variance, chronic only:  0.18579233625681113
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.385898
# R2 loop: 0.32327278905706025
# Explained var: 0.3901399510807976
# correlation: [[0.70679184]]
# Explained variance, chronic only:  0.3462135464728886
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.464473
# R2 loop: 0.12240730353201112
# Explained var: 0.12965916165889468
# correlation: [[0.38660354]]
# Explained variance, chronic only:  0.17105472199899363
# ---- Permutation avg. chronic explained variance: 0.12031637261041062----
# ---- Permutation avg. explained variance: 0.1531043389435375----
# Permutation: 23
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.248210
# R2 loop: 0.2712124188322572
# Explained var: 0.3417113947249829
# correlation: [[0.59648819]]
# Explained variance, chronic only:  0.450638975487759
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.365750
# R2 loop: 0.15171093406195513
# Explained var: 0.16305073773353418
# correlation: [[0.40870608]]
# Explained variance, chronic only:  0.00198059923109839
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.410554
# R2 loop: 0.02733267733560374
# Explained var: 0.1689366419299725
# correlation: [[0.43664197]]
# Explained variance, chronic only:  0.05919780921554996
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.321342
# R2 loop: 0.3354211650390807
# Explained var: 0.335500074918469
# correlation: [[0.58210133]]
# Explained variance, chronic only:  0.43584121561537525
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.426391
# R2 loop: 0.03946501544075587
# Explained var: 0.04240855270154009
# correlation: [[0.25517578]]
# Explained variance, chronic only:  0.06146389644103867
# ---- Permutation avg. chronic explained variance: 0.20182449919816428----
# ---- Permutation avg. explained variance: 0.21032148040169973----
# Permutation: 24
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.170482
# R2 loop: 0.6729896566652389
# Explained var: 0.6734082592892278
# correlation: [[0.85834356]]
# Explained variance, chronic only:  0.7179029745071254
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.378482
# R2 loop: -0.9783598073744617
# Explained var: -0.21437276642631486
# correlation: [[-0.26254287]]
# Explained variance, chronic only:  -0.1013206813830485
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.292531
# R2 loop: 0.07680230640342389
# Explained var: 0.1960347280469309
# correlation: [[0.48825064]]
# Explained variance, chronic only:  0.03444094902782979
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.268498
# R2 loop: 0.2946314259223064
# Explained var: 0.2969002712804071
# correlation: [[0.54556136]]
# Explained variance, chronic only:  0.28081988575223515
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.315714
# R2 loop: -0.5067083204114513
# Explained var: 0.0009723870912681232
# correlation: [[0.25371163]]
# Explained variance, chronic only:  -0.2406695933898697
# ---- Permutation avg. chronic explained variance: 0.13823470690285442----
# ---- Permutation avg. explained variance: 0.1905885758563038----
# Permutation: 25
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.277166
# R2 loop: 0.040657306620460965
# Explained var: 0.05320011452021156
# correlation: [[0.23076335]]
# Explained variance, chronic only:  0.053695775264042234
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.255323
# R2 loop: 0.33345274349616305
# Explained var: 0.3368207303925974
# correlation: [[0.60627584]]
# Explained variance, chronic only:  0.34421533193119513
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.340815
# R2 loop: 0.537141885456718
# Explained var: 0.5457824777811396
# correlation: [[0.74661664]]
# Explained variance, chronic only:  0.5498728462590876
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.382989
# R2 loop: -0.4157026546035141
# Explained var: -0.2708210764109622
# correlation: [[0.11020954]]
# Explained variance, chronic only:  -0.4353882930153907
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.364039
# R2 loop: 0.2255928862576535
# Explained var: 0.26561443342405455
# correlation: [[0.51539736]]
# Explained variance, chronic only:  0.20990685982222512
# ---- Permutation avg. chronic explained variance: 0.14446050405223188----
# ---- Permutation avg. explained variance: 0.1861193359414082----
# Permutation: 26
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.317457
# R2 loop: 0.10815558810682158
# Explained var: 0.1282396725992312
# correlation: [[0.3622161]]
# Explained variance, chronic only:  0.014102541505945032
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.406005
# R2 loop: 0.19877957579943561
# Explained var: 0.20439043223287934
# correlation: [[0.48623673]]
# Explained variance, chronic only:  0.09910341790958288
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.281881
# R2 loop: 0.394703981786535
# Explained var: 0.4386117892507114
# correlation: [[0.73322483]]
# Explained variance, chronic only:  0.479494328505519
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.383508
# R2 loop: 0.062144382377746665
# Explained var: 0.06574108449630811
# correlation: [[0.2579018]]
# Explained variance, chronic only:  0.026891737822111073
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.369575
# R2 loop: 0.25422867455249554
# Explained var: 0.38402841840435487
# correlation: [[0.69369841]]
# Explained variance, chronic only:  0.4160329137982014
# ---- Permutation avg. chronic explained variance: 0.20712498790827186----
# ---- Permutation avg. explained variance: 0.244202279396697----
# Permutation: 27
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.244499
# R2 loop: -0.04500260173106718
# Explained var: 0.05893836830945731
# correlation: [[0.57048918]]
# Explained variance, chronic only:  0.05570252673088438
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.372761
# R2 loop: 0.010956594462771974
# Explained var: 0.02523532600350531
# correlation: [[0.29396753]]
# Explained variance, chronic only:  -0.10295963183465573
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.247138
# R2 loop: 0.03632593142320972
# Explained var: 0.08701275815242349
# correlation: [[0.32878962]]
# Explained variance, chronic only:  0.19509981490333717
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.417203
# R2 loop: 0.03130972273805166
# Explained var: 0.038148991694836765
# correlation: [[0.25208875]]
# Explained variance, chronic only:  0.004849158412484789
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.225240
# R2 loop: 0.03630827403737369
# Explained var: 0.09005718427770071
# correlation: [[0.30671173]]
# Explained variance, chronic only:  0.07996162535630535
# ---- Permutation avg. chronic explained variance: 0.046530698713671194----
# ---- Permutation avg. explained variance: 0.05987852568758471----
# Permutation: 28
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.321064
# R2 loop: 0.1895084505412037
# Explained var: 0.24861031444886128
# correlation: [[0.50930668]]
# Explained variance, chronic only:  0.2968000205165202
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.297076
# R2 loop: 0.30421569725663833
# Explained var: 0.3372459788292005
# correlation: [[0.66141869]]
# Explained variance, chronic only:  0.35198207881029075
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.180991
# R2 loop: 0.0114274634073811
# Explained var: 0.06736330750642339
# correlation: [[0.35376803]]
# Explained variance, chronic only:  -0.02770149833542268
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.355471
# R2 loop: 0.4012652109418924
# Explained var: 0.4018655153198474
# correlation: [[0.66927219]]
# Explained variance, chronic only:  0.46667971710623235
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.315245
# R2 loop: 0.2360273739640899
# Explained var: 0.2534689357683285
# correlation: [[0.51607308]]
# Explained variance, chronic only:  0.133198558434114
# ---- Permutation avg. chronic explained variance: 0.2441917753063469----
# ---- Permutation avg. explained variance: 0.26171081037453214----
# Permutation: 29
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.368888
# R2 loop: 0.33775050109891724
# Explained var: 0.4172442468849913
# correlation: [[0.64690385]]
# Explained variance, chronic only:  0.4554201509099206
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.325887
# R2 loop: 0.09964848957951455
# Explained var: 0.10108086084265722
# correlation: [[0.40721682]]
# Explained variance, chronic only:  -0.11395270850594841
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.351859
# R2 loop: 0.24921990849124764
# Explained var: 0.2513247202583888
# correlation: [[0.52456962]]
# Explained variance, chronic only:  0.2571567973460006
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.375274
# R2 loop: 0.15866419756447392
# Explained var: 0.16392593169547887
# correlation: [[0.42279125]]
# Explained variance, chronic only:  0.02401277120385148
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# ...
# time to run loop: 0:00:04.161397
# R2 loop: 0.22933274890437028
# Explained var: 0.3108431249353295
# correlation: [[0.56524982]]
# Explained variance, chronic only:  0.329585608784821
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.304417
# R2 loop: 0.009657621456480858
# Explained var: 0.026170874386215237
# correlation: [[0.30956636]]
# Explained variance, chronic only:  0.006530614874827867
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.353115
# R2 loop: 0.4031964332031822
# Explained var: 0.40442952182128844
# correlation: [[0.73744222]]
# Explained variance, chronic only:  0.42994530018026256
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.413335
# R2 loop: 0.16067766245950366
# Explained var: 0.2023800064772142
# correlation: [[0.44991619]]
# Explained variance, chronic only:  -0.03848995812843903
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.044102
# R2 loop: -0.1820081386892669
# Explained var: -0.0022358570368341546
# correlation: [[0.03828322]]
# Explained variance, chronic only:  -0.008781419859483997
# ---- Permutation avg. chronic explained variance: 0.14375802917039768----
# ---- Permutation avg. explained variance: 0.18831753411664265----
# Permutation: 91
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.375572
# R2 loop: 0.16403581704532555
# Explained var: 0.16448029291199207
# correlation: [[0.40765556]]
# Explained variance, chronic only:  0.14441145896144003
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.401284
# R2 loop: 0.4398392494445179
# Explained var: 0.5072602451713815
# correlation: [[0.75564945]]
# Explained variance, chronic only:  0.540371002636971
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.400304
# R2 loop: -0.017871871220863866
# Explained var: -0.011882821777706498
# correlation: [[0.27716796]]
# Explained variance, chronic only:  0.05977930683504318
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.380658
# R2 loop: 0.22098651889780108
# Explained var: 0.2368311067449409
# correlation: [[0.48745341]]
# Explained variance, chronic only:  0.05364101538368948
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.377492
# R2 loop: 0.24175907469467306
# Explained var: 0.24715901813426921
# correlation: [[0.54870518]]
# Explained variance, chronic only:  0.27444676378070165
# ---- Permutation avg. chronic explained variance: 0.2145299095195691----
# ---- Permutation avg. explained variance: 0.22876956823697542----
# Permutation: 92
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.281809
# R2 loop: -0.04189777650674986
# Explained var: -0.03459117067299289
# correlation: [[0.07987045]]
# Explained variance, chronic only:  -0.0879491438928095
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.146809
# R2 loop: 0.18436579889367755
# Explained var: 0.18457388433424304
# correlation: [[0.42964913]]
# Explained variance, chronic only:  0.04774188126120826
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.332457
# R2 loop: 0.2911088274692103
# Explained var: 0.33379032545952336
# correlation: [[0.72171755]]
# Explained variance, chronic only:  0.349188039797678
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.414396
# R2 loop: 0.13934706485662396
# Explained var: 0.20528731727686833
# correlation: [[0.49752232]]
# Explained variance, chronic only:  0.22932719678570657
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.283210
# R2 loop: 0.10236319462947208
# Explained var: 0.10843106160602567
# correlation: [[0.38403506]]
# Explained variance, chronic only:  0.11894237933567331
# ---- Permutation avg. chronic explained variance: 0.1314500706574913----
# ---- Permutation avg. explained variance: 0.1594982836007335----
# Permutation: 93
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.402271
# R2 loop: -0.9750231317932316
# Explained var: -0.972746161261788
# correlation: [[0.15335478]]
# Explained variance, chronic only:  -1.4512899706830371
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.032744
# R2 loop: 0.12230869273151079
# Explained var: 0.1312649233517681
# correlation: [[0.36347497]]
# Explained variance, chronic only:  0.009575116940116368
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.382151
# R2 loop: 0.17137071560064066
# Explained var: 0.18520773613840802
# correlation: [[0.43078494]]
# Explained variance, chronic only:  0.1525098268714956
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.326953
# R2 loop: 0.17167436273119385
# Explained var: 0.2716263831366891
# correlation: [[0.58141345]]
# Explained variance, chronic only:  0.3030381608097166
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.469633
# R2 loop: 0.46398224342536454
# Explained var: 0.46458250590191086
# correlation: [[0.732041]]
# Explained variance, chronic only:  0.5282768733510789
# ---- Permutation avg. chronic explained variance: -0.09157799854212592----
# ---- Permutation avg. explained variance: 0.015987077453397603----
# Permutation: 94
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.310147
# R2 loop: 0.06040104272406144
# Explained var: 0.23635306987488403
# correlation: [[0.61809949]]
# Explained variance, chronic only:  0.24348687712152595
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.132152
# R2 loop: -0.06450415486225314
# Explained var: 0.18366676055797693
# correlation: [[0.43030058]]
# Explained variance, chronic only:  -0.023346047458270958
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.298176
# R2 loop: -0.21166202144503288
# Explained var: -0.20928244827930365
# correlation: [[-0.16528737]]
# Explained variance, chronic only:  -0.30368477115756143
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.417571
# R2 loop: 0.28997717934153655
# Explained var: 0.39647554337462076
# correlation: [[0.71484052]]
# Explained variance, chronic only:  0.43332817034768256
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.399356
# R2 loop: -0.053742144962984684
# Explained var: 0.0306195597162231
# correlation: [[0.27243776]]
# Explained variance, chronic only:  0.13042124071003958
# ---- Permutation avg. chronic explained variance: 0.09604109391268315----
# ---- Permutation avg. explained variance: 0.12756649704888023----
# Permutation: 95
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.381725
# R2 loop: 0.26797231530649657
# Explained var: 0.2819886363504852
# correlation: [[0.54729072]]
# Explained variance, chronic only:  0.16250194593779055
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.293068
# R2 loop: -0.055360433343838444
# Explained var: 0.012223318559085206
# correlation: [[0.31106677]]
# Explained variance, chronic only:  -0.06666516940880785
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.393888
# R2 loop: -0.14923652000113763
# Explained var: -0.14422593415239326
# correlation: [[-0.31673268]]
# Explained variance, chronic only:  -0.042928851826822934
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.417777
# R2 loop: 0.5462724026743117
# Explained var: 0.5476597390679175
# correlation: [[0.74691841]]
# Explained variance, chronic only:  0.5450283641006736
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.295703
# R2 loop: 0.12760322873855934
# Explained var: 0.12766676880390182
# correlation: [[0.35730746]]
# Explained variance, chronic only:  0.11412119187870629
# ---- Permutation avg. chronic explained variance: 0.14241149613630794----
# ---- Permutation avg. explained variance: 0.1650625057257993----
# Permutation: 96
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.347236
# R2 loop: 0.13257274582950862
# Explained var: 0.23856207365624393
# correlation: [[0.51342051]]
# Explained variance, chronic only:  0.0958569303542619
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.296471
# R2 loop: 0.08151433522602924
# Explained var: 0.15778956483720263
# correlation: [[0.40047803]]
# Explained variance, chronic only:  0.11430315790356793
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.285503
# R2 loop: -0.08475210009883472
# Explained var: -0.07856096304330684
# correlation: [[0.04574094]]
# Explained variance, chronic only:  -0.07704734743523867
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.399465
# R2 loop: 0.30323522444565354
# Explained var: 0.3207465430886297
# correlation: [[0.80093479]]
# Explained variance, chronic only:  0.33269112853551486
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.225242
# R2 loop: 0.15486691181916112
# Explained var: 0.15515901032971313
# correlation: [[0.40575315]]
# Explained variance, chronic only:  0.0415950417457428
# ---- Permutation avg. chronic explained variance: 0.10147978222076977----
# ---- Permutation avg. explained variance: 0.15873924577369652----
# Permutation: 97
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.373854
# R2 loop: 0.1601439539571511
# Explained var: 0.16211469054358163
# correlation: [[0.40990193]]
# Explained variance, chronic only:  0.1619804648487586
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.139801
# R2 loop: 0.1747992620990989
# Explained var: 0.28002956604454055
# correlation: [[0.69643974]]
# Explained variance, chronic only:  0.2741545392413459
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.231188
# R2 loop: 0.020770515726340588
# Explained var: 0.062009249813615
# correlation: [[0.25097476]]
# Explained variance, chronic only:  0.06439754599886716
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.139022
# R2 loop: 0.14884236752900037
# Explained var: 0.15446206858085398
# correlation: [[0.39507802]]
# Explained variance, chronic only:  0.18499383214132858
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.289192
# R2 loop: -0.21327604275753997
# Explained var: 0.021710544420612488
# correlation: [[0.265213]]
# Explained variance, chronic only:  -0.3415816985669422
# ---- Permutation avg. chronic explained variance: 0.06878893673267161----
# ---- Permutation avg. explained variance: 0.13606522388064074----
# Permutation: 98
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.380019
# R2 loop: 0.3463027986700401
# Explained var: 0.37536608640360125
# correlation: [[0.73961233]]
# Explained variance, chronic only:  0.37861178181047317
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.378359
# R2 loop: 0.47381195534220744
# Explained var: 0.4754492742174278
# correlation: [[0.6901211]]
# Explained variance, chronic only:  0.5229399370366781
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.350506
# R2 loop: 0.12609482041686415
# Explained var: 0.13407360127620427
# correlation: [[0.38855855]]
# Explained variance, chronic only:  0.05918548289381487
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.195566
# R2 loop: -0.011932284297607065
# Explained var: 0.009912328693508998
# correlation: [[0.1736802]]
# Explained variance, chronic only:  0.034608791398969885
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.387157
# R2 loop: -0.04373388138536738
# Explained var: 0.14598020250416133
# correlation: [[0.44769224]]
# Explained variance, chronic only:  0.00045460903625571536
# ---- Permutation avg. chronic explained variance: 0.19916012043523834----
# ---- Permutation avg. explained variance: 0.22815629861898074----
# Permutation: 99
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.342695
# R2 loop: 0.24028066355737188
# Explained var: 0.2716006927875687
# correlation: [[0.5421501]]
# Explained variance, chronic only:  0.32665989323819944
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.135281
# R2 loop: 0.10402653412146556
# Explained var: 0.15070461374982935
# correlation: [[0.44150768]]
# Explained variance, chronic only:  0.02852484132412425
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.258699
# R2 loop: 0.15787553049120795
# Explained var: 0.27104697446461523
# correlation: [[0.62090627]]
# Explained variance, chronic only:  0.14360645051767185
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.408616
# R2 loop: 0.06259157236027102
# Explained var: 0.10998448896945034
# correlation: [[0.42694277]]
# Explained variance, chronic only:  0.18779864899979148
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.312566
# R2 loop: -0.947912194224849
# Explained var: -0.9339091314238563
# correlation: [[-0.37923799]]
# Explained variance, chronic only:  -1.0495614761141097
# ---- Permutation avg. chronic explained variance: -0.07259432840686453----
# ---- Permutation avg. explained variance: -0.02611447229047854----

# %%
# Plot example test/predicted

len(ypredc)
len(ytestc)

a=ypredc[9]
b=ytestc[9]

print(explained_variance_score(b,a))
plt.scatter(a,b)
plt.xlabel('Predicted WAIS')
plt.ylabel('True WAIS')
# Out:
# 0.16967015423035248
# Text(0, 0.5, 'True WAIS')

# %%
# -------- assessing model weights and features selected -----------
results_dir='/home/ubuntu/cognition_iowa/results/enhanced1/'
shape=[]
alldice=[]
alldicestd=[]
allalldice=[]
numfeatures=[]
countweights=np.zeros(shape=(3192, 1), dtype='int')
for p in range(0,100):
    with open(results_dir + 'correlation' + 'p' + str(p) + '_SC_features.pkl', 'rb') as f:
        feats = pickle.load(f)
        
    # calculate the dice coefficient
    dice=np.zeros(shape=(5,5),dtype='float')
    for x in range(0,5):
        for y in range(0,5):
            if x==y :
                continue
            one=feats[x]
            two= feats[y]
            test=np.intersect1d(one,two)
            dice[x,y]=2*(test.shape[0]/(one.shape[0]+two.shape[0]))
    
    for x in range(0,5):
        numfeatures.append(feats[x].shape[0])
        
    dice=dice[np.triu_indices(5,k=1)] # only calcualting mean/std across 10 unique comparisons
    allalldice.append(dice)
    alldice.append(np.mean(dice))
    alldicestd.append(np.std(dice))
    
    # count how many times a feature shows up? max 5 per thing.
    for k in range(0, 3192):
        for x in range(0,5):
            if np.isin(k, feats[x]):
                countweights[k] = countweights[k] +1

# %%
plt.figure(figsize=(10,10))
plt.hist(numfeatures)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.xlabel('Number of features', fontsize=18)
plt.ylabel('Count',fontsize=18)
# Out:
# Text(0, 0.5, 'Count')

# %%
alldice_null=[]
alldice_nullstd=[]
allalldice_null=[]
for k in range(0,100):
    # calculate the dice coefficient for randomly selected features
    dice_null=np.zeros(shape=(5,5),dtype='float')
    for x in range(0,5):
        for y in range(0,5):
            if x==y :
                continue
            one = np.random.randint(0,3193, size=(1,30))
            two =  np.random.randint(0,3193, size=(1,30))
            test=np.intersect1d(one,two)
            dice_null[x,y]=2*(test.shape[0]/(one.shape[1]+two.shape[1]))
     
    alldice_null.append(np.mean(dice_null))
    alldice_nullstd.append(np.std(dice_null))
    allalldice_null.append(dice_null)

alldice_null2=[]
alldice_nullstd2=[]
allalldice_null2=[]
for k in range(0,100):
    # calculate the dice coefficient for randomly selected features
    dice_null2=np.zeros(shape=(5,5),dtype='float')
    for x in range(0,5):
        for y in range(0,5):
            if x==y :
                continue
            one = np.random.randint(0,3193, size=(1,15))
            two =  np.random.randint(0,3193, size=(1,15))
            test=np.intersect1d(one,two)
            dice_null2[x,y]=2*(test.shape[0]/(one.shape[1]+two.shape[1]))
     
    alldice_null2.append(np.mean(dice_null2))
    alldice_nullstd2.append(np.std(dice_null2))
    allalldice_null2.append(dice_null2)

# %%
plt.figure(figsize=(17,14))

plt.plot(countweights/500)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('Proportion of outer folds including weight (x-axis)', fontsize =20)
# Out:
# Text(0.5, 1.0, 'Proportion of outer folds including weight (x-axis)')

# %%
# convert vectorized Triu to matrix
highweights = countweights > 250

# get weights back to matrix form 86x86
# remove inputs that are 0 for all subjects
X=sc
zeros=X==0
zeros=np.sum(zeros,0) # number of zeros across subjects
zeros=zeros==X.shape[0] # find columns with zeros for all 101 subjects
tmp=np.ones(shape=(3192, 1))

zeroidx=np.arange(0, 3655)
zeroidx=zeroidx[zeros]

# fill spots with 0's
k=0
cnt = countweights
while k < zeroidx.shape[0]:
    cnt=np.insert(cnt, zeroidx[k],0)
    tmp=np.insert(tmp, zeroidx[k],0)

    k=k+1
    
plt.figure(figsize=(17,14))

fs86_counts = np.zeros((86, 86))
inds = np.triu_indices(86, k=1)
fs86_counts[inds] = cnt

plt.imshow(fs86_counts)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.colorbar()
plt.title('Number of times each SC edge was used in outer loop of cross-validation (max = 500)', fontsize = 19)
# Out:
# Text(0.5, 1.0, 'Number of times each SC edge was used in outer loop of cross-validation (max = 500)')

# %%
from nilearn import datasets
from nilearn import plotting

plt.figure(figsize=(17,14))

coordinates = plotting.find_parcellation_cut_coords('fs86_allsubj_mode.nii.gz')
plotting.plot_connectome(fs86_counts, coordinates,
                         edge_threshold=250,
                         title='Features used in > 50% of outer loops')
# Out:
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/nilearn/plotting/displays/_projectors.py:166: UserWarning: 'adjacency_matrix' is not symmetric. A directed graph will be plotted.
#   warnings.warn(("'adjacency_matrix' is not symmetric. "

# %%
plt.figure(figsize=(17,10))
plt.errorbar(range(0,100), alldice, yerr=alldicestd, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=0);

plt.ylim([0, 1])
plt.title('Dice coefficient between outer loops for each permutation (grey = +/- 1 std), \n blue = average across permutations \n red = average across null permutations (30 features, left) (15 features, right)' , fontsize=20)
plt.xlabel('Permutation', fontsize=20)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)

plt.errorbar(105, np.mean(allalldice), yerr=np.std(allalldice), fmt='o', color='blue',
             ecolor='lightblue', elinewidth=3, capsize=0);

plt.errorbar(110, np.mean(allalldice_null), yerr=np.std(allalldice_null), fmt='o', color='red',
             ecolor='pink', elinewidth=3, capsize=0);

plt.errorbar(115, np.mean(allalldice_null2), yerr=np.std(allalldice_null2), fmt='o', color='red',
             ecolor='pink', elinewidth=3, capsize=0);

# %%
# Haufe transformation of feature weights
k=5
results_dir='/home/ubuntu/cognition_iowa/results/enhanced1/'
Y = np.array(wais)

# load activation weights
with open(results_dir + 'correlation' + 'p99_SC_varimpt.pkl', 'rb') as f:
    activ = pickle.load(f)

perm=0
fullactivations=[] 
#iterate through permutations
for p in range(0,100):
    k=5
    outer_cv = StratifiedKFold(n_splits=k, shuffle=True, random_state=p)
    
    # Load features selected from permutation
    with open(results_dir + 'correlation' + 'p' + str(p) + '_SC_features.pkl', 'rb') as f:
        feats = pickle.load(f)
    
    c=0   
    activations=[]
    X=sc
    X=prepare_data(X)
    fullactivation=[]
    activationweight=[]
    for train, test in outer_cv.split(X, chronic_id):
        x_train=X[train]
        X=x_train
        X_sub=X[:,feats[c][:]]
        
        X_sub=np.reshape(X_sub, [len(train),feats[c].shape[0]])
        cov_x=np.cov(np.transpose(X_sub))
        print(feats[c].shape[0])
        
        if feats[c].shape[0]==1:
            cov_x=np.reshape(cov_x, [1,1])
        
    
        cov_y=np.cov(np.transpose(Y[train]))
    
        activationweight=activ[p][c]

        activationweight=activationweight[:,0:-1]# remove binary chronicity variable
        #print(activationweight.shape)
        weight=np.transpose(activationweight)

        activation=np.matmul(cov_x,weight)*(1/cov_y)
        activations.append(activation)
        #print(activation.shape)

        # get activation weights back to matrix form 86x86
        # get indices of weights not selected as features; set weight to 0    
        idx=np.ones(shape=(3192,1), dtype='bool')
        idx[feats[c]]=False # set SC weights that are features to be 1
        idx=idx.flatten()
        zeroidx=np.arange(0, 3192, dtype='int')
        zeroidx=zeroidx[idx]
        
        # fill spots with 0's (up to 3192)
        k=0
        activation_full = activation
        while k < zeroidx.shape[0]:
            activation_full=np.insert(activation_full, zeroidx[k],0)
            k=k+1
        
        #print("Full 3192: " + str(np.sum(activation_full>0)))
        # fill spots with 0's (up to 3655)
        X=sc
        zeros=sc==0
        zeros=np.sum(zeros,0) # number of zeros across subjects
        zeros=zeros==X.shape[0] # find columns with zeros for all 101 subjects
        X=X[:,~zeros]
        
        zeroidx=np.arange(0, 3655)
        zeroidx=zeroidx[zeros]

        # fill spots with 0's
        k=0
        a = activation_full
        while k < zeroidx.shape[0]:
            a=np.insert(a, zeroidx[k],0)
            k=k+1
        
        #print("Full 3655: " + str(np.sum(a>0)))
        fullactivation.append(a)
        c=c+1
         
    fullactivations.append(fullactivation)
# Out:
# Final size of X: (107, 3192)
# 22
# 28
# 29
# 14
# 5
# Final size of X: (107, 3192)
# 11
# 30
# 7
# 13
# 30
# Final size of X: (107, 3192)
# 21
# 30
# 19
# 16
# 2
# Final size of X: (107, 3192)
# 9
# 17
# 6
# 29
# 29
# Final size of X: (107, 3192)
# 1
# 8
# 10
# 30
# 8
# Final size of X: (107, 3192)
# 8
# 16
# 22
# 13
# 3
# Final size of X: (107, 3192)
# 18
# 25
# 26
# 3
# 9
# Final size of X: (107, 3192)
# 29
# 19
# 10
# 2
# 22
# Final size of X: (107, 3192)
# 11
# 8
# 8
# 29
# 6
# Final size of X: (107, 3192)
# 6
# 13
# 1
# 13
# 11
# Final size of X: (107, 3192)
# 28
# 30
# 5
# 13
# 27
# Final size of X: (107, 3192)
# 30
# 8
# 24
# 6
# 8
# Final size of X: (107, 3192)
# 15
# 1
# 10
# 25
# 12
# Final size of X: (107, 3192)
# 8
# 15
# 9
# 21
# 13
# Final size of X: (107, 3192)
# 26
# 7
# 4
# 27
# 28
# Final size of X: (107, 3192)
# 3
# 3
# 11
# 23
# 7
# Final size of X: (107, 3192)
# 17
# 20
# 3
# 24
# 18
# Final size of X: (107, 3192)
# 1
# 30
# 30
# 10
# 21
# Final size of X: (107, 3192)
# 23
# 10
# 1
# 1
# 14
# Final size of X: (107, 3192)
# 9
# 5
# 17
# 2
# 3
# Final size of X: (107, 3192)
# 27
# 8
# 4
# 9
# 26
# Final size of X: (107, 3192)
# 14
# 19
# 6
# 9
# 9
# Final size of X: (107, 3192)
# 11
# 16
# 4
# 24
# 6
# Final size of X: (107, 3192)
# 16
# 5
# 21
# 30
# 27
# Final size of X: (107, 3192)
# 7
# 1
# 24
# 5
# 10
# Final size of X: (107, 3192)
# 14
# 1
# 28
# 3
# 18
# Final size of X: (107, 3192)
# 9
# 26
# 30
# 4
# 29
# Final size of X: (107, 3192)
# 27
# 4
# 9
# 9
# 1
# Final size of X: (107, 3192)
# 6
# 12
# 15
# 26
# 18
# Final size of X: (107, 3192)
# 4
# 3
# 29
# 6
# 1
# Final size of X: (107, 3192)
# 11
# 28
# 7
# 1
# 30
# Final size of X: (107, 3192)
# 1
# 9
# 29
# 10
# 25
# Final size of X: (107, 3192)
# 17
# 5
# 20
# 27
# 13
# Final size of X: (107, 3192)
# 19
# 14
# 12
# 21
# 2
# Final size of X: (107, 3192)
# 5
# 30
# 15
# 25
# 29
# Final size of X: (107, 3192)
# 2
# 10
# 9
# 28
# 23
# Final size of X: (107, 3192)
# 6
# 9
# 7
# 1
# 7
# Final size of X: (107, 3192)
# 9
# 17
# 9
# 30
# 22
# Final size of X: (107, 3192)
# 28
# 14
# 9
# 3
# 11
# Final size of X: (107, 3192)
# 19
# 25
# 16
# 8
# 5
# Final size of X: (107, 3192)
# 13
# 10
# 1
# 29
# 6
# Final size of X: (107, 3192)
# 25
# 10
# 9
# 7
# 9
# Final size of X: (107, 3192)
# 29
# 10
# 18
# 3
# 5
# Final size of X: (107, 3192)
# 2
# 30
# 5
# 30
# 10
# Final size of X: (107, 3192)
# 13
# 7
# 6
# 19
# 16
# Final size of X: (107, 3192)
# 14
# 20
# 1
# 30
# 14
# Final size of X: (107, 3192)
# 27
# 29
# 16
# 13
# 2
# Final size of X: (107, 3192)
# 15
# 3
# 17
# 12
# 10
# Final size of X: (107, 3192)
# 16
# 29
# 13
# 30
# 2
# Final size of X: (107, 3192)
# 10
# 12
# 30
# 18
# 16
# Final size of X: (107, 3192)
# 24
# 27
# 1
# 24
# 10
# Final size of X: (107, 3192)
# 21
# 10
# 20
# 14
# 25
# Final size of X: (107, 3192)
# 15
# 5
# 29
# 12
# 30
# Final size of X: (107, 3192)
# 23
# 13
# 8
# 28
# 10
# Final size of X: (107, 3192)
# 8
# 15
# 13
# 22
# 5
# Final size of X: (107, 3192)
# 15
# 17
# 11
# 1
# 7
# Final size of X: (107, 3192)
# 11
# 7
# 9
# 29
# 18
# Final size of X: (107, 3192)
# 9
# 29
# 16
# 2
# 8
# Final size of X: (107, 3192)
# 20
# 16
# 4
# 21
# 4
# Final size of X: (107, 3192)
# 3
# 2
# 9
# 15
# 8
# Final size of X: (107, 3192)
# 12
# 21
# 7
# 24
# 4
# Final size of X: (107, 3192)
# 1
# 3
# 27
# 11
# 24
# Final size of X: (107, 3192)
# 30
# 5
# 6
# 28
# 10
# Final size of X: (107, 3192)
# 25
# 5
# 5
# 2
# 18
# Final size of X: (107, 3192)
# 2
# 5
# 18
# 9
# 16
# Final size of X: (107, 3192)
# 4
# 28
# 7
# 7
# 13
# Final size of X: (107, 3192)
# 2
# 1
# 7
# 18
# 15
# Final size of X: (107, 3192)
# 7
# 30
# 16
# 12
# 16
# Final size of X: (107, 3192)
# 26
# 29
# 5
# 8
# 30
# Final size of X: (107, 3192)
# 8
# 29
# 7
# 23
# 11
# Final size of X: (107, 3192)
# 30
# 7
# 14
# 26
# 2
# Final size of X: (107, 3192)
# 4
# 19
# 6
# 27
# 6
# Final size of X: (107, 3192)
# 26
# 17
# 16
# 5
# 12
# Final size of X: (107, 3192)
# 15
# 5
# 30
# 11
# 30
# Final size of X: (107, 3192)
# 22
# 10
# 15
# 21
# 29
# Final size of X: (107, 3192)
# 8
# 2
# 18
# 19
# 11
# Final size of X: (107, 3192)
# 25
# 25
# 17
# 8
# 10
# Final size of X: (107, 3192)
# 26
# 1
# 12
# 22
# 30
# Final size of X: (107, 3192)
# 12
# 13
# 4
# 12
# 25
# Final size of X: (107, 3192)
# 30
# 3
# 30
# 13
# 9
# Final size of X: (107, 3192)
# 8
# 29
# 23
# 1
# 11
# Final size of X: (107, 3192)
# 11
# 1
# 10
# 30
# 28
# Final size of X: (107, 3192)
# 5
# 1
# 21
# 27
# 30
# Final size of X: (107, 3192)
# 14
# 16
# 3
# 13
# 9
# Final size of X: (107, 3192)
# 29
# 9
# 9
# 4
# 19
# Final size of X: (107, 3192)
# 23
# 24
# 25
# 11
# 21
# Final size of X: (107, 3192)
# 13
# 26
# 29
# 6
# 6
# Final size of X: (107, 3192)
# 5
# 24
# 30
# 30
# 28
# Final size of X: (107, 3192)
# 14
# 4
# 30
# 15
# 17
# Final size of X: (107, 3192)
# 28
# 20
# 7
# 5
# 9
# Final size of X: (107, 3192)
# 30
# 2
# 30
# 5
# 15
# Final size of X: (107, 3192)
# 6
# 10
# 10
# 9
# 30
# Final size of X: (107, 3192)
# 10
# 11
# 30
# 29
# 30
# Final size of X: (107, 3192)
# 20
# 10
# 10
# 28
# 1
# Final size of X: (107, 3192)
# 29
# 15
# 5
# 21
# 9
# Final size of X: (107, 3192)
# 8
# 25
# 10
# 15
# 19
# Final size of X: (107, 3192)
# 8
# 7
# 12
# 6
# 3
# Final size of X: (107, 3192)
# 6
# 24
# 20
# 23
# 3
# Final size of X: (107, 3192)
# 29
# 26
# 24
# 9
# 15
# Final size of X: (107, 3192)
# 13
# 16
# 22
# 30
# 7

# %%
countweights=np.zeros(shape=(3655, ), dtype='int')

for p in range(0,100):
    act=fullactivations[p] # features 
    for x in range(0,5):
        #print(act[x].shape)
        countweights=countweights+act[x]

# %%
plt.figure(figsize=(17,14))

plt.plot(countweights)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title('Sum of activations per feature across all folds', fontsize =20)
# Out:
# Text(0.5, 1.0, 'Sum of activations per feature across all folds')

# %%
# convert vectorized Triu to matrix
highweights = countweights

plt.figure(figsize=(17,14))

fs86_counts = np.zeros((86, 86))
inds = np.triu_indices(86, k=1)
fs86_counts[inds] = highweights

plt.imshow(fs86_counts)
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.colorbar()
plt.title('Number of times each SC edge was used in outer loop of cross-validation (max = 500)', fontsize = 19)
# Out:
# Text(0.5, 1.0, 'Number of times each SC edge was used in outer loop of cross-validation (max = 500)')

# %%
from nilearn import datasets
from nilearn import plotting

plt.figure(figsize=(17,14))

coordinates = plotting.find_parcellation_cut_coords('fs86_allsubj_mode.nii.gz')
plotting.plot_connectome(fs86_counts, coordinates,
                         title='Activations',edge_cmap='ocean_hot',colorbar=True)
# Out:
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/nilearn/plotting/displays/_projectors.py:166: UserWarning: 'adjacency_matrix' is not symmetric. A directed graph will be plotted.
#   warnings.warn(("'adjacency_matrix' is not symmetric. "

# %%
results_dir
# Out:
# '/home/ubuntu/cognition_iowa/results/enhanced1/'

# %%
np.savetxt(results_dir +'fs86_activ_weights.txt', fs86_counts, delimiter=',')

# %%
Y_og=np.array(wais)
Y_og=np.reshape(Y_og, (107,1))

# %%
# Null models - shuffle cognitive scores
# permute the cognitive scores before splitting into train-test

# predictions for SC-  PCA and correlation

import datetime

# feature selection type
f=['correlation']

for featselect in f: 
    #set the number of folds you want in the inner and outer folds of the nested cross-validation
    k = 5

    #set the proportion of data you want in your training set
    train_size = .8

    #X=np.concatenate([sc, fc], axis=1)
    X=sc
    X=prepare_data(X)
    #set y to be the measure you want to predict
    #Y = np.log(np.array(tmt))

    Y_og=np.array(wais)
    Y_og=np.reshape(Y_og, (107,1))
    

    # range of alphas
    n_alphas=20
    alpha_start=-1
    alpha_end=2
    alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

    #number of features (# pricipal components or variables to retain)
    feat_start=1
    feat_end=30
    n_feats=feat_end-feat_start+1
    feats = np.linspace(feat_start, feat_end, n_feats, dtype=int)

    # initialize lists to store model results for each permuation
    allR2=[]
    meanR2=[]
    features=[]
    bestalphas=[]
    importance=[]
    allexpl_var=[]
    correlations=[]
    chronic_allexpl_var=[]
    #joblib-based parallelism to increase speed,

    for p in range(0, 100):
        Y_og_chronic=Y_og[chronic_id]
        Y_og_acute=Y_og[acute_id]

        # permute chronic and acute separately
        Y_og_chronic_perm=np.random.permutation(Y_og_chronic)
        Y_og_acute_perm=np.random.permutation(Y_og_acute)

        Y_perm=np.zeros(shape=(107,1))
        # put chronic and acute back where they. belond
        Y_perm[chronic_id]=Y_og_chronic_perm
        Y_perm[acute_id]=Y_og_acute_perm
        
        Y=np.concatenate((Y_og_acute_perm, Y_og_chronic_perm))

        outer_cv = StratifiedKFold(n_splits=k, shuffle=True, random_state=p)
        print('Permutation: ' + str(p))
        # initialize lists to store model results for eah fold
        R2=[]
        featur=[]
        best_alphas=[]
        impt=[] 
        expl_var=[]
        chronic_explvar=[]
        cor=[]
        for train, test in outer_cv.split(X, chronic_id):
            begin_time = datetime.datetime.now()
            
            chronic_bin=chronic_id[train]
            chronic_test=chronic_id[test]
            
            # select model using training data
            bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv_strat(k, X[train], Y[train], chronic_bin, featselect, alphas, feats)

            # using optimal num. of features, select final features using entire training data.

            if featselect=='correlation':
                x_train_featselect,x_test_featureselect,ind = feature_select_correlation(X[train],X[test], Y[train], bestfeats)
                featur.append(ind)

            elif featselect=='PCA':
                x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(X[train],X[test], bestfeats)
                featur.append(ind)
                
            
            chronic_bin=np.reshape(np.double(chronic_bin), (x_train_featselect.shape[0], 1))
            x_train_featselect=np.concatenate((x_train_featselect, chronic_bin),axis=1)
        
            chronic_test=np.reshape(np.double(chronic_test), (x_test_featureselect.shape[0], 1))
            x_test_featureselect=np.concatenate((x_test_featureselect, chronic_test),axis=1)
                
            # initialize Ridge regression with alpha selected from hyperparameter search
            regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)

            # fit model 
            y_pred = regr.fit(x_train_featselect, Y[train]).predict(x_test_featureselect)

            # store results for each fold k
            impt.append(regr.coef_)
            R2.append(r2_score(Y[test], y_pred))
            expl_var.append(explained_variance_score(Y[test], y_pred))

            best_alphas.append(bestalpha)
            print('time to run loop: ' + str(datetime.datetime.now() - begin_time)) 
            print("R2 loop: " + str(r2_score(Y[test], y_pred)))
            print("Explained var: " + str(explained_variance_score(Y[test], y_pred)))
            print("correlation: " + str(np_pearson_cor(Y[test], y_pred)))
            
            chronicsubs_test=chronic_id[test]==True
            chronicsubs_train=chronic_id[train]==True
            chronicsubs_test=chronicsubs_test.flatten()
            chronicsubs_train=chronicsubs_train.flatten()
            cor.append(np_pearson_cor(Y[test], y_pred))
            Xtest=x_test_featureselect
            Xtrain=X[train]
            Ytest=Y[test]

            ytrue_chronic = Ytest[chronicsubs_test]
            xtest_chronic=Xtest[chronicsubs_test]
     
            ychronic_pred = regr.fit(x_train_featselect, Y[train]).predict(xtest_chronic)
            print("Explained variance, chronic only:  " + str(explained_variance_score(ytrue_chronic, ychronic_pred)))
            chronic_explvar.append(explained_variance_score(ytrue_chronic, ychronic_pred))
            
        # store results for each permutation p

        allexpl_var.append(expl_var)
        bestalphas.append(best_alphas)
        importance.append(impt)
        chronic_allexpl_var.append(chronic_explvar)
        correlations.append(cor)
        print("---- Permutation avg. chronic explained variance: " + str(np.mean(chronic_explvar)) + "----")
        np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_chronic_all_explvar_null.txt', chronic_allexpl_var, delimiter=',')

        print("---- Permutation avg. explained variance: " + str(np.mean(expl_var)) + "----")
        np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_all_explvar_null.txt', expl_var, delimiter=',')
# Out:
# Final size of X: (107, 3192)
# Permutation: 0
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:05.963470
# R2 loop: -0.08342188195479916
# Explained var: 0.0010654022476006553
# correlation: [[0.19299453]]
# Explained variance, chronic only:  0.0010798232322749568
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.763921
# R2 loop: -0.0450739728476135
# Explained var: -0.016262645932574094
# correlation: [[-0.15114692]]
# Explained variance, chronic only:  -0.011397071127254854
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.954408
# R2 loop: -0.026267985407570693
# Explained var: -0.02325364516363626
# correlation: [[0.1266387]]
# Explained variance, chronic only:  -0.027465353986188212
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.948075
# R2 loop: -0.017021694059347503
# Explained var: -0.014028174566877327
# correlation: [[-0.40823186]]
# Explained variance, chronic only:  -0.0009620912480348132
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.737130
# R2 loop: -0.004576598587768155
# Explained var: 0.0008236689095353356
# correlation: [[0.26187301]]
# Explained variance, chronic only:  0.0009006204156739583
# ---- Permutation avg. chronic explained variance: -0.007568814542705793----
# ---- Permutation avg. explained variance: -0.010331078901190338----
# Permutation: 1
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.781709
# R2 loop: -0.07325277813196251
# Explained var: -0.05671580820559763
# correlation: [[-0.14710423]]
# Explained variance, chronic only:  -0.07888211173956572
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.929972
# R2 loop: -0.14971481491365202
# Explained var: -0.0011377912568066861
# correlation: [[-0.26459365]]
# Explained variance, chronic only:  -0.0014878575056336274
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.899913
# R2 loop: -0.013820763615507659
# Explained var: -0.0023511385857624134
# correlation: [[-0.34823857]]
# Explained variance, chronic only:  0.00012645720514514736
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.844877
# R2 loop: -0.041594191209284315
# Explained var: -0.004385104371049664
# correlation: [[-0.40141733]]
# Explained variance, chronic only:  -0.0033311945752314553
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.792006
# R2 loop: -0.05776310073083346
# Explained var: -0.0019589074710850696
# correlation: [[-0.33281721]]
# Explained variance, chronic only:  -0.0014380837067169416
# ---- Permutation avg. chronic explained variance: -0.01700255806440052----
# ---- Permutation avg. explained variance: -0.013309749978060292----
# Permutation: 2
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.794574
# R2 loop: -0.058476784994923925
# Explained var: -0.053174500049989915
# correlation: [[-0.23679125]]
# Explained variance, chronic only:  -0.018087413365816207
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.729744
# R2 loop: -0.6667584835030771
# Explained var: -0.43331637837522274
# correlation: [[0.02858031]]
# Explained variance, chronic only:  -0.3004206543226251
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.814187
# R2 loop: -0.008764289243587298
# Explained var: 0.004583644706492196
# correlation: [[0.1238389]]
# Explained variance, chronic only:  -0.007404057725514113
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.875860
# R2 loop: -0.30683160933251497
# Explained var: -0.0654034681139668
# correlation: [[-0.05658993]]
# Explained variance, chronic only:  -0.0824474649834519
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.950264
# R2 loop: -0.005220817231613495
# Explained var: 0.0010984179482644851
# correlation: [[0.21604019]]
# Explained variance, chronic only:  0.0014316739996353967
# ---- Permutation avg. chronic explained variance: -0.08138558327955439----
# ---- Permutation avg. explained variance: -0.10924245677688456----
# Permutation: 3
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.687439
# R2 loop: -0.03928424568588329
# Explained var: 0.0025747238234858916
# correlation: [[0.1823242]]
# Explained variance, chronic only:  -0.004097019485162834
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.635416
# R2 loop: -0.1868204351550511
# Explained var: -0.08304853944633961
# correlation: [[-0.21896616]]
# Explained variance, chronic only:  -0.10140082289893115
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.964172
# R2 loop: -0.23672717487975437
# Explained var: -0.21856909821983428
# correlation: [[-0.36746985]]
# Explained variance, chronic only:  -0.20391269776180265
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.962486
# R2 loop: -0.00223401708405091
# Explained var: 0.001263698925499157
# correlation: [[0.16303952]]
# Explained variance, chronic only:  0.0013669574353866176
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.639662
# R2 loop: -0.11221427417386787
# Explained var: 7.317249832528017e-05
# correlation: [[0.0127937]]
# Explained variance, chronic only:  0.00033488510371659785
# ---- Permutation avg. chronic explained variance: -0.061541739521358683----
# ---- Permutation avg. explained variance: -0.059541208483772715----
# Permutation: 4
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.917134
# R2 loop: -0.24630284870381391
# Explained var: -0.2007036014078598
# correlation: [[0.08233348]]
# Explained variance, chronic only:  -0.07138678951046451
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.862535
# R2 loop: 0.01950952657098426
# Explained var: 0.021840786752392316
# correlation: [[0.15129727]]
# Explained variance, chronic only:  0.016762790836575614
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.965051
# R2 loop: -0.027963073972048003
# Explained var: -0.002704598735799868
# correlation: [[-0.25400544]]
# Explained variance, chronic only:  -1.4064947389869076e-05
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.936559
# R2 loop: -0.005955554048997502
# Explained var: 0.001567670956483913
# correlation: [[0.18583813]]
# Explained variance, chronic only:  0.0022212578034629393
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:05.027573
# R2 loop: -0.10476891996863413
# Explained var: -0.0053923425899438104
# correlation: [[-0.04805331]]
# Explained variance, chronic only:  -0.002782183474014044
# ---- Permutation avg. chronic explained variance: -0.011039797858365974----
# ---- Permutation avg. explained variance: -0.03707841700494545----
# Permutation: 5
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.873497
# R2 loop: 0.04323584893942445
# Explained var: 0.05201370108890824
# correlation: [[0.34954609]]
# Explained variance, chronic only:  0.004067693460518607
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.898427
# R2 loop: 0.006472546104166144
# Explained var: 0.10244966791256493
# correlation: [[0.56820484]]
# Explained variance, chronic only:  0.11372498872683878
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-7803d83fc20e>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:04.849235
# R2 loop: -6.616736890693463
# Explained var: -5.992304713360763
# correlation: [[0.12829079]]
# Explained variance, chronic only:  -7.536745567972595
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.984208
# R2 loop: -0.08426192168351365
# Explained var: -0.010252447229227135
# correlation: [[-0.10559418]]
# Explained variance, chronic only:  -0.010560100961813701
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.857032
# R2 loop: -0.01133712372363549
# Explained var: -0.009881287903630298
# correlation: [[0.08547321]]
# Explained variance, chronic only:  -0.028908072149277375
# ---- Permutation avg. chronic explained variance: -1.491684211779266----
# ---- Permutation avg. explained variance: -1.1715950158984296----
# Permutation: 6
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:05.018968
# R2 loop: -0.06703281384652571
# Explained var: 0.0057401607669316235
# correlation: [[0.12423167]]
# Explained variance, chronic only:  0.008881593374168162
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.918840
# R2 loop: -0.12260795960163406
# Explained var: -0.11864115275290454
# correlation: [[-0.42848663]]
# Explained variance, chronic only:  -0.1473302247000332
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.812061
# R2 loop: -0.44478447658594233
# Explained var: -0.09504279880852984
# correlation: [[0.10923046]]
# Explained variance, chronic only:  -0.07830791210766264
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.770141
# R2 loop: -0.5808343300948464
# Explained var: -0.010475550946908108
# correlation: [[0.04990328]]
# Explained variance, chronic only:  0.03550045422400039
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.946960
# R2 loop: 0.005668565683711102
# Explained var: 0.020956660081483225
# correlation: [[0.15145516]]
# Explained variance, chronic only:  0.03252047367669764
# ---- Permutation avg. chronic explained variance: -0.02974712310656593----
# ---- Permutation avg. explained variance: -0.03949253633198553----
# Permutation: 7
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.694628
# R2 loop: -0.12150974953085258
# Explained var: -0.04239821055329385
# correlation: [[-0.11809175]]
# Explained variance, chronic only:  -0.045132017769524246
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.761341
# R2 loop: -0.003648053914494964
# Explained var: 0.001501934913520131
# correlation: [[0.04405259]]
# Explained variance, chronic only:  0.0014586009373426245
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.861641
# R2 loop: -0.18398645954923443
# Explained var: -0.03613547467099343
# correlation: [[-0.29933463]]
# Explained variance, chronic only:  -0.03796778560028358
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.888579
# R2 loop: -0.04138421903005152
# Explained var: -0.01766562878239908
# correlation: [[0.00744851]]
# Explained variance, chronic only:  -0.06700897163711694
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.777580
# R2 loop: -0.011032381769751742
# Explained var: -0.010135624748777383
# correlation: [[-0.02354831]]
# Explained variance, chronic only:  -0.006029547929857548
# ---- Permutation avg. chronic explained variance: -0.03093594439988794----
# ---- Permutation avg. explained variance: -0.020966600768388723----
# Permutation: 8
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.684091
# R2 loop: -0.20125129047362655
# Explained var: -0.0007296942060726064
# correlation: [[-0.07712932]]
# Explained variance, chronic only:  -3.586521823240041e-05
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.790999
# R2 loop: -0.31079249899846295
# Explained var: -0.13059272122637933
# correlation: [[0.10670896]]
# Explained variance, chronic only:  -0.20807914025037944
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.873171
# R2 loop: -0.04711545518876625
# Explained var: -0.026402308618201697
# correlation: [[-0.40843045]]
# Explained variance, chronic only:  -0.04816633271538606
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.939929
# R2 loop: -0.018625840750180034
# Explained var: -0.001328207664434311
# correlation: [[-0.15952553]]
# Explained variance, chronic only:  -0.002179324713976749
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.958668
# R2 loop: -0.02084909607884433
# Explained var: -0.019671774828718513
# correlation: [[-0.04418353]]
# Explained variance, chronic only:  -0.025120013438601374
# ---- Permutation avg. chronic explained variance: -0.056716135267315206----
# ---- Permutation avg. explained variance: -0.03574494130876129----
# Permutation: 9
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:05.019405
# R2 loop: -0.065820326331955
# Explained var: 0.003361697793489493
# correlation: [[0.33660991]]
# Explained variance, chronic only:  0.004292545504264944
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.685145
# R2 loop: -0.011816465351884409
# Explained var: -0.010159595096399743
# correlation: [[-0.06986726]]
# Explained variance, chronic only:  -0.013460007390529105
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.924412
# R2 loop: -0.25248021012670474
# Explained var: -0.04742070433786849
# correlation: [[-0.17198712]]
# Explained variance, chronic only:  -0.09273331596579482
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.743948
# R2 loop: -0.9227944545890572
# Explained var: 0.001977271338387654
# correlation: [[0.28761624]]
# Explained variance, chronic only:  0.001964553027816951
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.860160
# R2 loop: -0.060452484971356135
# Explained var: 0.002369069678452518
# correlation: [[0.45131838]]
# Explained variance, chronic only:  0.0026470547540049516
# ---- Permutation avg. chronic explained variance: -0.019457834014047416----
# ---- Permutation avg. explained variance: -0.009974452124787713----
# Permutation: 10
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.915860
# R2 loop: -0.03238855311427913
# Explained var: -0.021900745811988864
# correlation: [[-0.09429793]]
# Explained variance, chronic only:  -0.014413524005393308
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.795781
# R2 loop: 0.059317593912655675
# Explained var: 0.05948349700718247
# correlation: [[0.28245186]]
# Explained variance, chronic only:  0.052301284243233215
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.963117
# R2 loop: -0.015749885671872965
# Explained var: -0.01550238581351504
# correlation: [[0.01663798]]
# Explained variance, chronic only:  -0.06081281237818814
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.679114
# R2 loop: -0.045457913880442735
# Explained var: -0.01503087669518366
# correlation: [[-0.21322631]]
# Explained variance, chronic only:  -0.029667231819738404
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.692687
# R2 loop: -0.019744093073861935
# Explained var: 0.0856975285746231
# correlation: [[0.3756601]]
# Explained variance, chronic only:  0.07775581689874822
# ---- Permutation avg. chronic explained variance: 0.0050327065877323164----
# ---- Permutation avg. explained variance: 0.0185494034522236----
# Permutation: 11
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.771764
# R2 loop: -0.03448470618550581
# Explained var: -0.028630352054019204
# correlation: [[-0.06186325]]
# Explained variance, chronic only:  0.017210610501565582
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.964494
# R2 loop: -0.029304150005282192
# Explained var: -0.00040555028790478787
# correlation: [[-0.1756977]]
# Explained variance, chronic only:  2.8684845183590824e-06
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.743699
# R2 loop: -0.11850889469080284
# Explained var: -0.01641289216961539
# correlation: [[-0.31917816]]
# Explained variance, chronic only:  -0.022653078126721127
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.602793
# R2 loop: -0.014329549894612326
# Explained var: 0.00017952116926001072
# correlation: [[0.04710662]]
# Explained variance, chronic only:  0.0004613129857831133
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.857129
# R2 loop: -0.03820786337984616
# Explained var: -0.0005763724501683942
# correlation: [[-0.09450186]]
# Explained variance, chronic only:  -0.0005992586631347052
# ---- Permutation avg. chronic explained variance: -0.0011155089635977555----
# ---- Permutation avg. explained variance: -0.009169129158489553----
# Permutation: 12
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.621204
# R2 loop: -0.11944301901020493
# Explained var: -0.1053613447189159
# correlation: [[0.10381344]]
# Explained variance, chronic only:  -0.08871889356036622
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.856658
# R2 loop: -0.12027613188517572
# Explained var: 0.008530977540665896
# correlation: [[0.09396451]]
# Explained variance, chronic only:  0.003614919281367812
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.562574
# R2 loop: -0.1901201896398661
# Explained var: -0.036539905364777026
# correlation: [[0.07489315]]
# Explained variance, chronic only:  0.04992653448273254
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.590853
# R2 loop: -0.04147705996957862
# Explained var: 0.09132871017473754
# correlation: [[0.30328612]]
# Explained variance, chronic only:  0.2638358293130244
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.680856
# R2 loop: -0.24222320350658633
# Explained var: -0.15774364530831297
# correlation: [[0.05368345]]
# Explained variance, chronic only:  -0.05159985349227614
# ---- Permutation avg. chronic explained variance: 0.03541170720489648----
# ---- Permutation avg. explained variance: -0.039957041535320495----
# Permutation: 13
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.723406
# R2 loop: -0.09184946039014164
# Explained var: 0.005418690021630201
# correlation: [[0.45169499]]
# Explained variance, chronic only:  -4.559297721251632e-05
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.809485
# R2 loop: -0.020127620740965746
# Explained var: 0.006000127800742772
# correlation: [[0.32992384]]
# Explained variance, chronic only:  0.0023523700584604512
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.853251
# R2 loop: -0.09454881054266395
# Explained var: -0.08810517713859833
# correlation: [[-0.1206544]]
# Explained variance, chronic only:  -0.049046277667945004
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.794239
# R2 loop: -0.44221451158060043
# Explained var: -0.1620586508927917
# correlation: [[-0.05056804]]
# Explained variance, chronic only:  -0.19579779642042938
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.915091
# R2 loop: -0.020203093465963606
# Explained var: -0.003708425799167747
# correlation: [[0.0014334]]
# Explained variance, chronic only:  -0.03634435692636795
# ---- Permutation avg. chronic explained variance: -0.05577633078669888----
# ---- Permutation avg. explained variance: -0.04849068720163696----
# Permutation: 14
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.804563
# R2 loop: -0.05400231780284681
# Explained var: -0.031225930285379455
# correlation: [[-0.16945937]]
# Explained variance, chronic only:  0.016841173818689437
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.762203
# R2 loop: -0.13687432447334702
# Explained var: -0.02418097333903968
# correlation: [[-0.07920605]]
# Explained variance, chronic only:  -0.07979110202552664
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.860253
# R2 loop: -0.4093811393215874
# Explained var: -0.0008834605286596187
# correlation: [[-0.09294904]]
# Explained variance, chronic only:  -0.003844432908573836
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.775818
# R2 loop: -0.05426386565260244
# Explained var: -0.007391014546133334
# correlation: [[-0.32902887]]
# Explained variance, chronic only:  -0.008568460214885443
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.893352
# R2 loop: -0.03629767627535241
# Explained var: -0.02195461170951063
# correlation: [[-0.00865959]]
# Explained variance, chronic only:  -0.0813038888738975
# ---- Permutation avg. chronic explained variance: -0.0313333420408388----
# ---- Permutation avg. explained variance: -0.017127198081744545----
# Permutation: 15
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.734178
# R2 loop: 0.023540876174056646
# Explained var: 0.03163572053942687
# correlation: [[0.20737548]]
# Explained variance, chronic only:  0.028423587081902846
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.821650
# R2 loop: -0.06232917531159865
# Explained var: 0.0014442427626277787
# correlation: [[0.18473637]]
# Explained variance, chronic only:  0.0009201261374334191
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.834818
# R2 loop: -0.20916376358363786
# Explained var: 0.003429203962053151
# correlation: [[0.46911175]]
# Explained variance, chronic only:  0.0030039177406552264
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.761191
# R2 loop: -0.2663151509474302
# Explained var: 0.02717253849237289
# correlation: [[0.16490281]]
# Explained variance, chronic only:  -0.00895848984726988
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.767338
# R2 loop: -0.1015979611264568
# Explained var: -0.04282118934743129
# correlation: [[-0.28403245]]
# Explained variance, chronic only:  -0.038888929913007964
# ---- Permutation avg. chronic explained variance: -0.00309995776005727----
# ---- Permutation avg. explained variance: 0.00417210328180988----
# Permutation: 16
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.939638
# R2 loop: -0.0562617598562436
# Explained var: -0.013175181821299509
# correlation: [[-0.06459375]]
# Explained variance, chronic only:  0.002012057353110386
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.894535
# R2 loop: -0.019499085620690915
# Explained var: -0.01557268474641793
# correlation: [[0.02169628]]
# Explained variance, chronic only:  -0.02528223350014902
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.879835
# R2 loop: -0.06474233915198169
# Explained var: -0.0006436702942738126
# correlation: [[0.04600194]]
# Explained variance, chronic only:  0.030132705001424287
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:05.019135
# R2 loop: -0.03562481987636157
# Explained var: -0.01431275235202567
# correlation: [[-0.00165587]]
# Explained variance, chronic only:  0.017905421806573174
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.809772
# R2 loop: -0.015389557325290015
# Explained var: -0.005563062064091406
# correlation: [[0.00461855]]
# Explained variance, chronic only:  -0.03298940360374347
# ---- Permutation avg. chronic explained variance: -0.0016442905885569292----
# ---- Permutation avg. explained variance: -0.009853470255621666----
# Permutation: 17
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.808906
# R2 loop: -2.4044129239186027
# Explained var: -2.376052519326109
# correlation: [[-0.18770026]]
# Explained variance, chronic only:  -3.0384533634123185
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.781849
# R2 loop: -0.10711695484465067
# Explained var: -0.0707902383288872
# correlation: [[-0.39480069]]
# Explained variance, chronic only:  0.12150966177723754
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.784960
# R2 loop: -0.00995046007454814
# Explained var: -0.003947178174411814
# correlation: [[-0.09689734]]
# Explained variance, chronic only:  -0.0028559106390628752
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.925309
# R2 loop: -0.41394022803494757
# Explained var: 7.708120772320637e-05
# correlation: [[0.01006256]]
# Explained variance, chronic only:  -0.0005423414719700759
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.684915
# R2 loop: -0.0014688977333658926
# Explained var: 1.2360813780976088e-05
# correlation: [[0.0425665]]
# Explained variance, chronic only:  5.6345087300235797e-05
# ---- Permutation avg. chronic explained variance: -0.5840571217317627----
# ---- Permutation avg. explained variance: -0.49014009876158066----
# Permutation: 18
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.866768
# R2 loop: -0.028327205798281074
# Explained var: -6.898246409825504e-05
# correlation: [[-0.01719255]]
# Explained variance, chronic only:  0.0004929941309983477
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.817771
# R2 loop: -0.03267800293134049
# Explained var: -0.004430193162079377
# correlation: [[-0.17924074]]
# Explained variance, chronic only:  4.0530217491729914e-05
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.832283
# R2 loop: -0.06969312533238292
# Explained var: 0.0005255736934566269
# correlation: [[0.15307765]]
# Explained variance, chronic only:  0.00036450210411131945
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.909483
# R2 loop: -0.00463282043449964
# Explained var: -0.002822488271245982
# correlation: [[-0.34150264]]
# Explained variance, chronic only:  -0.002393979889025566
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.868230
# R2 loop: -0.015584384834148368
# Explained var: -0.0009544838142492296
# correlation: [[-0.44052679]]
# Explained variance, chronic only:  -0.0005011833177641645
# ---- Permutation avg. chronic explained variance: -0.0003994273508376667----
# ---- Permutation avg. explained variance: -0.0015501148036432433----
# Permutation: 19
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.872163
# R2 loop: -0.01835328107747891
# Explained var: -0.013932855811516598
# correlation: [[-0.45082901]]
# Explained variance, chronic only:  0.00010306416100069882
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.619642
# R2 loop: 0.04625723012515792
# Explained var: 0.04863870217409594
# correlation: [[0.22546879]]
# Explained variance, chronic only:  0.028336155415494058
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.943737
# R2 loop: -0.12289464232331215
# Explained var: -0.022795414871142228
# correlation: [[0.01758266]]
# Explained variance, chronic only:  -0.02491582228321154
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.593099
# R2 loop: -0.11948862880430466
# Explained var: -0.0988348380795554
# correlation: [[-0.15354271]]
# Explained variance, chronic only:  -0.16664680947067634
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:05.005611
# R2 loop: 0.060534229739145906
# Explained var: 0.06120107313633327
# correlation: [[0.47617478]]
# Explained variance, chronic only:  0.06330132646838305
# ---- Permutation avg. chronic explained variance: -0.019964417141802016----
# ---- Permutation avg. explained variance: -0.0051446666903570025----
# Permutation: 20
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.936164
# R2 loop: -0.0012378571677562622
# Explained var: 4.701320282085586e-05
# correlation: [[0.01229539]]
# Explained variance, chronic only:  -4.67652436557664e-05
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.841037
# R2 loop: -0.1406759470819412
# Explained var: 0.0005145174026610633
# correlation: [[0.27598442]]
# Explained variance, chronic only:  -4.6879106779584845e-05
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.964473
# R2 loop: -0.09656533934293132
# Explained var: 0.0006334661640194916
# correlation: [[0.3173772]]
# Explained variance, chronic only:  0.0005051446467613241
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.893919
# R2 loop: -0.058547167793568944
# Explained var: -0.033892130910345264
# correlation: [[-0.45783784]]
# Explained variance, chronic only:  -0.034721727708566075
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.704404
# R2 loop: -0.011482429700262253
# Explained var: 0.001245687453573896
# correlation: [[0.17505119]]
# Explained variance, chronic only:  0.0012308135106462448
# ---- Permutation avg. chronic explained variance: -0.006615882780318771----
# ---- Permutation avg. explained variance: -0.006290289337453991----
# Permutation: 21
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.952296
# R2 loop: -0.011485294271078361
# Explained var: -0.00045690665201414404
# correlation: [[-0.09269005]]
# Explained variance, chronic only:  -0.0009193518517394139
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.929454
# R2 loop: 0.005957357083748227
# Explained var: 0.006099576486112146
# correlation: [[0.07831618]]
# Explained variance, chronic only:  0.0024605339664534043
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.775494
# R2 loop: -0.013464621272688104
# Explained var: 0.0003264798747494302
# correlation: [[0.09161235]]
# Explained variance, chronic only:  0.0003235257228910715
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.662372
# R2 loop: -22.09509120877138
# Explained var: -20.27148117682415
# correlation: [[0.04722258]]
# Explained variance, chronic only:  -20.773717080303797
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.812461
# R2 loop: -0.0011808435812876716
# Explained var: -0.0011751336948129243
# correlation: [[-0.13212029]]
# Explained variance, chronic only:  0.0009109781599608846
# ---- Permutation avg. chronic explained variance: -4.1541882788612465----
# ---- Permutation avg. explained variance: -4.053337432162023----
# Permutation: 22
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.770407
# R2 loop: -0.038308539041226775
# Explained var: -0.02696224571582695
# correlation: [[-0.04163575]]
# Explained variance, chronic only:  -0.038905528522440225
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.876656
# R2 loop: -0.024551185157261735
# Explained var: 0.0031216216215290693
# correlation: [[0.13635795]]
# Explained variance, chronic only:  0.0076180132295191605
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.918577
# R2 loop: -0.009881560160976077
# Explained var: 0.0002273197347256728
# correlation: [[0.47864963]]
# Explained variance, chronic only:  0.00033683589483402
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.948058
# R2 loop: -0.0008747756672722318
# Explained var: -0.0005346030946724589
# correlation: [[-0.00639531]]
# Explained variance, chronic only:  -0.001334865816340125
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.934558
# R2 loop: -0.016829171764757733
# Explained var: 0.00590100655061665
# correlation: [[0.0776361]]
# Explained variance, chronic only:  -0.0002921860330353798
# ---- Permutation avg. chronic explained variance: -0.00651554624949251----
# ---- Permutation avg. explained variance: -0.003649380180725603----
# Permutation: 23
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.831647
# R2 loop: -0.013213419718237196
# Explained var: 0.0007824746737908894
# correlation: [[0.1763106]]
# Explained variance, chronic only:  0.0009678780648890717
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.688029
# R2 loop: -0.1333979965990022
# Explained var: -0.0008597567443831
# correlation: [[-0.12517797]]
# Explained variance, chronic only:  -0.0017407393167729879
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.877062
# R2 loop: -0.04181972333541628
# Explained var: -0.02406493556043232
# correlation: [[-0.22759092]]
# Explained variance, chronic only:  -0.03920894493554439
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.901447
# R2 loop: -0.06485019803968939
# Explained var: -0.00022197286411018702
# correlation: [[-0.0108258]]
# Explained variance, chronic only:  0.0004449303824035633
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.933402
# R2 loop: -0.00783786433172784
# Explained var: 0.00010236614015035617
# correlation: [[0.03223821]]
# Explained variance, chronic only:  0.000938807130874908
# ---- Permutation avg. chronic explained variance: -0.007719613734829966----
# ---- Permutation avg. explained variance: -0.004852364870996872----
# Permutation: 24
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.833048
# R2 loop: -0.03276378725658491
# Explained var: 0.004732446661591561
# correlation: [[0.17575072]]
# Explained variance, chronic only:  0.005897264885192266
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.700112
# R2 loop: -0.3761703484216501
# Explained var: 0.002507309009439851
# correlation: [[0.25305168]]
# Explained variance, chronic only:  0.0006685065900596809
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.772125
# R2 loop: -0.33756211911213185
# Explained var: -0.039036952929973
# correlation: [[0.00065598]]
# Explained variance, chronic only:  0.0009299492856408298
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.874170
# R2 loop: -9.052337883908024e-05
# Explained var: 0.0020303846630613798
# correlation: [[0.04728963]]
# Explained variance, chronic only:  0.009406584603154022
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:05.026074
# R2 loop: -0.0015948112103894019
# Explained var: 0.001877814799468136
# correlation: [[0.41443935]]
# Explained variance, chronic only:  -4.170705867112545e-06
# ---- Permutation avg. chronic explained variance: 0.0033796269316359374----
# ---- Permutation avg. explained variance: -0.005577799559282415----
# Permutation: 25
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:05.011348
# R2 loop: -7.022575496920274
# Explained var: -6.977273028254848
# correlation: [[-0.10362154]]
# Explained variance, chronic only:  -13.76410153684315
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.794289
# R2 loop: -0.00086540807663682
# Explained var: -0.0005979242578793009
# correlation: [[-0.12116771]]
# Explained variance, chronic only:  -0.0002291424861065039
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.905891
# R2 loop: -0.18234808633747623
# Explained var: 0.00043229202946970524
# correlation: [[0.08002807]]
# Explained variance, chronic only:  0.00016356389562321993
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.920298
# R2 loop: -0.013877888881095979
# Explained var: 0.00036879261939459784
# correlation: [[0.07222384]]
# Explained variance, chronic only:  -1.1005048721202115e-06
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.957038
# R2 loop: -0.012531575513945459
# Explained var: -0.0008041116405834714
# correlation: [[-0.14446369]]
# Explained variance, chronic only:  -0.0011365359560264743
# ---- Permutation avg. chronic explained variance: -2.7530609503789063----
# ---- Permutation avg. explained variance: -1.395574795900889----
# Permutation: 26
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.955812
# R2 loop: -0.020027395761451405
# Explained var: -0.0004424123920030443
# correlation: [[-0.01264237]]
# Explained variance, chronic only:  -0.0006512335830024529
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.767307
# R2 loop: -0.007778049829539002
# Explained var: -0.006960894022485897
# correlation: [[-0.24609322]]
# Explained variance, chronic only:  0.00031414132175155984
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.984743
# R2 loop: -0.4194425388583001
# Explained var: -0.24556718483608764
# correlation: [[0.36330863]]
# Explained variance, chronic only:  -0.24623912767657208
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.857442
# R2 loop: -0.016217778297153762
# Explained var: -0.015605103691271882
# correlation: [[-0.2487173]]
# Explained variance, chronic only:  -0.02543761849877013
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.942250
# R2 loop: -0.1276048144997295
# Explained var: -0.011243262220092198
# correlation: [[-0.19185923]]
# Explained variance, chronic only:  -0.010576993399023848
# ---- Permutation avg. chronic explained variance: -0.05651816636712339----
# ---- Permutation avg. explained variance: -0.055963771432388135----
# Permutation: 27
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.803012
# R2 loop: -0.11239339305073681
# Explained var: -0.08874254278786786
# correlation: [[-0.3313818]]
# Explained variance, chronic only:  -0.0877309873967187
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.945783
# R2 loop: 0.0002761374668922567
# Explained var: 0.000715830290568209
# correlation: [[0.07041273]]
# Explained variance, chronic only:  0.0007456551944108325
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.866644
# R2 loop: -0.0281913784518808
# Explained var: -0.0012857223220905656
# correlation: [[-0.30113525]]
# Explained variance, chronic only:  -0.0014288146143277558
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.946584
# R2 loop: -0.07393375433557714
# Explained var: -0.000501250246688123
# correlation: [[-0.15685248]]
# Explained variance, chronic only:  0.0005372648338047847
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.864696
# R2 loop: -0.06580100795404609
# Explained var: -0.00011751727640962883
# correlation: [[-0.05369557]]
# Explained variance, chronic only:  -8.213398940970507e-06
# ---- Permutation avg. chronic explained variance: -0.01757701907635436----
# ---- Permutation avg. explained variance: -0.017986240468497595----
# Permutation: 28
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.794866
# R2 loop: -0.03088605855889104
# Explained var: -0.027101003976021554
# correlation: [[-0.03172739]]
# Explained variance, chronic only:  0.1301920660711352
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.899122
# R2 loop: -0.01045632191531598
# Explained var: -0.0029593521334250195
# correlation: [[-0.18536155]]
# Explained variance, chronic only:  -0.006125941184211836
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.829103
# R2 loop: -0.09042891012239052
# Explained var: 0.001452873875144367
# correlation: [[0.21481069]]
# Explained variance, chronic only:  -4.105228696871244e-05
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.933228
# R2 loop: -0.039259039993235545
# Explained var: 1.9638091190099516e-05
# correlation: [[0.00467539]]
# Explained variance, chronic only:  9.690729149025579e-05
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.856508
# R2 loop: -0.10103268798677778
# Explained var: -0.053067674063652426
# correlation: [[-0.24637573]]
# Explained variance, chronic only:  -0.05640533904513889
# ---- Permutation avg. chronic explained variance: 0.013543328169261204----
# ---- Permutation avg. explained variance: -0.016331103641352908----
# Permutation: 29
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.639570
# R2 loop: 0.026771122608753473
# Explained var: 0.03314592629951485
# correlation: [[0.19700431]]
# Explained variance, chronic only:  0.0343241243754816
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.732526
# ...
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.855261
# R2 loop: -0.004704152615725876
# Explained var: 0.0008198015756364363
# correlation: [[0.28016671]]
# Explained variance, chronic only:  0.00010659544588964565
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.780856
# R2 loop: -0.017231976087367373
# Explained var: -0.0019218161976091164
# correlation: [[-0.10221116]]
# Explained variance, chronic only:  -0.0022926185673646238
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.988216
# R2 loop: -0.1156355588540483
# Explained var: -0.0010245467931235819
# correlation: [[-0.02801409]]
# Explained variance, chronic only:  -0.0003969482332775165
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.835604
# R2 loop: -0.0072614202940051165
# Explained var: -0.0007312954330733756
# correlation: [[-0.10309784]]
# Explained variance, chronic only:  0.0008504564728819552
# ---- Permutation avg. chronic explained variance: -0.09248874484685761----
# ---- Permutation avg. explained variance: -0.07779256446502578----
# Permutation: 91
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.756042
# R2 loop: -0.30993561216620225
# Explained var: -0.2042658121797576
# correlation: [[-0.10256226]]
# Explained variance, chronic only:  -0.2792097483101661
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.732181
# R2 loop: -0.18896249470517446
# Explained var: -0.09243059489631378
# correlation: [[-0.00719248]]
# Explained variance, chronic only:  -0.07416232252062627
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.809018
# R2 loop: -0.09405244724221284
# Explained var: -0.04704114871419374
# correlation: [[0.0852717]]
# Explained variance, chronic only:  0.15815589364623528
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.931977
# R2 loop: 0.08048602499280877
# Explained var: 0.08086789393792537
# correlation: [[0.48431236]]
# Explained variance, chronic only:  0.10357769475503875
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.934117
# R2 loop: 0.057229961821570585
# Explained var: 0.05971282251562493
# correlation: [[0.41267488]]
# Explained variance, chronic only:  0.06834561737025291
# ---- Permutation avg. chronic explained variance: -0.0046585730118530845----
# ---- Permutation avg. explained variance: -0.04063136786734296----
# Permutation: 92
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.736194
# R2 loop: -0.03855150980596589
# Explained var: -0.012094099935373803
# correlation: [[-0.01290285]]
# Explained variance, chronic only:  -0.011506550257933235
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.818967
# R2 loop: -0.4364121967444694
# Explained var: -0.05092395013720585
# correlation: [[-0.15236698]]
# Explained variance, chronic only:  -0.07877571252724569
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.875703
# R2 loop: -0.2469464233717693
# Explained var: -0.00042326188378050134
# correlation: [[-0.08053308]]
# Explained variance, chronic only:  -0.0005034233898713047
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.956168
# R2 loop: -0.20237532660498236
# Explained var: -2.7563044735723352e-05
# correlation: [[-0.00036715]]
# Explained variance, chronic only:  -0.0007375964589049211
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.784735
# R2 loop: -0.969525389055206
# Explained var: -0.5924211110904045
# correlation: [[-0.33502769]]
# Explained variance, chronic only:  -0.7578364321229729
# ---- Permutation avg. chronic explained variance: -0.1698719429513856----
# ---- Permutation avg. explained variance: -0.1311779972183001----
# Permutation: 93
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.810616
# R2 loop: -0.07073666920280552
# Explained var: -0.04884979118332278
# correlation: [[-0.3063164]]
# Explained variance, chronic only:  -0.0503645405179074
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.938917
# R2 loop: -0.050526933904529336
# Explained var: -0.0069566059458825436
# correlation: [[-0.13677818]]
# Explained variance, chronic only:  0.0014011872151381555
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:05.000962
# R2 loop: -0.003821711030745023
# Explained var: 0.008660707036252435
# correlation: [[0.09995659]]
# Explained variance, chronic only:  0.007259993622428795
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.929698
# R2 loop: -0.04057323106178923
# Explained var: 0.004662856443810259
# correlation: [[0.06945588]]
# Explained variance, chronic only:  0.004592981271104635
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.654130
# R2 loop: -0.03693014296198793
# Explained var: -0.005178348167271807
# correlation: [[-0.3406956]]
# Explained variance, chronic only:  -0.005839085517649112
# ---- Permutation avg. chronic explained variance: -0.008589892785376984----
# ---- Permutation avg. explained variance: -0.009532236363282886----
# Permutation: 94
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.678482
# R2 loop: -0.03641489992287417
# Explained var: 0.0017025109718514786
# correlation: [[0.536429]]
# Explained variance, chronic only:  0.0
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.894801
# R2 loop: -0.22454471290052336
# Explained var: -0.0007704396971910388
# correlation: [[-0.00419391]]
# Explained variance, chronic only:  0.0024201711557637617
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.781914
# R2 loop: -0.0714572979980499
# Explained var: -0.010103963465939891
# correlation: [[0.03882983]]
# Explained variance, chronic only:  -0.01099352298022005
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.949750
# R2 loop: -0.10044396346147066
# Explained var: -0.03572570036438649
# correlation: [[-0.12497983]]
# Explained variance, chronic only:  0.0006964164658127547
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.770837
# R2 loop: -0.0796067058348442
# Explained var: -0.07201910081267338
# correlation: [[-0.25406339]]
# Explained variance, chronic only:  -0.08484396520362303
# ---- Permutation avg. chronic explained variance: -0.01854418011245331----
# ---- Permutation avg. explained variance: -0.023383338673667865----
# Permutation: 95
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.808435
# R2 loop: -0.04803638011512135
# Explained var: -0.036242911647478726
# correlation: [[-0.59621968]]
# Explained variance, chronic only:  -0.04752561600670413
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.774590
# R2 loop: -0.026676740818060818
# Explained var: -0.0019401260777534013
# correlation: [[-0.26285637]]
# Explained variance, chronic only:  -0.0022315982871861095
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.968609
# R2 loop: -0.004001528295752177
# Explained var: -0.003818264070841071
# correlation: [[-0.02859671]]
# Explained variance, chronic only:  -6.513288248610749e-05
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.950988
# R2 loop: -0.804976911395888
# Explained var: -0.7752867984295659
# correlation: [[-0.05925946]]
# Explained variance, chronic only:  -0.8406383562324711
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.950875
# R2 loop: -0.00410709630055428
# Explained var: 0.0007593301067498892
# correlation: [[0.18026988]]
# Explained variance, chronic only:  0.00012007786331746928
# ---- Permutation avg. chronic explained variance: -0.178068125109106----
# ---- Permutation avg. explained variance: -0.16330575402377784----
# Permutation: 96
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.913244
# R2 loop: -0.2352566879309279
# Explained var: 0.009008407943107755
# correlation: [[0.32116658]]
# Explained variance, chronic only:  -5.399538063111109e-06
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.867749
# R2 loop: -0.06659628686040642
# Explained var: -0.05907543190186759
# correlation: [[-0.16621265]]
# Explained variance, chronic only:  -0.03146891732056112
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.848684
# R2 loop: 0.008875272281137492
# Explained var: 0.01278525285830312
# correlation: [[0.12371339]]
# Explained variance, chronic only:  0.03228852004779448
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.944948
# R2 loop: -0.2440643379948153
# Explained var: -0.023648179094128752
# correlation: [[0.09340432]]
# Explained variance, chronic only:  -0.2975104546313554
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.879943
# R2 loop: -0.1820111245222693
# Explained var: -0.12074102547579146
# correlation: [[0.35947918]]
# Explained variance, chronic only:  0.004735318342647177
# ---- Permutation avg. chronic explained variance: -0.058392186619907596----
# ---- Permutation avg. explained variance: -0.03633419513407539----
# Permutation: 97
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.991499
# R2 loop: -0.20574230245657676
# Explained var: 0.0001918264435506467
# correlation: [[0.01514807]]
# Explained variance, chronic only:  0.0012860518547542776
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.742691
# R2 loop: -0.027339531107797743
# Explained var: -0.027319064843533303
# correlation: [[-0.26733808]]
# Explained variance, chronic only:  -0.009932002866483325
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.746760
# R2 loop: -0.3464459519833103
# Explained var: -0.0058904098144931805
# correlation: [[-0.27193878]]
# Explained variance, chronic only:  -0.007526460339655872
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.713659
# R2 loop: 0.0053411220776475865
# Explained var: 0.024544710435903117
# correlation: [[0.24922785]]
# Explained variance, chronic only:  0.03818444845437852
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.706001
# R2 loop: -0.07559152354886134
# Explained var: 0.0008928024546893676
# correlation: [[0.23031783]]
# Explained variance, chronic only:  0.0
# ---- Permutation avg. chronic explained variance: 0.00440240742059872----
# ---- Permutation avg. explained variance: -0.0015160270647766704----
# Permutation: 98
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.639085
# R2 loop: -0.001791157831794843
# Explained var: -0.0017773523751134501
# correlation: [[-0.25900557]]
# Explained variance, chronic only:  -0.004287975120156329
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.579524
# R2 loop: -0.45320453673978567
# Explained var: -0.4211674507983749
# correlation: [[-0.13424043]]
# Explained variance, chronic only:  -0.6865341608028823
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.664291
# R2 loop: 0.0002565032411835366
# Explained var: 0.003858270861978541
# correlation: [[0.20310952]]
# Explained variance, chronic only:  0.004461330464297419
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.959040
# R2 loop: -0.1459110252705731
# Explained var: 0.0016640848724155388
# correlation: [[0.14794306]]
# Explained variance, chronic only:  0.0016802070534146507
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.680569
# R2 loop: -0.39670267468742026
# Explained var: -0.011849639579639248
# correlation: [[-0.08874792]]
# Explained variance, chronic only:  0.0033445815598467377
# ---- Permutation avg. chronic explained variance: -0.13626720336909598----
# ---- Permutation avg. explained variance: -0.0858544174037467----
# Permutation: 99
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.671342
# R2 loop: -0.07440419069152182
# Explained var: -0.0014425289482447035
# correlation: [[-0.16279095]]
# Explained variance, chronic only:  -0.0019920590056887733
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:04.749224
# R2 loop: -0.008021185181718016
# Explained var: 0.0037468259113337954
# correlation: [[0.15652029]]
# Explained variance, chronic only:  -0.00028914572545146733
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.603347
# R2 loop: -0.011243684629591133
# Explained var: -0.0017644784496089194
# correlation: [[-0.20358898]]
# Explained variance, chronic only:  -0.0006677429248793665
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.700449
# R2 loop: -0.09359366455453855
# Explained var: 0.0003676701462260734
# correlation: [[0.08237677]]
# Explained variance, chronic only:  0.0010894387617778056
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:04.767512
# R2 loop: -0.02993040682165371
# Explained var: -0.00266894643197757
# correlation: [[-0.31490768]]
# Explained variance, chronic only:  -0.0010911818779315574
# ---- Permutation avg. chronic explained variance: -0.0005901381544346718----
# ---- Permutation avg. explained variance: -0.00035229155445426485----

# %%
import statsmodels.api as sm

# Simple linear model - using lesion volume to predict cognitive scores

#set x data to be the input variable you want to use
#ie fc, sc, or hc
#X=np.concatenate([sc, fc], axis=1)
X=lesionvol
X=prepare_data(X)
train_size=0.8

#set y to be the measure you want to predict
Y = np.array(wais)

# split data into train/test
x, x_test, y, y_test = train_test_split(X, Y, test_size=1-train_size, shuffle=True, random_state=41)

x_sm = sm.add_constant(x)
lr = sm.OLS(y, x_sm).fit()

lr.summary()
plt.scatter(x, y)
pms=lr.params

plt.plot(x, pms[0] + pms[1]*x, 'r')
plt.xlabel('Actual log lesionvol (mm^3)')
plt.ylabel('Predicted WAIS score')
plt.title('Training data')
plt.show()

# Predicting y_value using training data of X
y_train_pred = lr.predict(x_sm)

# Creating residuals from the y_train data and predicted y_data
res = (y - y_train_pred)

fig = plt.figure()
sns.distplot(res, bins = 15)
plt.title('Error Terms', fontsize = 15)
plt.xlabel('y_train - y_train_pred', fontsize = 15)
plt.show()

print('Verify that mean of residuals is zero. \n Mean of error terms: ' + str(np.mean(res)))
k=5
rsqs=[]
for p in range(0,100):
    # split data into train/test
    outer_cv = StratifiedKFold(n_splits=k, shuffle=True, random_state=p)
    
    for train, test in outer_cv.split(X, chronic_id):

        chronic_bin=chronic_id[train]
        chronic_test=chronic_id[test]
        
        x_train=X[train]
        x_test=X[test]
        y_train=Y[train]
        y_test=Y[test]

        # add constant to data
        x_sm = sm.add_constant(x_train)

        # fit on training data
        lr = sm.OLS(y_train, x_sm).fit()

        # Adding a constant to X_test
        X_test_sm = sm.add_constant(x_test)

        # Predicting the y values corresponding to X_test_sm 
        y_test_pred = lr.predict(X_test_sm)

        # Checking the R-squared value for chronic only
        y_test_pred_chronic=y_test_pred[chronic_test]
        y_test_chronic=y_test[chronic_test]
        r_squared = explained_variance_score(y_test, y_test_pred)
        #print('R-squared: ' + str(r_squared))
        rsqs.append(r_squared)

print("Permutation-avg ")
results_dir='/home/ubuntu/cognition_iowa/results/lesionvol/'

np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_chronic_all_explvar.txt', chronic_allexpl_var, delimiter=',')
# Out:
# Final size of X: (107, 1)
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Verify that mean of residuals is zero.
#  Mean of error terms: -6.771054305478601e-15
# Permutation-avg

# %%
# Out:
# -0.0185703161264231

# %%
# Using PCA of the lesion in MNi space to predict cognitive scores.
results_dir='/home/ubuntu/cognition_iowa/results/lesionpc/'
import datetime
#set the number of folds you want in the inner and outer folds of the nested cross-validation
k = 5

#set the proportion of data you want in your training set
train_size = .8

#set x data to be the input variable you want to use
#ie fc, sc, or hc
#X=np.concatenate([sc, fc], axis=1)
X=np.array(pc_lesion)
X=prepare_data(X)

#set y to be the measure you want to predict
Y = np.array(wais)
Y=np.reshape(Y, (107,1))

# feature selection type
featselect='correlation'

# range of alphas
n_alphas=20
alpha_start=-3
alpha_end=2
alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

#number of features (# pricipal components or variables to retain)
feat_start=1
feat_end=50
n_feats=feat_end-feat_start+1
feats = np.linspace(feat_start, feat_end, n_feats, dtype=int)

# initialize lists to store model results for each permuation
allR2=[]
meanR2=[]
features=[]
bestalphas=[]
importance=[]
allexpl_var=[]
correlations=[]
chronic_allexpl_var=[]
#joblib-based parallelism to increase speed,
ytestc=[]
ypredc=[]
for p in range(0, 100):
    outer_cv = StratifiedKFold(n_splits=k, shuffle=True, random_state=p)
    print('Permutation: ' + str(p))
    # initialize lists to store model results for eah fold
    R2=[]
    featur=[]
    best_alphas=[]
    impt=[] 
    expl_var=[]
    chronic_explvar=[]
    cor=[]
    for train, test in outer_cv.split(X, chronic_id):

        chronic_bin=chronic_id[train]
        chronic_test=chronic_id[test]

        print(X[train].shape)
        print(Y[train].shape)
        # select model using training data
        bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv_strat(k, X[train], Y[train], chronic_bin, featselect, alphas, feats)

        # using optimal num. of features, select final features using entire training data.

        if featselect=='correlation':
            x_train_featselect,x_test_featureselect,ind = feature_select_correlation(X[train],X[test], Y[train], bestfeats)
            featur.append(ind)

        elif featselect=='PCA':
            x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(X[train],X[test], bestfeats)
            featur.append(ind)


        chronic_bin=np.reshape(np.double(chronic_bin), (x_train_featselect.shape[0], 1))
        x_train_featselect=np.concatenate((x_train_featselect, chronic_bin),axis=1)

        chronic_test=np.reshape(np.double(chronic_test), (x_test_featureselect.shape[0], 1))
        x_test_featureselect=np.concatenate((x_test_featureselect, chronic_test),axis=1)

        # initialize Ridge regression with alpha selected from hyperparameter search
        regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)

        # fit model 
        y_pred = regr.fit(x_train_featselect, Y[train]).predict(x_test_featureselect)

        # store results for each fold k
        impt.append(regr.coef_)
        R2.append(r2_score(Y[test], y_pred))
        expl_var.append(explained_variance_score(Y[test], y_pred))

        best_alphas.append(bestalpha)
        print('time to run loop: ' + str(datetime.datetime.now() - begin_time)) 
        print("R2 loop: " + str(r2_score(Y[test], y_pred)))
        print("Explained var: " + str(explained_variance_score(Y[test], y_pred)))
        print("correlation: " + str(np_pearson_cor(Y[test], y_pred)))

        chronicsubs_test=chronic_id[test]==True
        chronicsubs_train=chronic_id[train]==True
        chronicsubs_test=chronicsubs_test.flatten()
        chronicsubs_train=chronicsubs_train.flatten()
        cor.append(np_pearson_cor(Y[test], y_pred))
        Xtest=x_test_featureselect
        Xtrain=X[train]
        Ytest=Y[test]

        ytrue_chronic = Ytest[chronicsubs_test]
        xtest_chronic=Xtest[chronicsubs_test]

        ytestc.append(ytrue_chronic)

        ychronic_pred = regr.fit(x_train_featselect, Y[train]).predict(xtest_chronic)
        print("Explained variance, chronic only:  " + str(explained_variance_score(ytrue_chronic, ychronic_pred)))
        ypredc.append(ychronic_pred)

        chronic_explvar.append(explained_variance_score(ytrue_chronic, ychronic_pred))
     
    # store results for each permutation p
    features.append(featur)
    allexpl_var.append(expl_var)
    bestalphas.append(best_alphas)
    importance.append(impt)
    chronic_allexpl_var.append(chronic_explvar)
    correlations.append(cor)
    print("---- Permutation avg. chronic explained variance: " + str(np.mean(chronic_explvar)) + "----")
    np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_chronic_all_explvar.txt', chronic_allexpl_var, delimiter=',')

    print("---- Permutation avg. explained variance: " + str(np.mean(expl_var)) + "----")
    np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_all_explvar.txt', expl_var, delimiter=',')

    output = open(results_dir + featselect + 'p' + str(p) + '_SC_features.pkl', 'wb')
    pickle.dump(featur, output)
    output.close()

    output = open(results_dir + featselect + 'p' + str(p) + '_SC_correlations.pkl', 'wb')
    pickle.dump(correlations, output)
    output.close()

    output = open(results_dir + featselect + 'p' + str(p) + '_SC_bestalphas.pkl', 'wb')
    pickle.dump(best_alphas, output)
    output.close()

    output = open(results_dir + featselect + 'p' + str(p) + '_SC_varimpt.pkl', 'wb')
    pickle.dump(importance, output)
    output.close()
# Out:
# Final size of X: (107, 106)
# Permutation: 0
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:16:27.805231
# R2 loop: 0.08578359810366287
# Explained var: 0.09430030410292856
# correlation: [[0.54254654]]
# Explained variance, chronic only:  0.0810073208368366
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:16:30.154603
# R2 loop: -0.04109013895669045
# Explained var: -0.039415485489696866
# correlation: [[0.05648275]]
# Explained variance, chronic only:  -0.030364759776249084
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:16:32.597793
# R2 loop: 0.2561056363741715
# Explained var: 0.2670349280646057
# correlation: [[0.70979413]]
# Explained variance, chronic only:  0.2920348412444914
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:16:34.996555
# R2 loop: -0.19003686935752762
# Explained var: -0.07734600618719578
# correlation: [[-0.20569299]]
# Explained variance, chronic only:  -0.1595724870618418
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:16:37.374030
# R2 loop: -0.2397702388071954
# Explained var: -0.1642790555799447
# correlation: [[-0.14036636]]
# Explained variance, chronic only:  -0.24570918751046023
# ---- Permutation avg. chronic explained variance: -0.012520854453444618----
# ---- Permutation avg. explained variance: 0.016058936982139383----
# Permutation: 1
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:16:39.677188
# R2 loop: -0.3036324090991003
# Explained var: -0.3018871665134968
# correlation: [[-0.30721849]]
# Explained variance, chronic only:  -0.5235243508897343
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:16:42.106122
# R2 loop: 0.21818738938042737
# Explained var: 0.2187889538046065
# correlation: [[0.57485921]]
# Explained variance, chronic only:  0.252528477046
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:16:44.516873
# R2 loop: -0.07225933807907414
# Explained var: -0.07099500308069562
# correlation: [[-0.19400645]]
# Explained variance, chronic only:  -0.08131629335840174
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:16:46.750158
# R2 loop: -0.08130002470571074
# Explained var: -0.026557559353331817
# correlation: [[-0.05891355]]
# Explained variance, chronic only:  -0.010250921897506649
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:16:48.911302
# R2 loop: -0.11355493080294399
# Explained var: -0.06331895846443691
# correlation: [[-0.15169257]]
# Explained variance, chronic only:  -0.03181435201367688
# ---- Permutation avg. chronic explained variance: -0.07887548822266391----
# ---- Permutation avg. explained variance: -0.04879394672147093----
# Permutation: 2
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:16:51.029440
# R2 loop: 0.05587344316637799
# Explained var: 0.05929718480054014
# correlation: [[0.24354145]]
# Explained variance, chronic only:  0.22157512851973638
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:16:53.501707
# R2 loop: 0.20053982748267662
# Explained var: 0.21112103492479983
# correlation: [[0.60315709]]
# Explained variance, chronic only:  0.21850970008097825
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:16:55.918271
# R2 loop: -0.37459863672569704
# Explained var: -0.3482239969276135
# correlation: [[-0.50857362]]
# Explained variance, chronic only:  -0.14238916579960637
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:16:58.237827
# R2 loop: 0.05664910990710392
# Explained var: 0.058302756267738065
# correlation: [[0.24815675]]
# Explained variance, chronic only:  0.005310420418383144
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:00.679413
# R2 loop: 0.016626052466951036
# Explained var: 0.019593979741500234
# correlation: [[0.14002677]]
# Explained variance, chronic only:  0.06390332458611037
# ---- Permutation avg. chronic explained variance: 0.07338188156112035----
# ---- Permutation avg. explained variance: 1.8191761392949424e-05----
# Permutation: 3
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:17:02.849443
# R2 loop: 0.10708393866960142
# Explained var: 0.13377324333752616
# correlation: [[0.46159921]]
# Explained variance, chronic only:  0.08208972118714486
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:17:04.959107
# R2 loop: -0.05160160574051398
# Explained var: -0.01016293872553975
# correlation: [[-0.04808198]]
# Explained variance, chronic only:  0.015124869979474376
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:07.390548
# R2 loop: -0.10488865011798221
# Explained var: -0.05683699299474876
# correlation: [[-0.03850333]]
# Explained variance, chronic only:  -0.13579143498386737
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:09.795891
# R2 loop: -0.06879342021220514
# Explained var: 0.06474728908224026
# correlation: [[0.26450917]]
# Explained variance, chronic only:  0.12903077750930858
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:12.148228
# R2 loop: -0.055007802877969025
# Explained var: -0.04650418471611828
# correlation: [[0.08526227]]
# Explained variance, chronic only:  -0.04186328851667365
# ---- Permutation avg. chronic explained variance: 0.00971812903507736----
# ---- Permutation avg. explained variance: 0.017003283196671926----
# Permutation: 4
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:17:14.451937
# R2 loop: -0.0885142236967782
# Explained var: -0.08386092707541803
# correlation: [[0.03623525]]
# Explained variance, chronic only:  -0.12438348212031647
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:17:16.643930
# R2 loop: -0.048527157497930684
# Explained var: -0.04813910782277575
# correlation: [[-0.12699021]]
# Explained variance, chronic only:  -0.09507604405382097
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:18.976877
# R2 loop: 0.18781148969575312
# Explained var: 0.28802781275634814
# correlation: [[0.57205219]]
# Explained variance, chronic only:  0.39492337200340966
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:21.515606
# R2 loop: 0.021555116789292228
# Explained var: 0.06293258832452298
# correlation: [[0.26205955]]
# Explained variance, chronic only:  0.041374313818259734
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:23.892466
# R2 loop: -0.05016918957976646
# Explained var: -0.04577701849272908
# correlation: [[-0.34212202]]
# Explained variance, chronic only:  -0.01618508610185332
# ---- Permutation avg. chronic explained variance: 0.040130614709135724----
# ---- Permutation avg. explained variance: 0.03463666953798965----
# Permutation: 5
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:17:26.390160
# R2 loop: 0.06909124619691032
# Explained var: 0.07059239770229198
# correlation: [[0.27866509]]
# Explained variance, chronic only:  -0.03646622629024665
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:17:28.829581
# R2 loop: -0.3916955665956052
# Explained var: 0.00986704247723258
# correlation: [[0.10928063]]
# Explained variance, chronic only:  -0.004552262631129844
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:31.223948
# R2 loop: -0.7758445590758187
# Explained var: -0.6001983651957621
# correlation: [[-0.27069213]]
# Explained variance, chronic only:  -0.641631968830271
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:33.421779
# R2 loop: 0.050756108069813344
# Explained var: 0.061632448862025346
# correlation: [[0.49669617]]
# Explained variance, chronic only:  0.06837186000281503
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:35.810850
# R2 loop: -0.2707285029247939
# Explained var: -0.006314828100659087
# correlation: [[0.07049916]]
# Explained variance, chronic only:  -0.08900385668780597
# ---- Permutation avg. chronic explained variance: -0.14065649088732768----
# ---- Permutation avg. explained variance: -0.09288426085097426----
# Permutation: 6
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:17:38.208250
# R2 loop: -0.14664313098663984
# Explained var: -0.14636840663970863
# correlation: [[0.04399599]]
# Explained variance, chronic only:  -0.17327333161756409
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:17:40.371012
# R2 loop: -0.19958739940342407
# Explained var: -0.1935943265690261
# correlation: [[-0.38304182]]
# Explained variance, chronic only:  -0.08857108318967555
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:42.630126
# R2 loop: -0.6218010856879355
# Explained var: -0.6202449969479396
# correlation: [[-0.29549434]]
# Explained variance, chronic only:  -0.729648264645324
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:44.786547
# R2 loop: 0.006640773227319929
# Explained var: 0.006714002214576631
# correlation: [[0.3100441]]
# Explained variance, chronic only:  0.007216371083084927
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:46.887971
# R2 loop: -0.012327920336361764
# Explained var: -0.011682244659676932
# correlation: [[-0.10415487]]
# Explained variance, chronic only:  -0.014348694652826843
# ---- Permutation avg. chronic explained variance: -0.1997250006044611----
# ---- Permutation avg. explained variance: -0.19303519452035492----
# Permutation: 7
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:17:48.984568
# R2 loop: -0.006376543266693346
# Explained var: 0.04308225295734669
# correlation: [[0.727172]]
# Explained variance, chronic only:  0.04195745509608639
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:17:51.082809
# R2 loop: 0.04487596606189104
# Explained var: 0.04697419279852355
# correlation: [[0.57958305]]
# Explained variance, chronic only:  0.06060253109932978
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:53.195686
# R2 loop: -1.1951747121859326
# Explained var: -1.1046757565925502
# correlation: [[-0.22101816]]
# Explained variance, chronic only:  -1.2255309827531922
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:55.396117
# R2 loop: -0.0795902974876821
# Explained var: -0.07268901576340658
# correlation: [[-0.3283128]]
# Explained variance, chronic only:  -0.09977352649018667
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:17:57.859988
# R2 loop: -0.1932171978934243
# Explained var: 0.006671213319161429
# correlation: [[0.34378839]]
# Explained variance, chronic only:  0.008819120819046344
# ---- Permutation avg. chronic explained variance: -0.24278508044578323----
# ---- Permutation avg. explained variance: -0.21612742265618506----
# Permutation: 8
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:18:00.223081
# R2 loop: -0.021417948941738763
# Explained var: -0.01107340941122903
# correlation: [[-0.03413585]]
# Explained variance, chronic only:  -0.0147479687178933
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:18:02.606390
# R2 loop: -0.012696364852201603
# Explained var: -0.005768075445192977
# correlation: [[0.22099208]]
# Explained variance, chronic only:  -0.10292214496319207
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:04.919495
# R2 loop: -0.09098580616592389
# Explained var: -0.062376011908573004
# correlation: [[0.02863176]]
# Explained variance, chronic only:  0.1459497011387877
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:07.296355
# R2 loop: 0.08256306424477644
# Explained var: 0.12560554587694162
# correlation: [[0.70479108]]
# Explained variance, chronic only:  0.13925293793029403
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:09.460582
# R2 loop: -0.14475614766923495
# Explained var: -0.00401256811598949
# correlation: [[0.13076107]]
# Explained variance, chronic only:  -0.07270626491462773
# ---- Permutation avg. chronic explained variance: 0.018965252094673722----
# ---- Permutation avg. explained variance: 0.008475096199191423----
# Permutation: 9
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:18:11.555983
# R2 loop: -0.20105846168538344
# Explained var: -0.08244807170071122
# correlation: [[-0.05088978]]
# Explained variance, chronic only:  -0.09997558076732016
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:18:13.820385
# R2 loop: -0.07645901233216557
# Explained var: -0.021073637305022874
# correlation: [[-0.17243471]]
# Explained variance, chronic only:  -0.010352253697369695
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:15.912396
# R2 loop: -0.614452818330858
# Explained var: -0.49694897216700396
# correlation: [[-0.44926366]]
# Explained variance, chronic only:  -0.29470824050722744
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:18.021145
# R2 loop: -0.17957300584742542
# Explained var: -0.16893777959657275
# correlation: [[-0.38633615]]
# Explained variance, chronic only:  -0.16456773506324973
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:20.150005
# R2 loop: -0.11933082619972835
# Explained var: -0.02056574462504379
# correlation: [[0.02715952]]
# Explained variance, chronic only:  0.018036855114198058
# ---- Permutation avg. chronic explained variance: -0.1103133909841938----
# ---- Permutation avg. explained variance: -0.1579948410788709----
# Permutation: 10
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:18:22.244189
# R2 loop: -0.15713988225222275
# Explained var: -0.12045584113037178
# correlation: [[0.04706838]]
# Explained variance, chronic only:  -0.021710563976002017
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:18:24.640202
# R2 loop: -0.10387387608322385
# Explained var: 0.1138987226936734
# correlation: [[0.48180296]]
# Explained variance, chronic only:  0.14313618285733765
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:27.138900
# R2 loop: -0.039897392752373584
# Explained var: 0.017757249712889944
# correlation: [[0.16894507]]
# Explained variance, chronic only:  0.009619696955381785
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:29.689386
# R2 loop: -0.1791091567525147
# Explained var: -0.001979319483556008
# correlation: [[0.19627249]]
# Explained variance, chronic only:  -0.12306456365495211
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:32.149506
# R2 loop: -0.18994461141596197
# Explained var: -0.17697000479503688
# correlation: [[-0.44380166]]
# Explained variance, chronic only:  -0.06864361551118003
# ---- Permutation avg. chronic explained variance: -0.012132572665882945----
# ---- Permutation avg. explained variance: -0.03354983860048026----
# Permutation: 11
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:18:34.419194
# R2 loop: -0.17160089679359602
# Explained var: 0.02212599396837578
# correlation: [[0.15024304]]
# Explained variance, chronic only:  0.07058466928959684
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:18:36.677217
# R2 loop: -0.1683760425009626
# Explained var: -0.01731358613113443
# correlation: [[-0.19765338]]
# Explained variance, chronic only:  -0.014645816008535206
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:38.993734
# R2 loop: -0.1335653647353252
# Explained var: -0.04009824128792472
# correlation: [[0.03508046]]
# Explained variance, chronic only:  0.01231653347632411
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:41.367995
# R2 loop: 0.044123896054928724
# Explained var: 0.053221537929223905
# correlation: [[0.43711904]]
# Explained variance, chronic only:  0.07117537412774266
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:43.524003
# R2 loop: -0.9380705474040278
# Explained var: -0.9265445832611099
# correlation: [[-0.2788842]]
# Explained variance, chronic only:  -1.0541130204759015
# ---- Permutation avg. chronic explained variance: -0.1829364519181546----
# ---- Permutation avg. explained variance: -0.18172177575651388----
# Permutation: 12
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:18:46.037175
# R2 loop: 0.06919319293766002
# Explained var: 0.06967704148176945
# correlation: [[0.52920753]]
# Explained variance, chronic only:  0.09224585459298984
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:18:48.517912
# R2 loop: 0.017348609674821658
# Explained var: 0.022395373973215005
# correlation: [[0.20163065]]
# Explained variance, chronic only:  -0.007188740087906043
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:50.908179
# R2 loop: -0.7972725169491579
# Explained var: -0.7718295412625651
# correlation: [[0.01221951]]
# Explained variance, chronic only:  -0.5866821000798328
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:53.163689
# R2 loop: -0.20717152073493095
# Explained var: -0.1487287919163811
# correlation: [[-0.46948584]]
# Explained variance, chronic only:  -0.10731082915512413
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:18:55.580415
# R2 loop: -0.13422243302896852
# Explained var: -0.1161524275860304
# correlation: [[-0.34342494]]
# Explained variance, chronic only:  -0.08459291176473727
# ---- Permutation avg. chronic explained variance: -0.13870574529892207----
# ---- Permutation avg. explained variance: -0.18892766906199843----
# Permutation: 13
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:18:57.871041
# R2 loop: -0.19617101716471796
# Explained var: -0.19030446467787665
# correlation: [[-0.25488423]]
# Explained variance, chronic only:  -0.20850986418348727
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:19:00.305718
# R2 loop: -0.10028672956921647
# Explained var: -0.09614298659558229
# correlation: [[-0.26763139]]
# Explained variance, chronic only:  -0.10763449613186382
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:02.638720
# R2 loop: -0.08596880370695015
# Explained var: -0.05123015881771642
# correlation: [[-0.20730132]]
# Explained variance, chronic only:  -0.020576280523991075
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:04.987095
# R2 loop: 0.027715788571568756
# Explained var: 0.052428562310650184
# correlation: [[0.29445349]]
# Explained variance, chronic only:  0.06533239113848865
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:07.384612
# R2 loop: -0.15702214460599984
# Explained var: -0.05194291987684818
# correlation: [[-0.07312338]]
# Explained variance, chronic only:  -0.07557176494567375
# ---- Permutation avg. chronic explained variance: -0.06939200292930545----
# ---- Permutation avg. explained variance: -0.06743839353147467----
# Permutation: 14
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:19:09.762092
# R2 loop: -0.2281787770237056
# Explained var: -0.09462014910928884
# correlation: [[-0.07163274]]
# Explained variance, chronic only:  -0.29402626278266886
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:19:12.099698
# R2 loop: -0.2503399469461052
# Explained var: -0.18261532512301204
# correlation: [[0.01291861]]
# Explained variance, chronic only:  -0.1907096354533373
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:14.341129
# R2 loop: -0.12614090400589117
# Explained var: -0.0996898205075114
# correlation: [[-0.04643952]]
# Explained variance, chronic only:  -0.09944568419848454
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:16.837605
# R2 loop: 0.06746420783736551
# Explained var: 0.08331584655785529
# correlation: [[0.37247574]]
# Explained variance, chronic only:  0.11033752722829493
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:19.282509
# R2 loop: 0.2812711620734928
# Explained var: 0.2880252733586517
# correlation: [[0.71701228]]
# Explained variance, chronic only:  0.3120875921053362
# ---- Permutation avg. chronic explained variance: -0.03235129262017191----
# ---- Permutation avg. explained variance: -0.0011168349646610621----
# Permutation: 15
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:19:21.697507
# R2 loop: -0.05504551149437931
# Explained var: 0.04429767518513317
# correlation: [[0.21521635]]
# Explained variance, chronic only:  0.05347330459547728
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:19:24.140258
# R2 loop: -2.187046834235222
# Explained var: -1.7389716356394191
# correlation: [[-0.59548895]]
# Explained variance, chronic only:  -1.8655431593171117
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:26.468283
# R2 loop: -0.10454317798844026
# Explained var: -0.1025418949507888
# correlation: [[-0.12991299]]
# Explained variance, chronic only:  -0.025825658615984404
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:28.798594
# R2 loop: -0.31332546539853623
# Explained var: -0.24549938620786338
# correlation: [[-0.271899]]
# Explained variance, chronic only:  -0.3293401625744321
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:31.196996
# R2 loop: -0.008836880965132021
# Explained var: 0.07425718834442285
# correlation: [[0.48222693]]
# Explained variance, chronic only:  0.032029955804759314
# ---- Permutation avg. chronic explained variance: -0.4270411440214583----
# ---- Permutation avg. explained variance: -0.393691610653703----
# Permutation: 16
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:19:33.622599
# R2 loop: 0.0554353736544515
# Explained var: 0.0644852545773319
# correlation: [[0.28960323]]
# Explained variance, chronic only:  0.08483134268385417
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:19:35.989222
# R2 loop: 0.048111244941358655
# Explained var: 0.05227158632661444
# correlation: [[0.32355515]]
# Explained variance, chronic only:  0.05518472322224344
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:38.233570
# R2 loop: -0.15520935310898065
# Explained var: -0.08361645185395772
# correlation: [[-0.13965477]]
# Explained variance, chronic only:  -0.016818457940964038
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:40.596317
# R2 loop: -0.09219203587530567
# Explained var: -0.06752310153386798
# correlation: [[0.12487454]]
# Explained variance, chronic only:  -0.014374479718350264
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:42.932602
# R2 loop: -0.008965158591450528
# Explained var: 0.0025134008727271118
# correlation: [[0.15656904]]
# Explained variance, chronic only:  0.0030566332828543263
# ---- Permutation avg. chronic explained variance: 0.022375952305927527----
# ---- Permutation avg. explained variance: -0.00637386232223045----
# Permutation: 17
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:19:45.349951
# R2 loop: -0.05447229041429047
# Explained var: -0.030179344461035207
# correlation: [[0.00150222]]
# Explained variance, chronic only:  -0.07144164898482264
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:19:47.743205
# R2 loop: -0.013142599589577308
# Explained var: 0.07172515783458011
# correlation: [[0.40696611]]
# Explained variance, chronic only:  0.031367530618413686
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:50.085659
# R2 loop: 0.16338648339730766
# Explained var: 0.16964572405113265
# correlation: [[0.63037105]]
# Explained variance, chronic only:  0.19440364848428848
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:52.497390
# R2 loop: 0.020191375454950533
# Explained var: 0.1771963855005827
# correlation: [[0.53713465]]
# Explained variance, chronic only:  0.2307857631763559
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:19:54.854978
# R2 loop: 0.0752303026868637
# Explained var: 0.08035582340797887
# correlation: [[0.40003451]]
# Explained variance, chronic only:  0.07205334004908093
# ---- Permutation avg. chronic explained variance: 0.09143372666866327----
# ---- Permutation avg. explained variance: 0.09374874926664782----
# Permutation: 18
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:19:57.244715
# R2 loop: -0.02012233387616713
# Explained var: 0.021987271785561924
# correlation: [[0.14875902]]
# Explained variance, chronic only:  0.013618424924134342
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:19:59.489501
# R2 loop: -0.017591898591842403
# Explained var: -0.009684858840284472
# correlation: [[-0.06200314]]
# Explained variance, chronic only:  -0.017304059750286482
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:01.856845
# R2 loop: -0.016094035054024625
# Explained var: 0.013172116714510462
# correlation: [[0.121312]]
# Explained variance, chronic only:  0.022222499824104402
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:04.136506
# R2 loop: -0.25366508054919423
# Explained var: -0.15774448806583052
# correlation: [[-0.01529924]]
# Explained variance, chronic only:  -0.1729823908552206
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:06.209109
# R2 loop: 0.08648757392266959
# Explained var: 0.11039529275179416
# correlation: [[0.33467444]]
# Explained variance, chronic only:  0.1793197931251388
# ---- Permutation avg. chronic explained variance: 0.004974853453574091----
# ---- Permutation avg. explained variance: -0.00437493313084969----
# Permutation: 19
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:20:08.575329
# R2 loop: -2.2173857242236994
# Explained var: -2.2142591719179547
# correlation: [[-0.11302355]]
# Explained variance, chronic only:  -2.227516204127108
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:20:10.774519
# R2 loop: -0.0037656660734872727
# Explained var: 0.0026353657040600886
# correlation: [[0.05882349]]
# Explained variance, chronic only:  -0.03061009809056925
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:13.062006
# R2 loop: -0.559567891387913
# Explained var: -0.5586392549000334
# correlation: [[-0.4582253]]
# Explained variance, chronic only:  -0.5071596094412909
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:15.499634
# R2 loop: 0.05370145510156721
# Explained var: 0.10088220387085545
# correlation: [[0.33187094]]
# Explained variance, chronic only:  0.14363324966719737
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:17.654164
# R2 loop: -0.0951736258049598
# Explained var: -0.07995981546191255
# correlation: [[-0.13936573]]
# Explained variance, chronic only:  -0.002738294301121158
# ---- Permutation avg. chronic explained variance: -0.5248781912585784----
# ---- Permutation avg. explained variance: -0.549868134540997----
# Permutation: 20
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:20:19.918808
# R2 loop: -0.2339778764526197
# Explained var: -0.11986559391810903
# correlation: [[-0.35713055]]
# Explained variance, chronic only:  -0.1265463532146487
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:20:22.148266
# R2 loop: 0.039502971119277586
# Explained var: 0.06431623814650977
# correlation: [[0.36058534]]
# Explained variance, chronic only:  0.046801725487234935
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:24.334068
# R2 loop: -0.06837431510779335
# Explained var: -0.014992753493755506
# correlation: [[0.14035242]]
# Explained variance, chronic only:  0.022402918203092703
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:26.555061
# R2 loop: -0.05053564700120439
# Explained var: -0.04995865559575474
# correlation: [[-0.09555183]]
# Explained variance, chronic only:  -0.05496230863550777
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:28.760053
# R2 loop: 0.1233515862289829
# Explained var: 0.13356398191556396
# correlation: [[0.64639073]]
# Explained variance, chronic only:  0.1460489858431815
# ---- Permutation avg. chronic explained variance: 0.0067489935366705335----
# ---- Permutation avg. explained variance: 0.002612643410890891----
# Permutation: 21
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:20:30.926350
# R2 loop: -0.08669252711193942
# Explained var: 0.04381479413611822
# correlation: [[0.21934616]]
# Explained variance, chronic only:  0.051318537209829374
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:20:33.016375
# R2 loop: -0.15244756919741875
# Explained var: -0.15239971562035182
# correlation: [[-0.18197612]]
# Explained variance, chronic only:  -0.2119865137647885
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:35.123367
# R2 loop: -0.03816493273276467
# Explained var: -0.038129590856768036
# correlation: [[-0.14551979]]
# Explained variance, chronic only:  -0.03312290875287127
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:37.453696
# R2 loop: -0.10694682186222848
# Explained var: 0.047256630447509496
# correlation: [[0.22073457]]
# Explained variance, chronic only:  0.08494794857335974
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:39.863274
# R2 loop: -0.00787891485677239
# Explained var: 0.006313704142667742
# correlation: [[0.09924972]]
# Explained variance, chronic only:  0.003710117742718011
# ---- Permutation avg. chronic explained variance: -0.02102656379835053----
# ---- Permutation avg. explained variance: -0.01862883555016488----
# Permutation: 22
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:20:42.193771
# R2 loop: -0.2978365124837723
# Explained var: -0.26737865019300466
# correlation: [[-0.12646706]]
# Explained variance, chronic only:  -0.47102575120002865
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:20:44.306894
# R2 loop: 0.11712611084402813
# Explained var: 0.12653777023706492
# correlation: [[0.57976366]]
# Explained variance, chronic only:  0.13356253759014847
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:46.398639
# R2 loop: -0.04201743482028575
# Explained var: 0.001459916404678796
# correlation: [[0.05242]]
# Explained variance, chronic only:  0.0425122748093395
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:48.493226
# R2 loop: 0.07087681697936576
# Explained var: 0.11768564905297196
# correlation: [[0.34363252]]
# Explained variance, chronic only:  0.12749791133861466
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:50.590679
# R2 loop: -0.03187132242082891
# Explained var: -0.020951732791145483
# correlation: [[-0.00199469]]
# Explained variance, chronic only:  -0.03737023520904437
# ---- Permutation avg. chronic explained variance: -0.04096465253419408----
# ---- Permutation avg. explained variance: -0.008529409457886893----
# Permutation: 23
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:20:52.692803
# R2 loop: -0.06485074790867063
# Explained var: 0.05377778321330162
# correlation: [[0.37731328]]
# Explained variance, chronic only:  0.1141495583622536
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:20:54.844811
# R2 loop: -0.058081227557456705
# Explained var: -0.04651409925000349
# correlation: [[-0.11866814]]
# Explained variance, chronic only:  -0.0455673600587847
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:57.321872
# R2 loop: -0.5465038717087085
# Explained var: -0.4305913171876308
# correlation: [[-0.23410828]]
# Explained variance, chronic only:  -0.6641275473234827
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:20:59.578898
# R2 loop: 0.18793090213509456
# Explained var: 0.19472165818035692
# correlation: [[0.44336291]]
# Explained variance, chronic only:  0.3706173656954522
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:01.688023
# R2 loop: 0.020827863769002142
# Explained var: 0.05761123631221221
# correlation: [[0.26250684]]
# Explained variance, chronic only:  0.07493362934976355
# ---- Permutation avg. chronic explained variance: -0.0299988707949596----
# ---- Permutation avg. explained variance: -0.0341989477463527----
# Permutation: 24
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:21:03.845148
# R2 loop: 0.2689674794157534
# Explained var: 0.2696639324448623
# correlation: [[0.60644599]]
# Explained variance, chronic only:  0.27774101791387007
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:21:05.963360
# R2 loop: -0.9437310959210259
# Explained var: -0.0005923735042363543
# correlation: [[0.01548891]]
# Explained variance, chronic only:  0.03379951027535255
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:08.295086
# R2 loop: -0.22825316874668355
# Explained var: -0.0049329214348246
# correlation: [[0.02948429]]
# Explained variance, chronic only:  -0.034841671180888545
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:10.383014
# R2 loop: 0.029762778298971337
# Explained var: 0.04472329407027065
# correlation: [[0.21372548]]
# Explained variance, chronic only:  0.037473047996559705
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:12.654793
# R2 loop: -0.2894164582953984
# Explained var: 0.04297644367588749
# correlation: [[0.24262492]]
# Explained variance, chronic only:  0.11519987604968607
# ---- Permutation avg. chronic explained variance: 0.08587435621091596----
# ---- Permutation avg. explained variance: 0.0703676750503919----
# Permutation: 25
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:21:14.990631
# R2 loop: -0.009008286472845795
# Explained var: 0.026246437224057506
# correlation: [[0.21513199]]
# Explained variance, chronic only:  0.030983548053067467
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:21:17.391056
# R2 loop: 0.021889800798294057
# Explained var: 0.03180148865590571
# correlation: [[0.20126404]]
# Explained variance, chronic only:  0.03773951139546794
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:19.578308
# R2 loop: 0.14720531229091594
# Explained var: 0.14857149552185112
# correlation: [[0.45980671]]
# Explained variance, chronic only:  0.15678684608660975
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:21.816719
# R2 loop: -0.38364614170496036
# Explained var: -0.15487220463691176
# correlation: [[-0.32386601]]
# Explained variance, chronic only:  -0.18020469959859176
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:24.286113
# R2 loop: -0.46622278086187263
# Explained var: -0.46235479537758106
# correlation: [[-0.4870279]]
# Explained variance, chronic only:  -0.4330842565476529
# ---- Permutation avg. chronic explained variance: -0.0775558101222199----
# ---- Permutation avg. explained variance: -0.0821215157225357----
# Permutation: 26
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:21:26.612289
# R2 loop: -0.035278642853588726
# Explained var: -0.014260205246793278
# correlation: [[0.03863868]]
# Explained variance, chronic only:  0.04647739197501477
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:21:28.822095
# R2 loop: -0.17410963942905244
# Explained var: -0.15920439324680613
# correlation: [[0.03020138]]
# Explained variance, chronic only:  -0.15809948760217196
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:31.162704
# R2 loop: 0.042630781368137804
# Explained var: 0.07989350229897418
# correlation: [[0.50224017]]
# Explained variance, chronic only:  0.10762848178430928
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:33.593209
# R2 loop: -0.0346045498789731
# Explained var: -0.028749049068596433
# correlation: [[-0.17203807]]
# Explained variance, chronic only:  -0.045924234199814506
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:35.959851
# R2 loop: 0.07109256100020911
# Explained var: 0.16578238483154595
# correlation: [[0.58580413]]
# Explained variance, chronic only:  0.18737883525374133
# ---- Permutation avg. chronic explained variance: 0.02749219744221578----
# ---- Permutation avg. explained variance: 0.008692447913664858----
# Permutation: 27
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:21:38.265850
# R2 loop: -0.09086931479094473
# Explained var: 0.00469123432031926
# correlation: [[0.48020945]]
# Explained variance, chronic only:  0.005442558753664062
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:21:40.699342
# R2 loop: 0.0453000148458752
# Explained var: 0.06046429312167434
# correlation: [[0.30696544]]
# Explained variance, chronic only:  0.04944414674199127
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:43.128378
# R2 loop: -0.07152392011698083
# Explained var: -0.023360207776760067
# correlation: [[-0.1074963]]
# Explained variance, chronic only:  -0.020369546788475468
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:45.569915
# R2 loop: 0.004324411374705517
# Explained var: 0.012752267724115751
# correlation: [[0.20754236]]
# Explained variance, chronic only:  0.016726592789973127
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:21:47.858226
# R2 loop: -0.11233597270397033
# Explained var: 0.012374978323348107
# correlation: [[0.26246979]]
# Explained variance, chronic only:  0.014501925296234841
# ---- Permutation avg. chronic explained variance: 0.013149135358677566----
# ---- Permutation avg. explained variance: 0.013384513142539477----
# Permutation: 28
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# ...
# time to run loop: 0:33:51.451700
# R2 loop: -0.010842535947706677
# Explained var: -0.002716823357410858
# correlation: [[0.01392608]]
# Explained variance, chronic only:  0.00032135040166036966
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:33:53.870383
# R2 loop: -0.3428395814054346
# Explained var: 0.009412584087296838
# correlation: [[0.12622732]]
# Explained variance, chronic only:  0.012722216339521641
# ---- Permutation avg. chronic explained variance: 0.015903357948954124----
# ---- Permutation avg. explained variance: 0.0022562002229559843----
# Permutation: 91
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:33:56.040213
# R2 loop: -0.09641686402552341
# Explained var: -0.08505327894184389
# correlation: [[-0.11707547]]
# Explained variance, chronic only:  -0.10711790086309025
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:33:58.147054
# R2 loop: 0.08668490021549613
# Explained var: 0.09606078060028655
# correlation: [[0.31577464]]
# Explained variance, chronic only:  0.07518758757463984
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:00.453290
# R2 loop: 0.10889109420272691
# Explained var: 0.14599145121392698
# correlation: [[0.38248546]]
# Explained variance, chronic only:  0.09042965800111447
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:02.861017
# R2 loop: 0.11504638098550724
# Explained var: 0.12997307887272647
# correlation: [[0.46636661]]
# Explained variance, chronic only:  0.15786018034825922
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:05.008368
# R2 loop: 0.0019575395781027405
# Explained var: 0.0026297567784929754
# correlation: [[0.12969272]]
# Explained variance, chronic only:  0.0837472581272386
# ---- Permutation avg. chronic explained variance: 0.060021356637632375----
# ---- Permutation avg. explained variance: 0.05792035770471782----
# Permutation: 92
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:34:07.332476
# R2 loop: -0.004100776033118647
# Explained var: 0.0017909454714265527
# correlation: [[0.10231161]]
# Explained variance, chronic only:  -0.045210872941254365
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:34:09.608782
# R2 loop: 0.02230854103341562
# Explained var: 0.022616279150106666
# correlation: [[0.15086829]]
# Explained variance, chronic only:  -0.03483808294521351
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:11.734056
# R2 loop: 0.11356498571722351
# Explained var: 0.16432273945462061
# correlation: [[0.57120933]]
# Explained variance, chronic only:  0.17562843074244905
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:13.862593
# R2 loop: -0.3536437940998398
# Explained var: -0.1553312315798554
# correlation: [[-0.00506229]]
# Explained variance, chronic only:  -0.11509096508552918
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:16.010737
# R2 loop: -0.004029647445600526
# Explained var: 0.009452420191636168
# correlation: [[0.21973834]]
# Explained variance, chronic only:  -0.04796502630431121
# ---- Permutation avg. chronic explained variance: -0.013495303306771844----
# ---- Permutation avg. explained variance: 0.008570230537586921----
# Permutation: 93
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:34:18.285036
# R2 loop: -0.09374737522626031
# Explained var: -0.09361936260041404
# correlation: [[0.12356006]]
# Explained variance, chronic only:  -0.16390390438207958
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:34:20.640867
# R2 loop: 0.016191712498419664
# Explained var: 0.016241715050788752
# correlation: [[0.13818054]]
# Explained variance, chronic only:  0.03131519654072534
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:22.948432
# R2 loop: -0.07363153534972766
# Explained var: -0.05213604676582606
# correlation: [[0.12050926]]
# Explained variance, chronic only:  -0.034531031759195585
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:25.316595
# R2 loop: -0.2647710311384368
# Explained var: -0.20450571247915694
# correlation: [[-0.14566125]]
# Explained variance, chronic only:  -0.24240574975322304
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:27.704990
# R2 loop: 0.07313238219792162
# Explained var: 0.1308842151856091
# correlation: [[0.53895852]]
# Explained variance, chronic only:  0.15516261624826633
# ---- Permutation avg. chronic explained variance: -0.050872574621101306----
# ---- Permutation avg. explained variance: -0.040627038321799834----
# Permutation: 94
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:34:30.118894
# R2 loop: -0.1381891434337903
# Explained var: 0.056708012232869254
# correlation: [[0.29815339]]
# Explained variance, chronic only:  0.05665791123569841
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:34:32.535391
# R2 loop: -0.18225193113626248
# Explained var: 0.09003251403653578
# correlation: [[0.30163703]]
# Explained variance, chronic only:  0.3297232237184059
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:34.908180
# R2 loop: 0.05278013653104896
# Explained var: 0.06775125043931862
# correlation: [[0.32249141]]
# Explained variance, chronic only:  0.10276024589773547
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:37.445368
# R2 loop: -0.31253804699876864
# Explained var: -0.14503226560023008
# correlation: [[-0.31077983]]
# Explained variance, chronic only:  -0.107527797970002
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:39.897626
# R2 loop: -0.03643247455257104
# Explained var: 0.04134813357584377
# correlation: [[0.20341564]]
# Explained variance, chronic only:  0.08091081781912968
# ---- Permutation avg. chronic explained variance: 0.0925048801401935----
# ---- Permutation avg. explained variance: 0.02216152893686747----
# Permutation: 95
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:34:42.096501
# R2 loop: 0.010005679668777412
# Explained var: 0.0291482225281966
# correlation: [[0.17104301]]
# Explained variance, chronic only:  0.11771859001390539
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:34:44.352796
# R2 loop: -0.11362910083947297
# Explained var: -0.06288214827395189
# correlation: [[0.05097457]]
# Explained variance, chronic only:  -0.14283977015966065
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:46.472174
# R2 loop: 0.015967648506789445
# Explained var: 0.04085865587577808
# correlation: [[0.2166094]]
# Explained variance, chronic only:  0.08477566158629946
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:48.780496
# R2 loop: 0.22493068581021258
# Explained var: 0.27143390876039775
# correlation: [[0.54019354]]
# Explained variance, chronic only:  0.31289177277823066
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:51.210397
# R2 loop: 0.0146430331008931
# Explained var: 0.020346175499249997
# correlation: [[0.18729075]]
# Explained variance, chronic only:  0.035033059525674815
# ---- Permutation avg. chronic explained variance: 0.08151586274888993----
# ---- Permutation avg. explained variance: 0.05978096287793411----
# Permutation: 96
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:34:53.437901
# R2 loop: -0.142027431051722
# Explained var: -0.026513962109645073
# correlation: [[0.15624768]]
# Explained variance, chronic only:  -0.13937852143617224
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:34:55.531572
# R2 loop: -0.10175640426327748
# Explained var: -0.006747405895018321
# correlation: [[0.06071043]]
# Explained variance, chronic only:  0.03573740107672074
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:57.631807
# R2 loop: -0.336061973000356
# Explained var: -0.30755109715265916
# correlation: [[-0.30892435]]
# Explained variance, chronic only:  -0.29665063455110463
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:34:59.782293
# R2 loop: 0.19530358851966445
# Explained var: 0.21187522001060355
# correlation: [[0.62381019]]
# Explained variance, chronic only:  0.24123446620658362
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:35:01.890269
# R2 loop: 0.0236829378381731
# Explained var: 0.024311984521962926
# correlation: [[0.32158178]]
# Explained variance, chronic only:  0.007991984620994041
# ---- Permutation avg. chronic explained variance: -0.030213060816595694----
# ---- Permutation avg. explained variance: -0.020925052124951216----
# Permutation: 97
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:35:03.999841
# R2 loop: -0.12027474512382441
# Explained var: -0.11659216730032074
# correlation: [[-0.08014931]]
# Explained variance, chronic only:  -0.10184594882439102
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:35:06.444647
# R2 loop: -0.15528856569402238
# Explained var: 0.015147553628097055
# correlation: [[0.56459094]]
# Explained variance, chronic only:  0.014185459124718025
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:35:08.719057
# R2 loop: 0.03389142398568534
# Explained var: 0.047287082529667845
# correlation: [[0.21791532]]
# Explained variance, chronic only:  0.06258392802748314
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:35:10.824505
# R2 loop: -0.01589892919395286
# Explained var: -0.007364877627012989
# correlation: [[0.08205731]]
# Explained variance, chronic only:  0.005484067727104525
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:35:13.328834
# R2 loop: -0.30979946372380396
# Explained var: -0.023458341976188013
# correlation: [[-0.0991137]]
# Explained variance, chronic only:  -0.033684392733142055
# ---- Permutation avg. chronic explained variance: -0.010655377335645477----
# ---- Permutation avg. explained variance: -0.016996150149151366----
# Permutation: 98
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:35:15.778321
# R2 loop: 0.05180418131752551
# Explained var: 0.07679586577937303
# correlation: [[0.36141915]]
# Explained variance, chronic only:  0.08219739006338522
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:35:18.070410
# R2 loop: 0.17671905646223451
# Explained var: 0.18693655446182167
# correlation: [[0.51509961]]
# Explained variance, chronic only:  0.18363576334369602
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:35:20.467395
# R2 loop: 0.09210863612767084
# Explained var: 0.09834868195173563
# correlation: [[0.35751532]]
# Explained variance, chronic only:  0.07875116440998242
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:35:22.938270
# R2 loop: -0.12456328619877666
# Explained var: -0.0978304936715424
# correlation: [[-0.03699832]]
# Explained variance, chronic only:  -0.08375492643699167
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:35:25.084809
# R2 loop: 0.05143507407321857
# Explained var: 0.08731491941769887
# correlation: [[0.50143287]]
# Explained variance, chronic only:  0.054862629838096755
# ---- Permutation avg. chronic explained variance: 0.06313840424363375----
# ---- Permutation avg. explained variance: 0.07031310558781736----
# Permutation: 99
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:35:27.444036
# R2 loop: -0.23258846085510432
# Explained var: -0.19598404854388396
# correlation: [[-0.33897452]]
# Explained variance, chronic only:  -0.20931304427949216
# (85, 106)
# (85, 1)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:35:29.723295
# R2 loop: -0.06132321514368866
# Explained var: 0.02057889791149814
# correlation: [[0.14704245]]
# Explained variance, chronic only:  0.0012825428180769372
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:35:32.004292
# R2 loop: -0.03808799966382437
# Explained var: 0.030191923035315926
# correlation: [[0.29149539]]
# Explained variance, chronic only:  0.04642541053962068
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:35:34.497267
# R2 loop: 0.017170990017889798
# Explained var: 0.038773759826015275
# correlation: [[0.19696244]]
# Explained variance, chronic only:  0.03338159077796643
# (86, 106)
# (86, 1)
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:35:36.878206
# R2 loop: -0.4610730585283527
# Explained var: -0.3314838713796844
# correlation: [[-0.40369042]]
# Explained variance, chronic only:  -0.3994271624218264
# ---- Permutation avg. chronic explained variance: -0.1055301325131309----
# ---- Permutation avg. explained variance: -0.0875846678301478----

# %%
# 
fig, axes = plt.subplots(1, 5, sharex=False, figsize=(20,5))

axes[0].set_title('Handedness: \n right dominant =1 \n left dominant =2, \n ambidextrous =3')
axes[1].set_title('Race: \n african american =3 \n caucasian =5, \n unknown =7')
axes[2].set_title('Education (years)')

sns.countplot(x="HANDEDNESS", data=clin_vars, ax=axes[0])
#1. american indian, 2. asian, 3. african american, 5. caucasian, 6. other, 7. unknown, 8. native pacific islander
sns.countplot(x='RACE', data=clin_vars, ax=axes[1])
#level of education (years)
sns.histplot(x='EDUC', data=clin_vars,ax=axes[2])
#Yes =1, No =2, borderline =3, unknown=4
sns.histplot(x='Diabetes_type_II', data=clin_vars,ax=axes[3])

sns.histplot(x='Cardiac_history', data=new,ax=axes[4])
# Out:
# <AxesSubplot:xlabel='Cardiac_history', ylabel='Count'>

# %%
results_dir='/home/ubuntu/cognition_iowa/results/clin_vars/'

# predictions with clinical variables only

import datetime

# feature selection type
f=['correlation']

for featselect in f: 
    #set the number of folds you want in the inner and outer folds of the nested cross-validation
    k = 5

    #set the proportion of data you want in your training set
    train_size = .8

    #X=np.concatenate([sc, fc], axis=1)
    X=np.array(clin_vars)
    X=prepare_data(X)
    #set y to be the measure you want to predict
    #Y = np.log(np.array(tmt))

    Y=np.array(wais)
    Y=np.reshape(Y, (107,1))
    
    # range of alphas
    n_alphas=20
    alpha_start=-1
    alpha_end=2
    alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

    #number of features (# pricipal components or variables to retain)
    feat_start=1
    feat_end=20
    n_feats=feat_end-feat_start+1
    feats = np.linspace(feat_start, feat_end, n_feats, dtype=int)

    # initialize lists to store model results for each permuation
    allR2=[]
    meanR2=[]
    features=[]
    bestalphas=[]
    importance=[]
    allexpl_var=[]
    correlations=[]
    chronic_allexpl_var=[]
    #joblib-based parallelism to increase speed,
    ytestc=[]
    ypredc=[]
    for p in range(0, 100):
        outer_cv = StratifiedKFold(n_splits=k, shuffle=True, random_state=p)
        print('Permutation: ' + str(p))
        # initialize lists to store model results for eah fold
        R2=[]
        featur=[]
        best_alphas=[]
        impt=[] 
        expl_var=[]
        chronic_explvar=[]
        cor=[]
        for train, test in outer_cv.split(X, chronic_id):
            begin_time = datetime.datetime.now()
            
            chronic_bin=chronic_id[train]
            chronic_test=chronic_id[test]
            
            xtrain, xtest=scale_data(X[train,0:2], X[test,0:2])
            xtrain=np.hstack((xtrain, X[train,2:21]))
            xtest=np.hstack((xtest, X[test,2:21]))

            # select model using training data
            bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv_strat(k, xtrain, Y[train], chronic_bin, featselect, alphas, feats)

            # using optimal num. of features, select final features using entire training data.

            if featselect=='correlation':
                x_train_featselect,x_test_featureselect,ind = feature_select_correlation(xtrain,xtest, Y[train], bestfeats)
                featur.append(ind)

            elif featselect=='PCA':
                x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(xtrain,xtest, bestfeats)
                featur.append(ind)
                
            chronic_bin=np.reshape(np.double(chronic_bin), (x_train_featselect.shape[0], 1))
            x_train_featselect=np.concatenate((x_train_featselect, chronic_bin),axis=1)
        
            chronic_test=np.reshape(np.double(chronic_test), (x_test_featureselect.shape[0], 1))
            x_test_featureselect=np.concatenate((x_test_featureselect, chronic_test),axis=1)
                
            # initialize Ridge regression with alpha selected from hyperparameter search
            regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)

            # fit model 
            y_pred = regr.fit(x_train_featselect, Y[train]).predict(x_test_featureselect)

            # store results for each fold k
            impt.append(regr.coef_)
            R2.append(r2_score(Y[test], y_pred))
            expl_var.append(explained_variance_score(Y[test], y_pred))

            best_alphas.append(bestalpha)
            print('time to run loop: ' + str(datetime.datetime.now() - begin_time)) 
            print("R2 loop: " + str(r2_score(Y[test], y_pred)))
            print("Explained var: " + str(explained_variance_score(Y[test], y_pred)))
            print("correlation: " + str(np_pearson_cor(Y[test], y_pred)))
            
            chronicsubs_test=chronic_id[test]==True
            chronicsubs_train=chronic_id[train]==True
            chronicsubs_test=chronicsubs_test.flatten()
            chronicsubs_train=chronicsubs_train.flatten()
            cor.append(np_pearson_cor(Y[test], y_pred))
            Xtest=x_test_featureselect
            Xtrain=X[train]
            Ytest=Y[test]

            ytrue_chronic = Ytest[chronicsubs_test]
            xtest_chronic=Xtest[chronicsubs_test]
            
            ytestc.append(ytrue_chronic)
            
            ychronic_pred = regr.fit(x_train_featselect, Y[train]).predict(xtest_chronic)
            print("Explained variance, chronic only:  " + str(explained_variance_score(ytrue_chronic, ychronic_pred)))
            ypredc.append(ychronic_pred)

            chronic_explvar.append(explained_variance_score(ytrue_chronic, ychronic_pred))
            
 
        # store results for each permutation p

        allexpl_var.append(expl_var)
        bestalphas.append(best_alphas)
        importance.append(impt)
        chronic_allexpl_var.append(chronic_explvar)
        correlations.append(cor)
        print("---- Permutation avg. chronic explained variance: " + str(np.mean(chronic_explvar)) + "----")
        np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_chronic_all_explvar.txt', chronic_allexpl_var, delimiter=',')

        print("---- Permutation avg. explained variance: " + str(np.mean(expl_var)) + "----")
        np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_all_explvar.txt', expl_var, delimiter=',')

        output = open(results_dir + featselect + 'p' + str(p) + '_SC_features.pkl', 'wb')
        pickle.dump(featur, output)
        output.close()
        
        output = open(results_dir + featselect + 'p' + str(p) + '_SC_correlations.pkl', 'wb')
        pickle.dump(correlations, output)
        output.close()

        output = open(results_dir + featselect + 'p' + str(p) + '_SC_bestalphas.pkl', 'wb')
        pickle.dump(best_alphas, output)
        output.close()
     
        output = open(results_dir + featselect + 'p' + str(p) + '_SC_varimpt.pkl', 'wb')
        pickle.dump(importance, output)
        output.close()
# Out:
# Final size of X: (107, 21)
# Permutation: 0
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:02.007113
# R2 loop: -0.20743356674430435
# Explained var: -0.14230168370059926
# correlation: [[-0.10895414]]
# Explained variance, chronic only:  -0.0967515222054316
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.939912
# R2 loop: 0.16651799063359773
# Explained var: 0.1763260881519123
# correlation: [[0.56715521]]
# Explained variance, chronic only:  0.2903957449033935
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.887099
# R2 loop: 0.11788844971614587
# Explained var: 0.13068329474326135
# correlation: [[0.48181386]]
# Explained variance, chronic only:  0.14868205587708727
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.932265
# R2 loop: -0.028943257502255015
# Explained var: 0.07749339242426634
# correlation: [[0.27840531]]
# Explained variance, chronic only:  -0.04169585108078788
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.892083
# R2 loop: 0.09811170590487284
# Explained var: 0.1893307072173166
# correlation: [[0.4486017]]
# Explained variance, chronic only:  0.19173784793439141
# ---- Permutation avg. chronic explained variance: 0.09847365508573054----
# ---- Permutation avg. explained variance: 0.08630635976723147----
# Permutation: 1
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.924731
# R2 loop: 0.06032187151373847
# Explained var: 0.06033998047444944
# correlation: [[0.28309874]]
# Explained variance, chronic only:  0.2690264222785411
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.031546
# R2 loop: 0.1008027498998959
# Explained var: 0.11583079481337188
# correlation: [[0.37913627]]
# Explained variance, chronic only:  0.10756617019658987
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.103695
# R2 loop: -0.10822658914098549
# Explained var: -0.09815371215104274
# correlation: [[-0.08816093]]
# Explained variance, chronic only:  -0.08805763220393725
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.123612
# R2 loop: -0.017079352805611903
# Explained var: -0.004100142944969853
# correlation: [[0.23560437]]
# Explained variance, chronic only:  0.007787787062605189
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.058221
# R2 loop: 0.06026241312335201
# Explained var: 0.1158382222549329
# correlation: [[0.35414475]]
# Explained variance, chronic only:  0.07257551423112474
# ---- Permutation avg. chronic explained variance: 0.07377965231298474----
# ---- Permutation avg. explained variance: 0.037951028489348324----
# Permutation: 2
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.985661
# R2 loop: -0.024714760614116482
# Explained var: -0.013446823717519374
# correlation: [[0.1437914]]
# Explained variance, chronic only:  0.01410386484081605
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.987820
# R2 loop: -0.03056681699610797
# Explained var: -0.022558264490215363
# correlation: [[0.09816424]]
# Explained variance, chronic only:  -0.013908591125029401
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.084019
# R2 loop: 0.06634496241114496
# Explained var: 0.06651608196766945
# correlation: [[0.26676296]]
# Explained variance, chronic only:  0.12463748653649642
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.031077
# R2 loop: 0.12878913304850537
# Explained var: 0.1288988629176967
# correlation: [[0.403626]]
# Explained variance, chronic only:  0.07916873030727312
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.014804
# R2 loop: -0.10756755839603449
# Explained var: -0.10727600098764656
# correlation: [[0.00778016]]
# Explained variance, chronic only:  0.054062515170207326
# ---- Permutation avg. chronic explained variance: 0.0516128011459527----
# ---- Permutation avg. explained variance: 0.010426771137996971----
# Permutation: 3
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.022645
# R2 loop: -0.0029215503982622515
# Explained var: 0.0067906853537185174
# correlation: [[0.14781486]]
# Explained variance, chronic only:  0.09843316617522713
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.017950
# R2 loop: 0.08135388158809298
# Explained var: 0.09617701859788363
# correlation: [[0.3267378]]
# Explained variance, chronic only:  0.08205964493315909
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.979448
# R2 loop: 0.048123267827019145
# Explained var: 0.10324476489655421
# correlation: [[0.32522949]]
# Explained variance, chronic only:  0.11314031787966516
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.968035
# R2 loop: -0.048172968801395655
# Explained var: 0.12230750868998275
# correlation: [[0.35254884]]
# Explained variance, chronic only:  0.04294337388201008
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.987297
# R2 loop: 0.07707157452467028
# Explained var: 0.08240191005022379
# correlation: [[0.37395884]]
# Explained variance, chronic only:  0.07499371538976085
# ---- Permutation avg. chronic explained variance: 0.08231404365196446----
# ---- Permutation avg. explained variance: 0.08218437751767257----
# Permutation: 4
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.003532
# R2 loop: 0.03978668831369847
# Explained var: 0.09465445992744215
# correlation: [[0.3102514]]
# Explained variance, chronic only:  0.09149691279414263
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.991015
# R2 loop: 0.08555057277551181
# Explained var: 0.08555941457127592
# correlation: [[0.32070744]]
# Explained variance, chronic only:  0.08123709263919165
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.011186
# R2 loop: -0.0316823971118918
# Explained var: 0.01928136730805996
# correlation: [[0.15477101]]
# Explained variance, chronic only:  0.013821854321481197
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.983450
# R2 loop: 0.09359708201400208
# Explained var: 0.1102101112729501
# correlation: [[0.35810605]]
# Explained variance, chronic only:  0.09161426086764635
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.978602
# R2 loop: -0.008124078464189388
# Explained var: 0.027643619243661544
# correlation: [[0.29515435]]
# Explained variance, chronic only:  -0.055094007006213364
# ---- Permutation avg. chronic explained variance: 0.04461522272324969----
# ---- Permutation avg. explained variance: 0.06746979446467793----
# Permutation: 5
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.028417
# R2 loop: 0.1192079853553838
# Explained var: 0.1315014930292716
# correlation: [[0.36502185]]
# Explained variance, chronic only:  0.08640944518409255
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.995343
# R2 loop: -0.2662221895834962
# Explained var: 0.11093245343340308
# correlation: [[0.35327809]]
# Explained variance, chronic only:  0.09335068761131404
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.916486
# R2 loop: 0.09143964712448316
# Explained var: 0.10973157978515968
# correlation: [[0.5418485]]
# Explained variance, chronic only:  0.1069129418840632
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.952415
# R2 loop: -0.2624506602493044
# Explained var: -0.24088846717280354
# correlation: [[-0.20491333]]
# Explained variance, chronic only:  -0.18980346142806792
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.935920
# R2 loop: 0.039689810023274874
# Explained var: 0.16789209568187768
# correlation: [[0.52095722]]
# Explained variance, chronic only:  0.26868564332298617
# ---- Permutation avg. chronic explained variance: 0.0731110513148776----
# ---- Permutation avg. explained variance: 0.055833830951381704----
# Permutation: 6
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.927780
# R2 loop: 0.014747976819489916
# Explained var: 0.019915459993290474
# correlation: [[0.18559635]]
# Explained variance, chronic only:  0.010397095090296293
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.027411
# R2 loop: 0.05984081538873676
# Explained var: 0.061921648149404485
# correlation: [[0.35850461]]
# Explained variance, chronic only:  0.04716559148902688
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.107682
# R2 loop: 0.03097045881489635
# Explained var: 0.04746707105506642
# correlation: [[0.21956673]]
# Explained variance, chronic only:  0.08262002666639678
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.061991
# R2 loop: 0.10527506510646889
# Explained var: 0.10545672779709514
# correlation: [[0.3377863]]
# Explained variance, chronic only:  0.07990179812864528
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.981113
# R2 loop: 0.02749750556101982
# Explained var: 0.030463529787595034
# correlation: [[0.22244196]]
# Explained variance, chronic only:  0.09637676998262279
# ---- Permutation avg. chronic explained variance: 0.0632922562713976----
# ---- Permutation avg. explained variance: 0.05304488735649031----
# Permutation: 7
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.999798
# R2 loop: -0.040093426038191105
# Explained var: 0.027171717320710442
# correlation: [[0.18073398]]
# Explained variance, chronic only:  0.039126024668292736
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.988671
# R2 loop: 0.07196563473709872
# Explained var: 0.07515485442323755
# correlation: [[0.32997038]]
# Explained variance, chronic only:  0.05756920372954988
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.890528
# R2 loop: -0.16442603874969564
# Explained var: -0.10612914513518157
# correlation: [[0.16032418]]
# Explained variance, chronic only:  -0.18492741731482076
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.935667
# R2 loop: 0.10699481752735518
# Explained var: 0.12355130062642039
# correlation: [[0.35154288]]
# Explained variance, chronic only:  0.15228354945097655
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.929229
# R2 loop: -0.23274597950678988
# Explained var: -0.21238039880862658
# correlation: [[-0.21559824]]
# Explained variance, chronic only:  -0.25140034485443885
# ---- Permutation avg. chronic explained variance: -0.03746979686408809----
# ---- Permutation avg. explained variance: -0.018526334314687955----
# Permutation: 8
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.874015
# R2 loop: -0.13822627652286323
# Explained var: -0.10476439856843656
# correlation: [[0.02211226]]
# Explained variance, chronic only:  -0.11271696345970672
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.936447
# R2 loop: -0.0193694098107009
# Explained var: -0.012762753550121131
# correlation: [[0.21909751]]
# Explained variance, chronic only:  -0.012178106590294613
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.986990
# R2 loop: 0.13368751640543597
# Explained var: 0.13467977071186432
# correlation: [[0.48496798]]
# Explained variance, chronic only:  0.13930757042829378
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.985027
# R2 loop: -0.008644289095182778
# Explained var: 0.004290781000881316
# correlation: [[0.10133156]]
# Explained variance, chronic only:  0.06893080452806732
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.996896
# R2 loop: 0.004630792911107906
# Explained var: 0.07460219923850797
# correlation: [[0.28780302]]
# Explained variance, chronic only:  0.07700702959779226
# ---- Permutation avg. chronic explained variance: 0.032070066900830405----
# ---- Permutation avg. explained variance: 0.019209119766539183----
# Permutation: 9
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.983538
# R2 loop: -0.009674547948856027
# Explained var: 0.030915665129537917
# correlation: [[0.26552997]]
# Explained variance, chronic only:  0.04570445794180966
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.019526
# R2 loop: -0.03606007432974523
# Explained var: 0.04600046154644544
# correlation: [[0.21450424]]
# Explained variance, chronic only:  0.01127876898239999
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.960184
# R2 loop: 0.09430266598348025
# Explained var: 0.13798243496761142
# correlation: [[0.42078861]]
# Explained variance, chronic only:  0.113466948381168
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.986272
# R2 loop: -0.2958632679657305
# Explained var: -0.2917916225006205
# correlation: [[0.15296595]]
# Explained variance, chronic only:  -0.04925018607531495
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.033617
# R2 loop: -0.12682376010960383
# Explained var: -0.06801132745518501
# correlation: [[0.04103074]]
# Explained variance, chronic only:  -0.049665783904602856
# ---- Permutation avg. chronic explained variance: 0.014306841065091969----
# ---- Permutation avg. explained variance: -0.028980877662442152----
# Permutation: 10
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.896868
# R2 loop: 0.15970854357322384
# Explained var: 0.1619347691750893
# correlation: [[0.41338428]]
# Explained variance, chronic only:  0.13482266627666517
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.958502
# R2 loop: -0.25797351404668944
# Explained var: -0.08855088574951075
# correlation: [[-0.065392]]
# Explained variance, chronic only:  -0.07076833733221521
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.970813
# R2 loop: -0.009779754913743055
# Explained var: 0.022557591928628495
# correlation: [[0.16038037]]
# Explained variance, chronic only:  -0.00038032426776557493
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.976676
# R2 loop: -0.1322351642146049
# Explained var: 0.04067697081228416
# correlation: [[0.20194004]]
# Explained variance, chronic only:  0.026846359029842226
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.985015
# R2 loop: -0.0033797209564649933
# Explained var: 0.10244671528369098
# correlation: [[0.32399985]]
# Explained variance, chronic only:  0.07882625092548468
# ---- Permutation avg. chronic explained variance: 0.033869322926402254----
# ---- Permutation avg. explained variance: 0.04781303229003644----
# Permutation: 11
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.966904
# R2 loop: -0.10887531996873534
# Explained var: 0.06246185778242486
# correlation: [[0.27791047]]
# Explained variance, chronic only:  -0.03068897269801174
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.986662
# R2 loop: -0.17746034465526006
# Explained var: -0.009342536243071908
# correlation: [[0.10790792]]
# Explained variance, chronic only:  -0.025867514974058814
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.957694
# R2 loop: -0.1235958778278683
# Explained var: -0.10332405623412533
# correlation: [[0.18621094]]
# Explained variance, chronic only:  0.10255280009836987
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.971192
# R2 loop: 0.13377559004331385
# Explained var: 0.14247574963823517
# correlation: [[0.4178115]]
# Explained variance, chronic only:  0.2092820705460544
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.995593
# R2 loop: 0.26585784921905675
# Explained var: 0.29149322781485165
# correlation: [[0.56345653]]
# Explained variance, chronic only:  0.2573161653118511
# ---- Permutation avg. chronic explained variance: 0.10251890965684096----
# ---- Permutation avg. explained variance: 0.0767528485516629----
# Permutation: 12
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.990719
# R2 loop: -0.2723306735257931
# Explained var: -0.22890253082206358
# correlation: [[0.14589357]]
# Explained variance, chronic only:  -0.22764874756352893
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.958753
# R2 loop: 0.16400110860680883
# Explained var: 0.16410663889411992
# correlation: [[0.59826613]]
# Explained variance, chronic only:  0.1422323371134624
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.953877
# R2 loop: 0.07000103175678773
# Explained var: 0.09308157102008241
# correlation: [[0.30862673]]
# Explained variance, chronic only:  0.20263164305039016
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.898360
# R2 loop: 0.006872492711785472
# Explained var: 0.03204519610286516
# correlation: [[0.18547724]]
# Explained variance, chronic only:  0.006134696129404205
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.879738
# R2 loop: 0.047826366880002635
# Explained var: 0.11301818245065964
# correlation: [[0.33634236]]
# Explained variance, chronic only:  0.051726064952130724
# ---- Permutation avg. chronic explained variance: 0.03501519873637171----
# ---- Permutation avg. explained variance: 0.03466981152913271----
# Permutation: 13
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.914220
# R2 loop: 0.039600882201611176
# Explained var: 0.04202322130363567
# correlation: [[0.20546019]]
# Explained variance, chronic only:  -0.012818516699524496
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.014438
# R2 loop: 0.18718933258745807
# Explained var: 0.18852478559538477
# correlation: [[0.49140623]]
# Explained variance, chronic only:  0.2263502760652345
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.975446
# R2 loop: 0.13184795672403804
# Explained var: 0.1318855405377325
# correlation: [[0.41140943]]
# Explained variance, chronic only:  0.053773873459648125
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.014591
# R2 loop: 0.0299053718964436
# Explained var: 0.10238509961599052
# correlation: [[0.32074691]]
# Explained variance, chronic only:  0.15565228542058873
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.947177
# R2 loop: -0.7452314223305436
# Explained var: -0.5797175080969297
# correlation: [[-0.0384437]]
# Explained variance, chronic only:  -0.24063558788426587
# ---- Permutation avg. chronic explained variance: 0.0364644660723362----
# ---- Permutation avg. explained variance: -0.022979772208837245----
# Permutation: 14
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.951725
# R2 loop: 0.07430840349988466
# Explained var: 0.10826987144625022
# correlation: [[0.33599163]]
# Explained variance, chronic only:  0.16217728083861993
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.966506
# R2 loop: -0.06337631212497019
# Explained var: 0.00734790148617781
# correlation: [[0.2700602]]
# Explained variance, chronic only:  -0.13989765322806913
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.071231
# R2 loop: -0.09234135278516509
# Explained var: -0.024138520818322906
# correlation: [[0.08500456]]
# Explained variance, chronic only:  0.032483551193741134
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.959929
# R2 loop: -0.10429115522612986
# Explained var: -0.018947252133707737
# correlation: [[0.14401103]]
# Explained variance, chronic only:  -0.15063709366528188
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.950798
# R2 loop: 0.0852630317992783
# Explained var: 0.10447709910920366
# correlation: [[0.34250329]]
# Explained variance, chronic only:  0.113596979046654
# ---- Permutation avg. chronic explained variance: 0.00354461283713281----
# ---- Permutation avg. explained variance: 0.03540181981792021----
# Permutation: 15
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.952234
# R2 loop: -0.013631265040038087
# Explained var: -0.003032896515398953
# correlation: [[0.16487304]]
# Explained variance, chronic only:  0.0029102526976708676
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.882219
# R2 loop: -0.021984556451055237
# Explained var: 0.09623179031648743
# correlation: [[0.37634523]]
# Explained variance, chronic only:  0.061232112808968564
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.943100
# R2 loop: 0.044244114397368306
# Explained var: 0.07213250231086654
# correlation: [[0.26890968]]
# Explained variance, chronic only:  0.218927398943083
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.009854
# R2 loop: -0.43354117453715335
# Explained var: -0.42950675645964154
# correlation: [[0.06619454]]
# Explained variance, chronic only:  -0.27921537187825085
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.015947
# R2 loop: -0.09693990900868732
# Explained var: -0.08975361060624776
# correlation: [[-0.13797999]]
# Explained variance, chronic only:  -0.1354276166293229
# ---- Permutation avg. chronic explained variance: -0.026314644811570264----
# ---- Permutation avg. explained variance: -0.07078579419078686----
# Permutation: 16
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.003235
# R2 loop: -0.043426088982042144
# Explained var: -0.02693632794076728
# correlation: [[0.16398462]]
# Explained variance, chronic only:  0.07476362501924727
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.992994
# R2 loop: 0.0664008909802809
# Explained var: 0.0771774405299468
# correlation: [[0.47043184]]
# Explained variance, chronic only:  0.05852320365502328
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.994289
# R2 loop: 0.003947321375742385
# Explained var: 0.07733415934767907
# correlation: [[0.33619577]]
# Explained variance, chronic only:  0.06977821465513079
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.884786
# R2 loop: 0.18929241083849868
# Explained var: 0.19198578457845117
# correlation: [[0.43817582]]
# Explained variance, chronic only:  0.14393329594662752
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.885904
# R2 loop: -0.20169495170005303
# Explained var: -0.1862511520312644
# correlation: [[-0.11598808]]
# Explained variance, chronic only:  -0.2212889140665555
# ---- Permutation avg. chronic explained variance: 0.025141885041894674----
# ---- Permutation avg. explained variance: 0.026661980896809066----
# Permutation: 17
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.005420
# R2 loop: 0.019879321222111335
# Explained var: 0.026538097874390876
# correlation: [[0.17784008]]
# Explained variance, chronic only:  0.12325492085536804
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.022539
# R2 loop: 0.06402273050344609
# Explained var: 0.14505657060823918
# correlation: [[0.49711371]]
# Explained variance, chronic only:  0.19137545702792114
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.986430
# R2 loop: 0.03832178536464825
# Explained var: 0.05190079795639835
# correlation: [[0.23141858]]
# Explained variance, chronic only:  -0.00943181059022069
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.053560
# R2 loop: -0.1978385575380155
# Explained var: 0.01031971858325953
# correlation: [[0.17986091]]
# Explained variance, chronic only:  0.003797347567583209
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.021428
# R2 loop: -0.16574451923842015
# Explained var: -0.12059627328128242
# correlation: [[0.01025361]]
# Explained variance, chronic only:  -0.04541099752376154
# ---- Permutation avg. chronic explained variance: 0.052716983467378034----
# ---- Permutation avg. explained variance: 0.0226437823482011----
# Permutation: 18
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.016411
# R2 loop: 0.05714588935893328
# Explained var: 0.11204504798475301
# correlation: [[0.34793855]]
# Explained variance, chronic only:  0.20300387464066372
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.951157
# R2 loop: 0.07588623250588122
# Explained var: 0.1006398409252186
# correlation: [[0.32557195]]
# Explained variance, chronic only:  0.12096440849199308
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.994363
# R2 loop: -0.057322540535484245
# Explained var: -0.03032268977026975
# correlation: [[0.04808223]]
# Explained variance, chronic only:  -0.051190643536241254
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.036759
# R2 loop: 0.1292079691073713
# Explained var: 0.21072537129318092
# correlation: [[0.46376623]]
# Explained variance, chronic only:  0.28926759566416704
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.963900
# R2 loop: 0.1294284871494582
# Explained var: 0.16184232133710408
# correlation: [[0.4192501]]
# Explained variance, chronic only:  -0.05123114637984738
# ---- Permutation avg. chronic explained variance: 0.10216281777614704----
# ---- Permutation avg. explained variance: 0.11098597835399737----
# Permutation: 19
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.903034
# R2 loop: -0.2523963151387849
# Explained var: -0.16531924490812
# correlation: [[-0.03092523]]
# Explained variance, chronic only:  -0.296027715250869
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.972833
# R2 loop: -0.007750170753842323
# Explained var: 0.06667497381704302
# correlation: [[0.25838561]]
# Explained variance, chronic only:  0.008436681886808572
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.010798
# R2 loop: 0.017687120708335002
# Explained var: 0.03876701948742545
# correlation: [[0.19720752]]
# Explained variance, chronic only:  0.07718216300716285
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.025367
# R2 loop: 0.04136737745342001
# Explained var: 0.06515475562432105
# correlation: [[0.2607009]]
# Explained variance, chronic only:  0.02519763993137325
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.084839
# R2 loop: 0.11787348572624734
# Explained var: 0.11827987095390202
# correlation: [[0.35601232]]
# Explained variance, chronic only:  0.12425954544198115
# ---- Permutation avg. chronic explained variance: -0.012190336996708639----
# ---- Permutation avg. explained variance: 0.024711474994914308----
# Permutation: 20
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.983905
# R2 loop: -0.18339493053423417
# Explained var: -0.0547087128488819
# correlation: [[0.00464428]]
# Explained variance, chronic only:  -0.0641505389754482
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.035191
# R2 loop: -0.011102749497473363
# Explained var: 0.032105253566548586
# correlation: [[0.19952212]]
# Explained variance, chronic only:  -0.03153343527837249
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.887926
# R2 loop: -0.435085995189161
# Explained var: -0.2504248753839382
# correlation: [[0.03593079]]
# Explained variance, chronic only:  0.01082049387377193
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.881560
# R2 loop: 0.2910049513652504
# Explained var: 0.30351628843943346
# correlation: [[0.63208091]]
# Explained variance, chronic only:  0.2674997687634465
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.875488
# R2 loop: 0.10698728254135581
# Explained var: 0.11073226214019938
# correlation: [[0.34371298]]
# Explained variance, chronic only:  0.13809032094194973
# ---- Permutation avg. chronic explained variance: 0.0641453218650695----
# ---- Permutation avg. explained variance: 0.028244043182672263----
# Permutation: 21
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.918366
# R2 loop: 0.011828374994548363
# Explained var: 0.08954025144938427
# correlation: [[0.299483]]
# Explained variance, chronic only:  0.12677050841460813
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.995207
# R2 loop: 0.15971593050802846
# Explained var: 0.1621691811179099
# correlation: [[0.51493324]]
# Explained variance, chronic only:  0.1549116958427561
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.989352
# R2 loop: -0.1730930119628682
# Explained var: -0.17308684418698017
# correlation: [[0.00072567]]
# Explained variance, chronic only:  -0.11436901799530608
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.069382
# R2 loop: -0.019953775240295846
# Explained var: 0.06972399013108366
# correlation: [[0.26578444]]
# Explained variance, chronic only:  0.05740934275189624
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.097268
# R2 loop: 0.03766532425658331
# Explained var: 0.037739274080965224
# correlation: [[0.21825478]]
# Explained variance, chronic only:  -0.04037039932408182
# ---- Permutation avg. chronic explained variance: 0.036870425937974516----
# ---- Permutation avg. explained variance: 0.03721717051847258----
# Permutation: 22
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.065252
# R2 loop: 0.1876628839264214
# Explained var: 0.18821854841872188
# correlation: [[0.4342046]]
# Explained variance, chronic only:  0.16526872087525468
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.018336
# R2 loop: -0.03825136866717749
# Explained var: -0.02633633389238743
# correlation: [[0.19540534]]
# Explained variance, chronic only:  -0.12039192833809476
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.008769
# R2 loop: 0.10045276291204741
# Explained var: 0.14631966191171397
# correlation: [[0.61712247]]
# Explained variance, chronic only:  0.12047749435503974
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.876632
# R2 loop: -0.042208589354186365
# Explained var: 0.009289253764235839
# correlation: [[0.19910118]]
# Explained variance, chronic only:  -0.02319974866759078
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.969480
# R2 loop: 0.12962891272782906
# Explained var: 0.13360377380191235
# correlation: [[0.37090441]]
# Explained variance, chronic only:  0.2829211053384061
# ---- Permutation avg. chronic explained variance: 0.085015128712603----
# ---- Permutation avg. explained variance: 0.09021898080083932----
# Permutation: 23
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.940936
# R2 loop: 0.005455991501171931
# Explained var: 0.09541089082737575
# correlation: [[0.39642223]]
# Explained variance, chronic only:  0.01300770454257083
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.928982
# R2 loop: 0.020569421437618085
# Explained var: 0.02405582372174986
# correlation: [[0.15578844]]
# Explained variance, chronic only:  0.049964629874093114
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.922421
# R2 loop: 0.04286046590314574
# Explained var: 0.16541959865316913
# correlation: [[0.58532794]]
# Explained variance, chronic only:  0.18264586034975505
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.973323
# R2 loop: 0.014605735895433125
# Explained var: 0.02700478248996674
# correlation: [[0.17193091]]
# Explained variance, chronic only:  -0.00017423694591078842
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.921017
# R2 loop: -0.3680445084310482
# Explained var: -0.2413268486106881
# correlation: [[-0.1526877]]
# Explained variance, chronic only:  -0.03454443517328465
# ---- Permutation avg. chronic explained variance: 0.042179904529444714----
# ---- Permutation avg. explained variance: 0.014112849416314677----
# Permutation: 24
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.968543
# R2 loop: 0.09414909493172641
# Explained var: 0.1061403038073766
# correlation: [[0.36904316]]
# Explained variance, chronic only:  0.07770076813904248
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.942028
# R2 loop: -1.1785693030672064
# Explained var: -0.039081365950274005
# correlation: [[0.13032144]]
# Explained variance, chronic only:  -0.11028160365175688
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.071356
# R2 loop: -0.10350174304919646
# Explained var: 0.06330945054237058
# correlation: [[0.26078676]]
# Explained variance, chronic only:  0.11642152132718664
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.016187
# R2 loop: 0.03814504460471302
# Explained var: 0.07615784701409833
# correlation: [[0.32322173]]
# Explained variance, chronic only:  0.06496277401457096
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.960307
# R2 loop: -0.23513270537157593
# Explained var: 0.029092321216995898
# correlation: [[0.31263308]]
# Explained variance, chronic only:  0.037320380179895585
# ---- Permutation avg. chronic explained variance: 0.037224768001787756----
# ---- Permutation avg. explained variance: 0.04712371132611348----
# Permutation: 25
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.001990
# R2 loop: 0.13547554869997847
# Explained var: 0.16829947338450368
# correlation: [[0.42690114]]
# Explained variance, chronic only:  0.2167891562610269
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.055764
# R2 loop: -0.011920915340931426
# Explained var: -0.002917218582588532
# correlation: [[0.1263827]]
# Explained variance, chronic only:  -0.052906065402223534
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.985182
# R2 loop: -0.005825548119607893
# Explained var: -0.005241620271445813
# correlation: [[0.10207574]]
# Explained variance, chronic only:  0.013330898078846132
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.959481
# R2 loop: -0.2245613985503332
# Explained var: -0.04503268349243972
# correlation: [[0.20519618]]
# Explained variance, chronic only:  -0.014441245488542531
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.985157
# R2 loop: 0.07567149373621918
# Explained var: 0.08230279673187524
# correlation: [[0.29786224]]
# Explained variance, chronic only:  0.07213170235210653
# ---- Permutation avg. chronic explained variance: 0.0469808891602427----
# ---- Permutation avg. explained variance: 0.03948214955398097----
# Permutation: 26
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.082619
# R2 loop: 0.05279956735864655
# Explained var: 0.08485584806167223
# correlation: [[0.29622244]]
# Explained variance, chronic only:  0.0400657931257733
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.007946
# R2 loop: 0.058728138807846664
# Explained var: 0.05881793964463211
# correlation: [[0.27130275]]
# Explained variance, chronic only:  0.05780982714354288
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.101681
# R2 loop: -0.4162133333014837
# Explained var: -0.3683131521554386
# correlation: [[-0.28601909]]
# Explained variance, chronic only:  -0.32402694523686293
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.994983
# R2 loop: 0.13899031296308073
# Explained var: 0.14001249953252093
# correlation: [[0.39192503]]
# Explained variance, chronic only:  0.14555106542946394
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.014946
# R2 loop: -0.11335238696737004
# Explained var: 0.07302451649777608
# correlation: [[0.28058705]]
# ...
# Permutation: 91
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.110595
# R2 loop: -0.10215423613892316
# Explained var: -0.059893652330415215
# correlation: [[0.02179846]]
# Explained variance, chronic only:  0.16714683256378116
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.031590
# R2 loop: 0.02280122304269616
# Explained var: 0.025581524887121065
# correlation: [[0.17663946]]
# Explained variance, chronic only:  0.006362189779948069
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.938523
# R2 loop: 0.12295107383974258
# Explained var: 0.1377796994764856
# correlation: [[0.38294508]]
# Explained variance, chronic only:  0.0946720950135369
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.026272
# R2 loop: -0.17779226757982025
# Explained var: -0.15754126028426718
# correlation: [[0.07254005]]
# Explained variance, chronic only:  -0.16741378807216445
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.096413
# R2 loop: 0.06764708090673277
# Explained var: 0.06961582778036601
# correlation: [[0.28356158]]
# Explained variance, chronic only:  0.0007025903099607822
# ---- Permutation avg. chronic explained variance: 0.020293983919012493----
# ---- Permutation avg. explained variance: 0.003108427905858058----
# Permutation: 92
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.009657
# R2 loop: -0.08438885144288322
# Explained var: -0.07729377871018261
# correlation: [[0.03949453]]
# Explained variance, chronic only:  0.1635938437719645
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.991222
# R2 loop: 0.06236872908408919
# Explained var: 0.06267938281962582
# correlation: [[0.2506064]]
# Explained variance, chronic only:  0.09160805547284401
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.919906
# R2 loop: 0.047559230396948315
# Explained var: 0.07881360971590134
# correlation: [[0.30531538]]
# Explained variance, chronic only:  0.05365659786573662
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.019961
# R2 loop: -0.10173019649322512
# Explained var: 0.015257648223152231
# correlation: [[0.15842251]]
# Explained variance, chronic only:  -0.042717326492280216
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.998786
# R2 loop: 0.13053416671392248
# Explained var: 0.13101546618043658
# correlation: [[0.37349362]]
# Explained variance, chronic only:  0.07505846212879375
# ---- Permutation avg. chronic explained variance: 0.06823992654941173----
# ---- Permutation avg. explained variance: 0.04209446564578667----
# Permutation: 93
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.070084
# R2 loop: -0.9757000031504308
# Explained var: -0.6782321458389655
# correlation: [[0.2630967]]
# Explained variance, chronic only:  -0.2326464892982154
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.061437
# R2 loop: 0.1867278009260357
# Explained var: 0.18705198867590078
# correlation: [[0.51907571]]
# Explained variance, chronic only:  0.09911617837563202
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.012945
# R2 loop: 0.05628244507416402
# Explained var: 0.0705636997540755
# correlation: [[0.27475788]]
# Explained variance, chronic only:  0.06954736260887195
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.984395
# R2 loop: -0.18056903026147242
# Explained var: -0.08315836394080178
# correlation: [[-0.01252435]]
# Explained variance, chronic only:  -0.13340955623218775
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.005654
# R2 loop: 0.012304716573928176
# Explained var: 0.03336186270495012
# correlation: [[0.18661641]]
# Explained variance, chronic only:  0.0854978623184326
# ---- Permutation avg. chronic explained variance: -0.02237892844549332----
# ---- Permutation avg. explained variance: -0.09408259172896818----
# Permutation: 94
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.972246
# R2 loop: -0.11983499364075345
# Explained var: 0.12735910261008443
# correlation: [[0.3720951]]
# Explained variance, chronic only:  0.10434232969826984
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.971059
# R2 loop: -0.16887139218950553
# Explained var: 0.05070875507892758
# correlation: [[0.22740031]]
# Explained variance, chronic only:  0.049764264765987276
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.000962
# R2 loop: -0.0930769800979856
# Explained var: 0.022002585597976965
# correlation: [[0.18541548]]
# Explained variance, chronic only:  0.05148304553117744
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.946736
# R2 loop: -0.07036543457012101
# Explained var: 0.08121474851700605
# correlation: [[0.29755482]]
# Explained variance, chronic only:  0.080068492461699
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.109767
# R2 loop: 0.07354900994135272
# Explained var: 0.10344978124952076
# correlation: [[0.32164601]]
# Explained variance, chronic only:  0.14591032511302504
# ---- Permutation avg. chronic explained variance: 0.08631369151403172----
# ---- Permutation avg. explained variance: 0.07694699461070316----
# Permutation: 95
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.027083
# R2 loop: 0.07831596521773565
# Explained var: 0.08314367105401343
# correlation: [[0.33817473]]
# Explained variance, chronic only:  0.037316353920232026
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.989270
# R2 loop: 0.09690634421441624
# Explained var: 0.1148606701556586
# correlation: [[0.33891147]]
# Explained variance, chronic only:  0.17777090628364522
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.062047
# R2 loop: -0.01983120667566829
# Explained var: 0.03689552102905724
# correlation: [[0.21006089]]
# Explained variance, chronic only:  0.054938567995571286
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.006398
# R2 loop: 0.036393590919297614
# Explained var: 0.06197143830217544
# correlation: [[0.29576248]]
# Explained variance, chronic only:  0.08074037791422384
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.880851
# R2 loop: 0.10326038436677087
# Explained var: 0.11080282662332908
# correlation: [[0.35107186]]
# Explained variance, chronic only:  0.07572129040141529
# ---- Permutation avg. chronic explained variance: 0.08529749930301753----
# ---- Permutation avg. explained variance: 0.08153482543284676----
# Permutation: 96
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:01.062364
# R2 loop: 0.02025370230739376
# Explained var: 0.0657750673320684
# correlation: [[0.27525257]]
# Explained variance, chronic only:  0.07995655293666515
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.993156
# R2 loop: -0.17207659133139308
# Explained var: -0.053624254344728284
# correlation: [[0.08859422]]
# Explained variance, chronic only:  -0.21889129403072305
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.977182
# R2 loop: -0.016347836507082825
# Explained var: -0.01435636455988143
# correlation: [[0.21938008]]
# Explained variance, chronic only:  0.02056571773732363
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.038200
# R2 loop: 0.05342303344844801
# Explained var: 0.10150425561976795
# correlation: [[0.4069102]]
# Explained variance, chronic only:  0.07894961810627465
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.985367
# R2 loop: 0.08852653599134241
# Explained var: 0.08952520838798328
# correlation: [[0.38778334]]
# Explained variance, chronic only:  0.056350621295659264
# ---- Permutation avg. chronic explained variance: 0.0033862432090399296----
# ---- Permutation avg. explained variance: 0.03776478248704198----
# Permutation: 97
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.971854
# R2 loop: -0.01061152602477744
# Explained var: 0.036467370506671704
# correlation: [[0.20925516]]
# Explained variance, chronic only:  0.12872065416457978
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.930694
# R2 loop: -0.05794115013365864
# Explained var: 0.0565080528786398
# correlation: [[0.23854368]]
# Explained variance, chronic only:  0.05371447322030087
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.958381
# R2 loop: 0.08554449525767771
# Explained var: 0.09951829643813703
# correlation: [[0.31549847]]
# Explained variance, chronic only:  0.07174405313082044
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.085386
# R2 loop: 0.004322412516644114
# Explained var: 0.006479094999241597
# correlation: [[0.10933832]]
# Explained variance, chronic only:  -0.0034706977223915025
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.023040
# R2 loop: -0.08789192639657273
# Explained var: 0.07325704590525206
# correlation: [[0.27110735]]
# Explained variance, chronic only:  0.017766578683124923
# ---- Permutation avg. chronic explained variance: 0.053695012295286906----
# ---- Permutation avg. explained variance: 0.05444597214558844----
# Permutation: 98
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.895381
# R2 loop: -0.051500124260876357
# Explained var: -0.051464445744222376
# correlation: [[0.0874097]]
# Explained variance, chronic only:  0.01432648507271872
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.887179
# R2 loop: 0.03266013682464408
# Explained var: 0.061194111512910876
# correlation: [[0.27938107]]
# Explained variance, chronic only:  0.08375021330881482
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:00.901426
# R2 loop: 0.1522751451867227
# Explained var: 0.16413522483077214
# correlation: [[0.49289589]]
# Explained variance, chronic only:  0.11512346122867712
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.048542
# R2 loop: 0.033195880159177404
# Explained var: 0.03578197514383674
# correlation: [[0.19051348]]
# Explained variance, chronic only:  0.0015017992102343003
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:00.982538
# R2 loop: 0.09300425570083715
# Explained var: 0.0940187312988302
# correlation: [[0.30763343]]
# Explained variance, chronic only:  0.12176347720369685
# ---- Permutation avg. chronic explained variance: 0.06729308720482836----
# ---- Permutation avg. explained variance: 0.06073311940842552----
# Permutation: 99
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.986533
# R2 loop: -0.6441839869434418
# Explained var: -0.4276293471517225
# correlation: [[-0.06162675]]
# Explained variance, chronic only:  0.0699097867507601
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# time to run loop: 0:00:00.958590
# R2 loop: -0.19192321377559662
# Explained var: -0.0725568510620791
# correlation: [[0.11856326]]
# Explained variance, chronic only:  -0.05073392042695524
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.063518
# R2 loop: -0.024895056049134334
# Explained var: 0.059580761881640965
# correlation: [[0.25049309]]
# Explained variance, chronic only:  0.0677971329079734
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# time to run loop: 0:00:01.064049
# R2 loop: 0.027187996523241886
# Explained var: 0.06442865911932483
# correlation: [[0.29462611]]
# Explained variance, chronic only:  0.020213798171981434
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# time to run loop: 0:00:01.019175
# R2 loop: 0.26809838646983064
# Explained var: 0.2734169753849386
# correlation: [[0.53244449]]
# Explained variance, chronic only:  0.27454733430615086
# ---- Permutation avg. chronic explained variance: 0.07634682634198212----
# ---- Permutation avg. explained variance: -0.020551960365579446----

# %%
# ENSEMBLE MODEL - clinical variables plus SC 


results_dir='/home/ubuntu/cognition_iowa/results/ensemble/'

# predictions with clinical variables only

import datetime

# feature selection type
f=['correlation']

for featselect in f: 
    #set the number of folds you want in the inner and outer folds of the nested cross-validation
    k = 5

    #set the proportion of data you want in your training set
    train_size = .8

    # Structural Connectivity
    X_sc=sc
    X_sc=prepare_data(X_sc)
    
    # Clinical variables
    X_clin=np.array(clin_vars)
    X_clin=prepare_data(X_clin)
    
    #set y to be the measure you want to predict
    Y=np.array(wais)
    Y=np.reshape(Y, (107,1))
    
    # range of alphas
    n_alphas=20
    alpha_start=-1
    alpha_end=2
    alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

    #number of features for SC(# pricipal components or variables to retain)
    feat_start=1
    feat_end=30
    n_feats=feat_end-feat_start+1
    feats_sc = np.linspace(feat_start, feat_end, n_feats, dtype=int)
    

    #number of features for clincial variables (# pricipal components or variables to retain)
    feat_start=1
    feat_end=20
    n_feats=feat_end-feat_start+1
    feats_clin = np.linspace(feat_start, feat_end, n_feats, dtype=int)
    
    # initialize lists to store model results for each permuation
    allR2=[]
    meanR2=[]
    features=[]
    bestalphas=[]
    importance=[]
    allexpl_var=[]
    correlations=[]
    chronic_allexpl_var=[]
    #joblib-based parallelism to increase speed,
    ytestc=[]
    ypredc=[]
    for p in range(0, 100):
        outer_cv = StratifiedKFold(n_splits=k, shuffle=True, random_state=p)
        print('Permutation: ' + str(p))
        # initialize lists to store model results for eah fold
        R2=[]
        featur=[]
        best_alphas=[]
        impt=[] 
        expl_var=[]
        chronic_explvar=[]
        cor=[]
        for train, test in outer_cv.split(X_clin, chronic_id):

            begin_time = datetime.datetime.now()
            
            chronic_bin=chronic_id[train]
            chronic_test=chronic_id[test]
            
            # SC build model
            X=X_sc
            # select model using training data
            bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv_strat(k, X[train], Y[train], chronic_bin, featselect, alphas, feats_sc)
            # using optimal num. of features, select final features using entire training data.
            if featselect=='correlation':
                x_train_featselect,x_test_featureselect,ind = feature_select_correlation(X[train],X[test], Y[train], bestfeats)
                featur.append(ind)

            elif featselect=='PCA':
                x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(X[train],X[test], bestfeats)
                featur.append(ind)
            
            chronic_bin=np.reshape(np.double(chronic_bin), (x_train_featselect.shape[0], 1))
            x_train_featselect=np.concatenate((x_train_featselect, chronic_bin),axis=1)
            chronic_test=np.reshape(np.double(chronic_test), (x_test_featureselect.shape[0], 1))
            x_test_featureselect=np.concatenate((x_test_featureselect, chronic_test),axis=1)
            # initialize Ridge regression with alpha selected from hyperparameter search
            regr_sc = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)
            # fit model 
            y_pred = regr_sc.fit(x_train_featselect, Y[train]).predict(x_test_featureselect)
            
            chronicsubs_test=chronic_id[test]==True
            chronicsubs_train=chronic_id[train]==True
            chronicsubs_test=chronicsubs_test.flatten()
            chronicsubs_train=chronicsubs_train.flatten()
            cor.append(np_pearson_cor(Y[test], y_pred))
            Xtest=x_test_featureselect
            Xtrain=X[train]
            Ytest=Y[test]
            ytrue_chronic = Ytest[chronicsubs_test]
            xtest_chronic=Xtest[chronicsubs_test]
            ychronic_pred_sc = regr_sc.fit(x_train_featselect, Y[train]).predict(xtest_chronic)
            
        
            # CLINICAL VARIABLES build model
            X=X_clin
            xtrain, xtest=scale_data(X[train,0:2], X[test,0:2])
            xtrain=np.hstack((xtrain, X[train,2:21]))
            xtest=np.hstack((xtest, X[test,2:21]))
            # select model using training data
            bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv_strat(k, xtrain, Y[train], chronic_bin, featselect, alphas, feats_clin)
            # using optimal num. of features, select final features using entire training data.
            if featselect=='correlation':
                x_train_featselect,x_test_featureselect,ind = feature_select_correlation(xtrain,xtest, Y[train], bestfeats)
                featur.append(ind)
            elif featselect=='PCA':
                x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(xtrain,xtest, bestfeats)
                featur.append(ind)    
            chronic_bin=np.reshape(np.double(chronic_bin), (x_train_featselect.shape[0], 1))
            x_train_featselect=np.concatenate((x_train_featselect, chronic_bin),axis=1)
            chronic_test=np.reshape(np.double(chronic_test), (x_test_featureselect.shape[0], 1))
            x_test_featureselect=np.concatenate((x_test_featureselect, chronic_test),axis=1)     
            # initialize Ridge regression with alpha selected from hyperparameter search
            regr_clinvars = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)
            # fit model 
            y_pred = regr_clinvars.fit(x_train_featselect, Y[train]).predict(x_test_featureselect)

            # CLINICAL VARIABLES predictions for chronic only
            
            chronicsubs_test=chronic_id[test]==True
            chronicsubs_train=chronic_id[train]==True
            chronicsubs_test=chronicsubs_test.flatten()
            chronicsubs_train=chronicsubs_train.flatten()
            cor.append(np_pearson_cor(Y[test], y_pred))
            Xtest=x_test_featureselect
            Xtrain=X[train]
            Ytest=Y[test]
            ytrue_chronic = Ytest[chronicsubs_test]
            xtest_chronic=Xtest[chronicsubs_test]

            ychronic_pred_clin = regr_clinvars.fit(x_train_featselect, Y[train]).predict(xtest_chronic)
            
            # Average predictions 
            ychronic_pred_ensemble = np.average([ychronic_pred_sc, ychronic_pred_sc], axis=0)
            
            print("Explained variance ensemble, chronic only:  " + str(explained_variance_score(ytrue_chronic, ychronic_pred_ensemble)))

            chronic_explvar.append(explained_variance_score(ytrue_chronic, ychronic_pred_ensemble))
            
        # store results for each permutation p

        allexpl_var.append(expl_var)
        bestalphas.append(best_alphas)
        importance.append(impt)
        chronic_allexpl_var.append(chronic_explvar)
        correlations.append(cor)
        print("---- Permutation avg. chronic explained variance: " + str(np.mean(chronic_explvar)) + "----")
        np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_chronic_all_explvar.txt', chronic_allexpl_var, delimiter=',')

        print("---- Permutation avg. explained variance: " + str(np.mean(expl_var)) + "----")
        np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_all_explvar.txt', expl_var, delimiter=',')

        output = open(results_dir + featselect + 'p' + str(p) + '_SC_features.pkl', 'wb')
        pickle.dump(featur, output)
        output.close()
        
        output = open(results_dir + featselect + 'p' + str(p) + '_SC_correlations.pkl', 'wb')
        pickle.dump(correlations, output)
        output.close()

        output = open(results_dir + featselect + 'p' + str(p) + '_SC_bestalphas.pkl', 'wb')
        pickle.dump(best_alphas, output)
        output.close()
     
        output = open(results_dir + featselect + 'p' + str(p) + '_SC_varimpt.pkl', 'wb')
        pickle.dump(importance, output)
        output.close()
# Out:
# Final size of X: (107, 3192)
# Final size of X: (107, 21)
# Permutation: 0
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.2651276874840044
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.18187840387803988
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.3392309925457041
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  -0.3320572175456351
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.2666379057759731
# ---- Permutation avg. chronic explained variance: 0.14416355442761727----
# ---- Permutation avg. explained variance: nan----
# Permutation: 1
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.13468030262290465
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5232545551490665
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.2287221561142122
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.06237285262557268
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.16967015423035248
# ---- Permutation avg. chronic explained variance: 0.16986788309925985----
# ---- Permutation avg. explained variance: nan----
# Permutation: 2
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.05496599172670824
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.35228457349605435
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.05786457592284422
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.19041018799178622
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.34698019543367775
# ---- Permutation avg. chronic explained variance: 0.15536887785439318----
# ---- Permutation avg. explained variance: nan----
# Permutation: 3
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.04005554598943162
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.12494931247769925
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.04969834348812108
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.3524517669998948
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5712290337532158
# ---- Permutation avg. chronic explained variance: 0.20779746314642406----
# ---- Permutation avg. explained variance: nan----
# Permutation: 4
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.0789256760855016
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.008179562508309424
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.6711630167461258
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.36923167978575866
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.025603624749878096
# ---- Permutation avg. chronic explained variance: 0.22734888697179093----
# ---- Permutation avg. explained variance: nan----
# Permutation: 5
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  -0.44440273117906326
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.15825857868036863
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5146636088651436
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.2511706644229851
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.30735012202344314
# ---- Permutation avg. chronic explained variance: 0.034467999753198184----
# ---- Permutation avg. explained variance: nan----
# Permutation: 6
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.4947037296682435
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.49657011939766327
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.4238614543074015
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.07784041424995158
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.1640996471848325
# ---- Permutation avg. chronic explained variance: 0.13353358109432106----
# ---- Permutation avg. explained variance: nan----
# Permutation: 7
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5064583780878223
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.3240262971545722
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.6432342014193284
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.024222107999253284
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Explained variance ensemble, chronic only:  0.13167526988477984
# ---- Permutation avg. chronic explained variance: 0.06862957034141985----
# ---- Permutation avg. explained variance: nan----
# Permutation: 8
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5589351769020869
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.10978452931977456
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.03078119101420007
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.2949544527388107
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.15778931866031343
# ---- Permutation avg. chronic explained variance: 0.1865351219991273----
# ---- Permutation avg. explained variance: nan----
# Permutation: 9
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.2415340821469869
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.4063727343117264
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.28997753809903015
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.1638636993709499
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Explained variance ensemble, chronic only:  0.03510723994003773
# ---- Permutation avg. chronic explained variance: 0.04583456378575419----
# ---- Permutation avg. explained variance: nan----
# Permutation: 10
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.018010148845604146
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.19224701522382714
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.08790097093377458
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.07158354786552912
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.043338773290398924
# ---- Permutation avg. chronic explained variance: 0.029443103231213907----
# ---- Permutation avg. explained variance: nan----
# Permutation: 11
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.18793361282274268
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.07978529678053758
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.09618500728228241
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  -0.18557983049584492
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.10261354911933052
# ---- Permutation avg. chronic explained variance: 0.05618752710180965----
# ---- Permutation avg. explained variance: nan----
# Permutation: 12
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.338122006561698
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.0391351247456555
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.1514370068635229
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.10922391156744371
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.21978625374107308
# ---- Permutation avg. chronic explained variance: 0.15588681079761643----
# ---- Permutation avg. explained variance: nan----
# Permutation: 13
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.41207024753703336
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.0664310536892132
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.05295083511874776
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.23899941690054038
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.0463114145613458
# ---- Permutation avg. chronic explained variance: 0.1633525935613761----
# ---- Permutation avg. explained variance: nan----
# Permutation: 14
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -1.044950730136959
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.1207438061424605
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.2679818622308161
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.3060053307388907
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.40469437071851166
# ---- Permutation avg. chronic explained variance: 0.010894927938744003----
# ---- Permutation avg. explained variance: nan----
# Permutation: 15
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.27742906088869135
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5738974504726395
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.30774210076814434
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.8174832930695928
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Explained variance ensemble, chronic only:  0.11911853549176432
# ---- Permutation avg. chronic explained variance: 0.09214077091032932----
# ---- Permutation avg. explained variance: nan----
# Permutation: 16
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.04926314849815683
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.22968353026850186
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.37780261007500626
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.044496624992448774
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.1852873699365144
# ---- Permutation avg. chronic explained variance: 0.06763459464974537----
# ---- Permutation avg. explained variance: nan----
# Permutation: 17
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  -0.07367283289959858
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.02774824893970962
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5316230276266211
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.4369624058689314
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.16379305907894004
# ---- Permutation avg. chronic explained variance: 0.2061914821470369----
# ---- Permutation avg. explained variance: nan----
# Permutation: 18
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.19609619513159748
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  -0.31028174125109187
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.30475936737796727
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.13393095283268597
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.05951551508323838
# ---- Permutation avg. chronic explained variance: 0.07680405783487945----
# ---- Permutation avg. explained variance: nan----
# Permutation: 19
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5549037178463939
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.10873335281728447
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.011307872790185414
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.09164451052690892
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Explained variance ensemble, chronic only:  0.47048343694666817
# ---- Permutation avg. chronic explained variance: 0.24289142906941402----
# ---- Permutation avg. explained variance: nan----
# Permutation: 20
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  -0.003980329919400338
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.24853721002405005
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.12240251421843029
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.0627886927555188
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5904106393107043
# ---- Permutation avg. chronic explained variance: 0.1789162681756531----
# ---- Permutation avg. explained variance: nan----
# Permutation: 21
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.05007786705419193
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  -0.0844501323551079
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.3119096376369651
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5199380654050751
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.020448259818283576
# ---- Permutation avg. chronic explained variance: 0.16358473951188157----
# ---- Permutation avg. explained variance: nan----
# Permutation: 22
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.661605207422451
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.5601264657458107
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.18579233625681113
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.3462135464728886
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.17105472199899363
# ---- Permutation avg. chronic explained variance: 0.12031637261041062----
# ---- Permutation avg. explained variance: nan----
# Permutation: 23
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# ...
# Explained variance ensemble, chronic only:  0.04774188126120826
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.349188039797678
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.22932719678570657
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.11894237933567331
# ---- Permutation avg. chronic explained variance: 0.1314500706574913----
# ---- Permutation avg. explained variance: nan----
# Permutation: 93
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -1.4512899706830371
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.009575116940116368
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.1525098268714956
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.3030381608097166
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5282768733510789
# ---- Permutation avg. chronic explained variance: -0.09157799854212592----
# ---- Permutation avg. explained variance: nan----
# Permutation: 94
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.24348687712152595
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.023346047458270958
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.30368477115756143
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.43332817034768256
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.13042124071003958
# ---- Permutation avg. chronic explained variance: 0.09604109391268315----
# ---- Permutation avg. explained variance: nan----
# Permutation: 95
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.16250194593779055
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.06666516940880785
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.042928851826822934
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5450283641006736
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Explained variance ensemble, chronic only:  0.11412119187870629
# ---- Permutation avg. chronic explained variance: 0.14241149613630794----
# ---- Permutation avg. explained variance: nan----
# Permutation: 96
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.0958569303542619
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.11430315790356793
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.07704734743523867
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.33269112853551486
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Explained variance ensemble, chronic only:  0.0415950417457428
# ---- Permutation avg. chronic explained variance: 0.10147978222076977----
# ---- Permutation avg. explained variance: nan----
# Permutation: 97
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.1619804648487586
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.2741545392413459
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.06439754599886716
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.18499383214132858
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -0.3415816985669422
# ---- Permutation avg. chronic explained variance: 0.06878893673267161----
# ---- Permutation avg. explained variance: nan----
# Permutation: 98
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.37861178181047317
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.5229399370366781
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.05918548289381487
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.034608791398969885
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.00045460903625571536
# ---- Permutation avg. chronic explained variance: 0.19916012043523834----
# ---- Permutation avg. explained variance: nan----
# Permutation: 99
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.32665989323819944
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# 5-fold cross-validation results in 68.0 subjects in the training set, and 17.0 subjects in the validation set
# Explained variance ensemble, chronic only:  0.02852484132412425
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  0.14360645051767185
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# <ipython-input-2-343597912cef>:89: RuntimeWarning: invalid value encountered in true_divide
#   result = np.matmul(xv.transpose(), yv) / np.sqrt(np.outer(xvss, yvss))
# Explained variance ensemble, chronic only:  0.18779864899979148
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# 5-fold cross-validation results in 68.8 subjects in the training set, and 17.2 subjects in the validation set
# Explained variance ensemble, chronic only:  -1.0495614761141097
# ---- Permutation avg. chronic explained variance: -0.07259432840686453----
# ---- Permutation avg. explained variance: nan----
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3419: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/ubuntu/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:188: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# Functional Connectivity 

import datetime
#set the number of folds you want in the inner and outer folds of the nested cross-validation
k = 5

#set the proportion of data you want in your training set
train_size = .8

#set x data to be the input variable you want to use
#ie fc, sc, or hc
#X=np.concatenate([sc, fc], axis=1)
X=fc
X=prepare_data(X)

#set y to be the measure you want to predict
Y = np.array(wais)

# feature selection type
featselect='PCA'

# range of alphas
n_alphas=20
alpha_start=-1
alpha_end=2
alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

#number of features (# pricipal components or variables to retain)
feat_start=10
feat_end=30
n_feats=feat_end-feat_start+1
feats = np.linspace(feat_start, feat_end, n_feats, dtype=int)

# initialize lists to store model results for each permuation
allR2=[]
meanR2=[]
features=[]
bestalphas=[]
importance=[]
allexpl_var=[]
#joblib-based parallelism to increase speed,

for p in range(0, 100):
    outer_cv = KFold(n_splits=k, shuffle=True, random_state=p)
    print('Permutation: ' + str(p))
    # initialize lists to store model results for eah fold
    R2=[]
    featur=[]
    best_alphas=[]
    impt=[] 
    expl_var=[]
    for train, test in outer_cv.split(X):
        begin_time = datetime.datetime.now()
        
        # select model using training data
        bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv(k, X[train], Y[train], featselect, alphas, feats)
        
        # using optimal num. of features, select final features using entire training data.
 
        if featselect=='correlation':
            x_train_featselect,x_test_featureselect,ind = feature_select_correlation(X[train],X[test], Y[train], bestfeats)
            featur.append(ind)
            
        elif featselect=='PCA':
            x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(X[train],X[test], bestfeats)
            featur.append(ind)

        # initialize Ridge regression with alpha selected from hyperparameter search
        regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)

        # fit model 
        y_pred = regr.fit(x_train_featselect, Y[train]).predict(x_test_featureselect)

        # store results for each fold k
        impt.append(regr.coef_)
        R2.append(r2_score(Y[test], y_pred))
        expl_var.append(explained_variance_score(Y[test], y_pred))

        best_alphas.append(bestalpha)
        print('time to run loop: ' + str(datetime.datetime.now() - begin_time)) 
        print("R2 loop: " + str(r2_score(Y[test], y_pred)))
        print("Explained var: " + str(explained_variance_score(Y[test], y_pred)))
        print("correlation: " + str(np_pearson_cor(Y[test], y_pred)))

    # store results for each permutation p

    allexpl_var.append(expl_var)
    bestalphas.append(best_alphas)
    importance.append(impt)
    print("Permutation avg. explained variance: " + str(np.mean(expl_var)))

    np.savetxt(results_dir + featselect + 'p' + str(p) + '_FC_all_explvar.txt', expl_var, delimiter=',')

    output = open(results_dir + featselect + 'p' + str(p) + '_FC_features.pkl', 'wb')
    pickle.dump(featur, output)
    output.close()

    output = open(results_dir + featselect + 'p' + str(p) + '_FC_bestalphas.pkl', 'wb')
    pickle.dump(best_alphas, output)
    output.close()
# Out:
# Final size of X: (101, 3655)
# Permutation: 0
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.943851
# R2 loop: 0.08725713909177901
# Explained var: 0.13015329181304736
# correlation: [[0.4859394]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.023496
# R2 loop: -0.042102289306928053
# Explained var: 0.1000335577592052
# correlation: [[0.33519712]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.050199
# R2 loop: -0.033714981097657803
# Explained var: 0.11728474378817944
# correlation: [[0.41664356]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.068258
# R2 loop: 0.13813398258424248
# Explained var: 0.19102031432312272
# correlation: [[0.46956806]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.266699
# R2 loop: -0.25412819661893504
# Explained var: -0.12225503989184383
# correlation: [[0.06396854]]
# Permutation avg. explained variance: 0.08324737355834218
# Permutation: 1
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.862244
# R2 loop: 0.15263852876797346
# Explained var: 0.18438823326369724
# correlation: [[0.42952273]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.172135
# R2 loop: 0.21218779536707888
# Explained var: 0.23540087158560485
# correlation: [[0.64910151]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.122351
# R2 loop: 0.010848276803251178
# Explained var: 0.06846362165011566
# correlation: [[0.27760277]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.151690
# R2 loop: 0.20241767603584526
# Explained var: 0.31583707947786543
# correlation: [[0.62088037]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.056522
# R2 loop: 0.24087934174127312
# Explained var: 0.2552823382212771
# correlation: [[0.5253319]]
# Permutation avg. explained variance: 0.21187442883971208
# Permutation: 2
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.013855
# R2 loop: 0.16832431939651604
# Explained var: 0.1787382984138981
# correlation: [[0.5322983]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.089180
# R2 loop: 0.1861068370143275
# Explained var: 0.18895043176357873
# correlation: [[0.43612154]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.203695
# R2 loop: 0.20595326326987007
# Explained var: 0.21450449299683816
# correlation: [[0.75351171]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.022099
# R2 loop: -0.4065913351670718
# Explained var: -0.4034053408788816
# correlation: [[-0.19294047]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.040154
# R2 loop: -0.07530715938245525
# Explained var: -0.07528610491702792
# correlation: [[0.12147738]]
# Permutation avg. explained variance: 0.0207003554756811
# Permutation: 3
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.900495
# R2 loop: -0.10179862244565019
# Explained var: 0.01876249817883957
# correlation: [[0.20245097]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.223831
# R2 loop: -0.19715830974149662
# Explained var: 0.08400406641888791
# correlation: [[0.29257306]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.181813
# R2 loop: 0.08914087116968028
# Explained var: 0.12150959140514206
# correlation: [[0.34943142]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.130110
# R2 loop: 0.061793126212064786
# Explained var: 0.16865362773396164
# correlation: [[0.41121538]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.206018
# R2 loop: -0.26702643169322404
# Explained var: -0.21493329650114612
# correlation: [[-0.12534136]]
# Permutation avg. explained variance: 0.03559929744713701
# Permutation: 4
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.165197
# R2 loop: 0.3849547135299275
# Explained var: 0.38500662861420243
# correlation: [[0.76301414]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.139579
# R2 loop: 0.17032340336526985
# Explained var: 0.17162115118297105
# correlation: [[0.45052514]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.194161
# R2 loop: -0.05392973709017124
# Explained var: -0.052471938382425476
# correlation: [[0.05231841]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.047259
# R2 loop: 0.14442267685601673
# Explained var: 0.14442380629785034
# correlation: [[0.416206]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.204957
# R2 loop: -0.2714665712764912
# Explained var: -0.23150974207413055
# correlation: [[0.24052472]]
# Permutation avg. explained variance: 0.08341398112769356
# Permutation: 5
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.043925
# R2 loop: 0.17667342777332673
# Explained var: 0.17669541886255613
# correlation: [[0.57796883]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.147476
# R2 loop: -0.5247890921397966
# Explained var: -0.49634579440187565
# correlation: [[-0.3568424]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.157609
# R2 loop: -0.21076523077377907
# Explained var: -0.21038242624844927
# correlation: [[-0.14604146]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.161964
# R2 loop: -0.2589860281819478
# Explained var: -0.020157740303162308
# correlation: [[-0.00877267]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.070271
# R2 loop: 0.2582402942109162
# Explained var: 0.3117791574043747
# correlation: [[0.65208624]]
# Permutation avg. explained variance: -0.04768227693731129
# Permutation: 6
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.843339
# R2 loop: -0.37383673116416727
# Explained var: -0.30333094362106583
# correlation: [[-0.18885718]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.126492
# R2 loop: 0.2198314659347479
# Explained var: 0.25401796111595476
# correlation: [[0.53640995]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.107513
# R2 loop: -0.021436313209157953
# Explained var: 0.09392355911910544
# correlation: [[0.35279227]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.958254
# R2 loop: -0.2272411080435801
# Explained var: -0.08823804402848756
# correlation: [[-0.00569989]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.125986
# R2 loop: 0.36339667889785343
# Explained var: 0.3698844641563934
# correlation: [[0.71596751]]
# Permutation avg. explained variance: 0.06525139934838005
# Permutation: 7
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.005382
# R2 loop: -0.08347379700809232
# Explained var: -0.08321557595772155
# correlation: [[0.24179643]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.069382
# R2 loop: 0.14781105465094402
# Explained var: 0.18019839848059627
# correlation: [[0.68528379]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.978985
# R2 loop: -0.21688097190167133
# Explained var: -0.21581642523884748
# correlation: [[0.04945767]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.081031
# R2 loop: -0.10469297129826671
# Explained var: -0.10285451063733997
# correlation: [[0.0999098]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.971395
# R2 loop: 0.10400118344331988
# Explained var: 0.26248533667639196
# correlation: [[0.52098253]]
# Permutation avg. explained variance: 0.008159444664615845
# Permutation: 8
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.969994
# R2 loop: 0.012928826444825181
# Explained var: 0.23572065473852966
# correlation: [[0.69287102]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.101648
# R2 loop: 0.018394087824885164
# Explained var: 0.02905417298311974
# correlation: [[0.38938854]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.061063
# R2 loop: -0.13761952749408946
# Explained var: 0.11931615734588485
# correlation: [[0.35424904]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.185773
# R2 loop: 0.015984842966823898
# Explained var: 0.18984066499906993
# correlation: [[0.43570925]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.052715
# R2 loop: -0.17570642399606218
# Explained var: -0.15800409927614423
# correlation: [[0.05030851]]
# Permutation avg. explained variance: 0.08318551015809199
# Permutation: 9
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.962886
# R2 loop: -0.0014271933821272675
# Explained var: 0.06755097461175996
# correlation: [[0.26861643]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.914995
# R2 loop: 0.01856116692690113
# Explained var: 0.023784563271164072
# correlation: [[0.2175947]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.119660
# R2 loop: 0.06949536950611723
# Explained var: 0.07357100721649945
# correlation: [[0.4727805]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.029604
# R2 loop: -0.1713684479694988
# Explained var: -0.08064346995535421
# correlation: [[0.00603697]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.183605
# R2 loop: 0.16869941314293113
# Explained var: 0.33639065952975433
# correlation: [[0.70359848]]
# Permutation avg. explained variance: 0.08413074693476472
# Permutation: 10
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.970910
# R2 loop: 0.09733396941805073
# Explained var: 0.10203227625378775
# correlation: [[0.31963709]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.122539
# R2 loop: 0.06563337731365715
# Explained var: 0.06757074833971799
# correlation: [[0.2681844]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.303292
# R2 loop: -0.7849394128883842
# Explained var: -0.5243673245265548
# correlation: [[-0.1616058]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.184364
# R2 loop: 0.1333935633656459
# Explained var: 0.1665329254588086
# correlation: [[0.44966798]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.152170
# R2 loop: 0.13448627682713177
# Explained var: 0.16399328337579921
# correlation: [[0.59567226]]
# Permutation avg. explained variance: -0.004847618219688243
# Permutation: 11
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.077993
# R2 loop: 0.01882221383246052
# Explained var: 0.04483254878815546
# correlation: [[0.24351917]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.181924
# R2 loop: 0.2084665849560754
# Explained var: 0.21974203405749737
# correlation: [[0.63841157]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.168079
# R2 loop: -0.2547958323049795
# Explained var: 0.03855220385323621
# correlation: [[0.32107635]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.189508
# R2 loop: -0.30861576505835964
# Explained var: 0.08170464291758572
# correlation: [[0.40791385]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.280740
# R2 loop: 0.08635881734909856
# Explained var: 0.1126665051687451
# correlation: [[0.34321892]]
# Permutation avg. explained variance: 0.09949958695704397
# Permutation: 12
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.018764
# R2 loop: 0.17134716082783563
# Explained var: 0.21206287364070964
# correlation: [[0.4613718]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.341066
# R2 loop: 0.054294798709173864
# Explained var: 0.10535621832918729
# correlation: [[0.35648369]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.046395
# R2 loop: 0.052578180569664235
# Explained var: 0.07173112816918437
# correlation: [[0.47827724]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.232823
# R2 loop: 0.10485352726705577
# Explained var: 0.10902944238967105
# correlation: [[0.4425765]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.208444
# R2 loop: 0.04193166333146847
# Explained var: 0.14263199482159572
# correlation: [[0.38580245]]
# Permutation avg. explained variance: 0.1281623314700696
# Permutation: 13
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.196244
# R2 loop: -0.31411354054792073
# Explained var: -0.2491346187806831
# correlation: [[-0.33523335]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.103544
# R2 loop: 0.00445618880906129
# Explained var: 0.03871405839538311
# correlation: [[0.22964426]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.303263
# R2 loop: 0.17140105203521827
# Explained var: 0.23722806999600066
# correlation: [[0.51800497]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.146447
# R2 loop: -0.21508380988363762
# Explained var: -0.17329531923466823
# correlation: [[0.09717486]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.212280
# R2 loop: 0.27986292792318745
# Explained var: 0.2799085786697725
# correlation: [[0.65207874]]
# Permutation avg. explained variance: 0.026684153809160983
# Permutation: 14
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.963274
# R2 loop: 0.020062402033113158
# Explained var: 0.048514651692565636
# correlation: [[0.23445911]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.008620
# R2 loop: 0.24002373743058125
# Explained var: 0.2554939536433928
# correlation: [[0.78287275]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.170179
# R2 loop: 0.2318056716899437
# Explained var: 0.2333371791899873
# correlation: [[0.52337559]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.104257
# R2 loop: -0.6218745020561911
# Explained var: -0.47435325679695595
# correlation: [[-0.24496527]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.005472
# R2 loop: 0.08549148800150441
# Explained var: 0.10677567621772843
# correlation: [[0.32683071]]
# Permutation avg. explained variance: 0.03395364078934364
# Permutation: 15
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.845585
# R2 loop: 0.18523892674802345
# Explained var: 0.19000226645231477
# correlation: [[0.44045649]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.046046
# R2 loop: 0.05869694336254183
# Explained var: 0.15376918817179108
# correlation: [[0.41899637]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.117251
# R2 loop: -0.879853841696729
# Explained var: -0.13480613759720184
# correlation: [[0.20310646]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.220903
# R2 loop: 0.14140561350653946
# Explained var: 0.2003320476490026
# correlation: [[0.46254164]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.206339
# R2 loop: 0.25109772745188275
# Explained var: 0.2916300017200073
# correlation: [[0.67616852]]
# Permutation avg. explained variance: 0.1401854732791828
# Permutation: 16
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.746600
# R2 loop: 0.09249423382214517
# Explained var: 0.09354388508785494
# correlation: [[0.30750206]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.191332
# R2 loop: 0.11760593606512737
# Explained var: 0.12118439230641631
# correlation: [[0.35623449]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.024149
# R2 loop: -0.4982240687120145
# Explained var: -0.4896910314035776
# correlation: [[-0.36129934]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.105389
# R2 loop: 0.31738149359162393
# Explained var: 0.3300312488918953
# correlation: [[0.80425001]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.145894
# R2 loop: 0.18152356752652865
# Explained var: 0.1900640413732163
# correlation: [[0.54425866]]
# Permutation avg. explained variance: 0.04902650725116105
# Permutation: 17
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.846462
# R2 loop: 0.0294476532339929
# Explained var: 0.0741685669699208
# correlation: [[0.27582327]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.060243
# R2 loop: 0.21107841434298835
# Explained var: 0.21618860969703446
# correlation: [[0.46498914]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.090255
# R2 loop: 0.2079151436540485
# Explained var: 0.21287630688491155
# correlation: [[0.55702802]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.140481
# R2 loop: 0.23551483678359664
# Explained var: 0.28160405620557327
# correlation: [[0.62439255]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.094047
# R2 loop: -0.1016610796296804
# Explained var: -0.10102183570174561
# correlation: [[0.04196426]]
# Permutation avg. explained variance: 0.13676314081113888
# Permutation: 18
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.100364
# R2 loop: 0.23223560600632231
# Explained var: 0.23428830715271554
# correlation: [[0.51794003]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.036014
# R2 loop: -0.20354758126901662
# Explained var: -0.19040333539594134
# correlation: [[-0.13891517]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.348556
# R2 loop: 0.24370599528496495
# Explained var: 0.24382671419965019
# correlation: [[0.52440665]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.063304
# R2 loop: -0.2642928938945479
# Explained var: -0.07192844869123483
# correlation: [[0.11172395]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.062331
# R2 loop: 0.16102124048954747
# Explained var: 0.181821507566012
# correlation: [[0.44850238]]
# Permutation avg. explained variance: 0.07952094896624032
# Permutation: 19
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.073551
# R2 loop: 0.19208504090342193
# Explained var: 0.19698551401027586
# correlation: [[0.75409821]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.257767
# R2 loop: -0.24147164070798266
# Explained var: -0.24146935059683794
# correlation: [[0.07545534]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.206805
# R2 loop: -0.33335186507525694
# Explained var: -0.17615065980024114
# correlation: [[-0.09511473]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.124347
# R2 loop: 0.26031000880560606
# Explained var: 0.26709199250172655
# correlation: [[0.62530954]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.066944
# R2 loop: -0.10598397332286114
# Explained var: 0.02861416062153488
# correlation: [[0.28149249]]
# Permutation avg. explained variance: 0.015014331347291642
# Permutation: 20
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.040386
# R2 loop: -0.10555038966588914
# Explained var: -0.0458662651737487
# correlation: [[0.23430459]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.224206
# R2 loop: 0.14230836392396506
# Explained var: 0.1603438547977344
# correlation: [[0.40043032]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.172765
# R2 loop: 0.2663025307478569
# Explained var: 0.3679978765958327
# correlation: [[0.66342942]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.113103
# R2 loop: 0.34343626235955915
# Explained var: 0.35396582372884977
# correlation: [[0.62248717]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.157181
# R2 loop: 0.15727279210057143
# Explained var: 0.15746656113539825
# correlation: [[0.39736949]]
# Permutation avg. explained variance: 0.19878157021681328
# Permutation: 21
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.006110
# R2 loop: 0.12524080415842676
# Explained var: 0.1253442175604348
# correlation: [[0.35405544]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.459185
# R2 loop: 0.14571547183663813
# Explained var: 0.17090820423859898
# correlation: [[0.41389024]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.353230
# R2 loop: 0.04714929694102621
# Explained var: 0.04731085627065368
# correlation: [[0.22741533]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.057644
# R2 loop: 0.1302512874919708
# Explained var: 0.13066971304092845
# correlation: [[0.36162444]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.056424
# R2 loop: -0.24085938515263483
# Explained var: -0.21443343850642815
# correlation: [[-0.01638872]]
# Permutation avg. explained variance: 0.05195991052083755
# Permutation: 22
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.981444
# R2 loop: 0.12048477170830774
# Explained var: 0.14641454361625816
# correlation: [[0.57136693]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.982901
# R2 loop: 0.10459822801742358
# Explained var: 0.17447051576947048
# correlation: [[0.42551626]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.172770
# R2 loop: 0.1193602462542721
# Explained var: 0.15982554282366124
# correlation: [[0.48470059]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.947482
# R2 loop: -0.27714426379464907
# Explained var: -0.2639503335604201
# correlation: [[0.04582862]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.054334
# R2 loop: -0.23063135008760005
# Explained var: -0.11951604811399896
# correlation: [[-0.29114368]]
# Permutation avg. explained variance: 0.019448844106994167
# Permutation: 23
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.007116
# R2 loop: 0.08797772607058085
# Explained var: 0.1008874403614235
# correlation: [[0.31768919]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.106053
# R2 loop: 0.10314172951501699
# Explained var: 0.13442517004878862
# correlation: [[0.3709226]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.089225
# R2 loop: 0.1408618499462163
# Explained var: 0.14426993908681696
# correlation: [[0.40400554]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.240991
# R2 loop: 0.09104369784988686
# Explained var: 0.09774868361346567
# correlation: [[0.49005589]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.171557
# R2 loop: 0.20069582447234624
# Explained var: 0.224333924172883
# correlation: [[0.54627524]]
# Permutation avg. explained variance: 0.14033303145667556
# Permutation: 24
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.994494
# R2 loop: 0.4339813737151479
# Explained var: 0.5143179518560337
# correlation: [[0.78512281]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.077616
# R2 loop: 0.34763077711626855
# Explained var: 0.36946327345698615
# correlation: [[0.66971791]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.203491
# R2 loop: -0.3421702396432964
# Explained var: -0.34176682926677815
# correlation: [[-0.16654028]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.152112
# R2 loop: 0.0657397169944921
# Explained var: 0.08388104228535798
# correlation: [[0.30073467]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.074509
# R2 loop: 0.12025894559529715
# Explained var: 0.14357737940543758
# correlation: [[0.38042903]]
# Permutation avg. explained variance: 0.15389456354740744
# Permutation: 25
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.908554
# R2 loop: -0.27696988836535197
# Explained var: -0.2712820165760761
# correlation: [[0.31693089]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.060264
# R2 loop: 0.36588057504761895
# Explained var: 0.36791140789599097
# correlation: [[0.66871856]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.129228
# R2 loop: -0.42556015150005533
# Explained var: -0.27635775070854196
# correlation: [[-0.10287348]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.022700
# R2 loop: -0.058664692450271616
# Explained var: 0.23175050718813017
# correlation: [[0.51786344]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.224907
# R2 loop: 0.015780128003457405
# Explained var: 0.06010876300404333
# correlation: [[0.27685568]]
# Permutation avg. explained variance: 0.022426182160709286
# Permutation: 26
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.112188
# R2 loop: 0.04421682832487617
# Explained var: 0.12479382479094425
# correlation: [[0.35342617]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.259720
# R2 loop: 0.18906924663133806
# Explained var: 0.3216157148797596
# correlation: [[0.59226273]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.100267
# R2 loop: -0.229855736057071
# Explained var: -0.1624339983957721
# correlation: [[-0.13776782]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.996453
# R2 loop: 0.0358540810693988
# Explained var: 0.15013694507053865
# correlation: [[0.38877237]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.125129
# R2 loop: 0.17172069399966317
# Explained var: 0.1738502107470209
# correlation: [[0.4428869]]
# Permutation avg. explained variance: 0.12159253941849826
# Permutation: 27
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.202153
# R2 loop: -0.18471565596518102
# Explained var: -0.15447127280363948
# correlation: [[0.21079301]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.350952
# R2 loop: 0.17120496564187437
# Explained var: 0.18259787942509942
# correlation: [[0.58140236]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.096703
# R2 loop: 0.2035286811235083
# Explained var: 0.25943702842317806
# correlation: [[0.61430129]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.208808
# R2 loop: -0.00811700834297091
# Explained var: 0.04907606255247621
# correlation: [[0.23909359]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.141538
# R2 loop: 0.1653918916163175
# Explained var: 0.1764352112098453
# correlation: [[0.70056618]]
# Permutation avg. explained variance: 0.1026149817613919
# Permutation: 28
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.113920
# R2 loop: 0.04951552649006574
# Explained var: 0.06408981160037597
# correlation: [[0.29254264]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.183837
# R2 loop: 0.12325969150463034
# Explained var: 0.17923210746680518
# correlation: [[0.66078861]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.152523
# R2 loop: 0.22737256287481855
# Explained var: 0.23443023338892233
# correlation: [[0.49925895]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.027281
# R2 loop: 0.007656096987204375
# Explained var: 0.22021295305509847
# correlation: [[0.60374166]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.964765
# R2 loop: -0.23876451319634606
# Explained var: -0.23259281015480404
# correlation: [[-0.14720153]]
# Permutation avg. explained variance: 0.09307445907127958
# Permutation: 29
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.022158
# R2 loop: 0.37839528677044776
# Explained var: 0.3987868007504537
# correlation: [[0.73075197]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.259434
# R2 loop: 0.1906471670744665
# Explained var: 0.19168430326779118
# correlation: [[0.57538974]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.138313
# R2 loop: 0.17482533912132325
# Explained var: 0.2534892520484403
# correlation: [[0.5209512]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.240483
# R2 loop: -0.03212011011804439
# Explained var: -0.029259268492364265
# correlation: [[0.14174714]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.014240
# R2 loop: -0.32576160510167385
# Explained var: -0.08584569378703999
# correlation: [[0.08427624]]
# Permutation avg. explained variance: 0.14577107875745618
# Permutation: 30
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.988685
# R2 loop: -0.3107219606050533
# Explained var: -0.16458471890447068
# correlation: [[0.03010729]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.124290
# R2 loop: 0.3335659237580284
# Explained var: 0.3497518912809039
# correlation: [[0.64173856]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.133732
# R2 loop: 0.16948977035777024
# Explained var: 0.2422368829522915
# correlation: [[0.49836]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.273109
# R2 loop: 0.24160112625925723
# Explained var: 0.25423652134284314
# correlation: [[0.58699961]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.233941
# R2 loop: 0.07813417496244568
# Explained var: 0.141032807545463
# correlation: [[0.38773275]]
# Permutation avg. explained variance: 0.16453467684340617
# Permutation: 31
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.068590
# R2 loop: 0.04345606917452727
# Explained var: 0.054444012136567355
# correlation: [[0.23526071]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.101404
# R2 loop: 0.10555596135350165
# Explained var: 0.10636802457048866
# correlation: [[0.39976408]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.071453
# R2 loop: 0.2519320117369739
# Explained var: 0.2602093097933239
# correlation: [[0.51693912]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.074194
# R2 loop: 0.28450196870488664
# Explained var: 0.47367983690876203
# correlation: [[0.78387436]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.100128
# R2 loop: -0.4200426455484201
# Explained var: 0.31868704377341595
# correlation: [[0.56687862]]
# Permutation avg. explained variance: 0.24267764543651155
# Permutation: 32
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.001235
# R2 loop: -0.007314613950536675
# Explained var: 0.05151677993357062
# correlation: [[0.23220398]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.198030
# R2 loop: -0.518768361447431
# Explained var: -0.033486996486157494
# correlation: [[0.26812042]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.177686
# R2 loop: -0.047586107782118914
# Explained var: -0.030270254537443586
# correlation: [[0.13137999]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.139375
# R2 loop: 0.12343356417321083
# Explained var: 0.12655592432919893
# correlation: [[0.38894393]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.058945
# R2 loop: 0.0906250241776757
# Explained var: 0.18388010131847765
# correlation: [[0.55335244]]
# Permutation avg. explained variance: 0.05963911091152922
# Permutation: 33
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.946170
# R2 loop: 0.28417227591510197
# Explained var: 0.3151600801719846
# correlation: [[0.5669632]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.187399
# R2 loop: 0.12894196496214305
# Explained var: 0.18383647357811705
# correlation: [[0.48044193]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.192928
# R2 loop: -0.020803133796630124
# Explained var: -0.018538139741217208
# correlation: [[0.20677026]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.165177
# R2 loop: -0.12492525561028067
# Explained var: -0.10391856023339341
# correlation: [[0.03544022]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.891796
# R2 loop: 0.2367192618114341
# Explained var: 0.24048334122126114
# correlation: [[0.49043948]]
# Permutation avg. explained variance: 0.12340463899935043
# Permutation: 34
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.909118
# R2 loop: 0.14944683002684267
# Explained var: 0.18970764335967993
# correlation: [[0.48508448]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.088283
# R2 loop: -0.03296596906526661
# Explained var: 0.09858500421550331
# correlation: [[0.34279543]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.115954
# R2 loop: -0.24209082420410089
# Explained var: -0.2165472885040618
# correlation: [[0.01343816]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.182921
# R2 loop: 0.09712530064941671
# Explained var: 0.131130610863043
# correlation: [[0.36241254]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.165448
# R2 loop: -0.10258389597388162
# Explained var: -0.005660649238033111
# correlation: [[0.28601419]]
# Permutation avg. explained variance: 0.03944306413922627
# Permutation: 35
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.092657
# R2 loop: 0.1741821572738057
# Explained var: 0.24401858774769425
# correlation: [[0.49404671]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.259931
# R2 loop: -0.5051979797085295
# Explained var: -0.47514267637471885
# correlation: [[-0.03227238]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.154010
# R2 loop: 0.1555343168058595
# Explained var: 0.15672165269146954
# correlation: [[0.74449909]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.081644
# R2 loop: 0.13813461225444157
# Explained var: 0.13835396617208906
# correlation: [[0.41390093]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.048955
# R2 loop: -0.015480550412272587
# Explained var: 0.031001375901147155
# correlation: [[0.30251235]]
# Permutation avg. explained variance: 0.01899058122753623
# Permutation: 36
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:10.050813
# R2 loop: 0.01843752516153041
# Explained var: 0.020205118592282245
# correlation: [[0.20203231]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.116550
# R2 loop: 0.18507488659973037
# Explained var: 0.27933355500135304
# correlation: [[0.67764599]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.261193
# R2 loop: -0.015303839219949378
# Explained var: 0.11805083889062973
# correlation: [[0.39100878]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.180807
# R2 loop: -0.14017026527872178
# Explained var: 0.10063870516150919
# correlation: [[0.45908091]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.081108
# R2 loop: -0.21677132874959892
# Explained var: 0.0067948376175887
# correlation: [[0.204598]]
# Permutation avg. explained variance: 0.10500461105267259
# Permutation: 37
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.869354
# R2 loop: -0.27768323957980234
# Explained var: 0.005206660847196787
# correlation: [[0.20177807]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.320348
# R2 loop: -0.2708996764631668
# Explained var: -0.14661368704333055
# correlation: [[-0.22623521]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.069086
# R2 loop: -0.018952823315827594
# Explained var: -0.0069809413952219845
# correlation: [[0.21223392]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.052708
# R2 loop: 0.2972968402484233
# Explained var: 0.3449257310505144
# correlation: [[0.79301076]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.136660
# R2 loop: 0.11338572571155558
# Explained var: 0.1135409377352461
# correlation: [[0.34414186]]
# Permutation avg. explained variance: 0.06201574023888094
# Permutation: 38
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.985157
# R2 loop: -0.023378953413565773
# Explained var: 0.030919490758969825
# correlation: [[0.21496968]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:10.115121
# R2 loop: 0.22534973411479842
# Explained var: 0.2322681398250629
# correlation: [[0.56886263]]
# ...
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.491472
# R2 loop: 0.0831971687767884
# Explained var: 0.08719188341350803
# correlation: [[0.31191878]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.466400
# R2 loop: -0.4845147647565351
# Explained var: -0.15669413536868837
# correlation: [[-0.14242694]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.731994
# R2 loop: 0.2883996736781762
# Explained var: 0.3071603950387395
# correlation: [[0.71510755]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.596100
# R2 loop: 0.26977142410185073
# Explained var: 0.28609262831309756
# correlation: [[0.56553353]]
# Permutation avg. explained variance: 0.14035586779715503
# Permutation: 88
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.428949
# R2 loop: 0.08739094307393647
# Explained var: 0.1685248749131053
# correlation: [[0.41062951]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.511882
# R2 loop: 0.17819587661087222
# Explained var: 0.1785827208797639
# correlation: [[0.46297096]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.504288
# R2 loop: -0.025728450721172136
# Explained var: -0.020101390688465504
# correlation: [[0.35172113]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.547338
# R2 loop: -0.12539958691503128
# Explained var: -0.12123228296544819
# correlation: [[-0.0231793]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.503358
# R2 loop: 0.03469804183037695
# Explained var: 0.1258558834438569
# correlation: [[0.46602045]]
# Permutation avg. explained variance: 0.06632596111656248
# Permutation: 89
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.554321
# R2 loop: 0.2711155694192493
# Explained var: 0.2772007248079823
# correlation: [[0.70659616]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.596762
# R2 loop: 0.17138442551625865
# Explained var: 0.24912395869802928
# correlation: [[0.64069458]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.436875
# R2 loop: 0.2747796822019649
# Explained var: 0.32257280527517984
# correlation: [[0.56980996]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.552040
# R2 loop: -0.39035436891193687
# Explained var: -0.3877755899720534
# correlation: [[0.24745736]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.577434
# R2 loop: -0.2370119099285346
# Explained var: -0.19303413638608036
# correlation: [[-0.01494961]]
# Permutation avg. explained variance: 0.05361755248461153
# Permutation: 90
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.123964
# R2 loop: 0.017315577453781872
# Explained var: 0.10165664266782592
# correlation: [[0.35238502]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.525542
# R2 loop: -0.17840699953586703
# Explained var: -0.1649582681962427
# correlation: [[-0.07781685]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.562281
# R2 loop: 0.18768083906185828
# Explained var: 0.19999479992439084
# correlation: [[0.65857185]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.630720
# R2 loop: -0.029653954370325808
# Explained var: 0.09194762948707513
# correlation: [[0.30365008]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.588652
# R2 loop: 0.0770239608196569
# Explained var: 0.14267924232792206
# correlation: [[0.39845413]]
# Permutation avg. explained variance: 0.07426400924219426
# Permutation: 91
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.327510
# R2 loop: -0.08235880297822118
# Explained var: -0.06015110358526887
# correlation: [[0.12672842]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.465951
# R2 loop: 0.1442187968508779
# Explained var: 0.15550004720765187
# correlation: [[0.71010895]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.566480
# R2 loop: -0.04890010549134027
# Explained var: -0.04886940139557239
# correlation: [[0.31958179]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.689627
# R2 loop: -0.04210425246485516
# Explained var: 0.11781469321674765
# correlation: [[0.34514534]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.572051
# R2 loop: -0.10705027962143232
# Explained var: 0.19050868005498156
# correlation: [[0.4402343]]
# Permutation avg. explained variance: 0.07096058309970796
# Permutation: 92
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.411536
# R2 loop: 0.1374883121198862
# Explained var: 0.23408531984050962
# correlation: [[0.69355923]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.639487
# R2 loop: 0.01362939204594571
# Explained var: 0.10048182592060517
# correlation: [[0.32021141]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.452210
# R2 loop: 0.052636304858766136
# Explained var: 0.06299620928299121
# correlation: [[0.25588088]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.614184
# R2 loop: 0.24581002103495164
# Explained var: 0.24811660052898432
# correlation: [[0.49862026]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.552261
# R2 loop: -0.03193098892712176
# Explained var: 0.017423086108217856
# correlation: [[0.35299718]]
# Permutation avg. explained variance: 0.13262060833626163
# Permutation: 93
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.302492
# R2 loop: 0.23954532522104244
# Explained var: 0.25188836949352855
# correlation: [[0.52803408]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.549603
# R2 loop: 0.31055425268720993
# Explained var: 0.35171499966136643
# correlation: [[0.64263388]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.453544
# R2 loop: -0.025871176704424625
# Explained var: -0.004174316149366364
# correlation: [[0.1241186]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.461640
# R2 loop: -0.014811694787114416
# Explained var: -0.011183699685392012
# correlation: [[0.14280559]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.369637
# R2 loop: 0.11961488366417727
# Explained var: 0.1196772200942463
# correlation: [[0.34659137]]
# Permutation avg. explained variance: 0.14158451468287658
# Permutation: 94
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.196641
# R2 loop: -0.46683959992116786
# Explained var: -0.10760448700975811
# correlation: [[0.09320566]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.524066
# R2 loop: 0.1279151905447914
# Explained var: 0.14218433177290435
# correlation: [[0.38606507]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.521763
# R2 loop: 0.08698632746627932
# Explained var: 0.19058775878697276
# correlation: [[0.55369706]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.614060
# R2 loop: 0.2384094756989208
# Explained var: 0.3539981105505139
# correlation: [[0.6177396]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.707019
# R2 loop: -0.03781445215530166
# Explained var: -0.023749875422926614
# correlation: [[0.12308234]]
# Permutation avg. explained variance: 0.11108316773554125
# Permutation: 95
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.493697
# R2 loop: -0.3384239028809497
# Explained var: -0.07527405201877113
# correlation: [[0.35193485]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.801674
# R2 loop: 0.2199311527949005
# Explained var: 0.22458431830878223
# correlation: [[0.48757919]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.616100
# R2 loop: 0.17194834215787935
# Explained var: 0.17220043403015317
# correlation: [[0.45037333]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.838061
# R2 loop: 0.09000749914686712
# Explained var: 0.20444519357968505
# correlation: [[0.51373939]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.728332
# R2 loop: 0.15022699296985664
# Explained var: 0.15106701149869806
# correlation: [[0.4486982]]
# Permutation avg. explained variance: 0.13540458107970949
# Permutation: 96
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.568917
# R2 loop: -0.10010584829689884
# Explained var: -0.025846378770800094
# correlation: [[0.31326363]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.657097
# R2 loop: -0.029957883742857128
# Explained var: -0.003776777910039275
# correlation: [[0.10549649]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.695218
# R2 loop: -0.10676315343090814
# Explained var: -0.10134005560111903
# correlation: [[0.07799459]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.821414
# R2 loop: 0.3411333833397432
# Explained var: 0.3597491564840599
# correlation: [[0.59997721]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.706773
# R2 loop: 0.1679505195377492
# Explained var: 0.2543667619986725
# correlation: [[0.80286951]]
# Permutation avg. explained variance: 0.0966305412401548
# Permutation: 97
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.723433
# R2 loop: 0.1757723964110024
# Explained var: 0.175870527626783
# correlation: [[0.55249493]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.741166
# R2 loop: 0.1729759186552131
# Explained var: 0.1989677188115735
# correlation: [[0.44864996]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.784450
# R2 loop: -0.28099752847293824
# Explained var: -0.21581499386284952
# correlation: [[-0.02226232]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.436849
# R2 loop: 0.23974114003735225
# Explained var: 0.24012041173780696
# correlation: [[0.51557195]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.508657
# R2 loop: 0.25931309242373934
# Explained var: 0.3506837639832323
# correlation: [[0.64402959]]
# Permutation avg. explained variance: 0.14996548565930926
# Permutation: 98
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.626196
# R2 loop: -0.03726760881168012
# Explained var: -0.03152339360328571
# correlation: [[0.10670199]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.655141
# R2 loop: 0.006875592478911452
# Explained var: 0.09852560270965516
# correlation: [[0.31966385]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.693463
# R2 loop: -0.49688146040717185
# Explained var: -0.45366433042078147
# correlation: [[-0.0262619]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.586775
# R2 loop: -0.0774626397108551
# Explained var: -0.023258782604000716
# correlation: [[0.20064427]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.679762
# R2 loop: 0.2228361052341158
# Explained var: 0.22551496138297922
# correlation: [[0.49684664]]
# Permutation avg. explained variance: -0.0368811885070867
# Permutation: 99
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:09.679744
# R2 loop: -0.07071511346363679
# Explained var: -0.057809905210901125
# correlation: [[0.19968947]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.914094
# R2 loop: 0.10309215456679055
# Explained var: 0.22170812854875765
# correlation: [[0.60540122]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.538237
# R2 loop: -0.06109368777806368
# Explained var: -0.03477172294611797
# correlation: [[0.09326905]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.765448
# R2 loop: 0.028235866381595587
# Explained var: 0.12779605918149006
# correlation: [[0.3823278]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:09.727813
# R2 loop: 0.4121205140355174
# Explained var: 0.41250593043840633
# correlation: [[0.657611]]
# Permutation avg. explained variance: 0.133885698002327

# %%
# predictions for FC (node) - PCA and correlation

import datetime

# feature selection type
f=['correlation', 'PCA']

for featselect in f: 
    #set the number of folds you want in the inner and outer folds of the nested cross-validation
    k = 5

    #set the proportion of data you want in your training set
    train_size = .8

    #set x data to be the input variable you want to use
    #ie fc, sc, or hc
    #X=np.concatenate([sc, fc], axis=1)
    X=fc_n
    X=prepare_data(X)

    #set y to be the measure you want to predict
    Y = np.array(wais)


    # range of alphas
    n_alphas=20
    alpha_start=-1
    alpha_end=2
    alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

    #number of features (# pricipal components or variables to retain)
    feat_start=10
    feat_end=30
    n_feats=feat_end-feat_start+1
    feats = np.linspace(feat_start, feat_end, n_feats, dtype=int)

    # initialize lists to store model results for each permuation
    allR2=[]
    meanR2=[]
    features=[]
    bestalphas=[]
    importance=[]
    allexpl_var=[]
    #joblib-based parallelism to increase speed,

    for p in range(0, 100):
        outer_cv = KFold(n_splits=k, shuffle=True, random_state=p)
        print('Permutation: ' + str(p))
        # initialize lists to store model results for eah fold
        R2=[]
        featur=[]
        best_alphas=[]
        impt=[] 
        expl_var=[]
        for train, test in outer_cv.split(X):
            begin_time = datetime.datetime.now()

            # select model using training data
            bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv(k, X[train], Y[train], featselect, alphas, feats)

            # using optimal num. of features, select final features using entire training data.

            if featselect=='correlation':
                x_train_featselect,x_test_featureselect,ind = feature_select_correlation(X[train],X[test], Y[train], bestfeats)
                featur.append(ind)

            elif featselect=='PCA':
                x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(X[train],X[test], bestfeats)
                featur.append(ind)

            # initialize Ridge regression with alpha selected from hyperparameter search
            regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)

            # fit model 
            y_pred = regr.fit(x_train_featselect, Y[train]).predict(x_test_featureselect)

            # store results for each fold k
            impt.append(regr.coef_)
            R2.append(r2_score(Y[test], y_pred))
            expl_var.append(explained_variance_score(Y[test], y_pred))

            best_alphas.append(bestalpha)
            print('time to run loop: ' + str(datetime.datetime.now() - begin_time)) 
            print("R2 loop: " + str(r2_score(Y[test], y_pred)))
            print("Explained var: " + str(explained_variance_score(Y[test], y_pred)))
            print("correlation: " + str(np_pearson_cor(Y[test], y_pred)))

        # store results for each permutation p

        allexpl_var.append(expl_var)
        bestalphas.append(best_alphas)
        importance.append(impt)
        print("Permutation avg. explained variance: " + str(np.mean(expl_var)))

        np.savetxt(results_dir + featselect + 'p' + str(p) + '_FCn_all_explvar.txt', expl_var, delimiter=',')

        output = open(results_dir + featselect + 'p' + str(p) + '_FCn_features.pkl', 'wb')
        pickle.dump(featur, output)
        output.close()

        output = open(results_dir + featselect + 'p' + str(p) + '_FCn_bestalphas.pkl', 'wb')
        pickle.dump(best_alphas, output)
        output.close()
# Out:
# Final size of X: (101, 86)
# Permutation: 0
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:02.178083
# R2 loop: 0.07394512584719448
# Explained var: 0.09305103902910405
# correlation: [[0.40141334]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.240586
# R2 loop: -0.2368757558225214
# Explained var: -0.028671472923573305
# correlation: [[0.05460586]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.199235
# R2 loop: 0.014499800231772886
# Explained var: 0.13442294295769142
# correlation: [[0.39495908]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.192819
# R2 loop: 0.05841683626553029
# Explained var: 0.10350039879191975
# correlation: [[0.51243111]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.221338
# R2 loop: -0.16912365143950447
# Explained var: -0.1262079193943566
# correlation: [[-0.02177142]]
# Permutation avg. explained variance: 0.03521899769215706
# Permutation: 1
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.222994
# R2 loop: 0.03215262240176797
# Explained var: 0.07050648594816833
# correlation: [[0.26645203]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.259691
# R2 loop: 0.1792389081342869
# Explained var: 0.1989316521004194
# correlation: [[0.5689581]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.386009
# R2 loop: -0.05054801715994972
# Explained var: -0.011801133953475151
# correlation: [[0.0790206]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.167389
# R2 loop: 0.15408920208529042
# Explained var: 0.24900370273281391
# correlation: [[0.5899204]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.215802
# R2 loop: 0.1656764756214093
# Explained var: 0.16828938022392337
# correlation: [[0.42708769]]
# Permutation avg. explained variance: 0.13498601741036997
# Permutation: 2
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.282891
# R2 loop: 0.09588876791915513
# Explained var: 0.11333885440740665
# correlation: [[0.3403685]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.301952
# R2 loop: 0.15376571234378666
# Explained var: 0.15449850377294416
# correlation: [[0.39308724]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.209045
# R2 loop: 0.13668231658646468
# Explained var: 0.1514019416328748
# correlation: [[0.5842393]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.188983
# R2 loop: -0.11980191192747625
# Explained var: -0.11482948010449068
# correlation: [[0.00714519]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.327084
# R2 loop: -0.01604406410866388
# Explained var: -0.016041100978236633
# correlation: [[0.08201158]]
# Permutation avg. explained variance: 0.05767374374609966
# Permutation: 3
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.229184
# R2 loop: -0.13729044191961237
# Explained var: -0.0071121805767693225
# correlation: [[0.19077883]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.277134
# R2 loop: -0.22380495064103223
# Explained var: 0.09538604495948155
# correlation: [[0.32214463]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.221271
# R2 loop: -0.020970036533732417
# Explained var: 0.0670691480243304
# correlation: [[0.57694432]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.099443
# R2 loop: -0.10966437718858324
# Explained var: 0.056201334301201666
# correlation: [[0.24822144]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.228539
# R2 loop: -0.2792293568388684
# Explained var: -0.25410275566549156
# correlation: [[-0.20951357]]
# Permutation avg. explained variance: -0.008511681791449455
# Permutation: 4
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.272325
# R2 loop: 0.3062982671529799
# Explained var: 0.307953019334797
# correlation: [[0.69038488]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.278754
# R2 loop: 0.10410630741473392
# Explained var: 0.10512859719458723
# correlation: [[0.35894089]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.289799
# R2 loop: -0.06348149771592637
# Explained var: -0.058792961906693364
# correlation: [[-0.01261392]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.374822
# R2 loop: 0.08751200265218584
# Explained var: 0.09331508906478503
# correlation: [[0.36421944]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.169309
# R2 loop: -0.5254790379235783
# Explained var: -0.523689477782266
# correlation: [[0.03443951]]
# Permutation avg. explained variance: -0.015217146818958027
# Permutation: 5
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.267166
# R2 loop: 0.08357404087002585
# Explained var: 0.08467809580279517
# correlation: [[0.42435506]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.302679
# R2 loop: -0.8600855015326856
# Explained var: -0.8478642949413155
# correlation: [[-0.30824332]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.054068
# R2 loop: -0.5384367230629656
# Explained var: -0.5363682327161363
# correlation: [[-0.37849004]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.195978
# R2 loop: -0.2958030759440584
# Explained var: -0.0468704370710864
# correlation: [[0.03626331]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.236143
# R2 loop: 0.06707453933653251
# Explained var: 0.1340242396679584
# correlation: [[0.47484292]]
# Permutation avg. explained variance: -0.24248012585155693
# Permutation: 6
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.128679
# R2 loop: -0.18753706399980952
# Explained var: -0.14349129792801985
# correlation: [[-0.16987143]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.240348
# R2 loop: 0.053232375469771775
# Explained var: 0.10129384046770318
# correlation: [[0.32586701]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.274659
# R2 loop: 0.08120269173078665
# Explained var: 0.17243103240363078
# correlation: [[0.5431035]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.248922
# R2 loop: -0.4425671095906156
# Explained var: -0.2874165435448235
# correlation: [[-0.05624848]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.221376
# R2 loop: 0.08159418455490197
# Explained var: 0.0872918026055638
# correlation: [[0.4768978]]
# Permutation avg. explained variance: -0.013978233199189116
# Permutation: 7
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.293331
# R2 loop: 0.056574963648445276
# Explained var: 0.05740653937331763
# correlation: [[0.31846642]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.224777
# R2 loop: 0.00018082347423142853
# Explained var: 0.030693329523585278
# correlation: [[0.63268593]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.234765
# R2 loop: 0.024806435832078866
# Explained var: 0.025120368868498777
# correlation: [[0.24395597]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.251372
# R2 loop: -0.17417195640602534
# Explained var: -0.15895350421253562
# correlation: [[-0.01724665]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.261424
# R2 loop: -0.05953582631556298
# Explained var: 0.09776015289014328
# correlation: [[0.42317334]]
# Permutation avg. explained variance: 0.010405377288601868
# Permutation: 8
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.215427
# R2 loop: 0.004198488283117974
# Explained var: 0.23637853300881562
# correlation: [[0.57485329]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.214591
# R2 loop: 0.07811645880030393
# Explained var: 0.08651354579723103
# correlation: [[0.34140575]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.201804
# R2 loop: -0.1821133109709987
# Explained var: 0.012673960529211992
# correlation: [[0.1314327]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.189253
# R2 loop: -0.22940281502099547
# Explained var: -0.08909120665640824
# correlation: [[0.09913657]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.247582
# R2 loop: -0.4273785138697215
# Explained var: -0.3968593448116886
# correlation: [[-0.31799969]]
# Permutation avg. explained variance: -0.03007690242656764
# Permutation: 9
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.196219
# R2 loop: -0.12181579180873614
# Explained var: -0.059467645953145576
# correlation: [[0.10842635]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.256833
# R2 loop: -0.09027457246761106
# Explained var: -0.032174947999658254
# correlation: [[0.12336871]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.273608
# R2 loop: 0.12352540046846294
# Explained var: 0.12878489560576756
# correlation: [[0.35886662]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.301861
# R2 loop: -0.1865281481159462
# Explained var: -0.09645678968077198
# correlation: [[-0.0353214]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.309833
# R2 loop: -0.17886441462307356
# Explained var: 0.06506794862976828
# correlation: [[0.75973943]]
# Permutation avg. explained variance: 0.001150692120392005
# Permutation: 10
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.209216
# R2 loop: -0.020778276643298677
# Explained var: -0.020646706853666652
# correlation: [[0.09582247]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.270391
# R2 loop: -0.09441179370587238
# Explained var: -0.0916468759088509
# correlation: [[0.06537638]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.173338
# R2 loop: -1.093776524640886
# Explained var: -0.7847451794124358
# correlation: [[-0.18664184]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.219483
# R2 loop: 0.13662588934888875
# Explained var: 0.15506241831825474
# correlation: [[0.57577173]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.263963
# R2 loop: -0.01278728049268385
# Explained var: 0.016583125714136893
# correlation: [[0.75863087]]
# Permutation avg. explained variance: -0.14507864362851236
# Permutation: 11
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.381347
# R2 loop: 0.20863569831194928
# Explained var: 0.21786612077652456
# correlation: [[0.52179419]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.383109
# R2 loop: 0.1174653497676088
# Explained var: 0.14678579504278622
# correlation: [[0.66122655]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.270614
# R2 loop: -0.4720425140933495
# Explained var: -0.2275569599385825
# correlation: [[0.09757377]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.218254
# R2 loop: -0.32160503275199726
# Explained var: 0.1998211565874919
# correlation: [[0.45040951]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.264161
# R2 loop: -0.03522143204751793
# Explained var: -0.013355383056809833
# correlation: [[0.19575783]]
# Permutation avg. explained variance: 0.06471214588228207
# Permutation: 12
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.238666
# R2 loop: -0.03358060386994355
# Explained var: 0.03486599475037655
# correlation: [[0.21777194]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.189061
# R2 loop: 0.1008913937550251
# Explained var: 0.13165495173304576
# correlation: [[0.53466169]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.294789
# R2 loop: -0.0416123559908419
# Explained var: 0.0649669464163134
# correlation: [[0.27567522]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.253762
# R2 loop: 0.07610815913698743
# Explained var: 0.07621845255938386
# correlation: [[0.32248443]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.258740
# R2 loop: -0.16952188695638282
# Explained var: -0.09530358329547939
# correlation: [[0.09280504]]
# Permutation avg. explained variance: 0.04248055243272804
# Permutation: 13
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.342043
# R2 loop: -0.12992239785336612
# Explained var: 0.005668869915567476
# correlation: [[0.11235541]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.341785
# R2 loop: -0.0033021310968301965
# Explained var: 0.016642746423064625
# correlation: [[0.12978736]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.215701
# R2 loop: -0.23769913773384643
# Explained var: -0.1851261402824591
# correlation: [[0.22692952]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.137244
# R2 loop: -0.24091889506187192
# Explained var: -0.11976343630322384
# correlation: [[0.1446492]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.216182
# R2 loop: 0.07645721928424487
# Explained var: 0.0919847643635201
# correlation: [[0.41301421]]
# Permutation avg. explained variance: -0.038118639176706146
# Permutation: 14
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.183677
# R2 loop: -0.08102169534728598
# Explained var: -0.04233507015537197
# correlation: [[-0.05540969]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.229021
# R2 loop: 0.12479876013964064
# Explained var: 0.1505650327622181
# correlation: [[0.54432013]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.237062
# R2 loop: 0.05514394146750967
# Explained var: 0.06935880478308654
# correlation: [[0.2760179]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.242451
# R2 loop: -0.2767971703380414
# Explained var: -0.18750083456232813
# correlation: [[0.06291465]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.357004
# R2 loop: 0.06290123938899506
# Explained var: 0.08518103360525942
# correlation: [[0.33483101]]
# Permutation avg. explained variance: 0.015053793286572793
# Permutation: 15
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.269668
# R2 loop: 0.05801446479275074
# Explained var: 0.058900406743344624
# correlation: [[0.58588084]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.268364
# R2 loop: 0.06619039076439903
# Explained var: 0.17047246663480364
# correlation: [[0.42020276]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.180694
# R2 loop: -1.3623142278186808
# Explained var: -0.48162386348155595
# correlation: [[0.05441555]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.067547
# R2 loop: 0.0915238047631659
# Explained var: 0.15034655411028874
# correlation: [[0.41016676]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.128621
# R2 loop: 0.06925482552448681
# Explained var: 0.11609911560649
# correlation: [[0.59189579]]
# Permutation avg. explained variance: 0.002838935922674213
# Permutation: 16
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.305879
# R2 loop: 0.02669011029970403
# Explained var: 0.026993219489004794
# correlation: [[0.18099404]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.275108
# R2 loop: 0.03723904532314326
# Explained var: 0.0389358106139166
# correlation: [[0.55827367]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.330777
# R2 loop: -1.2019543154743553
# Explained var: -1.196374686249864
# correlation: [[-0.5199737]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.331661
# R2 loop: 0.026136231177554925
# Explained var: 0.027049865721844535
# correlation: [[0.63049011]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.236238
# R2 loop: 0.18606928982332382
# Explained var: 0.20575086134386633
# correlation: [[0.56996809]]
# Permutation avg. explained variance: -0.17952898581624638
# Permutation: 17
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.244964
# R2 loop: 0.02482606820367772
# Explained var: 0.07966502432521505
# correlation: [[0.29665464]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.226219
# R2 loop: -0.03506242689279637
# Explained var: -0.021097585002732178
# correlation: [[0.12428986]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.256577
# R2 loop: 0.04744411123554293
# Explained var: 0.0493173928249343
# correlation: [[0.23319426]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.257121
# R2 loop: 0.27243008181874795
# Explained var: 0.3027275110038049
# correlation: [[0.58615961]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.258308
# R2 loop: -0.09337314187539913
# Explained var: -0.09331880773726331
# correlation: [[0.19988567]]
# Permutation avg. explained variance: 0.06345870708279175
# Permutation: 18
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.242029
# R2 loop: 0.09058672946076962
# Explained var: 0.09087636267218058
# correlation: [[0.68127657]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.237563
# R2 loop: -0.4441074635329494
# Explained var: -0.4415312293753899
# correlation: [[-0.29141371]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.391202
# R2 loop: 0.3907600420132058
# Explained var: 0.39080068501222653
# correlation: [[0.67890279]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.256201
# R2 loop: -0.8742377289575693
# Explained var: -0.5978322539375669
# correlation: [[0.02550496]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.346691
# R2 loop: -0.014409745671034813
# Explained var: 0.02937997269506698
# correlation: [[0.17736322]]
# Permutation avg. explained variance: -0.10566129258669654
# Permutation: 19
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.321154
# R2 loop: 0.04482430675543658
# Explained var: 0.05011434188395092
# correlation: [[0.53351694]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.241583
# R2 loop: -0.4146649781856018
# Explained var: -0.4113325436533306
# correlation: [[-0.07297238]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.317839
# R2 loop: -0.5424973216793125
# Explained var: -0.3880460775105943
# correlation: [[-0.16744421]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.275037
# R2 loop: 0.1545106765888581
# Explained var: 0.16328640988575427
# correlation: [[0.55170648]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.245350
# R2 loop: 0.046905405414921164
# Explained var: 0.1316180570871106
# correlation: [[0.36505864]]
# Permutation avg. explained variance: -0.09087196246142182
# Permutation: 20
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.311772
# R2 loop: -0.2583441547134957
# Explained var: -0.11783318449582136
# correlation: [[0.08684674]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.198960
# R2 loop: -0.03129383896379445
# Explained var: -0.0165911599207349
# correlation: [[0.14085806]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.185071
# R2 loop: 0.12123167118732026
# Explained var: 0.25150813165992925
# correlation: [[0.60895662]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.224902
# R2 loop: 0.10063222464609545
# Explained var: 0.10359422051376455
# correlation: [[0.33736404]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.371899
# R2 loop: 0.08441682940734851
# Explained var: 0.08501353198727568
# correlation: [[0.29250711]]
# Permutation avg. explained variance: 0.06113830794888264
# Permutation: 21
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.368782
# R2 loop: 0.06578422813134288
# Explained var: 0.0661479660433556
# correlation: [[0.26422616]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.234449
# R2 loop: 0.02834630335149113
# Explained var: 0.05043389116935737
# correlation: [[0.48324539]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.232568
# R2 loop: -0.13397344028690306
# Explained var: -0.12140474431505344
# correlation: [[0.08041252]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.268267
# R2 loop: 0.011346280191081193
# Explained var: 0.01985174345134222
# correlation: [[0.71506952]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.330442
# R2 loop: -0.34896980947637735
# Explained var: -0.33289169502770277
# correlation: [[-0.20676858]]
# Permutation avg. explained variance: -0.0635725677357402
# Permutation: 22
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.245957
# R2 loop: 0.013410154226876969
# Explained var: 0.027558865374669117
# correlation: [[0.54959543]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.311521
# R2 loop: -0.028900411271981508
# Explained var: 0.14772409590027247
# correlation: [[0.51477596]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.378276
# R2 loop: -0.10350302895285024
# Explained var: -0.046173211285464255
# correlation: [[0.07721663]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.243169
# R2 loop: -0.06985583487100899
# Explained var: 0.0035141172813257793
# correlation: [[0.15049572]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.282111
# R2 loop: -0.3410056025071788
# Explained var: -0.2612512158838045
# correlation: [[-0.38228676]]
# Permutation avg. explained variance: -0.02572546972260028
# Permutation: 23
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.249525
# R2 loop: -0.0628990374431091
# Explained var: -0.058329662659696524
# correlation: [[0.06801814]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.178736
# R2 loop: 0.08022775403970495
# Explained var: 0.08980102479624286
# correlation: [[0.32837316]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.170137
# R2 loop: 0.18184540758453338
# Explained var: 0.1826394639580894
# correlation: [[0.44218785]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.185639
# R2 loop: 0.13586372125371615
# Explained var: 0.14554732428471062
# correlation: [[0.43744041]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.319242
# R2 loop: 0.04468316069999445
# Explained var: 0.07414693533388006
# correlation: [[0.34460088]]
# Permutation avg. explained variance: 0.08676101714264528
# Permutation: 24
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.237187
# R2 loop: 0.23445845809660515
# Explained var: 0.28716671390440673
# correlation: [[0.58719608]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.226779
# R2 loop: 0.1757248073658373
# Explained var: 0.21978928672039177
# correlation: [[0.58568109]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.260956
# R2 loop: 0.01466759540893825
# Explained var: 0.033681732533026865
# correlation: [[0.19812697]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.282109
# R2 loop: -0.10445690642326899
# Explained var: -0.08085493513232644
# correlation: [[-0.10345994]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.256582
# R2 loop: 0.0823890362367512
# Explained var: 0.08421625398387966
# correlation: [[0.30011514]]
# Permutation avg. explained variance: 0.10879981040187572
# Permutation: 25
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.251695
# R2 loop: 0.09576877436596454
# Explained var: 0.1470690354068791
# correlation: [[0.41916565]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.261271
# R2 loop: 0.15069846028235578
# Explained var: 0.1508096854176454
# correlation: [[0.63812355]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.231374
# R2 loop: -0.42971504232210034
# Explained var: -0.29716727619048133
# correlation: [[-0.15587277]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.208637
# R2 loop: -0.18047008904295958
# Explained var: 0.15947754672442827
# correlation: [[0.5722171]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.216962
# R2 loop: -0.07183882926452467
# Explained var: -0.021187779508095472
# correlation: [[0.11294928]]
# Permutation avg. explained variance: 0.02780024237007519
# Permutation: 26
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.306212
# R2 loop: -0.08538705097184285
# Explained var: -0.03002734365471693
# correlation: [[0.14457802]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.213434
# R2 loop: -0.15246659318467026
# Explained var: 0.022455262988838265
# correlation: [[0.63993771]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.263933
# R2 loop: -0.1386485394498611
# Explained var: -0.028363533672589814
# correlation: [[0.09130536]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.351351
# R2 loop: -0.09365349484336005
# Explained var: 0.09933422213893894
# correlation: [[0.31647705]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.243264
# R2 loop: 0.0874411026053703
# Explained var: 0.09064045127084686
# correlation: [[0.30136694]]
# Permutation avg. explained variance: 0.030807811814263463
# Permutation: 27
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.292877
# R2 loop: -0.4122196450888893
# Explained var: -0.4097406842527058
# correlation: [[0.0352868]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.309073
# R2 loop: 0.03844411282991356
# Explained var: 0.05170365225124807
# correlation: [[0.25942749]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.215095
# R2 loop: 0.08253922485257204
# Explained var: 0.11005154747604828
# correlation: [[0.54103939]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.280871
# R2 loop: -0.24590139574407144
# Explained var: -0.1800865388869175
# correlation: [[0.0205987]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.221818
# R2 loop: 0.018701398077156983
# Explained var: 0.023347724092905975
# correlation: [[0.73019146]]
# Permutation avg. explained variance: -0.0809448598638842
# Permutation: 28
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.226310
# R2 loop: -0.02035224593673357
# Explained var: -0.011425894667108638
# correlation: [[0.12793913]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.182564
# R2 loop: -0.04061701462651346
# Explained var: 0.0571980784178604
# correlation: [[0.51477064]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.267232
# R2 loop: 0.05518589719942735
# Explained var: 0.06938275240071234
# correlation: [[0.28707556]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.290143
# R2 loop: -0.08332187134802194
# Explained var: 0.10769482650230122
# correlation: [[0.51249778]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.247897
# R2 loop: -0.2727344586511433
# Explained var: -0.23720469254571808
# correlation: [[-0.00228448]]
# Permutation avg. explained variance: -0.00287098597839055
# Permutation: 29
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.280266
# R2 loop: 0.02504601062339551
# Explained var: 0.03222754629716862
# correlation: [[0.6562145]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.272785
# R2 loop: 0.0016373146594510501
# Explained var: 0.012570971187484514
# correlation: [[0.1180727]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.246276
# R2 loop: -0.10889622980831759
# Explained var: 0.03900454176735102
# correlation: [[0.29071827]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.227882
# R2 loop: 0.15769840799202317
# Explained var: 0.16833177129167654
# correlation: [[0.42193326]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.253647
# R2 loop: -0.2932244895058673
# Explained var: -0.10861294563107737
# correlation: [[0.05443563]]
# Permutation avg. explained variance: 0.028704376982520662
# Permutation: 30
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.252962
# R2 loop: -0.47287921933411514
# Explained var: -0.2375458518039646
# correlation: [[-0.00392033]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.313175
# R2 loop: 0.042193993996385126
# Explained var: 0.0757904271163441
# correlation: [[0.50630355]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.301763
# R2 loop: 0.17221060967405433
# Explained var: 0.18485214046606802
# correlation: [[0.43911515]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.265653
# R2 loop: 0.08496720089333176
# Explained var: 0.10123844718695285
# correlation: [[0.32015187]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.366381
# R2 loop: 0.04512749085955614
# Explained var: 0.046373333223969415
# correlation: [[0.2211819]]
# Permutation avg. explained variance: 0.034141699237873954
# Permutation: 31
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.332119
# R2 loop: -0.028073652003017813
# Explained var: -0.009245263704554807
# correlation: [[0.0372955]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.211733
# R2 loop: -0.034874664810394584
# Explained var: -0.03482362953371432
# correlation: [[0.01368928]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.184019
# R2 loop: -0.13461520451704878
# Explained var: -0.12519530584170346
# correlation: [[0.06129912]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.171923
# R2 loop: 0.09120793992230325
# Explained var: 0.25173305481213926
# correlation: [[0.8130952]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.282868
# R2 loop: -0.3698890477195711
# Explained var: 0.16127657381473737
# correlation: [[0.52783094]]
# Permutation avg. explained variance: 0.048749085909380804
# Permutation: 32
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.174553
# R2 loop: -0.203652251008833
# Explained var: -0.19633782207462125
# correlation: [[-0.05955666]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.048896
# R2 loop: -1.032212977310282
# Explained var: -0.21083412461599593
# correlation: [[0.17651437]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.136606
# R2 loop: 0.14959236414582033
# Explained var: 0.19009981288423805
# correlation: [[0.65903228]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.177385
# R2 loop: -0.028789867514231515
# Explained var: -0.021106565587508452
# correlation: [[0.10808957]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.205428
# R2 loop: -0.021309751837112145
# Explained var: 0.10025087873029237
# correlation: [[0.46664811]]
# Permutation avg. explained variance: -0.027585564132719044
# Permutation: 33
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.302780
# R2 loop: 0.07900791391047246
# Explained var: 0.11082943670803935
# correlation: [[0.33300245]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.198480
# R2 loop: 0.07718245936647494
# Explained var: 0.15714027717168721
# correlation: [[0.42762578]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.227964
# R2 loop: -0.2583838044630413
# Explained var: -0.24190760911258247
# correlation: [[-0.06222291]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.296565
# R2 loop: 0.032894622853447575
# Explained var: 0.05368871422534727
# correlation: [[0.23575343]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.221985
# R2 loop: 0.2011354376193718
# Explained var: 0.20272716688450154
# correlation: [[0.45183233]]
# Permutation avg. explained variance: 0.05649559717539858
# Permutation: 34
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.246582
# R2 loop: -0.05324102567770006
# Explained var: 0.016514425905915564
# correlation: [[0.48662383]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.246283
# R2 loop: -0.09498082131804453
# Explained var: -0.022045623591549823
# correlation: [[0.19076582]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.240310
# R2 loop: -0.37737860545483204
# Explained var: -0.3750346832319029
# correlation: [[-0.18787155]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.333808
# R2 loop: -0.23213245635919377
# Explained var: -0.19232012830616574
# correlation: [[0.01465874]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.264214
# R2 loop: 0.0779670930802755
# Explained var: 0.11370937700356709
# correlation: [[0.42244716]]
# Permutation avg. explained variance: -0.09183532644402717
# Permutation: 35
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.259174
# R2 loop: 0.13535065641818056
# Explained var: 0.19053215759840159
# correlation: [[0.45054247]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.165234
# R2 loop: 0.018350014967171813
# Explained var: 0.020047180975066414
# correlation: [[0.25358732]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.246835
# R2 loop: 0.02870412279252288
# Explained var: 0.03231502962044086
# correlation: [[0.70983699]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.278999
# R2 loop: 0.011829904823044468
# Explained var: 0.019741274781258533
# correlation: [[0.1407933]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.309915
# R2 loop: -0.26357076778930977
# Explained var: -0.08754836362350082
# correlation: [[0.12480487]]
# Permutation avg. explained variance: 0.035017455870333315
# Permutation: 36
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.311231
# R2 loop: 0.00063891371904512
# Explained var: 0.0032279088986801874
# correlation: [[0.12466592]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.365372
# R2 loop: -0.10345806253561118
# Explained var: 0.06038929444073671
# correlation: [[0.50049285]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.235936
# R2 loop: -0.14445303614104565
# Explained var: -0.006052541127044675
# correlation: [[0.1284202]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.222219
# R2 loop: 0.11825093759682459
# Explained var: 0.17361965710788774
# correlation: [[0.51123163]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.203545
# R2 loop: -0.12929125579461598
# Explained var: -0.11193132739472689
# correlation: [[0.07638664]]
# Permutation avg. explained variance: 0.023850598385106614
# Permutation: 37
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.187493
# R2 loop: -0.3592227690945189
# Explained var: -0.1298900126201381
# correlation: [[0.02895012]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.212042
# R2 loop: 0.003299954509768943
# Explained var: 0.0801570108611549
# correlation: [[0.34497829]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.078335
# R2 loop: 0.08449382629697422
# Explained var: 0.0845929908641313
# correlation: [[0.31462415]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.195207
# R2 loop: 0.22404329400725576
# Explained var: 0.31459512963884073
# correlation: [[0.62313126]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.319957
# R2 loop: 0.004418356997732076
# Explained var: 0.022233640459815684
# correlation: [[0.19009814]]
# Permutation avg. explained variance: 0.0743377518407609
# Permutation: 38
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.283406
# R2 loop: 0.049118820752893755
# Explained var: 0.07707262473538823
# correlation: [[0.28471313]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# ...
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.620347
# R2 loop: 0.003095613431019162
# Explained var: 0.0034208423444963554
# correlation: [[0.12845518]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.570474
# R2 loop: -0.3842975441834955
# Explained var: -0.10933525051184545
# correlation: [[-0.09914986]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.647365
# R2 loop: 0.3111633773910424
# Explained var: 0.3270993265911356
# correlation: [[0.7053845]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.575710
# R2 loop: 0.32371553795108554
# Explained var: 0.3560979471232284
# correlation: [[0.74562094]]
# Permutation avg. explained variance: 0.13386794172049693
# Permutation: 88
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.655834
# R2 loop: 0.18761019686183833
# Explained var: 0.2595156038075396
# correlation: [[0.53582246]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.627613
# R2 loop: 0.35166603507771554
# Explained var: 0.3550233269227999
# correlation: [[0.65343467]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.599684
# R2 loop: 0.03315959872881269
# Explained var: 0.07354269745112829
# correlation: [[0.29029478]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.657654
# R2 loop: -0.5843995865027054
# Explained var: -0.5837152538384733
# correlation: [[-0.28864593]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.567548
# R2 loop: -0.06367918006653128
# Explained var: 0.06132842821515838
# correlation: [[0.32530093]]
# Permutation avg. explained variance: 0.033138960511630566
# Permutation: 89
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.621559
# R2 loop: 0.19786717642091234
# Explained var: 0.19801186233146784
# correlation: [[0.47467244]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.575290
# R2 loop: 0.1856003971575323
# Explained var: 0.2704362721488036
# correlation: [[0.5777112]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.626086
# R2 loop: 0.282471815647802
# Explained var: 0.3244922369559271
# correlation: [[0.6202216]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.635493
# R2 loop: -0.11271306991191365
# Explained var: -0.11160338034802386
# correlation: [[0.21502635]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.690145
# R2 loop: -0.22713391271615158
# Explained var: -0.18914521025119657
# correlation: [[0.04028113]]
# Permutation avg. explained variance: 0.09843835616739563
# Permutation: 90
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.609592
# R2 loop: -0.17904614225369486
# Explained var: -0.1736151803541397
# correlation: [[0.25026919]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.601785
# R2 loop: -0.21622825063372741
# Explained var: -0.21127164890506367
# correlation: [[0.02318029]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.586581
# R2 loop: 0.12152426509530212
# Explained var: 0.12821392146030042
# correlation: [[0.41690376]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.566561
# R2 loop: -0.014315001422240181
# Explained var: 0.075189907758898
# correlation: [[0.31822099]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.604148
# R2 loop: 0.09539521405291729
# Explained var: 0.16746346948378288
# correlation: [[0.41959426]]
# Permutation avg. explained variance: -0.002803906111244414
# Permutation: 91
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.604578
# R2 loop: -0.4295905573312899
# Explained var: -0.35938030515998176
# correlation: [[-0.23055038]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.586862
# R2 loop: 0.21003221456971843
# Explained var: 0.21895427289226121
# correlation: [[0.6555865]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.608369
# R2 loop: -0.11567846076335009
# Explained var: -0.10090279487525322
# correlation: [[0.26798382]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.627850
# R2 loop: -0.1290495369148119
# Explained var: 0.05426079173784515
# correlation: [[0.24448704]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.641367
# R2 loop: -0.23240816837834166
# Explained var: 0.07667675652171813
# correlation: [[0.29670176]]
# Permutation avg. explained variance: -0.0220782557766821
# Permutation: 92
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.641490
# R2 loop: 0.10533027217310897
# Explained var: 0.21664907926202104
# correlation: [[0.73483818]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.626138
# R2 loop: -0.15615048842197976
# Explained var: -0.06444358340200695
# correlation: [[0.04748765]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.606198
# R2 loop: 0.09852594591673136
# Explained var: 0.09852854376085296
# correlation: [[0.31420912]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.670600
# R2 loop: 0.26894789533954266
# Explained var: 0.2783325415381249
# correlation: [[0.53047465]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.713336
# R2 loop: -0.12158772060231593
# Explained var: -0.08889061372788265
# correlation: [[0.16751965]]
# Permutation avg. explained variance: 0.08803519348622187
# Permutation: 93
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.610074
# R2 loop: 0.12805796356551735
# Explained var: 0.1356009627383835
# correlation: [[0.36848679]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.695015
# R2 loop: 0.43946757785583856
# Explained var: 0.4457021815007942
# correlation: [[0.70148533]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.590982
# R2 loop: -0.11751482008691672
# Explained var: -0.10940116369914987
# correlation: [[-0.05566861]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.584488
# R2 loop: 0.1068907600308403
# Explained var: 0.10689138102099482
# correlation: [[0.3292992]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.631260
# R2 loop: 0.07710896646169019
# Explained var: 0.09473302106284576
# correlation: [[0.31391469]]
# Permutation avg. explained variance: 0.13470527652477368
# Permutation: 94
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.636025
# R2 loop: -0.2267215294571845
# Explained var: 0.0023033096818544374
# correlation: [[0.15460434]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.585394
# R2 loop: 0.01613956487149759
# Explained var: 0.07810977333438296
# correlation: [[0.27960639]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.527236
# R2 loop: 0.051889242550381076
# Explained var: 0.15890029294959196
# correlation: [[0.47737638]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.711430
# R2 loop: 0.3908148988265061
# Explained var: 0.42615359375473183
# correlation: [[0.65318174]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.633533
# R2 loop: -0.17366641769679614
# Explained var: -0.1617268816494326
# correlation: [[-0.07247994]]
# Permutation avg. explained variance: 0.10074801761422572
# Permutation: 95
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.539613
# R2 loop: -0.033360294313542704
# Explained var: 0.1574496316895957
# correlation: [[0.43293616]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.593009
# R2 loop: 0.24849749060231963
# Explained var: 0.2521913779332253
# correlation: [[0.54606562]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.595678
# R2 loop: 0.20517827649900744
# Explained var: 0.20739165658486558
# correlation: [[0.4560734]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.566183
# R2 loop: 0.18214366966496132
# Explained var: 0.26257127374954703
# correlation: [[0.57433047]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.653613
# R2 loop: 0.09062279480078239
# Explained var: 0.09135329867151543
# correlation: [[0.33440194]]
# Permutation avg. explained variance: 0.1941914477257498
# Permutation: 96
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.615409
# R2 loop: -0.15341332228756976
# Explained var: 0.0361214190486141
# correlation: [[0.38041344]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.614031
# R2 loop: 0.013077394867503589
# Explained var: 0.04499915919610109
# correlation: [[0.23443011]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.685027
# R2 loop: -0.12216957820705221
# Explained var: -0.11753291999778193
# correlation: [[0.0332492]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.541962
# R2 loop: 0.3016089343342062
# Explained var: 0.31542226927595096
# correlation: [[0.64469983]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.561587
# R2 loop: 0.06225221341566334
# Explained var: 0.16011604239371613
# correlation: [[0.51132443]]
# Permutation avg. explained variance: 0.08782519398332007
# Permutation: 97
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.554310
# R2 loop: 0.22120018847772616
# Explained var: 0.22547576577452977
# correlation: [[0.61986996]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.689461
# R2 loop: 0.2515956157881969
# Explained var: 0.2813233628838767
# correlation: [[0.55332694]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.635596
# R2 loop: -0.5217319623044248
# Explained var: -0.4422082088131496
# correlation: [[-0.19412319]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.656181
# R2 loop: 0.21336687178587443
# Explained var: 0.21518503674632206
# correlation: [[0.62307004]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.577588
# R2 loop: 0.1894401368924742
# Explained var: 0.23917931960804972
# correlation: [[0.60702764]]
# Permutation avg. explained variance: 0.10379105523992574
# Permutation: 98
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.568956
# R2 loop: 0.09487970726003236
# Explained var: 0.1055179657253924
# correlation: [[0.3327067]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.562319
# R2 loop: 0.18497014324051797
# Explained var: 0.2474696733667625
# correlation: [[0.49765605]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.662451
# R2 loop: -0.4808453007590623
# Explained var: -0.442368090405743
# correlation: [[-0.04712798]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.631076
# R2 loop: 0.00425667462733248
# Explained var: 0.01341671251008758
# correlation: [[0.20970485]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.620080
# R2 loop: 0.19829237600984606
# Explained var: 0.2096817419372219
# correlation: [[0.53086656]]
# Permutation avg. explained variance: 0.02674360062674428
# Permutation: 99
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.713281
# R2 loop: -0.1179893657074973
# Explained var: -0.09746963117222518
# correlation: [[0.12164245]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.615972
# R2 loop: 0.1746085243697152
# Explained var: 0.3065550253492285
# correlation: [[0.66450474]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.649713
# R2 loop: 0.0033114839065501167
# Explained var: 0.019280346408030558
# correlation: [[0.18318829]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.624001
# R2 loop: 0.04003623406909118
# Explained var: 0.16163409636105985
# correlation: [[0.40543767]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.604388
# R2 loop: 0.27720584544919813
# Explained var: 0.28226010706429605
# correlation: [[0.56447867]]
# Permutation avg. explained variance: 0.13445198880207795

# %%
# predictions for SC (node) - PCA and correlation

import datetime

# feature selection type
f=['PCA']

for featselect in f: 
    #set the number of folds you want in the inner and outer folds of the nested cross-validation
    k = 5

    #set the proportion of data you want in your training set
    train_size = .8

    #set x data to be the input variable you want to use
    #ie fc, sc, or hc
    #X=np.concatenate([sc, fc], axis=1)
    X=sc_n
    X=prepare_data(X)

    #set y to be the measure you want to predict
    Y = np.array(wais)


    # range of alphas
    n_alphas=20
    alpha_start=-1
    alpha_end=2
    alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

    #number of features (# pricipal components or variables to retain)
    feat_start=10
    feat_end=30
    n_feats=feat_end-feat_start+1
    feats = np.linspace(feat_start, feat_end, n_feats, dtype=int)

    # initialize lists to store model results for each permuation
    allR2=[]
    meanR2=[]
    features=[]
    bestalphas=[]
    importance=[]
    allexpl_var=[]
    #joblib-based parallelism to increase speed,

    for p in range(0, 100):
        outer_cv = KFold(n_splits=k, shuffle=True, random_state=p)
        print('Permutation: ' + str(p))
        # initialize lists to store model results for eah fold
        R2=[]
        featur=[]
        best_alphas=[]
        impt=[] 
        expl_var=[]
        for train, test in outer_cv.split(X):
            begin_time = datetime.datetime.now()

            # select model using training data
            bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv(k, X[train], Y[train], featselect, alphas, feats)

            # using optimal num. of features, select final features using entire training data.

            if featselect=='correlation':
                x_train_featselect,x_test_featureselect,ind = feature_select_correlation(X[train],X[test], Y[train], bestfeats)
                featur.append(ind)

            elif featselect=='PCA':
                x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(X[train],X[test], bestfeats)
                featur.append(ind)

            # initialize Ridge regression with alpha selected from hyperparameter search
            regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)

            # fit model 
            y_pred = regr.fit(x_train_featselect, Y[train]).predict(x_test_featureselect)

            # store results for each fold k
            impt.append(regr.coef_)
            R2.append(r2_score(Y[test], y_pred))
            expl_var.append(explained_variance_score(Y[test], y_pred))

            best_alphas.append(bestalpha)
            print('time to run loop: ' + str(datetime.datetime.now() - begin_time)) 
            print("R2 loop: " + str(r2_score(Y[test], y_pred)))
            print("Explained var: " + str(explained_variance_score(Y[test], y_pred)))
            print("correlation: " + str(np_pearson_cor(Y[test], y_pred)))

        # store results for each permutation p

        allexpl_var.append(expl_var)
        bestalphas.append(best_alphas)
        importance.append(impt)
        print("Permutation avg. explained variance: " + str(np.mean(expl_var)))

        np.savetxt(results_dir + featselect + 'p' + str(p) + '_SCn_all_explvar.txt', expl_var, delimiter=',')

        output = open(results_dir + featselect + 'p' + str(p) + '_SCn_features.pkl', 'wb')
        pickle.dump(featur, output)
        output.close()

        output = open(results_dir + featselect + 'p' + str(p) + '_SCn_bestalphas.pkl', 'wb')
        pickle.dump(best_alphas, output)
        output.close()
# Out:
# Final size of X: (101, 86)
# Permutation: 0
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.585224
# R2 loop: 0.05955713961050679
# Explained var: 0.09488560626309062
# correlation: [[0.63308466]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.673085
# R2 loop: -0.05662220705049381
# Explained var: 0.12970450008782886
# correlation: [[0.36810152]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.718243
# R2 loop: -0.039780638763009524
# Explained var: 0.09544023982086391
# correlation: [[0.3127368]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.591048
# R2 loop: 0.1915333799382395
# Explained var: 0.23342962865646488
# correlation: [[0.62727104]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.622095
# R2 loop: 0.15069954869390623
# Explained var: 0.17614928907125216
# correlation: [[0.43093982]]
# Permutation avg. explained variance: 0.14592185277990008
# Permutation: 1
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.620766
# R2 loop: 0.09003189992525173
# Explained var: 0.10380199713903582
# correlation: [[0.41772721]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.666048
# R2 loop: 0.14615821456233768
# Explained var: 0.15916638336484368
# correlation: [[0.74050213]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.599867
# R2 loop: 0.05290461981795247
# Explained var: 0.0838081428294396
# correlation: [[0.32707674]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.622082
# R2 loop: 0.33005637422768697
# Explained var: 0.4404595415994744
# correlation: [[0.72826681]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.601184
# R2 loop: 0.1637812138459802
# Explained var: 0.16559892753786087
# correlation: [[0.46938009]]
# Permutation avg. explained variance: 0.1905669984941309
# Permutation: 2
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.645894
# R2 loop: 0.18853240451757358
# Explained var: 0.20139486722824673
# correlation: [[0.53297682]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.615606
# R2 loop: 0.2072383241945136
# Explained var: 0.21417066074960678
# correlation: [[0.56073762]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.677360
# R2 loop: 0.2432893553706288
# Explained var: 0.25060725907995673
# correlation: [[0.76050259]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.749655
# R2 loop: -0.010697421534639151
# Explained var: -0.010009473581219064
# correlation: [[0.05713571]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.642696
# R2 loop: 0.02382415449135389
# Explained var: 0.0310067836618253
# correlation: [[0.36276183]]
# Permutation avg. explained variance: 0.1374340194276833
# Permutation: 3
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.569530
# R2 loop: 0.08266951754933416
# Explained var: 0.17016780301528012
# correlation: [[0.49222607]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.648336
# R2 loop: -0.31386049738277744
# Explained var: 0.047062629076966234
# correlation: [[0.24844325]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.573464
# R2 loop: 0.0765590963036874
# Explained var: 0.16057106367141982
# correlation: [[0.61381697]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.612995
# R2 loop: 0.020387547149050667
# Explained var: 0.19952890641294174
# correlation: [[0.58246973]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.669114
# R2 loop: 0.02263667444250128
# Explained var: 0.03763418231789495
# correlation: [[0.21244929]]
# Permutation avg. explained variance: 0.12299291689890057
# Permutation: 4
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.574573
# R2 loop: 0.4488928351980558
# Explained var: 0.4494007187463369
# correlation: [[0.79655218]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.689202
# R2 loop: 0.2508192687802343
# Explained var: 0.25086872253019576
# correlation: [[0.57528142]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.670672
# R2 loop: -0.12962899633541602
# Explained var: -0.12317242845282705
# correlation: [[-0.31052994]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.651932
# R2 loop: 0.1959157431294719
# Explained var: 0.19592684125182835
# correlation: [[0.49337922]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.566911
# R2 loop: 0.1134782174344634
# Explained var: 0.12026666716660173
# correlation: [[0.35728896]]
# Permutation avg. explained variance: 0.17865810424842715
# Permutation: 5
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.672518
# R2 loop: 0.06160563380609696
# Explained var: 0.06404481976155585
# correlation: [[0.73903794]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.623036
# R2 loop: -0.13386042165832657
# Explained var: -0.11754128947632969
# correlation: [[-0.47477974]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.673932
# R2 loop: -0.010714968687057791
# Explained var: 0.03554033125646283
# correlation: [[0.19171175]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.578373
# R2 loop: -0.31467221907157517
# Explained var: 0.027408980246256487
# correlation: [[0.18504078]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.653640
# R2 loop: 0.11751566509307054
# Explained var: 0.18436180735977936
# correlation: [[0.65572607]]
# Permutation avg. explained variance: 0.03876292982954497
# Permutation: 6
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.635332
# R2 loop: -0.1367742807162733
# Explained var: -0.12416937585254217
# correlation: [[-0.25366395]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.601156
# R2 loop: 0.21272659958967166
# Explained var: 0.23561202453297436
# correlation: [[0.53294614]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.610369
# R2 loop: 0.34603774311648305
# Explained var: 0.4229433328941675
# correlation: [[0.76844477]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.669351
# R2 loop: -0.15742327772430542
# Explained var: 0.015836341337970627
# correlation: [[0.15983749]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.596416
# R2 loop: 0.006756302809699188
# Explained var: 0.008498375724761531
# correlation: [[0.64601011]]
# Permutation avg. explained variance: 0.11174413972746637
# Permutation: 7
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.639041
# R2 loop: 0.03730552203580706
# Explained var: 0.0430549663119526
# correlation: [[0.36550956]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.598470
# R2 loop: 0.022774624239506047
# Explained var: 0.05393858681496877
# correlation: [[0.536736]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.654287
# R2 loop: 0.16826788766928558
# Explained var: 0.1689173996697675
# correlation: [[0.52828008]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.607309
# R2 loop: 0.08334808038591257
# Explained var: 0.11395803860977949
# correlation: [[0.35706826]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.595295
# R2 loop: -0.25617960277342244
# Explained var: 0.0058511238890901485
# correlation: [[0.23831112]]
# Permutation avg. explained variance: 0.0771440230591117
# Permutation: 8
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.614239
# R2 loop: -0.017921938605966137
# Explained var: 0.19922806145791838
# correlation: [[0.76445578]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.642624
# R2 loop: 0.169333864577911
# Explained var: 0.17060575067510741
# correlation: [[0.5066856]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.689154
# R2 loop: -0.05355454135325499
# Explained var: 0.14617638934362176
# correlation: [[0.5311044]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.594866
# R2 loop: 0.04422760079244148
# Explained var: 0.10071594440997345
# correlation: [[0.32402355]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.639592
# R2 loop: -0.09256075843520595
# Explained var: -0.024335381676952927
# correlation: [[0.04327341]]
# Permutation avg. explained variance: 0.11847815284193361
# Permutation: 9
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.599861
# R2 loop: 0.10094878416671382
# Explained var: 0.1399440423806012
# correlation: [[0.40520618]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.575776
# R2 loop: -0.04038971740556119
# Explained var: -0.03379114463960042
# correlation: [[0.08074415]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.594885
# R2 loop: 0.11811126962624718
# Explained var: 0.11840963707887509
# correlation: [[0.3491472]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.660907
# R2 loop: -0.0909245958910938
# Explained var: 0.09961896794213243
# correlation: [[0.34708589]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.605163
# R2 loop: -0.0961861404855393
# Explained var: 0.12279544532944142
# correlation: [[0.70230825]]
# Permutation avg. explained variance: 0.08939538961828994
# Permutation: 10
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.644594
# R2 loop: 0.1846487113951385
# Explained var: 0.18500584593911718
# correlation: [[0.43709556]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.589164
# R2 loop: 0.06342620769367102
# Explained var: 0.06416392202329568
# correlation: [[0.25646361]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.569072
# R2 loop: -0.4127380263789573
# Explained var: -0.17692445326767414
# correlation: [[-0.14559]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.720111
# R2 loop: 0.27412187852430414
# Explained var: 0.28934315149952494
# correlation: [[0.66263539]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.617069
# R2 loop: 0.017728359367034652
# Explained var: 0.04645845693273565
# correlation: [[0.73737071]]
# Permutation avg. explained variance: 0.08160938462539986
# Permutation: 11
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.581425
# R2 loop: 0.12734847901299362
# Explained var: 0.14588882558207428
# correlation: [[0.7591299]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.673378
# R2 loop: 0.25543550483278465
# Explained var: 0.2709442452672317
# correlation: [[0.69612743]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.682988
# R2 loop: -0.13181884071401373
# Explained var: 0.03200877660890844
# correlation: [[0.24387233]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.557093
# R2 loop: -0.4098585972186952
# Explained var: 0.09436219809829038
# correlation: [[0.30835981]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.618858
# R2 loop: 0.044584694586289
# Explained var: 0.0499310318488877
# correlation: [[0.29423432]]
# Permutation avg. explained variance: 0.1186270154810785
# Permutation: 12
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.646962
# R2 loop: 0.0014359090923060647
# Explained var: 0.04639213728552094
# correlation: [[0.22371378]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.629625
# R2 loop: 0.03724775231734878
# Explained var: 0.08631512684511355
# correlation: [[0.74790932]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.697460
# R2 loop: 0.09867553839136012
# Explained var: 0.24170466624717335
# correlation: [[0.50691559]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.655267
# R2 loop: 0.20863142441828642
# Explained var: 0.21284224585415745
# correlation: [[0.57349369]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.583314
# R2 loop: -0.06572505675664542
# Explained var: 0.07461112745834797
# correlation: [[0.30113543]]
# Permutation avg. explained variance: 0.13237306073806265
# Permutation: 13
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.545561
# R2 loop: 0.07642622114105369
# Explained var: 0.10282107936701401
# correlation: [[0.42638128]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.563609
# R2 loop: 0.1544265484309021
# Explained var: 0.17521512107945736
# correlation: [[0.57746766]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.732460
# R2 loop: 0.004124949922888366
# Explained var: 0.09027624705617354
# correlation: [[0.6450278]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.565807
# R2 loop: -0.06899691896278948
# Explained var: -0.03751502661128514
# correlation: [[-0.15152275]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.632598
# R2 loop: 0.10421476800561602
# Explained var: 0.11980711330943461
# correlation: [[0.6248712]]
# Permutation avg. explained variance: 0.09012090684015887
# Permutation: 14
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.653650
# R2 loop: -0.05366778278773565
# Explained var: 0.0025712885971709287
# correlation: [[0.21872426]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.587437
# R2 loop: 0.015702059781383948
# Explained var: 0.037200370975717933
# correlation: [[0.69357374]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.700619
# R2 loop: 0.09401565078836338
# Explained var: 0.11696437241477176
# correlation: [[0.36970219]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.646763
# R2 loop: -0.0038156778295919125
# Explained var: 0.0786278496196886
# correlation: [[0.32383063]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.708795
# R2 loop: 0.10007836548934468
# Explained var: 0.14662548782061668
# correlation: [[0.43487328]]
# Permutation avg. explained variance: 0.07639787388559319
# Permutation: 15
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.618686
# R2 loop: 0.29213793962162327
# Explained var: 0.3062140215204623
# correlation: [[0.55363715]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.625327
# R2 loop: 0.3317081971716691
# Explained var: 0.3593067979116491
# correlation: [[0.64747383]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.651175
# R2 loop: -0.4491838285408336
# Explained var: 0.048269611041084404
# correlation: [[0.24434486]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.568368
# R2 loop: -0.04935258770837647
# Explained var: 0.010151898908889456
# correlation: [[0.54983411]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.731540
# R2 loop: 0.256341407426918
# Explained var: 0.292821581256977
# correlation: [[0.77065879]]
# Permutation avg. explained variance: 0.20335278212781244
# Permutation: 16
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.727288
# R2 loop: 0.09936290864849784
# Explained var: 0.11278720799114328
# correlation: [[0.42585096]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.704231
# R2 loop: 0.1230356931840042
# Explained var: 0.12430220786256063
# correlation: [[0.3842749]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.653807
# R2 loop: -0.1709939529098774
# Explained var: -0.16447234406626476
# correlation: [[-0.28692843]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.733500
# R2 loop: 0.121031230318846
# Explained var: 0.12201092131122071
# correlation: [[0.50302505]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.635212
# R2 loop: 0.12658451605892662
# Explained var: 0.12662606885216
# correlation: [[0.48954243]]
# Permutation avg. explained variance: 0.06425081239016397
# Permutation: 17
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.611179
# R2 loop: -0.09581792529820476
# Explained var: -0.048972901198506946
# correlation: [[0.12802855]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.591853
# R2 loop: 0.018265207649251547
# Explained var: 0.06067810718456779
# correlation: [[0.67074104]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.661141
# R2 loop: 0.15617352112337002
# Explained var: 0.1584401141125521
# correlation: [[0.70877769]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.588122
# R2 loop: 0.026225017452796706
# Explained var: 0.05552659039195784
# correlation: [[0.77503774]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.613185
# R2 loop: 0.12217343281541015
# Explained var: 0.12624000294312632
# correlation: [[0.35534527]]
# Permutation avg. explained variance: 0.07038238268673942
# Permutation: 18
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.576206
# R2 loop: 0.16620551757724633
# Explained var: 0.16633736918482123
# correlation: [[0.51828298]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.649168
# R2 loop: -0.013936467263740981
# Explained var: 0.008715787271836861
# correlation: [[0.13962865]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.599072
# R2 loop: 0.0013837297088846734
# Explained var: 0.01713933518938071
# correlation: [[0.40819821]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.649598
# R2 loop: -0.233302891058371
# Explained var: 0.023650617120535178
# correlation: [[0.16927787]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.724913
# R2 loop: 0.16616830064270294
# Explained var: 0.2162748203372904
# correlation: [[0.64235405]]
# Permutation avg. explained variance: 0.08642358582077288
# Permutation: 19
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.584719
# R2 loop: 0.11494908520672109
# Explained var: 0.11640707615878076
# correlation: [[0.62226802]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.584826
# R2 loop: -0.16552326334779166
# Explained var: -0.1636990590026952
# correlation: [[0.07217999]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.597157
# R2 loop: -0.2542234479348404
# Explained var: -0.09381002216327783
# correlation: [[0.03057532]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.662958
# R2 loop: 0.22930298142485817
# Explained var: 0.23758324571681522
# correlation: [[0.70129072]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.660257
# R2 loop: -0.07956737931976532
# Explained var: 0.10537225720667587
# correlation: [[0.32462637]]
# Permutation avg. explained variance: 0.04037069958325976
# Permutation: 20
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.557900
# R2 loop: 0.023672093690242035
# Explained var: 0.03808396207049569
# correlation: [[0.2951121]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.598938
# R2 loop: 0.10706838715668132
# Explained var: 0.12753612838348616
# correlation: [[0.37537955]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.598383
# R2 loop: 0.30466176797661504
# Explained var: 0.4072543080010659
# correlation: [[0.70548053]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.617181
# R2 loop: 0.2710742458544746
# Explained var: 0.29302863289791403
# correlation: [[0.64949397]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.622192
# R2 loop: 0.198793984574547
# Explained var: 0.2122863119915016
# correlation: [[0.51228805]]
# Permutation avg. explained variance: 0.21563786866889267
# Permutation: 21
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.570487
# R2 loop: 0.11025260383511659
# Explained var: 0.11798681273775413
# correlation: [[0.45100128]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.625146
# R2 loop: 0.09759218512907519
# Explained var: 0.11851252028803483
# correlation: [[0.43125968]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.578682
# R2 loop: 0.04011618406550754
# Explained var: 0.041596065429760465
# correlation: [[0.20406341]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.575357
# R2 loop: 0.23053301814106064
# Explained var: 0.23697802475982943
# correlation: [[0.75406372]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.545691
# R2 loop: 0.08288066553189721
# Explained var: 0.08635330301241517
# correlation: [[0.30468639]]
# Permutation avg. explained variance: 0.12028534524555881
# Permutation: 22
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.659186
# R2 loop: 0.19442365898519254
# Explained var: 0.2217825056640026
# correlation: [[0.6939825]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.623069
# R2 loop: -0.11730990673697694
# Explained var: 0.056035962377051884
# correlation: [[0.5205666]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.706242
# R2 loop: 0.06756409466341129
# Explained var: 0.10688891528405475
# correlation: [[0.49039561]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.554273
# R2 loop: -0.0019539139713746767
# Explained var: 0.029483509966987786
# correlation: [[0.18407208]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.620992
# R2 loop: -0.16028028642425918
# Explained var: -0.014285252964246098
# correlation: [[-0.11765833]]
# Permutation avg. explained variance: 0.07998112806557019
# Permutation: 23
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.662124
# R2 loop: 0.029930075890812646
# Explained var: 0.03294954618519674
# correlation: [[0.27299373]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.657755
# R2 loop: 0.18464306823238053
# Explained var: 0.1925999658472214
# correlation: [[0.57786485]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.619686
# R2 loop: 0.015364548032114844
# Explained var: 0.02845169720648011
# correlation: [[0.32495567]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.610427
# R2 loop: 0.009676745519982988
# Explained var: 0.012208001276676428
# correlation: [[0.32441299]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.579951
# R2 loop: -0.02670631589158523
# Explained var: 0.010903708484827024
# correlation: [[0.6340177]]
# Permutation avg. explained variance: 0.05542258380008034
# Permutation: 24
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.643925
# R2 loop: 0.3331092406963013
# Explained var: 0.3456122213160141
# correlation: [[0.71679825]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.592994
# R2 loop: 0.09978190327961622
# Explained var: 0.1340621697563661
# correlation: [[0.72198491]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.616199
# R2 loop: -0.045429102452412495
# Explained var: -0.04440281099050791
# correlation: [[-0.09981687]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.635353
# R2 loop: 0.04533467853337947
# Explained var: 0.05415107887661297
# correlation: [[0.241689]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.662487
# R2 loop: 0.04424991581812687
# Explained var: 0.04822425386286844
# correlation: [[0.39930561]]
# Permutation avg. explained variance: 0.10752938256427073
# Permutation: 25
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.607194
# R2 loop: 0.20242501647413336
# Explained var: 0.20253536171349384
# correlation: [[0.4538159]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.642903
# R2 loop: 0.518931116584014
# Explained var: 0.5228501578899489
# correlation: [[0.81770017]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.561684
# R2 loop: -0.04493527236509509
# Explained var: 0.018717469934886766
# correlation: [[0.19104284]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.617343
# R2 loop: -0.1695215264796215
# Explained var: 0.12352805756284113
# correlation: [[0.35468824]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.706876
# R2 loop: 0.07063156061995635
# Explained var: 0.11637576574379949
# correlation: [[0.43993319]]
# Permutation avg. explained variance: 0.19680136256899403
# Permutation: 26
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.605536
# R2 loop: 0.00681669402491436
# Explained var: 0.07701488232604947
# correlation: [[0.28814192]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.618830
# R2 loop: 0.027151969513281027
# Explained var: 0.17039673585229453
# correlation: [[0.52173763]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.577567
# R2 loop: -0.029718384016988786
# Explained var: 0.028474385430931615
# correlation: [[0.20906203]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.619034
# R2 loop: -0.1982883118059071
# Explained var: -0.004440474717605447
# correlation: [[0.11514966]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.767516
# R2 loop: 0.0582716792453285
# Explained var: 0.0737946963746896
# correlation: [[0.34552495]]
# Permutation avg. explained variance: 0.06904804505327196
# Permutation: 27
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.656616
# R2 loop: 0.08220574049083629
# Explained var: 0.0904887460201208
# correlation: [[0.35657474]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.605680
# R2 loop: 0.14609246678585042
# Explained var: 0.16008528348264806
# correlation: [[0.54626744]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.624672
# R2 loop: 0.12645787863362123
# Explained var: 0.1703954671763671
# correlation: [[0.43776443]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.577296
# R2 loop: 0.019874783317591516
# Explained var: 0.10246892045590639
# correlation: [[0.42396229]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.576727
# R2 loop: 0.002881505420668784
# Explained var: 0.007494860715373752
# correlation: [[0.79269394]]
# Permutation avg. explained variance: 0.10618665557008322
# Permutation: 28
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.599709
# R2 loop: 0.0820285874728457
# Explained var: 0.11757817251378133
# correlation: [[0.44716698]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.604924
# R2 loop: 0.06700679318468494
# Explained var: 0.16287311777511937
# correlation: [[0.76034641]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.623368
# R2 loop: 0.2806874351196079
# Explained var: 0.28570951784113774
# correlation: [[0.56380009]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.620812
# R2 loop: 0.0009223172387200496
# Explained var: 0.1550641359352346
# correlation: [[0.47596458]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.618202
# R2 loop: -0.026667627319717502
# Explained var: -0.025890273558108134
# correlation: [[-0.0726356]]
# Permutation avg. explained variance: 0.13906693410143298
# Permutation: 29
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.639309
# R2 loop: 0.3356560089682957
# Explained var: 0.34722743247368326
# correlation: [[0.67880951]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.634357
# R2 loop: 0.12090130422231649
# Explained var: 0.12273358692897296
# correlation: [[0.49635115]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.682409
# R2 loop: 0.1601972735234285
# Explained var: 0.22765994125315714
# correlation: [[0.54695127]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.585187
# R2 loop: -0.1062650525378217
# Explained var: -0.1049868642778844
# correlation: [[0.24862429]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.602280
# R2 loop: -0.2886938592291599
# Explained var: 0.056816276316504544
# correlation: [[0.28923695]]
# Permutation avg. explained variance: 0.1298900745388867
# Permutation: 30
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.650013
# R2 loop: -0.1834465890114001
# Explained var: -0.07789865173607913
# correlation: [[0.06570754]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.619970
# R2 loop: 0.16847840602356445
# Explained var: 0.19415527697024093
# correlation: [[0.67987837]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.652902
# R2 loop: 0.23045591132619803
# Explained var: 0.27038025875605276
# correlation: [[0.52325584]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.648467
# R2 loop: 0.24118915313998457
# Explained var: 0.2572964977323908
# correlation: [[0.64078892]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.687330
# R2 loop: 0.20484836461909484
# Explained var: 0.23426330864975897
# correlation: [[0.48686084]]
# Permutation avg. explained variance: 0.17563933807447288
# Permutation: 31
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.575725
# R2 loop: 0.1055696118736541
# Explained var: 0.11145761315089642
# correlation: [[0.33594088]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.725050
# R2 loop: 0.16403897054434557
# Explained var: 0.1711976654785703
# correlation: [[0.6196984]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.567970
# R2 loop: -0.026078276344385642
# Explained var: -0.007950758130933933
# correlation: [[0.17424118]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.686599
# R2 loop: 0.5655979946761707
# Explained var: 0.6653325823739449
# correlation: [[0.820388]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.611242
# R2 loop: -0.4946151979229496
# Explained var: 0.11321347489957145
# correlation: [[0.57266194]]
# Permutation avg. explained variance: 0.21065011555440982
# Permutation: 32
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.588158
# R2 loop: 0.006801351930727395
# Explained var: 0.02524987280283053
# correlation: [[0.20890759]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.673946
# R2 loop: -0.838870606904434
# Explained var: -0.31149095860046816
# correlation: [[-0.07691403]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.630805
# R2 loop: 0.11151178430371145
# Explained var: 0.2049089849116401
# correlation: [[0.46014251]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.573164
# R2 loop: 0.11627477199874037
# Explained var: 0.1579002292423819
# correlation: [[0.43068917]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.563223
# R2 loop: -0.0562312041637123
# Explained var: 0.08533630581071894
# correlation: [[0.7130042]]
# Permutation avg. explained variance: 0.03238088683342066
# Permutation: 33
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.769501
# R2 loop: -0.030748528091150584
# Explained var: 0.015357308779485046
# correlation: [[0.56576547]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.605273
# R2 loop: 0.19030548104473088
# Explained var: 0.251350087797781
# correlation: [[0.57581818]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.601764
# R2 loop: 0.02738411717882161
# Explained var: 0.031558012334450325
# correlation: [[0.21378963]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.586028
# R2 loop: -0.041602039958853254
# Explained var: -0.026783687067286843
# correlation: [[0.00872694]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.590052
# R2 loop: 0.38953738751366196
# Explained var: 0.39059230843246673
# correlation: [[0.62789808]]
# Permutation avg. explained variance: 0.13241480605537925
# Permutation: 34
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.586373
# R2 loop: 0.20269641585805365
# Explained var: 0.25075690418347985
# correlation: [[0.67093918]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.847221
# R2 loop: 0.12206300105682777
# Explained var: 0.2270807034115072
# correlation: [[0.48385427]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.620640
# R2 loop: 0.09131028471830915
# Explained var: 0.09313672991332855
# correlation: [[0.30581167]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.615108
# R2 loop: -0.0016419822310544951
# Explained var: 0.015329677768367023
# correlation: [[0.15595658]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.648890
# R2 loop: 0.3185955410302105
# Explained var: 0.3523842458214428
# correlation: [[0.68729217]]
# Permutation avg. explained variance: 0.18773765221962507
# Permutation: 35
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.628661
# R2 loop: 0.08989323935087867
# Explained var: 0.17337145186797365
# correlation: [[0.46137054]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.654518
# R2 loop: -0.029870501081605605
# Explained var: -0.029281950278931435
# correlation: [[0.04916329]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.622869
# R2 loop: 0.030160456275026948
# Explained var: 0.03320863930696549
# correlation: [[0.77061242]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.583778
# R2 loop: 0.06899079386198459
# Explained var: 0.06960341794121405
# correlation: [[0.30644884]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.613886
# R2 loop: -0.0073293846989281874
# Explained var: 0.10658143294685074
# correlation: [[0.37578111]]
# Permutation avg. explained variance: 0.0706965983568145
# Permutation: 36
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.597636
# R2 loop: 0.005717176490459552
# Explained var: 0.008215294870074441
# correlation: [[0.10451011]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.615872
# R2 loop: -0.0319689569163526
# Explained var: 0.10637147117949997
# correlation: [[0.70254325]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.626551
# R2 loop: -0.030653403998893713
# Explained var: 0.12585796217634426
# correlation: [[0.41369843]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.607349
# R2 loop: 0.07632993152518219
# Explained var: 0.13271355814950603
# correlation: [[0.58987419]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.638102
# R2 loop: -0.027268878117802098
# Explained var: 0.06545666694224361
# correlation: [[0.34771314]]
# Permutation avg. explained variance: 0.08772299066353366
# Permutation: 37
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.593395
# R2 loop: -0.1989894288302203
# Explained var: 0.08280830876603629
# correlation: [[0.37842475]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.697844
# R2 loop: 0.0465300734473123
# Explained var: 0.10237279658762988
# correlation: [[0.3269146]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.669792
# R2 loop: 0.09591246189585234
# Explained var: 0.09928173798953599
# correlation: [[0.45200357]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.651192
# R2 loop: 0.4017191556163834
# Explained var: 0.4765435040977567
# correlation: [[0.75658423]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.586205
# R2 loop: 0.17320195630744883
# Explained var: 0.18672991261287464
# correlation: [[0.4761061]]
# Permutation avg. explained variance: 0.1895472520107667
# Permutation: 38
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.575438
# R2 loop: -0.0203476078250171
# Explained var: 0.007851604306380988
# correlation: [[0.15173363]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.629766
# R2 loop: 0.15223854032086404
# Explained var: 0.1654982728978972
# correlation: [[0.64381137]]
# ...
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.587431
# R2 loop: 0.08266264275000212
# Explained var: 0.09617733512430848
# correlation: [[0.37370806]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.590408
# R2 loop: -0.2693646485132841
# Explained var: -0.010858574543301636
# correlation: [[-0.06433786]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.678212
# R2 loop: 0.13043613570964185
# Explained var: 0.18891113087021338
# correlation: [[0.66537201]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.646231
# R2 loop: 0.307408064433523
# Explained var: 0.33035639243875525
# correlation: [[0.74517856]]
# Permutation avg. explained variance: 0.13729232294462168
# Permutation: 88
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.636031
# R2 loop: 0.10139159739705661
# Explained var: 0.1707747146900026
# correlation: [[0.60751301]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.621736
# R2 loop: 0.3667785879658032
# Explained var: 0.36680442347174314
# correlation: [[0.64213642]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.598015
# R2 loop: 0.1809355066974192
# Explained var: 0.20578214149144713
# correlation: [[0.45824304]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.591591
# R2 loop: 0.0057188162307963974
# Explained var: 0.013422802588988536
# correlation: [[0.11982449]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.612396
# R2 loop: 0.05798184585544586
# Explained var: 0.175947157674471
# correlation: [[0.62026242]]
# Permutation avg. explained variance: 0.18654624798333047
# Permutation: 89
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.610896
# R2 loop: 0.15537689220923345
# Explained var: 0.16545969896842005
# correlation: [[0.65552796]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.587792
# R2 loop: 0.2976525927901206
# Explained var: 0.35952507568705894
# correlation: [[0.66640895]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.653690
# R2 loop: 0.2575670343909582
# Explained var: 0.30039303546282126
# correlation: [[0.63004839]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.625146
# R2 loop: 0.061077139921571044
# Explained var: 0.0631285600559297
# correlation: [[0.38492622]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.622548
# R2 loop: -0.00632656440999102
# Explained var: 0.04082642010700155
# correlation: [[0.21793889]]
# Permutation avg. explained variance: 0.1858665580562463
# Permutation: 90
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.658015
# R2 loop: 0.12135969850214745
# Explained var: 0.17618194413200405
# correlation: [[0.46885299]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.704047
# R2 loop: 0.0026144654420230395
# Explained var: 0.02805431010840409
# correlation: [[0.16955489]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.547993
# R2 loop: 0.18337746946203115
# Explained var: 0.19813382911053634
# correlation: [[0.74879075]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.690487
# R2 loop: -0.04638464536519771
# Explained var: 0.04364136681376751
# correlation: [[0.29570005]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.581741
# R2 loop: 0.16722839816851565
# Explained var: 0.28722556094874985
# correlation: [[0.62406733]]
# Permutation avg. explained variance: 0.14664740222269237
# Permutation: 91
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.592125
# R2 loop: -0.012141970313827466
# Explained var: 0.024175964061653343
# correlation: [[0.24679887]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.595073
# R2 loop: 0.251736910214334
# Explained var: 0.25550453745402335
# correlation: [[0.72434188]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.587188
# R2 loop: -0.0171285295491701
# Explained var: 0.015785675660736853
# correlation: [[0.27700087]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.591278
# R2 loop: -0.2163325868860546
# Explained var: -0.009526384384074937
# correlation: [[0.29097848]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.598414
# R2 loop: -0.15541782825207195
# Explained var: 0.14123437468946476
# correlation: [[0.50460239]]
# Permutation avg. explained variance: 0.08543483349636068
# Permutation: 92
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.714195
# R2 loop: 0.005117816026706246
# Explained var: 0.10604421111642393
# correlation: [[0.72920949]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.558952
# R2 loop: -0.1432622744456249
# Explained var: -0.059344555464781124
# correlation: [[0.17889718]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.618902
# R2 loop: 0.028736857334630606
# Explained var: 0.030047110983268177
# correlation: [[0.23176998]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.612879
# R2 loop: 0.21208203589726216
# Explained var: 0.21728919714953998
# correlation: [[0.5647008]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.673811
# R2 loop: 0.08254517875339284
# Explained var: 0.1109294198590246
# correlation: [[0.33351057]]
# Permutation avg. explained variance: 0.08099307672869512
# Permutation: 93
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.617263
# R2 loop: 0.30215019368869633
# Explained var: 0.3031137769898653
# correlation: [[0.57661546]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.647831
# R2 loop: 0.34297739530998483
# Explained var: 0.3559333745905878
# correlation: [[0.70432014]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.670513
# R2 loop: 0.023063792814636663
# Explained var: 0.060219023083121215
# correlation: [[0.25184825]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.644508
# R2 loop: 0.05975058114498888
# Explained var: 0.05975058467352823
# correlation: [[0.38811781]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.615885
# R2 loop: -0.03558597254833851
# Explained var: 0.009032238944150506
# correlation: [[0.16075813]]
# Permutation avg. explained variance: 0.1576097996562506
# Permutation: 94
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.686802
# R2 loop: -0.28751533547743646
# Explained var: 0.07650317746704283
# correlation: [[0.28659683]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.613851
# R2 loop: 0.044058126045436574
# Explained var: 0.05457732787491765
# correlation: [[0.32574844]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.654187
# R2 loop: 0.059705302000936045
# Explained var: 0.16303001457323474
# correlation: [[0.69698205]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.740319
# R2 loop: -0.07782608358854093
# Explained var: 0.16714972165500175
# correlation: [[0.71365909]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.663148
# R2 loop: 0.10173901242556138
# Explained var: 0.10702084926668043
# correlation: [[0.32714586]]
# Permutation avg. explained variance: 0.11365621816737548
# Permutation: 95
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.633143
# R2 loop: -0.08883110966878438
# Explained var: 0.03407575216269654
# correlation: [[0.18655591]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.597850
# R2 loop: 0.3584984723282376
# Explained var: 0.36318360671411787
# correlation: [[0.72069581]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.618912
# R2 loop: 0.22655913223887048
# Explained var: 0.22968114857499644
# correlation: [[0.4829636]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.787749
# R2 loop: 0.05840070443130352
# Explained var: 0.10068220423487051
# correlation: [[0.7511929]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.701386
# R2 loop: 0.18350298770939144
# Explained var: 0.1872733143305182
# correlation: [[0.63018852]]
# Permutation avg. explained variance: 0.1829792052034399
# Permutation: 96
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.613220
# R2 loop: 0.037874410636873135
# Explained var: 0.054229329198918985
# correlation: [[0.29013939]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.579197
# R2 loop: 0.05888728294100953
# Explained var: 0.07053211033030493
# correlation: [[0.32122153]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.685363
# R2 loop: -0.024464236020733
# Explained var: -0.010739836945195869
# correlation: [[0.07695278]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.583531
# R2 loop: 0.34584336456750076
# Explained var: 0.3619813427621593
# correlation: [[0.64581578]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.637934
# R2 loop: -0.06858384368931869
# Explained var: 0.010967897236555557
# correlation: [[0.7807514]]
# Permutation avg. explained variance: 0.09739416851654858
# Permutation: 97
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.600343
# R2 loop: 0.21339713102096725
# Explained var: 0.21349184542950272
# correlation: [[0.68079114]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.683393
# R2 loop: -0.0010841840510884548
# Explained var: -0.0010765213053747225
# correlation: [[0.16146346]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.652967
# R2 loop: -0.07915913367326444
# Explained var: 0.01267245628907876
# correlation: [[0.17627298]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.584010
# R2 loop: 0.3742818506920317
# Explained var: 0.40062343704536674
# correlation: [[0.6937281]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.531239
# R2 loop: 0.15113283483012918
# Explained var: 0.19451545483833732
# correlation: [[0.61460041]]
# Permutation avg. explained variance: 0.16404533445938216
# Permutation: 98
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.570919
# R2 loop: 0.05806784733107517
# Explained var: 0.07073337592695894
# correlation: [[0.5716683]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.685849
# R2 loop: 0.21077522202905485
# Explained var: 0.28267952641996164
# correlation: [[0.53967306]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.617610
# R2 loop: -0.032288536788850575
# Explained var: -0.01893097753100692
# correlation: [[-0.04187873]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.659779
# R2 loop: -0.07305118749281458
# Explained var: 0.01474338833426514
# correlation: [[0.31998514]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.632789
# R2 loop: 0.23777285289111438
# Explained var: 0.2497137840262288
# correlation: [[0.57119808]]
# Permutation avg. explained variance: 0.11978781943528152
# Permutation: 99
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:01.595841
# R2 loop: 0.06719441532595982
# Explained var: 0.08331038075771313
# correlation: [[0.29498274]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.632138
# R2 loop: -0.08352366991318028
# Explained var: 0.005317794731509062
# correlation: [[0.53963921]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.665863
# R2 loop: -0.06099776575547633
# Explained var: -0.02234257616891555
# correlation: [[-0.10104371]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.640149
# R2 loop: 0.02377801798059853
# Explained var: 0.10487913676067617
# correlation: [[0.55566436]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:01.593049
# R2 loop: 0.43898851441368414
# Explained var: 0.4405830677741144
# correlation: [[0.66405669]]
# Permutation avg. explained variance: 0.12234956077101944

# %%
# predictions for FC (node) - PCA and correlation

import datetime

# feature selection type
f=['PCA']

for featselect in f: 
    #set the number of folds you want in the inner and outer folds of the nested cross-validation
    k = 5

    #set the proportion of data you want in your training set
    train_size = .8

    #set x data to be the input variable you want to use
    #ie fc, sc, or hc
    #X=np.concatenate([sc, fc], axis=1)
    X=sc
    X=prepare_data(X)

    #set y to be the measure you want to predict
    Y = np.array(wais)

    # range of alphas
    n_alphas=20
    alpha_start=-1
    alpha_end=2
    alphas = np.logspace(alpha_start, alpha_end, n_alphas, base=10, dtype=None)

    #number of features (# pricipal components or variables to retain)
    feat_start=10
    feat_end=30
    n_feats=feat_end-feat_start+1
    feats = np.linspace(feat_start, feat_end, n_feats, dtype=int)

    # initialize lists to store model results for each permuation
    allR2=[]
    meanR2=[]
    features=[]
    bestalphas=[]
    importance=[]
    allexpl_var=[]
    #joblib-based parallelism to increase speed,

    for p in range(0, 100):
        outer_cv = KFold(n_splits=k, shuffle=True, random_state=p)
        print('Permutation: ' + str(p))
        # initialize lists to store model results for eah fold
        R2=[]
        featur=[]
        best_alphas=[]
        impt=[] 
        expl_var=[]
        for train, test in outer_cv.split(X):
            begin_time = datetime.datetime.now()

            # select model using training data
            bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv(k, X[train], Y[train], featselect, alphas, feats)

            # using optimal num. of features, select final features using entire training data.

            if featselect=='correlation':
                x_train_featselect,x_test_featureselect,ind = feature_select_correlation(X[train],X[test], Y[train], bestfeats)
                featur.append(ind)

            elif featselect=='PCA':
                x_train_featselect,x_test_featureselect,ind  = feature_select_PCA(X[train],X[test], bestfeats)
                featur.append(ind)

            # initialize Ridge regression with alpha selected from hyperparameter search
            regr = linear_model.Ridge(alpha=bestalpha, normalize=True, max_iter=1000000, random_state=p)

            # fit model 
            y_pred = regr.fit(x_train_featselect, Y[train]).predict(x_test_featureselect)

            # store results for each fold k
            impt.append(regr.coef_)
            R2.append(r2_score(Y[test], y_pred))
            expl_var.append(explained_variance_score(Y[test], y_pred))

            best_alphas.append(bestalpha)
            print('time to run loop: ' + str(datetime.datetime.now() - begin_time)) 
            print("R2 loop: " + str(r2_score(Y[test], y_pred)))
            print("Explained var: " + str(explained_variance_score(Y[test], y_pred)))
            print("correlation: " + str(np_pearson_cor(Y[test], y_pred)))

        # store results for each permutation p

        allexpl_var.append(expl_var)
        bestalphas.append(best_alphas)
        importance.append(impt)
        print("Permutation avg. explained variance: " + str(np.mean(expl_var)))

        np.savetxt(results_dir + featselect + 'p' + str(p) + '_SC_all_explvar2.txt', expl_var, delimiter=',')

        output = open(results_dir + featselect + 'p' + str(p) + '_SC_features.pkl', 'wb')
        pickle.dump(featur, output)
        output.close()

        output = open(results_dir + featselect + 'p' + str(p) + '_SC_bestalphas.pkl', 'wb')
        pickle.dump(best_alphas, output)
        output.close()
# Out:
# Final size of X: (101, 3192)
# Permutation: 0
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:07.912273
# R2 loop: 0.03411165109990011
# Explained var: 0.06384022405123146
# correlation: [[0.4112619]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.900848
# R2 loop: -0.08919969675788875
# Explained var: 0.09253510222432648
# correlation: [[0.36379834]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.828411
# R2 loop: 0.009644101953378614
# Explained var: 0.17349087406672936
# correlation: [[0.41684302]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.938240
# R2 loop: 0.05374068127015852
# Explained var: 0.10551336571215308
# correlation: [[0.45508862]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.874521
# R2 loop: 0.12806566400040464
# Explained var: 0.15617797190152083
# correlation: [[0.3952044]]
# Permutation avg. explained variance: 0.11831150759119224
# Permutation: 1
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:07.802748
# R2 loop: 0.12187191942273679
# Explained var: 0.13110552567848677
# correlation: [[0.44662453]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.853973
# R2 loop: 0.2074114446473967
# Explained var: 0.21954416850662772
# correlation: [[0.71570539]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.773892
# R2 loop: -0.022261856394759416
# Explained var: 0.008919514393944117
# correlation: [[0.25261912]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.961380
# R2 loop: 0.005638899812702158
# Explained var: 0.05458771374752791
# correlation: [[0.2345912]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.748102
# R2 loop: 0.02999898212122265
# Explained var: 0.031039753843129514
# correlation: [[0.17685426]]
# Permutation avg. explained variance: 0.08903933523394321
# Permutation: 2
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:07.846418
# R2 loop: 0.0782675730729574
# Explained var: 0.10292182909963765
# correlation: [[0.55840374]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.896415
# R2 loop: 0.17009415566726716
# Explained var: 0.17202884787326145
# correlation: [[0.42079697]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.781520
# R2 loop: 0.1548973860044871
# Explained var: 0.16461275058706515
# correlation: [[0.62500992]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.803397
# R2 loop: -0.3005054420841462
# Explained var: -0.2852003152128262
# correlation: [[0.07327528]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.710637
# R2 loop: 0.03641905623809172
# Explained var: 0.04111280601373668
# correlation: [[0.21427984]]
# Permutation avg. explained variance: 0.039095183672174946
# Permutation: 3
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:07.740264
# R2 loop: 0.024348810024243828
# Explained var: 0.1363387421052844
# correlation: [[0.38564903]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.843609
# R2 loop: -0.20396601989655982
# Explained var: 0.1147486510602771
# correlation: [[0.4032937]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.767280
# R2 loop: 0.19010837435998507
# Explained var: 0.24208214327556432
# correlation: [[0.66115891]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.849124
# R2 loop: -0.07549752739729976
# Explained var: 0.06510841305950721
# correlation: [[0.29871666]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.791211
# R2 loop: -0.013969726024404716
# Explained var: 0.02809519158371221
# correlation: [[0.16762758]]
# Permutation avg. explained variance: 0.11727462821686904
# Permutation: 4
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:07.831895
# R2 loop: 0.06525407143286632
# Explained var: 0.06625882072948353
# correlation: [[0.80717785]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.810398
# R2 loop: 0.18444041987922832
# Explained var: 0.18661826951970695
# correlation: [[0.48081098]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.865115
# R2 loop: -0.16337914075014393
# Explained var: -0.14605749330142714
# correlation: [[-0.15318374]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.837623
# R2 loop: 0.02149749497332054
# Explained var: 0.02501065060658869
# correlation: [[0.37681768]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.752576
# R2 loop: -0.05548227039410558
# Explained var: -0.02785396236928528
# correlation: [[-0.06687168]]
# Permutation avg. explained variance: 0.02079525703701335
# Permutation: 5
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:07.725078
# R2 loop: 0.0076661180867446665
# Explained var: 0.010747986934306009
# correlation: [[0.69590837]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.999151
# R2 loop: -0.07480574204131707
# Explained var: -0.06361313169222638
# correlation: [[-0.3208339]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.772874
# R2 loop: 0.026251966566111062
# Explained var: 0.07503259086443126
# correlation: [[0.29215564]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.791187
# R2 loop: -0.30504616822176644
# Explained var: 0.007128527538454166
# correlation: [[0.09066764]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.918668
# R2 loop: 0.09081366853895045
# Explained var: 0.1872668468034433
# correlation: [[0.56124122]]
# Permutation avg. explained variance: 0.04331256408968167
# Permutation: 6
# 5-fold cross-validation results in 64.0 subjects in the training set, and 16.0 subjects in the validation set
# time to run loop: 0:00:07.733705
# R2 loop: -0.24834352051666775
# Explained var: -0.23974768692999104
# correlation: [[-0.41199625]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.881475
# R2 loop: 0.13302367203400434
# Explained var: 0.1671209070001064
# correlation: [[0.52450437]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.959396
# R2 loop: -0.14135629367303082
# Explained var: 0.013540889588250615
# correlation: [[0.71546466]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# time to run loop: 0:00:07.826590
# R2 loop: -0.026085367062440135
# Explained var: 0.10094490283646784
# correlation: [[0.46625783]]
# 5-fold cross-validation results in 64.8 subjects in the training set, and 16.2 subjects in the validation set
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-51-9eedcd2a0d58> in <module>
#      56
#      57             # select model using training data
# ---> 58             bestalpha, bestfeats, bestr2, gcv_values = gridsearch_cv(k, X[train], Y[train], featselect, alphas, feats)
#      59
#      60             # using optimal num. of features, select final features using entire training data.
#
# <ipython-input-50-4bfbee3fa2ae> in gridsearch_cv(k, x, y, featselect, alphas, feats)
#     271
#     272         # run feature selection (# of components) in parallel
# --> 273         gcv=Parallel(n_jobs=-1,verbose=0)(delayed(parallel_featsearch)(alpha,x, y, k, featselect, feat) for feat in feats)
#     274         gcv=np.array(gcv)
#     275         gcv_values[row]=gcv
#
# ~/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/anaconda3/lib/python3.8/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/anaconda3/lib/python3.8/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/anaconda3/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     432                 return self.__get_result()
#     433
# --> 434             self._condition.wait(timeout)
#     435
#     436             if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/anaconda3/lib/python3.8/threading.py in wait(self, timeout)
#     300         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301             if timeout is None:
# --> 302                 waiter.acquire()
#     303                 gotit = True
#     304             else:
#
# KeyboardInterrupt:

# %%
row=np.argmax(np.max(gcv_values, axis=1))
col=np.argmax(np.max(gcv_values, axis=0))
k = 5
bestalpha=alphas[row]
bestfeats=feats[col]

print('Best combination: \n alpha = ', str(alphas[row]), '\n Features = ', str(feats[col]), '\n R^2 = ', str(np.round(np.max(gcv_values), 3)))

r2, comps=gcv_ridge(bestalpha, x, y, k, featselect, bestfeats)
# Out:
# Best combination:
#  alpha =  0.8858667904100825
#  Features =  15
#  R^2 =  0.134

# %%
#Consistency of correlation feature selection
k=5
intersect=np.empty(shape=(k, k), dtype='float')

for i in range(0,k): # compare each fold to each other fold
    for j in range(0,k):
        intersect[i,j]=np.shape(np.intersect1d(comps[i], comps[j]))[0]

print(intersect)
plt.figure(figsize=(5,5))

plt.imshow(intersect, cmap='hot', interpolation='nearest')
cbar = plt.colorbar()
cbar.set_label('Number of shared features')
plt.title('Similarity of features between folds', fontsize=20)

plt.scatter(row,col,color='k')
plt.savefig(results_dir+string+ '.png')
plt.show()
# Out:
# [[24.  5. 13. 13. 17.]
#  [ 5. 24.  5.  4.  6.]
#  [13.  5. 24. 16. 17.]
#  [13.  4. 16. 24. 17.]
#  [17.  6. 17. 17. 24.]]

# %%
# partial least squares regression
from sklearn.cross_decomposition import PLSRegression
import hoggorm as ho
from scipy.stats import zscore

# cross-validation to find the number of components
components=np.linspace(1,10,10,dtype=int)

train_size=0.8
k=5

#X=np.concatenate([sc, fc], axis=1)
X=fc_n
X=prepare_data(X)

#set y to be the measure you want to predict
#Y = np.log(np.array(tmt))
Y=np.array(scores7)
Y=zscore(Y)

allvar=[]

outer_cv = KFold(n_splits=k, shuffle=True, random_state=p)

explvar=[]
for train, test in outer_cv.split(X):
    press=gridsearch_plsr(k, X[train], Y[train], components)
    
plt.plot(press)
# Out:
# Final size of X: (101, 86)

# %%
#Consistency of PCA feature selection

print(bestfeats)

correl=np.empty(shape=(k, k), dtype='float')
correlationp=[]
for p in range(0, bestfeats):
    for i in range(0,k): # compare each fold to each other fold
        for j in range(0,k):
            if i==j:
                correl[i,j]=np.nan
            else:
                #correlation between fold i and j for feature # p
                correl[i,j]=np.corrcoef(comps[i][p], comps[j][p])[1,0]
                #intersect[i, j]=np.intersect1d(comps[i], comps[j])
    plt.figure(figsize=(15,15))

    plt.subplot(bestfeats,2, p+1)
    plt.imshow(correl)
    cbar = plt.colorbar()
    cbar.set_label('Correlation between folds')
    plt.show()

    correlationp.append(np.nanmean(np.nanmean(correl)))
            


plt.bar(range(0, bestfeats), correlationp)
# Out:
# 15
# <BarContainer object of 15 artists>
