# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_csv("~/GIT/cognition_nemo/data_wais_tmt.csv", header=0) 
IDs = pd.read_csv("~/GIT/cognition_nemo/data/spreadsheets/subIDs.csv", header=None) 
demog = pd.read_csv("~/GIT/cognition_nemo/data/spreadsheets/demogs_acutechronic.csv", header=0) 

df=pd.read_csv("~/GIT/cognition_nemo/data/spreadsheets/cog_stroke_alldata_waisbinary.csv", header=0) 
#df=pd.read_csv("~/GIT/cognition_nemo/test.csv", header=0) 

df=df.replace('DNC', np.NaN)
df=df.replace('DNC ', np.NaN)
df=df.replace('DNC (80)', np.NaN)
df=df.replace('-', np.NaN)
df=df.replace('M', np.NaN)
df=df.replace("'", np.NaN)
df=df.replace('                                    -', np.NaN)
df=df.replace('161/DNC', np.NaN)
df=df.replace('4/DNC', np.NaN)
df=df.replace('                    -', np.NaN)
df=df.replace('                              -', np.NaN)
df=df.replace('nan', np.NaN)
df=df.replace(' nan ', np.NaN)

nans_replicates=demog.acute_chronic.isnull()
nans_nowais=df.wais.isnull()

# remove replicate rows (created by boes lab, double of each subject)
demog=demog[~nans_replicates]
ids=IDs[~nans_replicates]
#df=df[~nans_replicates]

#df=df.reset_index(drop=True)
ids=ids.reset_index(drop=True)
demog=demog.reset_index(drop=True)

ids.to_csv('/Users/emilyolafson/GIT/cognition_nemo/ids_all.csv')

# find duplicates - i.e. when a subject has more than one scan.
# only keep the earliest scan (i.e. if there is chronic vs acute, choose acute as it is in the row before chronic)
duplicate={}
i=0
c=0
while i < ids.size-1:
    if np.where(ids.iloc[i]==ids.iloc[i+1], True, False):
        duplicate[c]=i+1

        print(ids.iloc[i])
        print("Current scan: " + demog["RedID"].iloc[i])
        print("Current scan scan date: " + str(demog["Age_at_test"].iloc[i]))
        print("Next scan (to be removed): " + demog["RedID"].iloc[i+1])
        print("Next scan scan date: " + str(demog["Age_at_test"].iloc[i+1]))

        c=c+1
    i=i+1
    
result=duplicate.items()
# Convert object to a list
data = list(result)
# Convert list to an array
numpyArray = np.array(data)
indexes=numpyArray[:,1]

#df=df.drop(labels=indexes,axis=0,inplace=False) #remove duplicate scans from scores table
ids=ids.drop(labels=indexes,axis=0,inplace=False) #remove duplicate scans from ID list
df=df.drop(labels=indexes,axis=0,inplace=False)
df=df.reset_index(drop=True)

df.to_csv('/Users/emilyolafson/GIT/cognition_nemo/df_all.csv')
ids.to_csv('/Users/emilyolafson/GIT/cognition_nemo/ids_all.csv')
# Out:
# 0    ca011
# Name: 8, dtype: object
# Current scan: ca011
# Current scan scan date: 114.2555556
# Next scan (to be removed): ca011
# Next scan scan date: 114.6055556
# 0    ca012
# Name: 10, dtype: object
# Current scan: ca012
# Current scan scan date: 115.3361111
# Next scan (to be removed): ca012
# Next scan scan date: 116.1638889
# 0    ca017
# Name: 16, dtype: object
# Current scan: ca017
# Current scan scan date: 117.9194444
# Next scan (to be removed): ca017
# Next scan scan date: 118.3638889
# 0    ca017
# Name: 17, dtype: object
# Current scan: ca017
# Current scan scan date: 118.3638889
# Next scan (to be removed): ca017
# Next scan scan date: 119.85
# 0    ca018
# Name: 19, dtype: object
# Current scan: ca018
# Current scan scan date: 107.5722222
# Next scan (to be removed): ca018
# Next scan scan date: 111.9694444
# 0    ca019
# Name: 21, dtype: object
# Current scan: ca019
# Current scan scan date: 109.7444444
# Next scan (to be removed): ca019
# Next scan scan date: 110.5805556
# 0    ca019
# Name: 22, dtype: object
# Current scan: ca019
# Current scan scan date: 110.5805556
# Next scan (to be removed): ca019
# Next scan scan date: 111.5166667
# 0    ca024
# Name: 28, dtype: object
# Current scan: ca024
# Current scan scan date: 112.3916667
# Next scan (to be removed): ca024
# Next scan scan date: 113.0694444
# 0    ca024
# Name: 29, dtype: object
# Current scan: ca024
# Current scan scan date: 113.0694444
# Next scan (to be removed): ca024
# Next scan scan date: 115.3638889
# 0    ca026
# Name: 31, dtype: object
# Current scan: ca026
# Current scan scan date: 114.7944444
# Next scan (to be removed): ca026
# Next scan scan date: 115.8333333
# 0    ca027
# Name: 33, dtype: object
# Current scan: ca027
# Current scan scan date: 116.3972222
# Next scan (to be removed): ca027
# Next scan scan date: 116.3972222
# 0    ca032
# Name: 38, dtype: object
# Current scan: ca032
# Current scan scan date: 116.2666667
# Next scan (to be removed): ca032
# Next scan scan date: 116.825
# 0    ca032
# Name: 39, dtype: object
# Current scan: ca032
# Current scan scan date: 116.825
# Next scan (to be removed): ca032
# Next scan scan date: 117.325
# 0    ca032
# Name: 40, dtype: object
# Current scan: ca032
# Current scan scan date: 117.325
# Next scan (to be removed): ca032
# Next scan scan date: 117.6416667
# 0    ca032
# Name: 41, dtype: object
# Current scan: ca032
# Current scan scan date: 117.6416667
# Next scan (to be removed): ca032
# Next scan scan date: 118.3916667
# 0    ca034
# Name: 44, dtype: object
# Current scan: ca034
# Current scan scan date: 110.6166667
# Next scan (to be removed): ca034
# Next scan scan date: 111.3416667
# 0    ca036
# Name: 47, dtype: object
# Current scan: ca036
# Current scan scan date: 113.6805556
# Next scan (to be removed): ca036
# Next scan scan date: 113.8833333
# 0    ca039
# Name: 51, dtype: object
# Current scan: ca039
# Current scan scan date: 110.2388889
# Next scan (to be removed): ca039
# Next scan scan date: 118.5083333
# 0    ca043
# Name: 56, dtype: object
# Current scan: ca043
# Current scan scan date: nan
# Next scan (to be removed): ca043
# Next scan scan date: 116.8194444
# 0    ca043
# Name: 57, dtype: object
# Current scan: ca043
# Current scan scan date: 116.8194444
# Next scan (to be removed): ca043
# Next scan scan date: nan
# 0    ca046
# Name: 60, dtype: object
# Current scan: ca046
# Current scan scan date: 113.3916667
# Next scan (to be removed): ca046
# Next scan scan date: 113.5972222
# 0    ca051
# Name: 66, dtype: object
# Current scan: ca051
# Current scan scan date: 115.0722222
# Next scan (to be removed): ca051
# Next scan scan date: 115.5472222
# 0    ca052
# Name: 68, dtype: object
# Current scan: ca052
# Current scan scan date: 108.4722222
# Next scan (to be removed): ca052
# Next scan scan date: 109.4611111
# 0    ca053
# Name: 70, dtype: object
# Current scan: ca053
# Current scan scan date: 116.1694444
# Next scan (to be removed): ca053
# Next scan scan date: 118.1
# 0    ca056
# Name: 74, dtype: object
# Current scan: ca056
# Current scan scan date: 112.9444444
# Next scan (to be removed): ca056
# Next scan scan date: 113.3111111
# 0    ca061
# Name: 80, dtype: object
# Current scan: ca061
# Current scan scan date: 113.6027778
# Next scan (to be removed): ca061
# Next scan scan date: 114.5444444
# 0    ca066
# Name: 86, dtype: object
# Current scan: ca066
# Current scan scan date: 114.7694444
# Next scan (to be removed): ca066
# Next scan scan date: 115.0555556
# 0    ca067
# Name: 88, dtype: object
# Current scan: ca067
# Current scan scan date: 113.7111111
# Next scan (to be removed): ca067
# Next scan scan date: 114.1111111
# 0    ca070
# Name: 92, dtype: object
# Current scan: ca070
# Current scan scan date: 115.1194444
# Next scan (to be removed): ca070
# Next scan scan date: 115.5916667
# 0    ca070
# Name: 93, dtype: object
# Current scan: ca070
# Current scan scan date: 115.5916667
# Next scan (to be removed): ca070
# Next scan scan date: 116.125
# 0    ca070
# Name: 94, dtype: object
# Current scan: ca070
# Current scan scan date: 116.125
# Next scan (to be removed): ca070
# Next scan scan date: 116.6833333
# 0    ca070
# Name: 95, dtype: object
# Current scan: ca070
# Current scan scan date: 116.6833333
# Next scan (to be removed): ca070
# Next scan scan date: 117.1222222
# 0    ca081
# Name: 106, dtype: object
# Current scan: ca081
# Current scan scan date: 114.2361111
# Next scan (to be removed): ca081
# Next scan scan date: 115.0416667
# 0    ca082
# Name: 108, dtype: object
# Current scan: ca082
# Current scan scan date: 114.1805556
# Next scan (to be removed): ca082
# Next scan scan date: 116.0722222
# 0    ca085
# Name: 111, dtype: object
# Current scan: ca085
# Current scan scan date: 101.4861111
# Next scan (to be removed): ca085
# Next scan scan date: 114.7305556
# 0    ca087
# Name: 114, dtype: object
# Current scan: ca087
# Current scan scan date: 112.8888889
# Next scan (to be removed): ca087
# Next scan scan date: 113.3416667
# 0    ca089
# Name: 117, dtype: object
# Current scan: ca089
# Current scan scan date: 108.9972222
# Next scan (to be removed): ca089
# Next scan scan date: 109.2194444
# 0    ca089
# Name: 118, dtype: object
# Current scan: ca089
# Current scan scan date: 109.2194444
# Next scan (to be removed): ca089
# Next scan scan date: 109.6694444
# 0    ca090
# Name: 120, dtype: object
# Current scan: ca090
# Current scan scan date: 114.7527778
# Next scan (to be removed): ca090
# Next scan scan date: 115.0611111
# 0    ca091
# Name: 122, dtype: object
# Current scan: ca091
# Current scan scan date: 108.1972222
# Next scan (to be removed): ca091
# Next scan scan date: 108.5083333
# 0    ca091
# Name: 123, dtype: object
# Current scan: ca091
# Current scan scan date: 108.5083333
# Next scan (to be removed): ca091
# Next scan scan date: 109.5388889
# 0    ca091
# Name: 124, dtype: object
# Current scan: ca091
# Current scan scan date: 109.5388889
# Next scan (to be removed): ca091
# Next scan scan date: 116.7666667
# 0    ca091
# Name: 125, dtype: object
# Current scan: ca091
# Current scan scan date: 116.7666667
# Next scan (to be removed): ca091
# Next scan scan date: 118.4972222
# 0    ca092
# Name: 127, dtype: object
# Current scan: ca092
# Current scan scan date: 108.7166667
# Next scan (to be removed): ca092
# Next scan scan date: 108.9055556
# 0    ca093
# Name: 129, dtype: object
# Current scan: ca093
# Current scan scan date: 112.5333333
# Next scan (to be removed): ca093
# Next scan scan date: 112.7944444
# 0    ca093
# Name: 130, dtype: object
# Current scan: ca093
# Current scan scan date: 112.7944444
# Next scan (to be removed): ca093
# Next scan scan date: 113.5833333
# 0    ca093
# Name: 131, dtype: object
# Current scan: ca093
# Current scan scan date: 113.5833333
# Next scan (to be removed): ca093
# Next scan scan date: 114.6
# 0    ca094
# Name: 133, dtype: object
# Current scan: ca094
# Current scan scan date: 107.8
# Next scan (to be removed): ca094
# Next scan scan date: 108.3194444
# 0    ca096
# Name: 136, dtype: object
# Current scan: ca096
# Current scan scan date: 111.6861111
# Next scan (to be removed): ca096
# Next scan scan date: 111.9555556
# 0    ca098
# Name: 139, dtype: object
# Current scan: ca098
# Current scan scan date: 107.9527778
# Next scan (to be removed): ca098
# Next scan scan date: 108.2805556
# 0    ca098
# Name: 140, dtype: object
# Current scan: ca098
# Current scan scan date: 108.2805556
# Next scan (to be removed): ca098
# Next scan scan date: 109.3305556
# 0    ca100
# Name: 143, dtype: object
# Current scan: ca100
# Current scan scan date: 113.2166667
# Next scan (to be removed): ca100
# Next scan scan date: 113.3888889
# 0    ca102
# Name: 145, dtype: object
# Current scan: ca102
# Current scan scan date: 110.25
# Next scan (to be removed): ca102
# Next scan scan date: 110.2916667
# 0    ca102
# Name: 146, dtype: object
# Current scan: ca102
# Current scan scan date: 110.2916667
# Next scan (to be removed): ca102
# Next scan scan date: 110.5416667
# 0    ca103
# Name: 148, dtype: object
# Current scan: ca103
# Current scan scan date: 112.35
# Next scan (to be removed): ca103
# Next scan scan date: 113.6388889
# 0    ca104
# Name: 150, dtype: object
# Current scan: ca104
# Current scan scan date: 114.1861111
# Next scan (to be removed): ca104
# Next scan scan date: 114.45
# 0    ca105
# Name: 152, dtype: object
# Current scan: ca105
# Current scan scan date: 113.4833333
# Next scan (to be removed): ca105
# Next scan scan date: 113.7416667
# 0    ca105
# Name: 153, dtype: object
# Current scan: ca105
# Current scan scan date: 113.7416667
# Next scan (to be removed): ca105
# Next scan scan date: 114.7111111
# 0    ca106
# Name: 155, dtype: object
# Current scan: ca106
# Current scan scan date: 113.2222222
# Next scan (to be removed): ca106
# Next scan scan date: 113.3305556
# 0    ca108
# Name: 158, dtype: object
# Current scan: ca108
# Current scan scan date: 117.6972222
# Next scan (to be removed): ca108
# Next scan scan date: 118.3722222
# 0    ca109
# Name: 160, dtype: object
# Current scan: ca109
# Current scan scan date: 107.2583333
# Next scan (to be removed): ca109
# Next scan scan date: 108.775
# 0    ca110
# Name: 162, dtype: object
# Current scan: ca110
# Current scan scan date: 116.4
# Next scan (to be removed): ca110
# Next scan scan date: 116.6138889
# 0    ca110
# Name: 163, dtype: object
# Current scan: ca110
# Current scan scan date: 116.6138889
# Next scan (to be removed): ca110
# Next scan scan date: 117.0555556
# 0    ca111
# Name: 165, dtype: object
# Current scan: ca111
# Current scan scan date: 107.8527778
# Next scan (to be removed): ca111
# Next scan scan date: 108.1416667
# 0    ca111
# Name: 166, dtype: object
# Current scan: ca111
# Current scan scan date: 108.1416667
# Next scan (to be removed): ca111
# Next scan scan date: 109.2305556
# 0    ca133
# Name: 187, dtype: object
# Current scan: ca133
# Current scan scan date: 116.5166667
# Next scan (to be removed): ca133
# Next scan scan date: 117.5388889

# %%
# remove rows with no wais iv ds total raw
demog=demog[~nans_nowais]
ids=ids[~nans_nowais]
df=df[~nans_nowais]

ids=ids.reset_index(drop=True)
demog=demog.reset_index(drop=True)
df=df.reset_index(drop=True)
# Out:
# <ipython-input-14-21f6b5162cf6>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   demog=demog[~nans_nowais]
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-14-21f6b5162cf6> in <module>
#       1 # remove rows with no wais iv ds total raw
# ----> 2 demog=demog[~nans_nowais]
#       3 ids=ids[~nans_nowais]
#       4 df=df[~nans_nowais]
#       5
#
# ~/miniforge3/envs/myenv/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3013         # Do we have a (boolean) 1d indexer?
#    3014         if com.is_bool_indexer(key):
# -> 3015             return self._getitem_bool_array(key)
#    3016
#    3017         # We are left with two options: a single key, and a collection of keys,
#
# ~/miniforge3/envs/myenv/lib/python3.9/site-packages/pandas/core/frame.py in _getitem_bool_array(self, key)
#    3066         # check_bool_indexer will throw exception if Series key cannot
#    3067         # be reindexed to match DataFrame rows
# -> 3068         key = check_bool_indexer(self.index, key)
#    3069         indexer = key.nonzero()[0]
#    3070         return self._take_with_is_copy(indexer, axis=0)
#
# ~/miniforge3/envs/myenv/lib/python3.9/site-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2267         mask = isna(result._values)
#    2268         if mask.any():
# -> 2269             raise IndexingError(
#    2270                 "Unalignable boolean Series provided as "
#    2271                 "indexer (index of the boolean Series and of "
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
# find duplicates - i.e. when a subject has more than one scan.
# only keep the earliest scan (i.e. if there is chronic vs acute, choose acute as it is in the row before chronic)
duplicate={}
i=0
c=0
while i < ids.size-1:
    if np.where(ids.iloc[i]==ids.iloc[i+1], True, False):
        duplicate[c]=i+1

        print(ids.iloc[i])
        print("Current scan: " + demog["acute_chronic"].iloc[i])
        print("Current scan scan date: " + demog["Age_at_test"].iloc[i])
        print("Next scan (to be removed): " + demog["acute_chronic"].iloc[i+1])
        c=c+1
    i=i+1
    
result=duplicate.items()
# Convert object to a list
data = list(result)
# Convert list to an array
numpyArray = np.array(data)
indexes=numpyArray[:,1]

#df=df.drop(labels=indexes,axis=0,inplace=False) #remove duplicate scans from scores table
ids=ids.drop(labels=indexes,axis=0,inplace=False) #remove duplicate scans from ID list
df=df.drop(labels=indexes,axis=0,inplace=False)
df=df.reset_index(drop=True)


df.to_csv('/Users/emilyolafson/GIT/cognition_nemo/df_all.csv')
ids.to_csv('/Users/emilyolafson/GIT/cognition_nemo/ids_all.csv')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-193ddca90ed0> in <module>
#      20 # Convert list to an array
#      21 numpyArray = np.array(data)
# ---> 22 indexes=numpyArray[:,1]
#      23
#      24 #df=df.drop(labels=indexes,axis=0,inplace=False) #remove duplicate scans from scores table
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed

# %%
# Drop acute subjects (plus subject missing imaging ca089) 
acute=["ca157", "ca147", "ca148", "ca149", "ca150", "ca138", "ca139" ,"ca124", "ca141", "ca136", "ca132", "ca043", "ca027", "ca102", "ca116","ca089"]
print(np.sort(acute))
index=[]
for i in range(0,len(acute)):
    idx=np.where(df['RedID'] == acute[i])[0]
    index.append(idx[0])
# Out:
# ['ca027' 'ca043' 'ca089' 'ca102' 'ca116' 'ca124' 'ca132' 'ca136' 'ca138'
#  'ca139' 'ca141' 'ca147' 'ca148' 'ca149' 'ca150' 'ca157']

# %%
df_final=df.drop(labels=index,axis=0,inplace=False)
df_final=df_final.reset_index(drop=True)


df_final.to_csv('/Users/emilyolafson/GIT/cognition_nemo/df_final.csv')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-178-41cd8b31ed4a> in <module>
#       1 df_final=df.drop(labels=index,axis=0,inplace=False)
#       2 df_final=df_final.reset_index(drop=True)
# ----> 3 import matplotlib.pyplot as plt
#       4
#       5 df_final.to_csv('/Users/emilyolafson/GIT/cognition_nemo/df_final.csv')
#
# ~/miniforge3/envs/myenv/lib/python3.9/site-packages/matplotlib/__init__.py in <module>
#     155
#     156
# --> 157 _check_versions()
#     158
#     159
#
# ~/miniforge3/envs/myenv/lib/python3.9/site-packages/matplotlib/__init__.py in _check_versions()
#     140     # Quickfix to ensure Microsoft Visual C++ redistributable
#     141     # DLLs are loaded before importing kiwisolver
# --> 142     from . import ft2font
#     143
#     144     for modname, minver in [
#
# ImportError: dlopen(/Users/emilyolafson/miniforge3/envs/myenv/lib/python3.9/site-packages/matplotlib/ft2font.cpython-39-darwin.so, 2): Symbol not found: _FT_Done_Face
#   Referenced from: /Users/emilyolafson/miniforge3/envs/myenv/lib/python3.9/site-packages/matplotlib/ft2font.cpython-39-darwin.so
#   Expected in: flat namespace
#  in /Users/emilyolafson/miniforge3/envs/myenv/lib/python3.9/site-packages/matplotlib/ft2font.cpython-39-darwin.so

# %%
import matplotlib.pyplot as plt
df_final_acute=df_final[df_final['acute_chronic']=='acute']
plt.hist(df_final_acute['Age_at_Onset_Years'])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-179-cbc3607def37> in <module>
# ----> 1 import matplotlib.pyplot as plt
#       2 df_final_acute=df_final[df_final['acute_chronic']=='acute']
#       3 plt.hist(df_final_acute['Age_at_Onset_Years'])
#
# ~/miniforge3/envs/myenv/lib/python3.9/site-packages/matplotlib/__init__.py in <module>
#     155
#     156
# --> 157 _check_versions()
#     158
#     159
#
# ~/miniforge3/envs/myenv/lib/python3.9/site-packages/matplotlib/__init__.py in _check_versions()
#     140     # Quickfix to ensure Microsoft Visual C++ redistributable
#     141     # DLLs are loaded before importing kiwisolver
# --> 142     from . import ft2font
#     143
#     144     for modname, minver in [
#
# ImportError: dlopen(/Users/emilyolafson/miniforge3/envs/myenv/lib/python3.9/site-packages/matplotlib/ft2font.cpython-39-darwin.so, 2): Symbol not found: _FT_Done_Face
#   Referenced from: /Users/emilyolafson/miniforge3/envs/myenv/lib/python3.9/site-packages/matplotlib/ft2font.cpython-39-darwin.so
#   Expected in: flat namespace
#  in /Users/emilyolafson/miniforge3/envs/myenv/lib/python3.9/site-packages/matplotlib/ft2font.cpython-39-darwin.so

# %%
demog=demog.drop(labels=indexes,axis=0,inplace=False)

# find subjects with acute and chronic measurements
chronic = demog.acute_chronic == 'chronic'
acute = demog.acute_chronic == 'acute'

df_chronic=df[chronic]
df_acute=df[acute]

df_chronic_wais=df_chronic["WAIS_IV_DS_TOTAL_RAW"]
df_acute_wais=df_acute["WAIS_IV_DS_TOTAL_RAW"]

df.to_csv('/Users/emilyolafson/GIT/cognition_nemo/df_all.csv')
ids.to_csv('/Users/emilyolafson/GIT/cognition_nemo/ids_all.csv')

df_chronic_wais.to_csv('/Users/emilyolafson/GIT/cognition_nemo/df_chronic_wais.csv')
df_acute_wais.to_csv('/Users/emilyolafson/GIT/cognition_nemo/df_acute_wais.csv')

ids_chronic=ids[chronic]
ids_acute=ids[acute]
print(ids_chronic.shape)
print(df_chronic.shape)

print(df_chronic.shape)
print(df_acute.shape)

df_chronic.to_csv('/Users/emilyolafson/GIT/cognition_nemo/dataframe_noduplicates_NaNsincluded_chronic.csv')
df_acute.to_csv('/Users/emilyolafson/GIT/cognition_nemo/dataframe_noduplicates_NaNsincluded_acute.csv')

ids_chronic.to_csv('/Users/emilyolafson/GIT/cognition_nemo/ids_chronic.csv')
ids_acute.to_csv('/Users/emilyolafson/GIT/cognition_nemo/ids_acute.csv')
# Out:
# (71, 1)
# (71, 630)
# (71, 630)
# (52, 630)

# %%
ids.to_csv('/Users/emilyolafson/GIT/cognition_nemo/df_nans.csv')

# %%
IDs2=IDs2.reset_index()
ids=IDs2.drop(labels=indexes,axis=0,inplace=False) #remove duplicate scans from ID list

demogs=demog2.drop(labels=indexes,axis=0,inplace=False) #remove duplicate scans from demographics list

# %%
# load list of subjects with lesions
lesionIDs = pd.read_csv("~/GIT/cognition_nemo/lesionIDs.csv", header=None) 

lesionIDs_trunc=[]
for i in range(0, lesionIDs.size):
    lesionIDs_trunc.append(removeLastN(lesionIDs.iloc[i,0], 7))

# %%
print('scans with cog score but no scans:' + str(set(ids[0]) - set(lesionIDs_trunc))) # scans with cog score but no scans
print(ids.size)
print(len(lesionIDs_trunc))
diffsubs=str(set(ids[0]) - set(lesionIDs_trunc))
# Out:
# scans with cog score but no scans:{'ca089', 'ca094', 'ca069'}
# 182
# 145

# %%
nans=df.isnull()
nans=nans.to_numpy()
nans=nans.astype(int)

nans_column=nans.sum(axis=0)
nans_rows=nans.sum(axis=1)

print('Number of NaNs per cognitive measure:')
d1=np.vstack((df.columns.values, nans_column))
print(d1.T)

print('Number of NaNs per subject:')
d2=np.vstack((ids.values.T, nans_rows.T))
print(d2.T)
# Out:
# Number of NaNs per cognitive measure:
# [['RedID' 0]
#  ['Unnamed: 1' 149]
#  ['Date_of_Onset ' 0]
#  ...
#  ['Rey_15_Trial_3' 148]
#  ['DKEFS_Tower_Test_Raw' 147]
#  ['DKEFS_Tower_Test_Scaled' 147]]
# Number of NaNs per subject:
# [['ca001' 534]
#  ['ca002' 523]
#  ['ca003' 533]
#  ['ca004' 533]
#  ['ca005' 531]
#  ['ca006' 518]
#  ['ca008' 503]
#  ['ca009' 589]
#  ['ca011' 558]
#  ['ca012' 543]
#  ['ca013' 527]
#  ['ca014' 509]
#  ['ca015' 531]
#  ['ca016' 523]
#  ['ca017' 556]
#  ['ca018' 575]
#  ['ca019' 515]
#  ['ca020' 528]
#  ['ca021' 526]
#  ['ca022' 577]
#  ['ca023' 537]
#  ['ca024' 579]
#  ['ca026' 532]
#  ['ca027' 560]
#  ['ca028' 522]
#  ['ca029' 545]
#  ['ca030' 598]
#  ['ca032' 575]
#  ['ca033' 532]
#  ['ca034' 568]
#  ['ca035' 505]
#  ['ca036' 526]
#  ['ca037' 538]
#  ['ca038' 525]
#  ['ca039' 552]
#  ['ca040' 551]
#  ['ca041' 520]
#  ['ca042' 545]
#  ['ca043' 576]
#  ['ca044' 528]
#  ['ca046' 520]
#  ['ca047' 530]
#  ['ca048' 551]
#  ['ca049' 518]
#  ['ca050' 539]
#  ['ca051' 542]
#  ['ca052' 555]
#  ['ca053' 522]
#  ['ca054' 557]
#  ['ca055' 540]
#  ['ca056' 523]
#  ['ca057' 523]
#  ['ca058' 523]
#  ['ca059' 523]
#  ['ca060' 533]
#  ['ca061' 514]
#  ['ca062' 550]
#  ['ca063' 533]
#  ['ca064' 535]
#  ['ca065' 538]
#  ['ca066' 532]
#  ['ca067' 543]
#  ['ca068' 529]
#  ['ca069' 551]
#  ['ca070' 605]
#  ['ca072' 562]
#  ['ca073' 562]
#  ['ca074' 539]
#  ['ca075' 537]
#  ['ca076' 521]
#  ['ca077' 530]
#  ['ca078' 537]
#  ['ca079' 531]
#  ['ca080' 549]
#  ['ca081' 507]
#  ['ca082' 504]
#  ['ca083' 537]
#  ['ca085' 554]
#  ['ca086' 534]
#  ['ca087' 549]
#  ['ca088' 526]
#  ['ca089' 591]
#  ['ca090' 553]
#  ['ca091' 582]
#  ['ca092' 587]
#  ['ca093' 529]
#  ['ca094' 561]
#  ['ca095' 569]
#  ['ca096' 540]
#  ['ca097' 527]
#  ['ca098' 559]
#  ['ca099' 517]
#  ['ca100' 561]
#  ['ca102' 586]
#  ['ca103' 582]
#  ['ca104' 536]
#  ['ca105' 559]
#  ['ca106' 566]
#  ['ca107' 550]
#  ['ca108' 559]
#  ['ca109' 579]
#  ['ca110' 562]
#  ['ca111' 583]
#  ['ca112' 542]
#  ['ca113' 570]
#  ['ca114' 597]
#  ['ca115' 587]
#  ['ca116' 549]
#  ['ca118' 582]
#  ['ca119' 578]
#  ['ca120' 562]
#  ['ca121' 568]
#  ['ca122' 603]
#  ['ca123' 541]
#  ['ca124' 581]
#  ['ca126' 545]
#  ['ca127' 577]
#  ['ca128' 547]
#  ['ca129' 563]
#  ['ca130' 604]
#  ['ca131' 579]
#  ['ca132' 553]
#  ['ca133' 549]
#  ['ca134' 583]
#  ['ca135' 528]
#  ['ca136' 553]
#  ['ca137' 551]
#  ['ca138' 564]
#  ['ca139' 540]
#  ['ca140' 576]
#  ['ca141' 579]
#  ['ca142' 602]
#  ['ca143' 577]
#  ['ca144' 582]
#  ['ca145' 572]
#  ['ca146' 505]
#  ['ca147' 561]
#  ['ca148' 574]
#  ['ca149' 571]
#  ['ca150' 588]
#  ['ca151' 536]
#  ['ca152' 566]
#  ['ca153' 534]
#  ['ca154' 533]
#  ['ca155' 552]
#  ['ca156' 534]
#  ['ca157' 572]
#  ['ca158' 598]
#  ['ca159' 540]]

# %%
# save processed data
#np.savetxt('/Users/emilyolafson/GIT/cognition_nemo/dataframe_noduplicates_NaNsincluded.txt', df, delimiter=',')
df_chronic.to_csv('/Users/emilyolafson/GIT/cognition_nemo/dataframe_noduplicates_NaNsincluded_chronic.csv')
df_acute.to_csv('/Users/emilyolafson/GIT/cognition_nemo/dataframe_noduplicates_NaNsincluded_acute.csv')

ids.to_csv('/Users/emilyolafson/GIT/cognition_nemo/IDlist_noduplicates_NaNsincluded_chronic.csv')
demogs.to_csv('/Users/emilyolafson/GIT/cognition_nemo/demogs_noduplicates_NaNsincluded_chronic.csv')

np.savetxt('/Users/emilyolafson/GIT/cognition_nemo/nans_chronic.txt', nans)

# %%
# Function to remove last N
# characters from string
S=lesionIDs.iloc[0,0]
N=4
t=len(S)

def removeLastN(S, N):
    
    # Stores the resultant string
    res = ''
      
    # Traverse the string
    for i in range(len(S)-N):
        
          # Insert current character
        res += S[i]
  
    # Return the string
    return res
