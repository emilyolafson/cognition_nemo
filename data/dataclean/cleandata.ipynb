# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data_wasi_tmt.csv", header=0) 
IDs = pd.read_csv("subIDs.csv", header=None) 
demog = pd.read_csv("demographics.csv", header=0)

# %%
df=df.replace('DNC', np.NaN)
df=df.replace('DNC ', np.NaN)
df=df.replace('DNC (80)', np.NaN)
df=df.replace('-', np.NaN)
df=df.replace('M', np.NaN)
df=df.replace("'", np.NaN)
df=df.replace('                                    -', np.NaN)
df=df.replace('161/DNC', np.NaN)
df=df.replace('4/DNC', np.NaN)
df=df.replace('                    -', np.NaN)
df=df.replace('                              -', np.NaN)
df=df.replace('nan', np.NaN)
df=df.replace(' nan ', np.NaN)

#identify rows which are duplicate scans (after the first scan)
duplicate={}
i=0
c=0
while i < IDs.size-1:
    if np.where(IDs.iloc[i]==IDs.iloc[i+1], True, False):
        duplicate[c]=i
        c=c+1
    i=i+1

result=duplicate.items()
# Convert object to a list
data = list(result)
# Convert list to an array
numpyArray = np.array(data)
indexes=numpyArray[:,1]

# %%
df=df.drop(labels=indexes,axis=0,inplace=False) #remove duplicate scans from scores table
ids=IDs.drop(labels=indexes,axis=0,inplace=False) #remove duplicate scans from ID list
demogs=demog.drop(labels=indexes,axis=0,inplace=False) #remove duplicate scans from demographics list

# %%
# load list of subjects with lesions
lesionIDs = pd.read_csv("lesionIDs.csv", header=None) 

lesionIDs_trunc=[]
for i in range(0, lesionIDs.size):
    lesionIDs_trunc.append(removeLastN(lesionIDs.iloc[i,0], 7))

# %%
print('scans with cog score but no scans:' + str(set(ids[0]) - set(lesionIDs_trunc))) # scans with cog score but no scans
print(ids.size)
print(len(lesionIDs_trunc))
diffsubs=str(set(ids[0]) - set(lesionIDs_trunc))
# Out:
# scans with cog score but no scans:{'ca094', 'ca069', 'ca124', 'ca089'}
# 149
# 145

# %%
nans=df.isnull()
nans=nans.to_numpy()
nans=nans.astype(int)

nans_column=nans.sum(axis=0)
nans_rows=nans.sum(axis=1)

print('Number of NaNs per cognitive measure:')
d1=np.vstack((df.columns.values, nans_column))
print(d1.T)

print('Number of NaNs per subject:')
d2=np.vstack((ids.values.T, nans_rows.T))
print(d2.T)
# Out:
# Number of NaNs per cognitive measure:
# [['T_MT_A_TIME' 33]
#  ['T_MT_A_ERROR' 32]
#  ['T_MT_A_SSCORE' 41]
#  ['T_MT_A_TSCORE' 51]
#  ['T_MT_B_TIME' 52]
#  ['T_MT_B_ERROR' 50]
#  ['T_MT_B_SSCORE' 58]
#  ['T_MT_B_TSCORE' 66]
#  ['WAIS_IV_WM' 108]
#  ['WAIS_IV_WMI_COMP_SCORE' 106]
#  ['WAIS_IV_PS' 120]
#  ['WAIS_IV_PSI_COMP_SCORE' 120]
#  ['WAIS_IV_BD_RAW' 70]
#  ['WAIS_IV_BD_SCALED' 68]
#  ['WAIS_IV_SIM_RAW' 68]
#  ['WAIS_IV_SIM_SCALED' 65]
#  ['WAIS_IV_DS_FORW_RAW' 39]
#  ['WAIS_IV_DS_FORW_LONGEST' 31]
#  ['WAIS_IV_DS_BACK_RAW' 39]
#  ['WAIS_IV_DS_BACK_LONGEST' 31]
#  ['WAIS_IV_DS_SEQ_RAW' 40]
#  ['WAIS_IV_DS_SEQ_LONGEST' 31]
#  ['WAIS_IV_DS_TOTAL_RAW' 33]
#  ['WAIS_IV_DS_TOTAL_SCALED' 29]
#  ['WAIS_IV_MR_RAW' 92]
#  ['WAIS_IV_MR_SCALED' 91]
#  ['WAIS_IV_VOC_RAW' 146]
#  ['WAIS_IV_VOC_SCALED' 146]
#  ['WAIS_IV_ARI_RAW' 87]
#  ['WAIS_IV_ARI_SCALED' 84]
#  ['WAIS_IV_SS_CORR' 89]
#  ['WAIS_IV_SS_INCOR' 89]
#  ['WAIS_IV_SS_TOTAL_RAW' 83]
#  ['WAIS_IV_SS_TOTAL_SCALED' 83]
#  ['WAIS_IV_VP_RAW' 143]
#  ['WAIS_IV_VP_SCALED' 143]
#  ['WAIS_IV_INF_RAW' 134]
#  ['WAIS_IV_INF_SCALED' 132]
#  ['WAIS_IV_CD_TOTAL' 69]
#  ['WAIS_IV_CD_TOTAL_SCALED' 68]]
# Number of NaNs per subject:
# [['ca001' 10]
#  ['ca002' 10]
#  ['ca003' 12]
#  ['ca004' 24]
#  ['ca005' 14]
#  ['ca006' 8]
#  ['ca008' 4]
#  ['ca009' 40]
#  ['ca011' 12]
#  ['ca012' 10]
#  ['ca013' 14]
#  ['ca014' 4]
#  ['ca015' 12]
#  ['ca016' 12]
#  ['ca017' 20]
#  ['ca018' 8]
#  ['ca019' 8]
#  ['ca020' 8]
#  ['ca021' 12]
#  ['ca022' 38]
#  ['ca023' 18]
#  ['ca024' 16]
#  ['ca026' 22]
#  ['ca027' 36]
#  ['ca028' 10]
#  ['ca029' 24]
#  ['ca030' 38]
#  ['ca032' 40]
#  ['ca033' 6]
#  ['ca034' 10]
#  ['ca035' 6]
#  ['ca036' 6]
#  ['ca037' 13]
#  ['ca038' 12]
#  ['ca039' 22]
#  ['ca040' 18]
#  ['ca041' 10]
#  ['ca042' 20]
#  ['ca043' 40]
#  ['ca044' 14]
#  ['ca046' 8]
#  ['ca047' 16]
#  ['ca048' 18]
#  ['ca049' 10]
#  ['ca050' 16]
#  ['ca051' 24]
#  ['ca052' 20]
#  ['ca053' 18]
#  ['ca054' 22]
#  ['ca055' 14]
#  ['ca056' 10]
#  ['ca057' 10]
#  ['ca058' 12]
#  ['ca059' 16]
#  ['ca060' 16]
#  ['ca061' 10]
#  ['ca062' 16]
#  ['ca063' 12]
#  ['ca064' 13]
#  ['ca065' 12]
#  ['ca066' 10]
#  ['ca067' 8]
#  ['ca068' 18]
#  ['ca069' 25]
#  ['ca070' 40]
#  ['ca072' 22]
#  ['ca073' 16]
#  ['ca074' 14]
#  ['ca075' 10]
#  ['ca076' 14]
#  ['ca077' 10]
#  ['ca078' 14]
#  ['ca079' 14]
#  ['ca080' 19]
#  ['ca081' 14]
#  ['ca082' 4]
#  ['ca083' 14]
#  ['ca085' 22]
#  ['ca086' 14]
#  ['ca087' 18]
#  ['ca088' 14]
#  ['ca089' 39]
#  ['ca090' 20]
#  ['ca091' 30]
#  ['ca092' 17]
#  ['ca093' 8]
#  ['ca094' 32]
#  ['ca095' 32]
#  ['ca096' 14]
#  ['ca097' 10]
#  ['ca098' 26]
#  ['ca099' 16]
#  ['ca100' 16]
#  ['ca102' 33]
#  ['ca103' 28]
#  ['ca104' 14]
#  ['ca105' 14]
#  ['ca106' 14]
#  ['ca107' 22]
#  ['ca108' 16]
#  ['ca109' 32]
#  ['ca110' 16]
#  ['ca111' 23]
#  ['ca112' 14]
#  ['ca113' 28]
#  ['ca114' 40]
#  ['ca115' 38]
#  ['ca116' 24]
#  ['ca118' 40]
#  ['ca119' 38]
#  ['ca120' 28]
#  ['ca121' 28]
#  ['ca122' 40]
#  ['ca123' 20]
#  ['ca124' 35]
#  ['ca126' 16]
#  ['ca127' 38]
#  ['ca128' 32]
#  ['ca129' 30]
#  ['ca130' 40]
#  ['ca131' 36]
#  ['ca132' 23]
#  ['ca133' 27]
#  ['ca134' 28]
#  ['ca135' 12]
#  ['ca136' 30]
#  ['ca137' 20]
#  ['ca138' 30]
#  ['ca139' 16]
#  ['ca140' 35]
#  ['ca141' 33]
#  ['ca142' 40]
#  ['ca143' 40]
#  ['ca144' 32]
#  ['ca145' 38]
#  ['ca146' 0]
#  ['ca147' 24]
#  ['ca148' 30]
#  ['ca149' 32]
#  ['ca150' 32]
#  ['ca151' 24]
#  ['ca152' 33]
#  ['ca153' 18]
#  ['ca154' 15]
#  ['ca155' 16]
#  ['ca156' 16]
#  ['ca157' 32]
#  ['ca158' 38]
#  ['ca159' 21]]

# %%
# save processed data
#np.savetxt('/Users/emilyolafson/GIT/cognition_nemo/dataframe_noduplicates_NaNsincluded.txt', df, delimiter=',')
df.to_csv('/Users/emilyolafson/GIT/cognition_nemo/dataframe_noduplicates_NaNsincluded.csv')
ids.to_csv('/Users/emilyolafson/GIT/cognition_nemo/IDlist_noduplicates_NaNsincluded.csv')
demogs.to_csv('/Users/emilyolafson/GIT/cognition_nemo/demogs_noduplicates_NaNsincluded.csv')

np.savetxt('/Users/emilyolafson/GIT/cognition_nemo/nans.txt', nans)

# %%
# Function to remove last N
# characters from string
S=lesionIDs.iloc[0,0]
N=4
t=len(S)

def removeLastN(S, N):
    
    # Stores the resultant string
    res = ''
      
    # Traverse the string
    for i in range(len(S)-N):
        
          # Insert current character
        res += S[i]
  
    # Return the string
    return res
